# %%
# !pip install owlready2
# Out:
# ...
#      ---------------------------------------- 27.3/27.3 MB 8.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for owlready2: filename=owlready2-0.45-py3-none-any.whl size=23332913 sha256=2d28f5f714717d4f41e85a216b294ec9c1517d0c8f0988023ddbe91937d354eb
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\fd\3d\21\a3354f6877530e6efe0f645ca518f7fb07e9af5be7655b2355
# Successfully built owlready2
# ...

# %%
from owlready2 import *
onto = get_ontology("http://NBA_ontology/onto.owl")

onto
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# get_ontology("http://NBA_ontology/onto.owl#")

# %%
# NBA_Team Class
# Eastern_Conference, Western_Conference NBA_Team sub class (동부, 서부)

# TeamMembers Class (팀내 구성원)
# Coach TeamMembers sub class (코치진)
# Manager TeamMembers sub class (감독)
# General_manager TeamMembers sub class (구단주)
# Player TeamMembers sub class (선수)
# Position Class (포지션)

# %%
with onto:
    class NBA_Team(Thing): pass
    class Eastern_Conference(NBA_Team): pass
    class Western_Conference(NBA_Team): pass

    class Team_members(Thing): pass
    class Coach(Team_members): pass
    class Manager(Team_members): pass
    class General_manager(Team_members): pass

    class Player(Team_members): pass
    class Position(Thing): pass

# %%
# hasCoach (NBA_Team -> Coach) - ObjectProperty
# hasManager (NBA_Team -> Manager) - ObjectProperty
# hasGeneral_manager (NBA_Team -> General_manager) - ObjectProperty
# hasClubTeam (Player -> NBA_Team) - ObjectProperty
# hasPlayer (NBA_Team -> Player) - ObjectProperty, inverse_property = hasClubTeam

# hasYears (NBA_Team -> int) - DataProperty, FunctionalProperty
# hasGame_num (NBA_Team -> int) - DataProperty, FunctionalProperty
# hasWin_num (NBA_Team -> int) - DataProperty, FunctionalProperty
# hasLose_num (NBA_Team -> int) - DataProperty, FunctionalProperty

# hasPosition (Player -> Position) - ObjectProperty
# player_Age (Player -> int) - DataProperty, FunctionalProperty
# player_G (Player -> int) - DataProperty, FunctionalProperty
# player_MP (Player -> int) - DataProperty, FunctionalProperty
# player_FG (Player -> int) - DataProperty, FunctionalProperty
# player_FGA (Player -> int) - DataProperty, FunctionalProperty
# player_FT (Player -> int) - DataProperty, FunctionalProperty
# player_FTA (Player -> int) - DataProperty, FunctionalProperty
# player_TRB (Player -> int) - DataProperty, FunctionalProperty
# player_AST (Player -> int) - DataProperty, FunctionalProperty
# player_STL (Player -> int) - DataProperty, FunctionalProperty
# player_BLK (Player -> int) - DataProperty, FunctionalProperty
# player_TOV (Player -> int) - DataProperty, FunctionalProperty
# player_PF (Player -> int) - DataProperty, FunctionalProperty
# player_PTS (Player -> int) - DataProperty, FunctionalProperty

#-----------------------#
# G : 출전 수
# MP : 출전 시간
# FG : 야투성공 수
# FGA : 야투시도 수
# FT : 자유투 성공 수
# FTA : 자유투 시도 수
# TRB : 리바운드
# AST : 어시스트
# STL : 스틸
# BLK : 블록
# TOV : 실책
# PF : 파울
# PTS : 득점

# %%
with onto:
    class hasCoach(ObjectProperty):
        domain  = [NBA_Team]
        range   = [Coach]
    class hasManager(ObjectProperty):
        domain  = [NBA_Team]
        range   = [Manager]
    class hasGeneral_manager(ObjectProperty):
        domain  = [NBA_Team]
        range   = [General_manager]
    class hasClubTeam(ObjectProperty):
        domain  = [Player]
        range   = [NBA_Team]
    class hasPlayer(ObjectProperty):
        domain  = [NBA_Team]
        range   = [Player]
        inverse_property = hasClubTeam

    class hasYears(DataProperty, FunctionalProperty):
        domain = [NBA_Team]
        range  = [int]
    class hasGame_num(DataProperty, FunctionalProperty):
        domain = [NBA_Team]
        range  = [int]
    class hasWin_num(DataProperty, FunctionalProperty):
        domain = [NBA_Team]
        range  = [int]
    class hasLose_num(DataProperty, FunctionalProperty):
        domain = [NBA_Team]
        range  = [int]

    class hasPosition(ObjectProperty):
        domain = [Player]
        range  = [Position]
    class player_Age(DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_G(DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_MP(DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_FG (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_FGA (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_FT (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_FTA (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_TRB (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_AST (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_STL (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_BLK (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_TOV (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_PF (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]
    class player_PTS (DataProperty, FunctionalProperty):
        domain = [Player]
        range  = [int]

# %% [markdown]
# # 인스턴스 생성

# %% [markdown]
# ## position instance

# %%
CE = Position("CE")
SG = Position("SG")
PG = Position("PG")
PF = Position("PF")
SF = Position("SF")

# %% [markdown]
# # team instance

# %%
Atlanta_Hawks = Eastern_Conference('Atlanta Hawks')
Atlanta_Hawks.hasYears = 75
Atlanta_Hawks.hasGame_num = 5872
Atlanta_Hawks.hasWin_num = 2899
Atlanta_Hawks.hasLose_num = 2973

Boston_Celtics = Eastern_Conference('Boston Celtics')
Boston_Celtics.hasYears = 78
Boston_Celtics.hasGame_num = 6050
Boston_Celtics.hasWin_num = 3584
Boston_Celtics.hasLose_num = 2466

Brooklyn_Nets = Eastern_Conference('Brooklyn Nets')
Brooklyn_Nets.hasYears = 57
Brooklyn_Nets.hasGame_num = 4547
Brooklyn_Nets.hasWin_num = 2005
Brooklyn_Nets.hasLose_num = 2542

Charlotte_Hornets = Eastern_Conference('Charlotte Hornets')
Charlotte_Hornets.hasYears = 34
Charlotte_Hornets.hasGame_num = 2647
Charlotte_Hornets.hasWin_num = 1158
Charlotte_Hornets.hasLose_num = 1489

Chicago_Bulls = Eastern_Conference('Chicago Bulls')
Chicago_Bulls.hasYears = 58
Chicago_Bulls.hasGame_num = 4617
Chicago_Bulls.hasWin_num = 2349
Chicago_Bulls.hasLose_num = 2268

Cleveland_Cavaliers = Eastern_Conference('Cleveland Cavaliers')
Cleveland_Cavaliers.hasYears = 54
Cleveland_Cavaliers.hasGame_num = 4289
Cleveland_Cavaliers.hasWin_num = 1994
Cleveland_Cavaliers.hasLose_num = 2295

Dallas_Mavericks = Western_Conference('Dallas Mavericks')
Dallas_Mavericks.hasYears = 44
Dallas_Mavericks.hasGame_num = 3478
Dallas_Mavericks.hasWin_num = 1758
Dallas_Mavericks.hasLose_num = 1720

Denver_Nuggets = Western_Conference('Denver Nuggets')
Denver_Nuggets.hasYears = 57
Denver_Nuggets.hasGame_num = 4549
Denver_Nuggets.hasWin_num = 2322
Denver_Nuggets.hasLose_num = 2227

Detroit_Pistons = Eastern_Conference('Detroit Pistons')
Detroit_Pistons.hasYears = 76
Detroit_Pistons.hasGame_num = 5933
Detroit_Pistons.hasWin_num = 2815
Detroit_Pistons.hasLose_num = 3118

Golden_State_Warriors = Western_Conference('Golden State Warriors')
Golden_State_Warriors.hasYears = 78
Golden_State_Warriors.hasGame_num = 6039
Golden_State_Warriors.hasWin_num = 2931
Golden_State_Warriors.hasLose_num = 3108

Houston_Rockets = Western_Conference('Houston Rockets')
Houston_Rockets.hasYears = 57
Houston_Rockets.hasGame_num = 4539
Houston_Rockets.hasWin_num = 2336
Houston_Rockets.hasLose_num = 2203

Indiana_Pacers = Eastern_Conference('Indiana Pacers')
Indiana_Pacers.hasYears = 57
Indiana_Pacers.hasGame_num = 4546
Indiana_Pacers.hasWin_num = 2319
Indiana_Pacers.hasLose_num = 2227

Los_Angeles_Clippers = Western_Conference('Los Angeles Clippers')
Los_Angeles_Clippers.hasYears = 54
Los_Angeles_Clippers.hasGame_num = 4294
Los_Angeles_Clippers.hasWin_num = 1799
Los_Angeles_Clippers.hasLose_num = 2495

Los_Angeles_Lakers = Western_Conference('Los Angeles Lakers')
Los_Angeles_Lakers.hasYears = 76
Los_Angeles_Lakers.hasGame_num = 5940
Los_Angeles_Lakers.hasWin_num = 3513
Los_Angeles_Lakers.hasLose_num = 2427

Memphis_Grizzlies = Western_Conference('Memphis Grizzlies')
Memphis_Grizzlies.hasYears = 29
Memphis_Grizzlies.hasGame_num = 2245
Memphis_Grizzlies.hasWin_num = 974
Memphis_Grizzlies.hasLose_num = 1271

Miami_Heat = Eastern_Conference('Miami Heat')
Miami_Heat.hasYears = 36
Miami_Heat.hasGame_num = 2821
Miami_Heat.hasWin_num = 1485
Miami_Heat.hasLose_num = 1336

Milwaukee_Bucks = Eastern_Conference('Milwaukee Bucks')
Milwaukee_Bucks.hasYears = 56
Milwaukee_Bucks.hasGame_num = 4461
Milwaukee_Bucks.hasWin_num = 2353
Milwaukee_Bucks.hasLose_num = 2108

Minnesota_Timberwolves = Western_Conference('Minnesota Timberwolves')
Minnesota_Timberwolves.hasYears = 35
Minnesota_Timberwolves.hasGame_num = 2729
Minnesota_Timberwolves.hasWin_num = 1104
Minnesota_Timberwolves.hasLose_num = 1625

New_Orleans_Pelicans = Western_Conference('New Orleans Pelicans')
New_Orleans_Pelicans.hasYears = 22
New_Orleans_Pelicans.hasGame_num = 1704
New_Orleans_Pelicans.hasWin_num = 791
New_Orleans_Pelicans.hasLose_num = 913

New_York_Knicks = Eastern_Conference('New York Knicks')
New_York_Knicks.hasYears = 78
New_York_Knicks.hasGame_num = 6040
New_York_Knicks.hasWin_num = 2934
New_York_Knicks.hasLose_num = 3106

Oklahoma_City_Thunder = Western_Conference('Oklahoma City Thunder')
Oklahoma_City_Thunder.hasYears = 57
Oklahoma_City_Thunder.hasGame_num = 4541
Oklahoma_City_Thunder.hasWin_num = 2424
Oklahoma_City_Thunder.hasLose_num = 2117

Orlando_Magic = Eastern_Conference('Orlando Magic')
Orlando_Magic.hasYears = 35
Orlando_Magic.hasGame_num = 2738
Orlando_Magic.hasWin_num = 1280
Orlando_Magic.hasLose_num = 1458

Philadelphia_76ers = Eastern_Conference('Philadelphia 76ers')
Philadelphia_76ers.hasYears = 75
Philadelphia_76ers.hasGame_num = 5876
Philadelphia_76ers.hasWin_num = 3066
Philadelphia_76ers.hasLose_num = 2810

Phoenix_Suns = Western_Conference('Phoenix Suns')
Phoenix_Suns.hasYears = 56
Phoenix_Suns.hasGame_num = 4460
Phoenix_Suns.hasWin_num = 2391
Phoenix_Suns.hasLose_num = 2069

Portland_Trail_Blazers = Western_Conference('Portland Trail Blazers')
Portland_Trail_Blazers.hasYears = 54
Portland_Trail_Blazers.hasGame_num = 4297
Portland_Trail_Blazers.hasWin_num = 2276
Portland_Trail_Blazers.hasLose_num = 2021

Sacramento_Kings = Western_Conference('Sacramento Kings')
Sacramento_Kings.hasYears = 76
Sacramento_Kings.hasGame_num = 5939
Sacramento_Kings.hasWin_num = 2712
Sacramento_Kings.hasLose_num = 3227

San_Antonio_Spurs = Western_Conference('San Antonio Spurs')
San_Antonio_Spurs.hasYears = 57
San_Antonio_Spurs.hasGame_num = 4546
San_Antonio_Spurs.hasWin_num = 2664
San_Antonio_Spurs.hasLose_num = 1882

Toronto_Raptors = Eastern_Conference('Toronto Raptors')
Toronto_Raptors.hasYears = 29
Toronto_Raptors.hasGame_num = 2246
Toronto_Raptors.hasWin_num = 1079
Toronto_Raptors.hasLose_num = 1167

Utah_Jazz = Western_Conference('Utah Jazz')
Utah_Jazz.hasYears = 50
Utah_Jazz.hasGame_num = 3967
Utah_Jazz.hasWin_num = 2152
Utah_Jazz.hasLose_num = 1815

Washington_Wizards = Eastern_Conference('Washington Wizards')
Washington_Wizards.hasYears = 63
Washington_Wizards.hasGame_num = 5022
Washington_Wizards.hasWin_num = 2260
Washington_Wizards.hasLose_num = 2762

# %% [markdown]
# # coach instance

# %%
Gregg_Farnam = Coach('Gregg_Farnam')
Minnesota_Timberwolves.hasCoach.append(Gregg_Farnam)

Elston_Turner = Coach('Elston_Turner')
Minnesota_Timberwolves.hasCoach.append(Elston_Turner)

Micah_Nori = Coach('Micah_Nori')
Minnesota_Timberwolves.hasCoach.append(Micah_Nori)

Pablo_Prigioni = Coach('Pablo_Prigioni')
Minnesota_Timberwolves.hasCoach.append(Pablo_Prigioni)

Kevin_Hanson = Coach('Kevin_Hanson')
Minnesota_Timberwolves.hasCoach.append(Kevin_Hanson)

Joe_Boylan = Coach('Joe_Boylan')
Minnesota_Timberwolves.hasCoach.append(Joe_Boylan)

Eric_Maynor = Coach('Eric_Maynor')
Oklahoma_City_Thunder.hasCoach.append(Eric_Maynor)

Connor_Johnson = Coach('Connor_Johnson')
Oklahoma_City_Thunder.hasCoach.append(Connor_Johnson)

Dave_Bliss = Coach('Dave_Bliss')
Oklahoma_City_Thunder.hasCoach.append(Dave_Bliss)

Mike_Wilks = Coach('Mike_Wilks')
Oklahoma_City_Thunder.hasCoach.append(Mike_Wilks)

David_Akinyooye = Coach('David_Akinyooye')
Oklahoma_City_Thunder.hasCoach.append(David_Akinyooye)

Chip_Engelland = Coach('Chip_Engelland')
Oklahoma_City_Thunder.hasCoach.append(Chip_Engelland)

Grant_Gibbs = Coach('Grant_Gibbs')
Oklahoma_City_Thunder.hasCoach.append(Grant_Gibbs)

Dan_Shimensky = Coach('Dan_Shimensky')
Denver_Nuggets.hasCoach.append(Dan_Shimensky)

Felipe_Eichenberger = Coach('Felipe_Eichenberger')
Denver_Nuggets.hasCoach.append(Felipe_Eichenberger)

Ognjen_Stojaković = Coach('Ognjen_Stojaković')
Denver_Nuggets.hasCoach.append(Ognjen_Stojaković)

David_Adelman = Coach('David_Adelman')
Denver_Nuggets.hasCoach.append(David_Adelman)

Ryan_Bowen = Coach('Ryan_Bowen')
Denver_Nuggets.hasCoach.append(Ryan_Bowen)

Charles_Klask = Coach('Charles_Klask')
Denver_Nuggets.hasCoach.append(Charles_Klask)

John_Beckett = Coach('John_Beckett')
Denver_Nuggets.hasCoach.append(John_Beckett)

Elvis_Valcarcel = Coach('Elvis_Valcarcel')
Denver_Nuggets.hasCoach.append(Elvis_Valcarcel)

Ryan_Saunders = Coach('Ryan_Saunders')
Denver_Nuggets.hasCoach.append(Ryan_Saunders)

Popeye_Jones = Coach('Popeye_Jones')
Denver_Nuggets.hasCoach.append(Popeye_Jones)

Isaiah_Wright = Coach('Isaiah_Wright')
Utah_Jazz.hasCoach.append(Isaiah_Wright)

Jamal_Cort = Coach('Jamal_Cort')
Utah_Jazz.hasCoach.append(Jamal_Cort)

Scott_Morrison = Coach('Scott_Morrison')
Utah_Jazz.hasCoach.append(Scott_Morrison)

Jason_Terry = Coach('Jason_Terry')
Utah_Jazz.hasCoach.append(Jason_Terry)

Chad_Forcier = Coach('Chad_Forcier')
Utah_Jazz.hasCoach.append(Chad_Forcier)

Rick_Higgins = Coach('Rick_Higgins')
Utah_Jazz.hasCoach.append(Rick_Higgins)

Lamar_Skeeter = Coach('Lamar_Skeeter')
Utah_Jazz.hasCoach.append(Lamar_Skeeter)

Sean_Sheldon = Coach('Sean_Sheldon')
Utah_Jazz.hasCoach.append(Sean_Sheldon)

Geoff_Clark = Coach('Geoff_Clark')
Portland_Trail_Blazers.hasCoach.append(Geoff_Clark)

Mark_Tyndale = Coach('Mark_Tyndale')
Portland_Trail_Blazers.hasCoach.append(Mark_Tyndale)

Roy_Rogers = Coach('Roy_Rogers')
Portland_Trail_Blazers.hasCoach.append(Roy_Rogers)

Steve_Hetzel = Coach('Steve_Hetzel')
Portland_Trail_Blazers.hasCoach.append(Steve_Hetzel)

Scott_Brooks = Coach('Scott_Brooks')
Portland_Trail_Blazers.hasCoach.append(Scott_Brooks)

Rodney_Billups = Coach('Rodney_Billups')
Portland_Trail_Blazers.hasCoach.append(Rodney_Billups)

Jonah_Herscu = Coach('Jonah_Herscu')
Portland_Trail_Blazers.hasCoach.append(Jonah_Herscu)

Deividas_Dulkys = Coach('Deividas_Dulkys')
Sacramento_Kings.hasCoach.append(Deividas_Dulkys)

Joel_Noland = Coach('Joel_Noland')
Sacramento_Kings.hasCoach.append(Joel_Noland)

Jordi_Fernandez = Coach('Jordi_Fernandez')
Sacramento_Kings.hasCoach.append(Jordi_Fernandez)

Jay_Triano = Coach('Jay_Triano')
Sacramento_Kings.hasCoach.append(Jay_Triano)

Dutch_Gaitley = Coach('Dutch_Gaitley')
Sacramento_Kings.hasCoach.append(Dutch_Gaitley)

Doug_Christie = Coach('Doug_Christie')
Sacramento_Kings.hasCoach.append(Doug_Christie)

Lindsey_Harding = Coach('Lindsey_Harding')
Sacramento_Kings.hasCoach.append(Lindsey_Harding)

Leandro_Barbosa = Coach('Leandro_Barbosa')
Sacramento_Kings.hasCoach.append(Leandro_Barbosa)

Luke_Loucks = Coach('Luke_Loucks')
Sacramento_Kings.hasCoach.append(Luke_Loucks)

David_Crewe = Coach('David_Crewe')
Phoenix_Suns.hasCoach.append(David_Crewe)

Kevin_Young = Coach('Kevin_Young')
Phoenix_Suns.hasCoach.append(Kevin_Young)

Greg_St_Jean = Coach('Greg_St._Jean')
Phoenix_Suns.hasCoach.append(Greg_St_Jean)

David_Fizdale = Coach('David_Fizdale')
Phoenix_Suns.hasCoach.append(David_Fizdale)

Quinton_Crawford = Coach('Quinton_Crawford')
Phoenix_Suns.hasCoach.append(Quinton_Crawford)

Miles_Simon = Coach('Miles_Simon')
Phoenix_Suns.hasCoach.append(Miles_Simon)

John_Lucas_III = Coach('John_Lucas_III')
Phoenix_Suns.hasCoach.append(John_Lucas_III)

Dru_Anthrop = Coach('Dru_Anthrop')
Phoenix_Suns.hasCoach.append(Dru_Anthrop)

Jon_Pastorek = Coach('Jon_Pastorek')
Phoenix_Suns.hasCoach.append(Jon_Pastorek)

Roger_Sancho = Coach('Roger_Sancho')
Los_Angeles_Lakers.hasCoach.append(Roger_Sancho)

Ed_Streit = Coach('Ed_Streit')
Los_Angeles_Lakers.hasCoach.append(Ed_Streit)

Jordan_Ott = Coach('Jordan_Ott')
Los_Angeles_Lakers.hasCoach.append(Jordan_Ott)

Chris_Jent = Coach('Chris_Jent')
Los_Angeles_Lakers.hasCoach.append(Chris_Jent)

Phil_Handy = Coach('Phil_Handy')
Los_Angeles_Lakers.hasCoach.append(Phil_Handy)

JD_DuBois = Coach('J.D._DuBois')
Los_Angeles_Lakers.hasCoach.append(JD_DuBois)

Schuyler_Rimmer = Coach('Schuyler_Rimmer')
Los_Angeles_Lakers.hasCoach.append(Schuyler_Rimmer)

Zach_Peterson = Coach('Zach_Peterson')
Los_Angeles_Lakers.hasCoach.append(Zach_Peterson)

DeMarre_Carroll = Coach('DeMarre_Carroll')
Los_Angeles_Lakers.hasCoach.append(DeMarre_Carroll)

Todd_Wright = Coach('Todd_Wright')
Los_Angeles_Clippers.hasCoach.append(Todd_Wright)

Jasen_Powell = Coach('Jasen_Powell')
Los_Angeles_Clippers.hasCoach.append(Jasen_Powell)

Daniel_Shapiro = Coach('Daniel_Shapiro')
Los_Angeles_Clippers.hasCoach.append(Daniel_Shapiro)

Jay_Larranaga = Coach('Jay_Larranaga')
Los_Angeles_Clippers.hasCoach.append(Jay_Larranaga)

Dan_Craig = Coach('Dan_Craig')
Los_Angeles_Clippers.hasCoach.append(Dan_Craig)

Larry_Drew = Coach('Larry_Drew')
Los_Angeles_Clippers.hasCoach.append(Larry_Drew)

Brendan_OConnor = Coach('Brendan_OConnor')
Los_Angeles_Clippers.hasCoach.append(Brendan_OConnor)

Jeremy_Castleberry = Coach('Jeremy_Castleberry')
Los_Angeles_Clippers.hasCoach.append(Jeremy_Castleberry)

Brian_Shaw = Coach('Brian_Shaw')
Los_Angeles_Clippers.hasCoach.append(Brian_Shaw)

Shaun_Fein = Coach('Shaun_Fein')
Los_Angeles_Clippers.hasCoach.append(Shaun_Fein)

Dahntay_Jones = Coach('Dahntay_Jones')
Los_Angeles_Clippers.hasCoach.append(Dahntay_Jones)

Drew_Yoder = Coach('Drew_Yoder')
Golden_State_Warriors.hasCoach.append(Drew_Yoder)

Jacob_Rubin = Coach('Jacob_Rubin')
Golden_State_Warriors.hasCoach.append(Jacob_Rubin)

Anthony_Vereen = Coach('Anthony_Vereen')
Golden_State_Warriors.hasCoach.append(Anthony_Vereen)

Hilton_Armstrong = Coach('Hilton_Armstrong')
Golden_State_Warriors.hasCoach.append(Hilton_Armstrong)

Bruce_Fraser = Coach('Bruce_Fraser')
Golden_State_Warriors.hasCoach.append(Bruce_Fraser)

Ron_Adams = Coach('Ron_Adams')
Golden_State_Warriors.hasCoach.append(Ron_Adams)

Chris_DeMarco = Coach('Chris_DeMarco')
Golden_State_Warriors.hasCoach.append(Chris_DeMarco)

Kenny_Atkinson = Coach('Kenny_Atkinson')
Golden_State_Warriors.hasCoach.append(Kenny_Atkinson)

Dejan_Milojević = Coach('Dejan_Milojević')
Golden_State_Warriors.hasCoach.append(Dejan_Milojević)

Kris_Weems = Coach('Kris_Weems')
Golden_State_Warriors.hasCoach.append(Kris_Weems)

Jeremy_Holsopple = Coach('Jeremy_Holsopple')
Dallas_Mavericks.hasCoach.append(Jeremy_Holsopple)

Dionne_Calhoun = Coach('Dionne_Calhoun')
Dallas_Mavericks.hasCoach.append(Dionne_Calhoun)

God_Shammgod = Coach('God_Shammgod')
Dallas_Mavericks.hasCoach.append(God_Shammgod)

Jared_Dudley = Coach('Jared_Dudley')
Dallas_Mavericks.hasCoach.append(Jared_Dudley)

Darrell_Armstrong = Coach('Darrell_Armstrong')
Dallas_Mavericks.hasCoach.append(Darrell_Armstrong)

Sean_Sweeney = Coach('Sean_Sweeney')
Dallas_Mavericks.hasCoach.append(Sean_Sweeney)

Alex_Jensen = Coach('Alex_Jensen')
Dallas_Mavericks.hasCoach.append(Alex_Jensen)

Corey_Brewer = Coach('Corey_Brewer')
New_Orleans_Pelicans.hasCoach.append(Corey_Brewer)

Darnell_Lazare = Coach('Darnell_Lazare')
New_Orleans_Pelicans.hasCoach.append(Darnell_Lazare)

Ryan_Frazier = Coach('Ryan_Frazier')
New_Orleans_Pelicans.hasCoach.append(Ryan_Frazier)

Tom_Maystadt = Coach('Tom_Maystadt')
New_Orleans_Pelicans.hasCoach.append(Tom_Maystadt)

Stan_Williams = Coach('Stan_Williams')
New_Orleans_Pelicans.hasCoach.append(Stan_Williams)

Aaron_Miles = Coach('Aaron_Miles')
New_Orleans_Pelicans.hasCoach.append(Aaron_Miles)

Jarron_Collins = Coach('Jarron_Collins')
New_Orleans_Pelicans.hasCoach.append(Jarron_Collins)

Casey_Hill = Coach('Casey_Hill')
New_Orleans_Pelicans.hasCoach.append(Casey_Hill)

Fred_Vinson = Coach('Fred_Vinson')
New_Orleans_Pelicans.hasCoach.append(Fred_Vinson)

Teresa_Weatherspoon = Coach('Teresa_Weatherspoon')
New_Orleans_Pelicans.hasCoach.append(Teresa_Weatherspoon)

Tiago_Splitter = Coach('Tiago_Splitter')
Houston_Rockets.hasCoach.append(Tiago_Splitter)

Keith_Jones = Coach('Keith_Jones')
Houston_Rockets.hasCoach.append(Keith_Jones)

Jason_Biles = Coach('Jason_Biles')
Houston_Rockets.hasCoach.append(Jason_Biles)

Royal_Ivey = Coach('Royal_Ivey')
Houston_Rockets.hasCoach.append(Royal_Ivey)

Ben_Sullivan = Coach('Ben_Sullivan')
Houston_Rockets.hasCoach.append(Ben_Sullivan)

Garrett_Jackson = Coach('Garrett_Jackson')
Houston_Rockets.hasCoach.append(Garrett_Jackson)

Cam_Hodges = Coach('Cam_Hodges')
Houston_Rockets.hasCoach.append(Cam_Hodges)

Mike_Moser = Coach('Mike_Moser')
Houston_Rockets.hasCoach.append(Mike_Moser)

Pete_Elliott = Coach('Pete_Elliott')
Memphis_Grizzlies.hasCoach.append(Pete_Elliott)

Eric_Oetter = Coach('Eric_Oetter')
Memphis_Grizzlies.hasCoach.append(Eric_Oetter)

Anthony_Carter = Coach('Anthony_Carter')
Memphis_Grizzlies.hasCoach.append(Anthony_Carter)

Blake_Ahearn = Coach('Blake_Ahearn')
Memphis_Grizzlies.hasCoach.append(Blake_Ahearn)

Brad_Jones = Coach('Brad_Jones')
Memphis_Grizzlies.hasCoach.append(Brad_Jones)

David_McClure = Coach('David_McClure')
Memphis_Grizzlies.hasCoach.append(David_McClure)

James_Penn = Coach('James_Penn')
Memphis_Grizzlies.hasCoach.append(James_Penn)

Sonia_Raman = Coach('Sonia_Raman')
Memphis_Grizzlies.hasCoach.append(Sonia_Raman)

Vitaly_Potapenko = Coach('Vitaly_Potapenko')
Memphis_Grizzlies.hasCoach.append(Vitaly_Potapenko)

Patrick_St_Andrews = Coach('Patrick_St._Andrews')
Memphis_Grizzlies.hasCoach.append(Patrick_St_Andrews)

Will_Sevening = Coach('Will_Sevening')
San_Antonio_Spurs.hasCoach.append(Will_Sevening)

Mitch_Johnson = Coach('Mitch_Johnson')
San_Antonio_Spurs.hasCoach.append(Mitch_Johnson)

Darius_Songaila = Coach('Darius_Songaila')
San_Antonio_Spurs.hasCoach.append(Darius_Songaila)

Matt_Nielsen = Coach('Matt_Nielsen')
San_Antonio_Spurs.hasCoach.append(Matt_Nielsen)

Brett_Brown = Coach('Brett_Brown')
San_Antonio_Spurs.hasCoach.append(Brett_Brown)

Kenny_Graves = Coach('Kenny_Graves')
Boston_Celtics.hasCoach.append(Kenny_Graves)

Art_Horne = Coach('Art_Horne')
Boston_Celtics.hasCoach.append(Art_Horne)

Tyler_Yeaton = Coach('Tyler_Yeaton')
Boston_Celtics.hasCoach.append(Tyler_Yeaton)

Phil_Pressey = Coach('Phil_Pressey')
Boston_Celtics.hasCoach.append(Phil_Pressey)

Tony_Dobbins = Coach('Tony_Dobbins')
Boston_Celtics.hasCoach.append(Tony_Dobbins)

Charles_Lee = Coach('Charles_Lee')
Boston_Celtics.hasCoach.append(Charles_Lee)

Sam_Cassell = Coach('Sam_Cassell')
Boston_Celtics.hasCoach.append(Sam_Cassell)

DJ_MacLeay = Coach('D.J._MacLeay')
Boston_Celtics.hasCoach.append(DJ_MacLeay)

Matthew_Reynolds = Coach('Matthew_Reynolds')
Boston_Celtics.hasCoach.append(Matthew_Reynolds)

Amile_Jefferson = Coach('Amile_Jefferson')
Boston_Celtics.hasCoach.append(Amile_Jefferson)

Kevin_Johnson = Coach('Kevin_Johnson')
Philadelphia_76ers.hasCoach.append(Kevin_Johnson)

Ben_Kenyon = Coach('Ben_Kenyon')
Philadelphia_76ers.hasCoach.append(Ben_Kenyon)

John_Corbacio = Coach('John_Corbacio')
Philadelphia_76ers.hasCoach.append(John_Corbacio)

Fab_Flournoy = Coach('Fab_Flournoy')
Philadelphia_76ers.hasCoach.append(Fab_Flournoy)

Jason_Love = Coach('Jason_Love')
Philadelphia_76ers.hasCoach.append(Jason_Love)

Rico_Hines = Coach('Rico_Hines')
Philadelphia_76ers.hasCoach.append(Rico_Hines)

Doug_West = Coach('Doug_West')
Philadelphia_76ers.hasCoach.append(Doug_West)

Bobby_Jackson = Coach('Bobby_Jackson')
Philadelphia_76ers.hasCoach.append(Bobby_Jackson)

Coby_Karl = Coach('Coby_Karl')
Philadelphia_76ers.hasCoach.append(Coby_Karl)

Mike_Longabardi = Coach('Mike_Longabardi')
Philadelphia_76ers.hasCoach.append(Mike_Longabardi)

Bryan_Gates = Coach('Bryan_Gates')
Philadelphia_76ers.hasCoach.append(Bryan_Gates)

Matt_Brase = Coach('Matt_Brase')
Philadelphia_76ers.hasCoach.append(Matt_Brase)

Dice_Yoshimoto = Coach('Dice_Yoshimoto')
New_York_Knicks.hasCoach.append(Dice_Yoshimoto)

Anthony_Goenaga = Coach('Anthony_Goenaga')
New_York_Knicks.hasCoach.append(Anthony_Goenaga)

Richard_Williams = Coach('Richard_Williams')
New_York_Knicks.hasCoach.append(Richard_Williams)

Johnnie_Bryant = Coach('Johnnie_Bryant')
New_York_Knicks.hasCoach.append(Johnnie_Bryant)

Andy_Greer = Coach('Andy_Greer')
New_York_Knicks.hasCoach.append(Andy_Greer)

Darren_Erman = Coach('Darren_Erman')
New_York_Knicks.hasCoach.append(Darren_Erman)

Rick_Brunson = Coach('Rick_Brunson')
New_York_Knicks.hasCoach.append(Rick_Brunson)

Jonathan_Filipe = Coach('Jonathan_Filipe')
Brooklyn_Nets.hasCoach.append(Jonathan_Filipe)

Daniel_Jones = Coach('Daniel_Jones')
Brooklyn_Nets.hasCoach.append(Daniel_Jones)

Kevin_Ollie = Coach('Kevin_Ollie')
Brooklyn_Nets.hasCoach.append(Kevin_Ollie)

Corey_Vinson = Coach('Corey_Vinson')
Brooklyn_Nets.hasCoach.append(Corey_Vinson)

Ronnie_Burrell = Coach('Ronnie_Burrell')
Brooklyn_Nets.hasCoach.append(Ronnie_Burrell)

Ryan_Forehan_Kelly = Coach('Ryan_Forehan-Kelly')
Brooklyn_Nets.hasCoach.append(Ryan_Forehan_Kelly)

Adam_Caporn = Coach('Adam_Caporn')
Brooklyn_Nets.hasCoach.append(Adam_Caporn)

Trevor_Hendry = Coach('Trevor_Hendry')
Brooklyn_Nets.hasCoach.append(Trevor_Hendry)

Jay_Hernandez = Coach('Jay_Hernandez')
Brooklyn_Nets.hasCoach.append(Jay_Hernandez)

Will_Weaver = Coach('Will_Weaver')
Brooklyn_Nets.hasCoach.append(Will_Weaver)

Rayhan_Malik = Coach('Rayhan_Malik')
Toronto_Raptors.hasCoach.append(Rayhan_Malik)

Mike_Batiste = Coach('Mike_Batiste')
Toronto_Raptors.hasCoach.append(Mike_Batiste)

Ivo_Simovic = Coach('Ivo_Simovic')
Toronto_Raptors.hasCoach.append(Ivo_Simovic)

Drew_Jones = Coach('Drew_Jones')
Toronto_Raptors.hasCoach.append(Drew_Jones)

Vin_Bhavnani = Coach('Vin_Bhavnani')
Toronto_Raptors.hasCoach.append(Vin_Bhavnani)

ma_Mahlalela = Coach('ma_Mahlalela')
Toronto_Raptors.hasCoach.append(ma_Mahlalela)

Jim_Sann = Coach('Jim_Sann')
Toronto_Raptors.hasCoach.append(Jim_Sann)

Pat_Delany = Coach('Pat_Delany')
Toronto_Raptors.hasCoach.append(Pat_Delany)

Scott_Faust = Coach('Scott_Faust')
Milwaukee_Bucks.hasCoach.append(Scott_Faust)

Suki_Hobson = Coach('Suki_Hobson')
Milwaukee_Bucks.hasCoach.append(Suki_Hobson)

DJ_Bakker = Coach('DJ_Bakker')
Milwaukee_Bucks.hasCoach.append(DJ_Bakker)

Joe_Prunty = Coach('Joe_Prunty')
Milwaukee_Bucks.hasCoach.append(Joe_Prunty)

Vin_Baker = Coach('Vin_Baker')
Milwaukee_Bucks.hasCoach.append(Vin_Baker)

Josh_Oppenheimer = Coach('Josh_Oppenheimer')
Milwaukee_Bucks.hasCoach.append(Josh_Oppenheimer)

Patrick_Mutombo = Coach('Patrick_Mutombo')
Milwaukee_Bucks.hasCoach.append(Patrick_Mutombo)

Nathaniel_Mitchell = Coach('Nathaniel_Mitchell')
Milwaukee_Bucks.hasCoach.append(Nathaniel_Mitchell)

Lloyd_Pierce = Coach('Lloyd_Pierce')
Indiana_Pacers.hasCoach.append(Lloyd_Pierce)

Josh_Corbeil = Coach('Josh_Corbeil')
Indiana_Pacers.hasCoach.append(Josh_Corbeil)

Jannero_Pargo = Coach('Jannero_Pargo')
Indiana_Pacers.hasCoach.append(Jannero_Pargo)

Issac_Yacob = Coach('Issac_Yacob')
Indiana_Pacers.hasCoach.append(Issac_Yacob)

Mike_Weinar = Coach('Mike_Weinar')
Indiana_Pacers.hasCoach.append(Mike_Weinar)

Jenny_Boucek = Coach('Jenny_Boucek')
Indiana_Pacers.hasCoach.append(Jenny_Boucek)

Jim_Boylen = Coach('Jim_Boylen')
Indiana_Pacers.hasCoach.append(Jim_Boylen)

Stephen_Spiro = Coach('Stephen_Spiro')
Cleveland_Cavaliers.hasCoach.append(Stephen_Spiro)

Derek_Millender = Coach('Derek_Millender')
Cleveland_Cavaliers.hasCoach.append(Derek_Millender)

Greg_Buckner = Coach('Greg_Buckner')
Cleveland_Cavaliers.hasCoach.append(Greg_Buckner)

JJ_Outlaw = Coach('J.J._Outlaw')
Cleveland_Cavaliers.hasCoach.append(JJ_Outlaw)

Sidney_Lowe = Coach('Sidney_Lowe')
Cleveland_Cavaliers.hasCoach.append(Sidney_Lowe)

Luke_Walton = Coach('Luke_Walton')
Cleveland_Cavaliers.hasCoach.append(Luke_Walton)

Geoffrey_Puls = Coach('Geoffrey_Puls')
Chicago_Bulls.hasCoach.append(Geoffrey_Puls)

Todd_Campbell = Coach('Todd_Campbell')
Chicago_Bulls.hasCoach.append(Todd_Campbell)

Maurice_Cheeks = Coach('Maurice_Cheeks')
Chicago_Bulls.hasCoach.append(Maurice_Cheeks)

Chris_Fleming = Coach('Chris_Fleming')
Chicago_Bulls.hasCoach.append(Chris_Fleming)

Joshua_Longstaff = Coach('Joshua_Longstaff')
Chicago_Bulls.hasCoach.append(Joshua_Longstaff)

John_Bryant = Coach('John_Bryant')
Chicago_Bulls.hasCoach.append(John_Bryant)

Damian_Cotter = Coach('Damian_Cotter')
Chicago_Bulls.hasCoach.append(Damian_Cotter)

Billy_Schmidt = Coach('Billy_Schmidt')
Chicago_Bulls.hasCoach.append(Billy_Schmidt)

chel_Cutts = Coach('chel_Cutts')
Detroit_Pistons.hasCoach.append(chel_Cutts)

Jordan_Sabourin = Coach('Jordan_Sabourin')
Detroit_Pistons.hasCoach.append(Jordan_Sabourin)

Jamelle_McMillan = Coach('Jamelle_McMillan')
Detroit_Pistons.hasCoach.append(Jamelle_McMillan)

Jerome_Allen = Coach('Jerome_Allen')
Detroit_Pistons.hasCoach.append(Jerome_Allen)

Dan_Burke = Coach('Dan_Burke')
Detroit_Pistons.hasCoach.append(Dan_Burke)

Steve_Scalzi = Coach('Steve_Scalzi')
Detroit_Pistons.hasCoach.append(Steve_Scalzi)

Jarrett_Jack = Coach('Jarrett_Jack')
Detroit_Pistons.hasCoach.append(Jarrett_Jack)

Stephen_Silas = Coach('Stephen_Silas')
Detroit_Pistons.hasCoach.append(Stephen_Silas)

Mark_Bryant = Coach('Mark_Bryant')
Detroit_Pistons.hasCoach.append(Mark_Bryant)

Brian_Randle = Coach('Brian_Randle')
Detroit_Pistons.hasCoach.append(Brian_Randle)

Lionel_Chalmers = Coach('Lionel_Chalmers')
Orlando_Magic.hasCoach.append(Lionel_Chalmers)

Ernest_Eugene = Coach('Ernest_Eugene')
Orlando_Magic.hasCoach.append(Ernest_Eugene)

Todor_Pandov = Coach('Todor_Pandov')
Orlando_Magic.hasCoach.append(Todor_Pandov)

Dylan_Murphy = Coach('Dylan_Murphy')
Orlando_Magic.hasCoach.append(Dylan_Murphy)

Bret_Brielmaier = Coach('Bret_Brielmaier')
Orlando_Magic.hasCoach.append(Bret_Brielmaier)

Nate_Tibbetts = Coach('Nate_Tibbetts')
Orlando_Magic.hasCoach.append(Nate_Tibbetts)

Dale_Osbourne = Coach('Dale_Osbourne')
Orlando_Magic.hasCoach.append(Dale_Osbourne)

Jesse_Mermuys = Coach('Jesse_Mermuys')
Orlando_Magic.hasCoach.append(Jesse_Mermuys)

Octavio_De_La_Grana = Coach('Octavio_De_La_Grana')
Miami_Heat.hasCoach.append(Octavio_De_La_Grana)

Eric_Glass = Coach('Eric_Glass')
Miami_Heat.hasCoach.append(Eric_Glass)

Rob_Fodor = Coach('Rob_Fodor')
Miami_Heat.hasCoach.append(Rob_Fodor)

Wayne_Ellington = Coach('Wayne_Ellington')
Miami_Heat.hasCoach.append(Wayne_Ellington)

Eric_Foran = Coach('Eric_Foran')
Miami_Heat.hasCoach.append(Eric_Foran)

Wes_Brown = Coach('Wes_Brown')
Miami_Heat.hasCoach.append(Wes_Brown)

Chris_Quinn = Coach('Chris_Quinn')
Miami_Heat.hasCoach.append(Chris_Quinn)

Malik_Allen = Coach('Malik_Allen')
Miami_Heat.hasCoach.append(Malik_Allen)

Caron_Butler = Coach('Caron_Butler')
Miami_Heat.hasCoach.append(Caron_Butler)

Scottie_Parker = Coach('Scottie_Parker')
Atlanta_Hawks.hasCoach.append(Scottie_Parker)

Reggis_Onwukamuche = Coach('Reggis_Onwukamuche')
Atlanta_Hawks.hasCoach.append(Reggis_Onwukamuche)

Paddy_Hogben = Coach('Paddy_Hogben')
Atlanta_Hawks.hasCoach.append(Paddy_Hogben)

Jeff_Watkinson = Coach('Jeff_Watkinson')
Atlanta_Hawks.hasCoach.append(Jeff_Watkinson)

Bryan_Bailey = Coach('Bryan_Bailey')
Atlanta_Hawks.hasCoach.append(Bryan_Bailey)

Brittni_Donaldson = Coach('Brittni_Donaldson')
Atlanta_Hawks.hasCoach.append(Brittni_Donaldson)

Steve_Klei = Coach('Steve_Klei')
Atlanta_Hawks.hasCoach.append(Steve_Klei)

Sanjay_Lumpkin = Coach('Sanjay_Lumpkin')
Atlanta_Hawks.hasCoach.append(Sanjay_Lumpkin)

Ekpe_Udoh = Coach('Ekpe_Udoh')
Atlanta_Hawks.hasCoach.append(Ekpe_Udoh)

Mike_Brey = Coach('Mike_Brey')
Atlanta_Hawks.hasCoach.append(Mike_Brey)

Igor_Kokoskov = Coach('Igor_Kokoskov')
Atlanta_Hawks.hasCoach.append(Igor_Kokoskov)

Antonio_Lang = Coach('Antonio_Lang')
Atlanta_Hawks.hasCoach.append(Antonio_Lang)

Ronald_Nored = Coach('Ronald_Nored')
Atlanta_Hawks.hasCoach.append(Ronald_Nored)

Joe_Sharpe = Coach('Joe_Sharpe')
Charlotte_Hornets.hasCoach.append(Joe_Sharpe)

Adam_Linens = Coach('Adam_Linens')
Charlotte_Hornets.hasCoach.append(Adam_Linens)

Marlon_Garnett = Coach('Marlon_Garnett')
Charlotte_Hornets.hasCoach.append(Marlon_Garnett)

Tyrone_Corbin = Coach('Tyrone_Corbin')
Charlotte_Hornets.hasCoach.append(Tyrone_Corbin)

Bob_Beyer = Coach('Bob_Beyer')
Charlotte_Hornets.hasCoach.append(Bob_Beyer)

Rex_Walters = Coach('Rex_Walters')
Charlotte_Hornets.hasCoach.append(Rex_Walters)

Nick_Friedman = Coach('Nick_Friedman')
Charlotte_Hornets.hasCoach.append(Nick_Friedman)

Norm_Richardson = Coach('Norm_Richardson')
Charlotte_Hornets.hasCoach.append(Norm_Richardson)

Bruce_Kreutzer = Coach('Bruce_Kreutzer')
Charlotte_Hornets.hasCoach.append(Bruce_Kreutzer)

Michael_Ashton = Coach('Michael_Ashton')
Washington_Wizards.hasCoach.append(Michael_Ashton)

Brian_Keefe = Coach('Brian_Keefe')
Washington_Wizards.hasCoach.append(Brian_Keefe)

Zach_Guthrie = Coach('Zach_Guthrie')
Washington_Wizards.hasCoach.append(Zach_Guthrie)

Mike_Miller = Coach('Mike_Miller')
Washington_Wizards.hasCoach.append(Mike_Miller)

Joseph_Blair = Coach('Joseph_Blair')
Washington_Wizards.hasCoach.append(Joseph_Blair)

James_Posey = Coach('James_Posey')
Washington_Wizards.hasCoach.append(James_Posey)

# %% [markdown]
# # general manager instance

# %%
Calvin_Booth = General_manager('Calvin_Booth')
Denver_Nuggets.hasGeneral_manager.append(Calvin_Booth)

Elton_Brand = General_manager('Elton_Brand')
Philadelphia_76ers.hasGeneral_manager.append(Elton_Brand)

Chad_Buchanan = General_manager('Chad_Buchanan')
Indiana_Pacers.hasGeneral_manager.append(Chad_Buchanan)

Joe_Cronin = General_manager('Joe_Cronin')
Portland_Trail_Blazers.hasGeneral_manager.append(Joe_Cronin)

Will_Dawkins = General_manager('Will_Dawkins')
Washington_Wizards.hasGeneral_manager.append(Will_Dawkins)

Mike_Dunleavy = General_manager('Mike_Dunleavy')
Golden_State_Warriors.hasGeneral_manager.append(Mike_Dunleavy)

Andy_Elisburg = General_manager('Andy_Elisburg')
Miami_Heat.hasGeneral_manager.append(Andy_Elisburg)

Marc_Eversley = General_manager('Marc_Eversley')
Chicago_Bulls.hasGeneral_manager.append(Marc_Eversley)

Landry_Fields = General_manager('Landry_Fields')
Atlanta_Hawks.hasGeneral_manager.append(Landry_Fields)

Mike_Gansey = General_manager('Mike_Gansey')
Cleveland_Cavaliers.hasGeneral_manager.append(Mike_Gansey)

Nico_Harrison = General_manager('Nico_Harrison')
Dallas_Mavericks.hasGeneral_manager.append(Nico_Harrison)

Jon_Horst = General_manager('Jon_Horst')
Milwaukee_Bucks.hasGeneral_manager.append(Jon_Horst)

Zachary_Kleiman = General_manager('Zachary_Kleiman')
Memphis_Grizzlies.hasGeneral_manager.append(Zachary_Kleiman)

Mitch_Kupchak = General_manager('Mitch_Kupchak')
Charlotte_Hornets.hasGeneral_manager.append(Mitch_Kupchak)

Trajan_Langdon = General_manager('Trajan_Langdon')
New_Orleans_Pelicans.hasGeneral_manager.append(Trajan_Langdon)

Sean_Marks = General_manager('Sean_Marks')
Brooklyn_Nets.hasGeneral_manager.append(Sean_Marks)

Monte_McNair = General_manager('Monte_McNair')
Sacramento_Kings.hasGeneral_manager.append(Monte_McNair)

Anthony_Parker = General_manager('Anthony_Parker')
Orlando_Magic.hasGeneral_manager.append(Anthony_Parker)

Rob_Pelinka = General_manager('Rob_Pelinka')
Los_Angeles_Lakers.hasGeneral_manager.append(Rob_Pelinka)

Scott_Perry = General_manager('Scott_Perry')
New_York_Knicks.hasGeneral_manager.append(Scott_Perry)

Sam_Presti = General_manager('Sam_Presti')
Oklahoma_City_Thunder.hasGeneral_manager.append(Sam_Presti)

Trent_Redden = General_manager('Trent_Redden')
Los_Angeles_Clippers.hasGeneral_manager.append(Trent_Redden)

Rafael_Stone = General_manager('Rafael_Stone')
Houston_Rockets.hasGeneral_manager.append(Rafael_Stone)

Troy_Weaver = General_manager('Troy_Weaver')
Detroit_Pistons.hasGeneral_manager.append(Troy_Weaver)

Bobby_Webster = General_manager('Bobby_Webster')
Toronto_Raptors.hasGeneral_manager.append(Bobby_Webster)

Brian_Wright = General_manager('Brian_Wright')
San_Antonio_Spurs.hasGeneral_manager.append(Brian_Wright)

Justin_Zanik = General_manager('Justin_Zanik')
Utah_Jazz.hasGeneral_manager.append(Justin_Zanik)

James_Jones = General_manager('James_Jones')
Phoenix_Suns.hasGeneral_manager.append(James_Jones)

Tim_Connelly = General_manager('Tim_Connelly')
Minnesota_Timberwolves.hasGeneral_manager.append(Tim_Connelly)

Bradley_Stevens = General_manager('Bradley_Stevens')
Boston_Celtics.hasGeneral_manager.append(Bradley_Stevens)

# %% [markdown]
# # manager instance

# %%
Quin_Snyder = Manager('Quin_Snyder')
Atlanta_Hawks.hasManager.append(Quin_Snyder)

Joe_Mazzulla = Manager('Joe_Mazzulla')
Boston_Celtics.hasManager.append(Joe_Mazzulla)

Jacque_Vaughn = Manager('Jacque_Vaughn')
Brooklyn_Nets.hasManager.append(Jacque_Vaughn)

Billy_Donovan = Manager('Billy_Donovan')
Charlotte_Hornets.hasManager.append(Billy_Donovan)

Steve_Clifford = Manager('Steve_Clifford')
Chicago_Bulls.hasManager.append(Steve_Clifford)

JB_Bickerstaff = Manager('J.B._Bickerstaff')
Cleveland_Cavaliers.hasManager.append(JB_Bickerstaff)

Jason_Kidd = Manager('Jason_Kidd')
Dallas_Mavericks.hasManager.append(Jason_Kidd)

Michael_Malone = Manager('Michael_Malone')
Denver_Nuggets.hasManager.append(Michael_Malone)

Monty_Williams = Manager('Monty_Williams')
Detroit_Pistons.hasManager.append(Monty_Williams)

Steve_Kerr = Manager('Steve_Kerr')
Golden_State_Warriors.hasManager.append(Steve_Kerr)

Ime_Udoka = Manager('Ime_Udoka')
Houston_Rockets.hasManager.append(Ime_Udoka)

Rick_Carlisle = Manager('Rick_Carlisle')
Indiana_Pacers.hasManager.append(Rick_Carlisle)

Tyronn_Lue = Manager('Tyronn_Lue')
Los_Angeles_Clippers.hasManager.append(Tyronn_Lue)

Darvin_Ham = Manager('Darvin_Ham')
Los_Angeles_Lakers.hasManager.append(Darvin_Ham)

Taylor_Jenkins = Manager('Taylor_Jenkins')
Memphis_Grizzlies.hasManager.append(Taylor_Jenkins)

Erik_Spoelstra = Manager('Erik_Spoelstra')
Miami_Heat.hasManager.append(Erik_Spoelstra)

Adrian_Griffin = Manager('Adrian_Griffin')
Milwaukee_Bucks.hasManager.append(Adrian_Griffin)

Chris_Finch = Manager('Chris_Finch')
Minnesota_Timberwolves.hasManager.append(Chris_Finch)

Willie_Green = Manager('Willie_Green')
New_Orleans_Pelicans.hasManager.append(Willie_Green)

Tom_Thibodeau = Manager('Tom_Thibodeau')
New_York_Knicks.hasManager.append(Tom_Thibodeau)

Mark_Daigneault = Manager('Mark_Daigneault')
Oklahoma_City_Thunder.hasManager.append(Mark_Daigneault)

Jamahl_Mosley = Manager('Jamahl_Mosley')
Orlando_Magic.hasManager.append(Jamahl_Mosley)

Nick_Nurse = Manager('Nick_Nurse')
Philadelphia_76ers.hasManager.append(Nick_Nurse)

Frank_Vogel = Manager('Frank_Vogel')
Phoenix_Suns.hasManager.append(Frank_Vogel)

Chauncey_Billups = Manager('Chauncey_Billups')
Portland_Trail_Blazers.hasManager.append(Chauncey_Billups)

Mike_Brown = Manager('Mike_Brown')
Sacramento_Kings.hasManager.append(Mike_Brown)

Gregg_Popovich = Manager('Gregg_Popovich')
San_Antonio_Spurs.hasManager.append(Gregg_Popovich)

Darko_Rajakovic = Manager('Darko_Rajakovic')
Toronto_Raptors.hasManager.append(Darko_Rajakovic)

Will_Hardy = Manager('Will_Hardy')
Utah_Jazz.hasManager.append(Will_Hardy)

Wes_Unseld = Manager('Wes_Unseld')
Washington_Wizards.hasManager.append(Wes_Unseld)

# %% [markdown]
# # player instance

# %%
Achiuwa = Player('Achiuwa')
Achiuwa.hasClubTeam.append(Toronto_Raptors)
Achiuwa.hasPosition.append(CE)
Achiuwa.player_Age = 24
Achiuwa.player_G = 12
Achiuwa.player_MP = 218
Achiuwa.player_MP = 218
Achiuwa.player_FG = 32
Achiuwa.player_FGA = 74
Achiuwa.player_FT = 11
Achiuwa.player_FTA = 21
Achiuwa.player_TRB = 70
Achiuwa.player_AST = 26
Achiuwa.player_STL = 6
Achiuwa.player_BLK = 6
Achiuwa.player_TOV = 16
Achiuwa.player_PF = 21
Achiuwa.player_PTS = 80

Bam_Adebayo = Player('Bam_Adebayo')
Bam_Adebayo.hasClubTeam.append(Miami_Heat)
Bam_Adebayo.hasPosition.append(CE)
Bam_Adebayo.player_Age = 26
Bam_Adebayo.player_G = 15
Bam_Adebayo.player_MP = 524
Bam_Adebayo.player_MP = 524
Bam_Adebayo.player_FG = 129
Bam_Adebayo.player_FGA = 244
Bam_Adebayo.player_FT = 90
Bam_Adebayo.player_FTA = 110
Bam_Adebayo.player_TRB = 155
Bam_Adebayo.player_AST = 60
Bam_Adebayo.player_STL = 19
Bam_Adebayo.player_BLK = 16
Bam_Adebayo.player_TOV = 39
Bam_Adebayo.player_PF = 38
Bam_Adebayo.player_PTS = 349

Ochai_Agbaji = Player('Ochai_Agbaji')
Ochai_Agbaji.hasClubTeam.append(Utah_Jazz)
Ochai_Agbaji.hasPosition.append(SG)
Ochai_Agbaji.player_Age = 23
Ochai_Agbaji.player_G = 17
Ochai_Agbaji.player_MP = 319
Ochai_Agbaji.player_MP = 319
Ochai_Agbaji.player_FG = 34
Ochai_Agbaji.player_FGA = 77
Ochai_Agbaji.player_FT = 4
Ochai_Agbaji.player_FTA = 6
Ochai_Agbaji.player_TRB = 42
Ochai_Agbaji.player_AST = 16
Ochai_Agbaji.player_STL = 8
Ochai_Agbaji.player_BLK = 12
Ochai_Agbaji.player_TOV = 11
Ochai_Agbaji.player_PF = 25
Ochai_Agbaji.player_PTS = 91

Santi_Aldama = Player('Santi_Aldama')
Santi_Aldama.hasClubTeam.append(Memphis_Grizzlies)
Santi_Aldama.hasPosition.append(PF)
Santi_Aldama.player_Age = 23
Santi_Aldama.player_G = 10
Santi_Aldama.player_MP = 265
Santi_Aldama.player_MP = 265
Santi_Aldama.player_FG = 58
Santi_Aldama.player_FGA = 130
Santi_Aldama.player_FT = 10
Santi_Aldama.player_FTA = 17
Santi_Aldama.player_TRB = 59
Santi_Aldama.player_AST = 20
Santi_Aldama.player_STL = 5
Santi_Aldama.player_BLK = 6
Santi_Aldama.player_TOV = 13
Santi_Aldama.player_PF = 17
Santi_Aldama.player_PTS = 146

Nickeil_Alexander_Walker = Player('Nickeil_Alexander-Walker')
Nickeil_Alexander_Walker.hasClubTeam.append(Minnesota_Timberwolves)
Nickeil_Alexander_Walker.hasPosition.append(SG)
Nickeil_Alexander_Walker.player_Age = 25
Nickeil_Alexander_Walker.player_G = 17
Nickeil_Alexander_Walker.player_MP = 381
Nickeil_Alexander_Walker.player_MP = 381
Nickeil_Alexander_Walker.player_FG = 38
Nickeil_Alexander_Walker.player_FGA = 96
Nickeil_Alexander_Walker.player_FT = 3
Nickeil_Alexander_Walker.player_FTA = 9
Nickeil_Alexander_Walker.player_TRB = 34
Nickeil_Alexander_Walker.player_AST = 42
Nickeil_Alexander_Walker.player_STL = 13
Nickeil_Alexander_Walker.player_BLK = 12
Nickeil_Alexander_Walker.player_TOV = 15
Nickeil_Alexander_Walker.player_PF = 32
Nickeil_Alexander_Walker.player_PTS = 101

Grayson_Allen = Player('Grayson_Allen')
Grayson_Allen.hasClubTeam.append(Phoenix_Suns)
Grayson_Allen.hasPosition.append(SG)
Grayson_Allen.player_Age = 28
Grayson_Allen.player_G = 16
Grayson_Allen.player_MP = 520
Grayson_Allen.player_MP = 520
Grayson_Allen.player_FG = 66
Grayson_Allen.player_FGA = 135
Grayson_Allen.player_FT = 21
Grayson_Allen.player_FTA = 25
Grayson_Allen.player_TRB = 72
Grayson_Allen.player_AST = 46
Grayson_Allen.player_STL = 9
Grayson_Allen.player_BLK = 7
Grayson_Allen.player_TOV = 26
Grayson_Allen.player_PF = 39
Grayson_Allen.player_PTS = 191

Jarrett_Allen = Player('Jarrett_Allen')
Jarrett_Allen.hasClubTeam.append(Cleveland_Cavaliers)
Jarrett_Allen.hasPosition.append(CE)
Jarrett_Allen.player_Age = 25
Jarrett_Allen.player_G = 13
Jarrett_Allen.player_MP = 368
Jarrett_Allen.player_MP = 368
Jarrett_Allen.player_FG = 69
Jarrett_Allen.player_FGA = 102
Jarrett_Allen.player_FT = 38
Jarrett_Allen.player_FTA = 50
Jarrett_Allen.player_TRB = 100
Jarrett_Allen.player_AST = 30
Jarrett_Allen.player_STL = 7
Jarrett_Allen.player_BLK = 15
Jarrett_Allen.player_TOV = 23
Jarrett_Allen.player_PF = 35
Jarrett_Allen.player_PTS = 176

Jose_Alvarado = Player('Jose_Alvarado')
Jose_Alvarado.hasClubTeam.append(New_Orleans_Pelicans)
Jose_Alvarado.hasPosition.append(PG)
Jose_Alvarado.player_Age = 25
Jose_Alvarado.player_G = 5
Jose_Alvarado.player_MP = 86
Jose_Alvarado.player_MP = 86
Jose_Alvarado.player_FG = 14
Jose_Alvarado.player_FGA = 34
Jose_Alvarado.player_FT = 2
Jose_Alvarado.player_FTA = 6
Jose_Alvarado.player_TRB = 11
Jose_Alvarado.player_AST = 11
Jose_Alvarado.player_STL = 6
Jose_Alvarado.player_BLK = 1
Jose_Alvarado.player_TOV = 4
Jose_Alvarado.player_PF = 8
Jose_Alvarado.player_PTS = 36

Kyle_Anderson = Player('Kyle_Anderson')
Kyle_Anderson.hasClubTeam.append(Minnesota_Timberwolves)
Kyle_Anderson.hasPosition.append(PF)
Kyle_Anderson.player_Age = 30
Kyle_Anderson.player_G = 17
Kyle_Anderson.player_MP = 414
Kyle_Anderson.player_MP = 414
Kyle_Anderson.player_FG = 49
Kyle_Anderson.player_FGA = 93
Kyle_Anderson.player_FT = 23
Kyle_Anderson.player_FTA = 37
Kyle_Anderson.player_TRB = 65
Kyle_Anderson.player_AST = 66
Kyle_Anderson.player_STL = 14
Kyle_Anderson.player_BLK = 15
Kyle_Anderson.player_TOV = 29
Kyle_Anderson.player_PF = 25
Kyle_Anderson.player_PTS = 123

Giannis_Antetokounmpo = Player('Giannis_Antetokounmpo')
Giannis_Antetokounmpo.hasClubTeam.append(Milwaukee_Bucks)
Giannis_Antetokounmpo.hasPosition.append(PF)
Giannis_Antetokounmpo.player_Age = 29
Giannis_Antetokounmpo.player_G = 17
Giannis_Antetokounmpo.player_MP = 577
Giannis_Antetokounmpo.player_MP = 577
Giannis_Antetokounmpo.player_FG = 194
Giannis_Antetokounmpo.player_FGA = 324
Giannis_Antetokounmpo.player_FT = 115
Giannis_Antetokounmpo.player_FTA = 179
Giannis_Antetokounmpo.player_TRB = 180
Giannis_Antetokounmpo.player_AST = 79
Giannis_Antetokounmpo.player_STL = 22
Giannis_Antetokounmpo.player_BLK = 20
Giannis_Antetokounmpo.player_TOV = 69
Giannis_Antetokounmpo.player_PF = 53
Giannis_Antetokounmpo.player_PTS = 511

Thanasis_Antetokounmpo = Player('Thanasis_Antetokounmpo')
Thanasis_Antetokounmpo.hasClubTeam.append(Milwaukee_Bucks)
Thanasis_Antetokounmpo.hasPosition.append(PF)
Thanasis_Antetokounmpo.player_Age = 31
Thanasis_Antetokounmpo.player_G = 7
Thanasis_Antetokounmpo.player_MP = 44
Thanasis_Antetokounmpo.player_MP = 44
Thanasis_Antetokounmpo.player_FG = 3
Thanasis_Antetokounmpo.player_FGA = 8
Thanasis_Antetokounmpo.player_FT = 0
Thanasis_Antetokounmpo.player_FTA = 0
Thanasis_Antetokounmpo.player_TRB = 4
Thanasis_Antetokounmpo.player_AST = 4
Thanasis_Antetokounmpo.player_STL = 1
Thanasis_Antetokounmpo.player_BLK = 1
Thanasis_Antetokounmpo.player_TOV = 4
Thanasis_Antetokounmpo.player_PF = 7
Thanasis_Antetokounmpo.player_PTS = 6

Cole_Anthony = Player('Cole_Anthony')
Cole_Anthony.hasClubTeam.append(Orlando_Magic)
Cole_Anthony.hasPosition.append(PG)
Cole_Anthony.player_Age = 23
Cole_Anthony.player_G = 17
Cole_Anthony.player_MP = 441
Cole_Anthony.player_MP = 441
Cole_Anthony.player_FG = 80
Cole_Anthony.player_FGA = 186
Cole_Anthony.player_FT = 71
Cole_Anthony.player_FTA = 84
Cole_Anthony.player_TRB = 79
Cole_Anthony.player_AST = 63
Cole_Anthony.player_STL = 13
Cole_Anthony.player_BLK = 6
Cole_Anthony.player_TOV = 38
Cole_Anthony.player_PF = 48
Cole_Anthony.player_PTS = 255

OG_Anunoby = Player('OG_Anunoby')
OG_Anunoby.hasClubTeam.append(Toronto_Raptors)
OG_Anunoby.hasPosition.append(SF)
OG_Anunoby.player_Age = 26
OG_Anunoby.player_G = 14
OG_Anunoby.player_MP = 449
OG_Anunoby.player_MP = 449
OG_Anunoby.player_FG = 79
OG_Anunoby.player_FGA = 167
OG_Anunoby.player_FT = 17
OG_Anunoby.player_FTA = 28
OG_Anunoby.player_TRB = 58
OG_Anunoby.player_AST = 29
OG_Anunoby.player_STL = 14
OG_Anunoby.player_BLK = 9
OG_Anunoby.player_TOV = 25
OG_Anunoby.player_PF = 30
OG_Anunoby.player_PTS = 211

Ryan_Arcidiacono = Player('Ryan_Arcidiacono')
Ryan_Arcidiacono.hasClubTeam.append(New_York_Knicks)
Ryan_Arcidiacono.hasPosition.append(PG)
Ryan_Arcidiacono.player_Age = 29
Ryan_Arcidiacono.player_G = 5
Ryan_Arcidiacono.player_MP = 11
Ryan_Arcidiacono.player_MP = 11
Ryan_Arcidiacono.player_FG = 0
Ryan_Arcidiacono.player_FGA = 1
Ryan_Arcidiacono.player_FT = 0
Ryan_Arcidiacono.player_FTA = 0
Ryan_Arcidiacono.player_TRB = 2
Ryan_Arcidiacono.player_AST = 0
Ryan_Arcidiacono.player_STL = 0
Ryan_Arcidiacono.player_BLK = 0
Ryan_Arcidiacono.player_TOV = 0
Ryan_Arcidiacono.player_PF = 0
Ryan_Arcidiacono.player_PTS = 0

Deni_Avdija = Player('Deni_Avdija')
Deni_Avdija.hasClubTeam.append(Washington_Wizards)
Deni_Avdija.hasPosition.append(SF)
Deni_Avdija.player_Age = 23
Deni_Avdija.player_G = 17
Deni_Avdija.player_MP = 457
Deni_Avdija.player_MP = 457
Deni_Avdija.player_FG = 81
Deni_Avdija.player_FGA = 156
Deni_Avdija.player_FT = 24
Deni_Avdija.player_FTA = 29
Deni_Avdija.player_TRB = 93
Deni_Avdija.player_AST = 60
Deni_Avdija.player_STL = 15
Deni_Avdija.player_BLK = 5
Deni_Avdija.player_TOV = 27
Deni_Avdija.player_PF = 42
Deni_Avdija.player_PTS = 205

Deandre_Ayton = Player('Deandre_Ayton')
Deandre_Ayton.hasClubTeam.append(Portland_Trail_Blazers)
Deandre_Ayton.hasPosition.append(CE)
Deandre_Ayton.player_Age = 25
Deandre_Ayton.player_G = 16
Deandre_Ayton.player_MP = 510
Deandre_Ayton.player_MP = 510
Deandre_Ayton.player_FG = 99
Deandre_Ayton.player_FGA = 167
Deandre_Ayton.player_FT = 15
Deandre_Ayton.player_FTA = 19
Deandre_Ayton.player_TRB = 177
Deandre_Ayton.player_AST = 25
Deandre_Ayton.player_STL = 22
Deandre_Ayton.player_BLK = 13
Deandre_Ayton.player_TOV = 32
Deandre_Ayton.player_PF = 41
Deandre_Ayton.player_PTS = 213

Udoka_Azubuike = Player('Udoka_Azubuike')
Udoka_Azubuike.hasClubTeam.append(Phoenix_Suns)
Udoka_Azubuike.hasPosition.append(CE)
Udoka_Azubuike.player_Age = 24
Udoka_Azubuike.player_G = 2
Udoka_Azubuike.player_MP = 9
Udoka_Azubuike.player_MP = 9
Udoka_Azubuike.player_FG = 1
Udoka_Azubuike.player_FGA = 1
Udoka_Azubuike.player_FT = 0
Udoka_Azubuike.player_FTA = 0
Udoka_Azubuike.player_TRB = 4
Udoka_Azubuike.player_AST = 0
Udoka_Azubuike.player_STL = 0
Udoka_Azubuike.player_BLK = 0
Udoka_Azubuike.player_TOV = 0
Udoka_Azubuike.player_PF = 1
Udoka_Azubuike.player_PTS = 2

Marvin_Bagley_III = Player('Marvin_Bagley_III')
Marvin_Bagley_III.hasClubTeam.append(Detroit_Pistons)
Marvin_Bagley_III.hasPosition.append(CE)
Marvin_Bagley_III.player_Age = 24
Marvin_Bagley_III.player_G = 16
Marvin_Bagley_III.player_MP = 308
Marvin_Bagley_III.player_MP = 308
Marvin_Bagley_III.player_FG = 68
Marvin_Bagley_III.player_FGA = 116
Marvin_Bagley_III.player_FT = 38
Marvin_Bagley_III.player_FTA = 42
Marvin_Bagley_III.player_TRB = 83
Marvin_Bagley_III.player_AST = 22
Marvin_Bagley_III.player_STL = 1
Marvin_Bagley_III.player_BLK = 11
Marvin_Bagley_III.player_TOV = 21
Marvin_Bagley_III.player_PF = 27
Marvin_Bagley_III.player_PTS = 175

Amari_Bailey = Player('Amari_Bailey')
Amari_Bailey.hasClubTeam.append(Charlotte_Hornets)
Amari_Bailey.hasPosition.append(PG)
Amari_Bailey.player_Age = 19
Amari_Bailey.player_G = 1
Amari_Bailey.player_MP = 3
Amari_Bailey.player_MP = 3
Amari_Bailey.player_FG = 1
Amari_Bailey.player_FGA = 3
Amari_Bailey.player_FT = 0
Amari_Bailey.player_FTA = 0
Amari_Bailey.player_TRB = 2
Amari_Bailey.player_AST = 0
Amari_Bailey.player_STL = 0
Amari_Bailey.player_BLK = 0
Amari_Bailey.player_TOV = 0
Amari_Bailey.player_PF = 0
Amari_Bailey.player_PTS = 2

Patrick_Baldwin_Jr = Player('Patrick_Baldwin_Jr.')
Patrick_Baldwin_Jr.hasClubTeam.append(Washington_Wizards)
Patrick_Baldwin_Jr.hasPosition.append(SF)
Patrick_Baldwin_Jr.player_Age = 21
Patrick_Baldwin_Jr.player_G = 3
Patrick_Baldwin_Jr.player_MP = 11
Patrick_Baldwin_Jr.player_MP = 11
Patrick_Baldwin_Jr.player_FG = 0
Patrick_Baldwin_Jr.player_FGA = 2
Patrick_Baldwin_Jr.player_FT = 0
Patrick_Baldwin_Jr.player_FTA = 0
Patrick_Baldwin_Jr.player_TRB = 1
Patrick_Baldwin_Jr.player_AST = 1
Patrick_Baldwin_Jr.player_STL = 0
Patrick_Baldwin_Jr.player_BLK = 0
Patrick_Baldwin_Jr.player_TOV = 0
Patrick_Baldwin_Jr.player_PF = 1
Patrick_Baldwin_Jr.player_PTS = 0

LaMelo_Ball = Player('LaMelo_Ball')
LaMelo_Ball.hasClubTeam.append(Charlotte_Hornets)
LaMelo_Ball.hasPosition.append(PG)
LaMelo_Ball.player_Age = 22
LaMelo_Ball.player_G = 15
LaMelo_Ball.player_MP = 501
LaMelo_Ball.player_MP = 501
LaMelo_Ball.player_FG = 132
LaMelo_Ball.player_FGA = 298
LaMelo_Ball.player_FT = 54
LaMelo_Ball.player_FTA = 63
LaMelo_Ball.player_TRB = 82
LaMelo_Ball.player_AST = 123
LaMelo_Ball.player_STL = 21
LaMelo_Ball.player_BLK = 4
LaMelo_Ball.player_TOV = 59
LaMelo_Ball.player_PF = 52
LaMelo_Ball.player_PTS = 370

Mo_Bamba = Player('Mo_Bamba')
Mo_Bamba.hasClubTeam.append(Philadelphia_76ers)
Mo_Bamba.hasPosition.append(CE)
Mo_Bamba.player_Age = 25
Mo_Bamba.player_G = 7
Mo_Bamba.player_MP = 23
Mo_Bamba.player_MP = 23
Mo_Bamba.player_FG = 6
Mo_Bamba.player_FGA = 10
Mo_Bamba.player_FT = 5
Mo_Bamba.player_FTA = 5
Mo_Bamba.player_TRB = 11
Mo_Bamba.player_AST = 0
Mo_Bamba.player_STL = 1
Mo_Bamba.player_BLK = 2
Mo_Bamba.player_TOV = 3
Mo_Bamba.player_PF = 3
Mo_Bamba.player_PTS = 18

Paolo_Banchero = Player('Paolo_Banchero')
Paolo_Banchero.hasClubTeam.append(Orlando_Magic)
Paolo_Banchero.hasPosition.append(PF)
Paolo_Banchero.player_Age = 21
Paolo_Banchero.player_G = 17
Paolo_Banchero.player_MP = 570
Paolo_Banchero.player_MP = 570
Paolo_Banchero.player_FG = 122
Paolo_Banchero.player_FGA = 250
Paolo_Banchero.player_FT = 69
Paolo_Banchero.player_FTA = 106
Paolo_Banchero.player_TRB = 110
Paolo_Banchero.player_AST = 78
Paolo_Banchero.player_STL = 20
Paolo_Banchero.player_BLK = 11
Paolo_Banchero.player_TOV = 55
Paolo_Banchero.player_PF = 39
Paolo_Banchero.player_PTS = 337

Desmond_Bane = Player('Desmond_Bane')
Desmond_Bane.hasClubTeam.append(Memphis_Grizzlies)
Desmond_Bane.hasPosition.append(SG)
Desmond_Bane.player_Age = 25
Desmond_Bane.player_G = 16
Desmond_Bane.player_MP = 546
Desmond_Bane.player_MP = 546
Desmond_Bane.player_FG = 136
Desmond_Bane.player_FGA = 308
Desmond_Bane.player_FT = 54
Desmond_Bane.player_FTA = 62
Desmond_Bane.player_TRB = 70
Desmond_Bane.player_AST = 80
Desmond_Bane.player_STL = 20
Desmond_Bane.player_BLK = 10
Desmond_Bane.player_TOV = 43
Desmond_Bane.player_PF = 50
Desmond_Bane.player_PTS = 378

Dalano_Banton = Player('Dalano_Banton')
Dalano_Banton.hasClubTeam.append(Boston_Celtics)
Dalano_Banton.hasPosition.append(PG)
Dalano_Banton.player_Age = 24
Dalano_Banton.player_G = 8
Dalano_Banton.player_MP = 70
Dalano_Banton.player_MP = 70
Dalano_Banton.player_FG = 11
Dalano_Banton.player_FGA = 22
Dalano_Banton.player_FT = 5
Dalano_Banton.player_FTA = 5
Dalano_Banton.player_TRB = 16
Dalano_Banton.player_AST = 3
Dalano_Banton.player_STL = 2
Dalano_Banton.player_BLK = 1
Dalano_Banton.player_TOV = 2
Dalano_Banton.player_PF = 10
Dalano_Banton.player_PTS = 28

Dominick_Barlow = Player('Dominick_Barlow')
Dominick_Barlow.hasClubTeam.append(San_Antonio_Spurs)
Dominick_Barlow.hasPosition.append(PF)
Dominick_Barlow.player_Age = 20
Dominick_Barlow.player_G = 6
Dominick_Barlow.player_MP = 32
Dominick_Barlow.player_MP = 32
Dominick_Barlow.player_FG = 2
Dominick_Barlow.player_FGA = 6
Dominick_Barlow.player_FT = 2
Dominick_Barlow.player_FTA = 4
Dominick_Barlow.player_TRB = 5
Dominick_Barlow.player_AST = 0
Dominick_Barlow.player_STL = 1
Dominick_Barlow.player_BLK = 0
Dominick_Barlow.player_TOV = 0
Dominick_Barlow.player_PF = 2
Dominick_Barlow.player_PTS = 6

Harrison_Barnes = Player('Harrison_Barnes')
Harrison_Barnes.hasClubTeam.append(Sacramento_Kings)
Harrison_Barnes.hasPosition.append(PF)
Harrison_Barnes.player_Age = 31
Harrison_Barnes.player_G = 16
Harrison_Barnes.player_MP = 498
Harrison_Barnes.player_MP = 498
Harrison_Barnes.player_FG = 67
Harrison_Barnes.player_FGA = 140
Harrison_Barnes.player_FT = 36
Harrison_Barnes.player_FTA = 43
Harrison_Barnes.player_TRB = 50
Harrison_Barnes.player_AST = 23
Harrison_Barnes.player_STL = 13
Harrison_Barnes.player_BLK = 2
Harrison_Barnes.player_TOV = 14
Harrison_Barnes.player_PF = 17
Harrison_Barnes.player_PTS = 201

Scottie_Barnes = Player('Scottie_Barnes')
Scottie_Barnes.hasClubTeam.append(Toronto_Raptors)
Scottie_Barnes.hasPosition.append(SG)
Scottie_Barnes.player_Age = 22
Scottie_Barnes.player_G = 18
Scottie_Barnes.player_MP = 622
Scottie_Barnes.player_MP = 622
Scottie_Barnes.player_FG = 126
Scottie_Barnes.player_FGA = 279
Scottie_Barnes.player_FT = 53
Scottie_Barnes.player_FTA = 70
Scottie_Barnes.player_TRB = 165
Scottie_Barnes.player_AST = 101
Scottie_Barnes.player_STL = 31
Scottie_Barnes.player_BLK = 22
Scottie_Barnes.player_TOV = 44
Scottie_Barnes.player_PF = 36
Scottie_Barnes.player_PTS = 340

RJ_Barrett = Player('RJ_Barrett')
RJ_Barrett.hasClubTeam.append(New_York_Knicks)
RJ_Barrett.hasPosition.append(SG)
RJ_Barrett.player_Age = 23
RJ_Barrett.player_G = 12
RJ_Barrett.player_MP = 360
RJ_Barrett.player_MP = 360
RJ_Barrett.player_FG = 77
RJ_Barrett.player_FGA = 179
RJ_Barrett.player_FT = 50
RJ_Barrett.player_FTA = 58
RJ_Barrett.player_TRB = 46
RJ_Barrett.player_AST = 30
RJ_Barrett.player_STL = 7
RJ_Barrett.player_BLK = 3
RJ_Barrett.player_TOV = 24
RJ_Barrett.player_PF = 19
RJ_Barrett.player_PTS = 230

Charles_Bassey = Player('Charles_Bassey')
Charles_Bassey.hasClubTeam.append(San_Antonio_Spurs)
Charles_Bassey.hasPosition.append(CE)
Charles_Bassey.player_Age = 23
Charles_Bassey.player_G = 17
Charles_Bassey.player_MP = 182
Charles_Bassey.player_MP = 182
Charles_Bassey.player_FG = 25
Charles_Bassey.player_FGA = 36
Charles_Bassey.player_FT = 5
Charles_Bassey.player_FTA = 6
Charles_Bassey.player_TRB = 64
Charles_Bassey.player_AST = 18
Charles_Bassey.player_STL = 8
Charles_Bassey.player_BLK = 12
Charles_Bassey.player_TOV = 14
Charles_Bassey.player_PF = 24
Charles_Bassey.player_PTS = 55

Emoni_Bates = Player('Emoni_Bates')
Emoni_Bates.hasClubTeam.append(Cleveland_Cavaliers)
Emoni_Bates.hasPosition.append(SF)
Emoni_Bates.player_Age = 20
Emoni_Bates.player_G = 7
Emoni_Bates.player_MP = 52
Emoni_Bates.player_MP = 52
Emoni_Bates.player_FG = 4
Emoni_Bates.player_FGA = 15
Emoni_Bates.player_FT = 1
Emoni_Bates.player_FTA = 2
Emoni_Bates.player_TRB = 9
Emoni_Bates.player_AST = 2
Emoni_Bates.player_STL = 1
Emoni_Bates.player_BLK = 1
Emoni_Bates.player_TOV = 1
Emoni_Bates.player_PF = 2
Emoni_Bates.player_PTS = 12

Keita_Bates_Diop = Player('Keita_Bates-Diop')
Keita_Bates_Diop.hasClubTeam.append(Phoenix_Suns)
Keita_Bates_Diop.hasPosition.append(SF)
Keita_Bates_Diop.player_Age = 28
Keita_Bates_Diop.player_G = 14
Keita_Bates_Diop.player_MP = 285
Keita_Bates_Diop.player_MP = 285
Keita_Bates_Diop.player_FG = 29
Keita_Bates_Diop.player_FGA = 72
Keita_Bates_Diop.player_FT = 15
Keita_Bates_Diop.player_FTA = 22
Keita_Bates_Diop.player_TRB = 51
Keita_Bates_Diop.player_AST = 14
Keita_Bates_Diop.player_STL = 11
Keita_Bates_Diop.player_BLK = 14
Keita_Bates_Diop.player_TOV = 3
Keita_Bates_Diop.player_PF = 19
Keita_Bates_Diop.player_PTS = 81

Nicolas_Batum = Player('Nicolas_Batum')
Nicolas_Batum.hasClubTeam.append(Toronto_Raptors)
Nicolas_Batum.hasPosition.append(PF)
Nicolas_Batum.player_Age = 35
Nicolas_Batum.player_G = 12
Nicolas_Batum.player_MP = 294
Nicolas_Batum.player_MP = 294
Nicolas_Batum.player_FG = 26
Nicolas_Batum.player_FGA = 47
Nicolas_Batum.player_FT = 3
Nicolas_Batum.player_FTA = 4
Nicolas_Batum.player_TRB = 47
Nicolas_Batum.player_AST = 21
Nicolas_Batum.player_STL = 9
Nicolas_Batum.player_BLK = 11
Nicolas_Batum.player_TOV = 6
Nicolas_Batum.player_PF = 26
Nicolas_Batum.player_PTS = 74

Bradley_Beal = Player('Bradley_Beal')
Bradley_Beal.hasClubTeam.append(Phoenix_Suns)
Bradley_Beal.hasPosition.append(SG)
Bradley_Beal.player_Age = 30
Bradley_Beal.player_G = 3
Bradley_Beal.player_MP = 86
Bradley_Beal.player_MP = 86
Bradley_Beal.player_FG = 18
Bradley_Beal.player_FGA = 46
Bradley_Beal.player_FT = 11
Bradley_Beal.player_FTA = 16
Bradley_Beal.player_TRB = 16
Bradley_Beal.player_AST = 11
Bradley_Beal.player_STL = 2
Bradley_Beal.player_BLK = 1
Bradley_Beal.player_TOV = 9
Bradley_Beal.player_PF = 9
Bradley_Beal.player_PTS = 52

Malik_Beasley = Player('Malik_Beasley')
Malik_Beasley.hasClubTeam.append(Milwaukee_Bucks)
Malik_Beasley.hasPosition.append(SG)
Malik_Beasley.player_Age = 27
Malik_Beasley.player_G = 18
Malik_Beasley.player_MP = 502
Malik_Beasley.player_MP = 502
Malik_Beasley.player_FG = 72
Malik_Beasley.player_FGA = 147
Malik_Beasley.player_FT = 8
Malik_Beasley.player_FTA = 12
Malik_Beasley.player_TRB = 83
Malik_Beasley.player_AST = 24
Malik_Beasley.player_STL = 17
Malik_Beasley.player_BLK = 3
Malik_Beasley.player_TOV = 13
Malik_Beasley.player_PF = 36
Malik_Beasley.player_PTS = 201

MarJon_Beauchamp = Player('MarJon_Beauchamp')
MarJon_Beauchamp.hasClubTeam.append(Milwaukee_Bucks)
MarJon_Beauchamp.hasPosition.append(SF)
MarJon_Beauchamp.player_Age = 23
MarJon_Beauchamp.player_G = 14
MarJon_Beauchamp.player_MP = 220
MarJon_Beauchamp.player_MP = 220
MarJon_Beauchamp.player_FG = 28
MarJon_Beauchamp.player_FGA = 62
MarJon_Beauchamp.player_FT = 8
MarJon_Beauchamp.player_FTA = 12
MarJon_Beauchamp.player_TRB = 34
MarJon_Beauchamp.player_AST = 14
MarJon_Beauchamp.player_STL = 4
MarJon_Beauchamp.player_BLK = 2
MarJon_Beauchamp.player_TOV = 9
MarJon_Beauchamp.player_PF = 26
MarJon_Beauchamp.player_PTS = 76

Dāvis_Bertāns = Player('Dāvis_Bertāns')
Dāvis_Bertāns.hasClubTeam.append(Oklahoma_City_Thunder)
Dāvis_Bertāns.hasPosition.append(PF)
Dāvis_Bertāns.player_Age = 31
Dāvis_Bertāns.player_G = 5
Dāvis_Bertāns.player_MP = 46
Dāvis_Bertāns.player_MP = 46
Dāvis_Bertāns.player_FG = 3
Dāvis_Bertāns.player_FGA = 13
Dāvis_Bertāns.player_FT = 8
Dāvis_Bertāns.player_FTA = 9
Dāvis_Bertāns.player_TRB = 4
Dāvis_Bertāns.player_AST = 4
Dāvis_Bertāns.player_STL = 1
Dāvis_Bertāns.player_BLK = 1
Dāvis_Bertāns.player_TOV = 0
Dāvis_Bertāns.player_PF = 5
Dāvis_Bertāns.player_PTS = 17

Patrick_Beverley = Player('Patrick_Beverley')
Patrick_Beverley.hasClubTeam.append(Philadelphia_76ers)
Patrick_Beverley.hasPosition.append(PG)
Patrick_Beverley.player_Age = 35
Patrick_Beverley.player_G = 17
Patrick_Beverley.player_MP = 285
Patrick_Beverley.player_MP = 285
Patrick_Beverley.player_FG = 19
Patrick_Beverley.player_FGA = 53
Patrick_Beverley.player_FT = 4
Patrick_Beverley.player_FTA = 7
Patrick_Beverley.player_TRB = 52
Patrick_Beverley.player_AST = 34
Patrick_Beverley.player_STL = 7
Patrick_Beverley.player_BLK = 6
Patrick_Beverley.player_TOV = 10
Patrick_Beverley.player_PF = 34
Patrick_Beverley.player_PTS = 49

Saddiq_Bey = Player('Saddiq_Bey')
Saddiq_Bey.hasClubTeam.append(Atlanta_Hawks)
Saddiq_Bey.hasPosition.append(SF)
Saddiq_Bey.player_Age = 24
Saddiq_Bey.player_G = 17
Saddiq_Bey.player_MP = 484
Saddiq_Bey.player_MP = 484
Saddiq_Bey.player_FG = 76
Saddiq_Bey.player_FGA = 153
Saddiq_Bey.player_FT = 26
Saddiq_Bey.player_FTA = 33
Saddiq_Bey.player_TRB = 98
Saddiq_Bey.player_AST = 22
Saddiq_Bey.player_STL = 18
Saddiq_Bey.player_BLK = 3
Saddiq_Bey.player_TOV = 21
Saddiq_Bey.player_PF = 26
Saddiq_Bey.player_PTS = 205

Goga_Bitadze = Player('Goga_Bitadze')
Goga_Bitadze.hasClubTeam.append(Orlando_Magic)
Goga_Bitadze.hasPosition.append(CE)
Goga_Bitadze.player_Age = 24
Goga_Bitadze.player_G = 15
Goga_Bitadze.player_MP = 296
Goga_Bitadze.player_MP = 296
Goga_Bitadze.player_FG = 41
Goga_Bitadze.player_FGA = 71
Goga_Bitadze.player_FT = 24
Goga_Bitadze.player_FTA = 34
Goga_Bitadze.player_TRB = 91
Goga_Bitadze.player_AST = 26
Goga_Bitadze.player_STL = 14
Goga_Bitadze.player_BLK = 22
Goga_Bitadze.player_TOV = 9
Goga_Bitadze.player_PF = 37
Goga_Bitadze.player_PTS = 106

Onuralp_Bitim = Player('Onuralp_Bitim')
Onuralp_Bitim.hasClubTeam.append(Chicago_Bulls)
Onuralp_Bitim.hasPosition.append(SG)
Onuralp_Bitim.player_Age = 24
Onuralp_Bitim.player_G = 1
Onuralp_Bitim.player_MP = 3
Onuralp_Bitim.player_MP = 3
Onuralp_Bitim.player_FG = 0
Onuralp_Bitim.player_FGA = 0
Onuralp_Bitim.player_FT = 0
Onuralp_Bitim.player_FTA = 0
Onuralp_Bitim.player_TRB = 0
Onuralp_Bitim.player_AST = 0
Onuralp_Bitim.player_STL = 0
Onuralp_Bitim.player_BLK = 0
Onuralp_Bitim.player_TOV = 0
Onuralp_Bitim.player_PF = 0
Onuralp_Bitim.player_PTS = 0

Bismack_Biyombo = Player('Bismack_Biyombo')
Bismack_Biyombo.hasClubTeam.append(Memphis_Grizzlies)
Bismack_Biyombo.hasPosition.append(CE)
Bismack_Biyombo.player_Age = 31
Bismack_Biyombo.player_G = 11
Bismack_Biyombo.player_MP = 285
Bismack_Biyombo.player_MP = 285
Bismack_Biyombo.player_FG = 32
Bismack_Biyombo.player_FGA = 54
Bismack_Biyombo.player_FT = 18
Bismack_Biyombo.player_FTA = 30
Bismack_Biyombo.player_TRB = 81
Bismack_Biyombo.player_AST = 21
Bismack_Biyombo.player_STL = 5
Bismack_Biyombo.player_BLK = 11
Bismack_Biyombo.player_TOV = 8
Bismack_Biyombo.player_PF = 32
Bismack_Biyombo.player_PTS = 82

Anthony_Black = Player('Anthony_Black')
Anthony_Black.hasClubTeam.append(Orlando_Magic)
Anthony_Black.hasPosition.append(PG)
Anthony_Black.player_Age = 20
Anthony_Black.player_G = 15
Anthony_Black.player_MP = 275
Anthony_Black.player_MP = 275
Anthony_Black.player_FG = 26
Anthony_Black.player_FGA = 58
Anthony_Black.player_FT = 12
Anthony_Black.player_FTA = 18
Anthony_Black.player_TRB = 31
Anthony_Black.player_AST = 20
Anthony_Black.player_STL = 5
Anthony_Black.player_BLK = 5
Anthony_Black.player_TOV = 16
Anthony_Black.player_PF = 31
Anthony_Black.player_PTS = 69

Leaky_Black = Player('Leaky_Black')
Leaky_Black.hasClubTeam.append(Charlotte_Hornets)
Leaky_Black.hasPosition.append(SF)
Leaky_Black.player_Age = 24
Leaky_Black.player_G = 4
Leaky_Black.player_MP = 17
Leaky_Black.player_MP = 17
Leaky_Black.player_FG = 2
Leaky_Black.player_FGA = 5
Leaky_Black.player_FT = 0
Leaky_Black.player_FTA = 0
Leaky_Black.player_TRB = 2
Leaky_Black.player_AST = 1
Leaky_Black.player_STL = 1
Leaky_Black.player_BLK = 2
Leaky_Black.player_TOV = 0
Leaky_Black.player_PF = 1
Leaky_Black.player_PTS = 5

Bogdan_Bogdanović = Player('Bogdan_Bogdanović')
Bogdan_Bogdanović.hasClubTeam.append(Atlanta_Hawks)
Bogdan_Bogdanović.hasPosition.append(SG)
Bogdan_Bogdanović.player_Age = 31
Bogdan_Bogdanović.player_G = 17
Bogdan_Bogdanović.player_MP = 447
Bogdan_Bogdanović.player_MP = 447
Bogdan_Bogdanović.player_FG = 98
Bogdan_Bogdanović.player_FGA = 213
Bogdan_Bogdanović.player_FT = 21
Bogdan_Bogdanović.player_FTA = 23
Bogdan_Bogdanović.player_TRB = 54
Bogdan_Bogdanović.player_AST = 41
Bogdan_Bogdanović.player_STL = 24
Bogdan_Bogdanović.player_BLK = 6
Bogdan_Bogdanović.player_TOV = 24
Bogdan_Bogdanović.player_PF = 40
Bogdan_Bogdanović.player_PTS = 271

Bol_Bol = Player('Bol_Bol')
Bol_Bol.hasClubTeam.append(Phoenix_Suns)
Bol_Bol.hasPosition.append(PF)
Bol_Bol.player_Age = 24
Bol_Bol.player_G = 3
Bol_Bol.player_MP = 7
Bol_Bol.player_MP = 7
Bol_Bol.player_FG = 1
Bol_Bol.player_FGA = 1
Bol_Bol.player_FT = 0
Bol_Bol.player_FTA = 0
Bol_Bol.player_TRB = 1
Bol_Bol.player_AST = 0
Bol_Bol.player_STL = 0
Bol_Bol.player_BLK = 1
Bol_Bol.player_TOV = 2
Bol_Bol.player_PF = 0
Bol_Bol.player_PTS = 2

Marques_Bolden = Player('Marques_Bolden')
Marques_Bolden.hasClubTeam.append(Milwaukee_Bucks)
Marques_Bolden.hasPosition.append(CE)
Marques_Bolden.player_Age = 25
Marques_Bolden.player_G = 1
Marques_Bolden.player_MP = 3
Marques_Bolden.player_MP = 3
Marques_Bolden.player_FG = 0
Marques_Bolden.player_FGA = 0
Marques_Bolden.player_FT = 0
Marques_Bolden.player_FTA = 0
Marques_Bolden.player_TRB = 2
Marques_Bolden.player_AST = 0
Marques_Bolden.player_STL = 0
Marques_Bolden.player_BLK = 0
Marques_Bolden.player_TOV = 0
Marques_Bolden.player_PF = 1
Marques_Bolden.player_PTS = 0

Devin_Booker = Player('Devin_Booker')
Devin_Booker.hasClubTeam.append(Phoenix_Suns)
Devin_Booker.hasPosition.append(SG)
Devin_Booker.player_Age = 27
Devin_Booker.player_G = 9
Devin_Booker.player_MP = 306
Devin_Booker.player_MP = 306
Devin_Booker.player_FG = 89
Devin_Booker.player_FGA = 179
Devin_Booker.player_FT = 67
Devin_Booker.player_FTA = 73
Devin_Booker.player_TRB = 49
Devin_Booker.player_AST = 80
Devin_Booker.player_STL = 7
Devin_Booker.player_BLK = 5
Devin_Booker.player_TOV = 28
Devin_Booker.player_PF = 27
Devin_Booker.player_PTS = 265

Chris_Boucher = Player('Chris_Boucher')
Chris_Boucher.hasClubTeam.append(Toronto_Raptors)
Chris_Boucher.hasPosition.append(PF)
Chris_Boucher.player_Age = 31
Chris_Boucher.player_G = 16
Chris_Boucher.player_MP = 246
Chris_Boucher.player_MP = 246
Chris_Boucher.player_FG = 36
Chris_Boucher.player_FGA = 76
Chris_Boucher.player_FT = 29
Chris_Boucher.player_FTA = 35
Chris_Boucher.player_TRB = 68
Chris_Boucher.player_AST = 6
Chris_Boucher.player_STL = 6
Chris_Boucher.player_BLK = 9
Chris_Boucher.player_TOV = 7
Chris_Boucher.player_PF = 32
Chris_Boucher.player_PTS = 114

James_Bouknight = Player('James_Bouknight')
James_Bouknight.hasClubTeam.append(Charlotte_Hornets)
James_Bouknight.hasPosition.append(SG)
James_Bouknight.player_Age = 23
James_Bouknight.player_G = 1
James_Bouknight.player_MP = 5
James_Bouknight.player_MP = 5
James_Bouknight.player_FG = 2
James_Bouknight.player_FGA = 3
James_Bouknight.player_FT = 0
James_Bouknight.player_FTA = 0
James_Bouknight.player_TRB = 1
James_Bouknight.player_AST = 0
James_Bouknight.player_STL = 0
James_Bouknight.player_BLK = 0
James_Bouknight.player_TOV = 0
James_Bouknight.player_PF = 0
James_Bouknight.player_PTS = 5

Jamaree_Bouyea = Player('Jamaree_Bouyea')
Jamaree_Bouyea.hasClubTeam.append(Portland_Trail_Blazers)
Jamaree_Bouyea.hasPosition.append(PG)
Jamaree_Bouyea.player_Age = 24
Jamaree_Bouyea.player_G = 6
Jamaree_Bouyea.player_MP = 57
Jamaree_Bouyea.player_MP = 57
Jamaree_Bouyea.player_FG = 5
Jamaree_Bouyea.player_FGA = 21
Jamaree_Bouyea.player_FT = 0
Jamaree_Bouyea.player_FTA = 0
Jamaree_Bouyea.player_TRB = 10
Jamaree_Bouyea.player_AST = 8
Jamaree_Bouyea.player_STL = 0
Jamaree_Bouyea.player_BLK = 0
Jamaree_Bouyea.player_TOV = 8
Jamaree_Bouyea.player_PF = 3
Jamaree_Bouyea.player_PTS = 10

Malaki_Branham = Player('Malaki_Branham')
Malaki_Branham.hasClubTeam.append(San_Antonio_Spurs)
Malaki_Branham.hasPosition.append(SG)
Malaki_Branham.player_Age = 20
Malaki_Branham.player_G = 17
Malaki_Branham.player_MP = 353
Malaki_Branham.player_MP = 353
Malaki_Branham.player_FG = 60
Malaki_Branham.player_FGA = 143
Malaki_Branham.player_FT = 8
Malaki_Branham.player_FTA = 9
Malaki_Branham.player_TRB = 21
Malaki_Branham.player_AST = 38
Malaki_Branham.player_STL = 8
Malaki_Branham.player_BLK = 1
Malaki_Branham.player_TOV = 16
Malaki_Branham.player_PF = 23
Malaki_Branham.player_PTS = 144

Christian_Braun = Player('Christian_Braun')
Christian_Braun.hasClubTeam.append(Denver_Nuggets)
Christian_Braun.hasPosition.append(SG)
Christian_Braun.player_Age = 22
Christian_Braun.player_G = 18
Christian_Braun.player_MP = 380
Christian_Braun.player_MP = 380
Christian_Braun.player_FG = 60
Christian_Braun.player_FGA = 131
Christian_Braun.player_FT = 25
Christian_Braun.player_FTA = 35
Christian_Braun.player_TRB = 78
Christian_Braun.player_AST = 35
Christian_Braun.player_STL = 6
Christian_Braun.player_BLK = 4
Christian_Braun.player_TOV = 11
Christian_Braun.player_PF = 31
Christian_Braun.player_PTS = 157

Mikal_Bridges = Player('Mikal_Bridges')
Mikal_Bridges.hasClubTeam.append(Brooklyn_Nets)
Mikal_Bridges.hasPosition.append(SF)
Mikal_Bridges.player_Age = 27
Mikal_Bridges.player_G = 17
Mikal_Bridges.player_MP = 592
Mikal_Bridges.player_MP = 592
Mikal_Bridges.player_FG = 136
Mikal_Bridges.player_FGA = 285
Mikal_Bridges.player_FT = 63
Mikal_Bridges.player_FTA = 73
Mikal_Bridges.player_TRB = 104
Mikal_Bridges.player_AST = 67
Mikal_Bridges.player_STL = 18
Mikal_Bridges.player_BLK = 6
Mikal_Bridges.player_TOV = 43
Mikal_Bridges.player_PF = 30
Mikal_Bridges.player_PTS = 370

Miles_Bridges = Player('Miles_Bridges')
Miles_Bridges.hasClubTeam.append(Charlotte_Hornets)
Miles_Bridges.hasPosition.append(SF)
Miles_Bridges.player_Age = 25
Miles_Bridges.player_G = 6
Miles_Bridges.player_MP = 216
Miles_Bridges.player_MP = 216
Miles_Bridges.player_FG = 42
Miles_Bridges.player_FGA = 85
Miles_Bridges.player_FT = 24
Miles_Bridges.player_FTA = 30
Miles_Bridges.player_TRB = 48
Miles_Bridges.player_AST = 16
Miles_Bridges.player_STL = 9
Miles_Bridges.player_BLK = 3
Miles_Bridges.player_TOV = 12
Miles_Bridges.player_PF = 10
Miles_Bridges.player_PTS = 119

Oshae_Brissett = Player('Oshae_Brissett')
Oshae_Brissett.hasClubTeam.append(Boston_Celtics)
Oshae_Brissett.hasPosition.append(SF)
Oshae_Brissett.player_Age = 25
Oshae_Brissett.player_G = 8
Oshae_Brissett.player_MP = 90
Oshae_Brissett.player_MP = 90
Oshae_Brissett.player_FG = 3
Oshae_Brissett.player_FGA = 17
Oshae_Brissett.player_FT = 7
Oshae_Brissett.player_FTA = 12
Oshae_Brissett.player_TRB = 21
Oshae_Brissett.player_AST = 3
Oshae_Brissett.player_STL = 4
Oshae_Brissett.player_BLK = 0
Oshae_Brissett.player_TOV = 2
Oshae_Brissett.player_PF = 9
Oshae_Brissett.player_PTS = 14

Malcolm_Brogdon = Player('Malcolm_Brogdon')
Malcolm_Brogdon.hasClubTeam.append(Portland_Trail_Blazers)
Malcolm_Brogdon.hasPosition.append(PG)
Malcolm_Brogdon.player_Age = 31
Malcolm_Brogdon.player_G = 12
Malcolm_Brogdon.player_MP = 341
Malcolm_Brogdon.player_MP = 341
Malcolm_Brogdon.player_FG = 80
Malcolm_Brogdon.player_FGA = 194
Malcolm_Brogdon.player_FT = 35
Malcolm_Brogdon.player_FTA = 44
Malcolm_Brogdon.player_TRB = 53
Malcolm_Brogdon.player_AST = 76
Malcolm_Brogdon.player_STL = 9
Malcolm_Brogdon.player_BLK = 1
Malcolm_Brogdon.player_TOV = 18
Malcolm_Brogdon.player_PF = 18
Malcolm_Brogdon.player_PTS = 219

Armoni_Brooks = Player('Armoni_Brooks')
Armoni_Brooks.hasClubTeam.append(Brooklyn_Nets)
Armoni_Brooks.hasPosition.append(PG)
Armoni_Brooks.player_Age = 25
Armoni_Brooks.player_G = 5
Armoni_Brooks.player_MP = 45
Armoni_Brooks.player_MP = 45
Armoni_Brooks.player_FG = 6
Armoni_Brooks.player_FGA = 17
Armoni_Brooks.player_FT = 0
Armoni_Brooks.player_FTA = 0
Armoni_Brooks.player_TRB = 10
Armoni_Brooks.player_AST = 0
Armoni_Brooks.player_STL = 0
Armoni_Brooks.player_BLK = 0
Armoni_Brooks.player_TOV = 1
Armoni_Brooks.player_PF = 1
Armoni_Brooks.player_PTS = 17

Dillon_Brooks = Player('Dillon_Brooks')
Dillon_Brooks.hasClubTeam.append(Houston_Rockets)
Dillon_Brooks.hasPosition.append(SF)
Dillon_Brooks.player_Age = 28
Dillon_Brooks.player_G = 15
Dillon_Brooks.player_MP = 465
Dillon_Brooks.player_MP = 465
Dillon_Brooks.player_FG = 73
Dillon_Brooks.player_FGA = 153
Dillon_Brooks.player_FT = 31
Dillon_Brooks.player_FTA = 37
Dillon_Brooks.player_TRB = 54
Dillon_Brooks.player_AST = 27
Dillon_Brooks.player_STL = 16
Dillon_Brooks.player_BLK = 1
Dillon_Brooks.player_TOV = 25
Dillon_Brooks.player_PF = 61
Dillon_Brooks.player_PTS = 204

Bruce_Brown = Player('Bruce_Brown')
Bruce_Brown.hasClubTeam.append(Indiana_Pacers)
Bruce_Brown.hasPosition.append(SG)
Bruce_Brown.player_Age = 27
Bruce_Brown.player_G = 16
Bruce_Brown.player_MP = 504
Bruce_Brown.player_MP = 504
Bruce_Brown.player_FG = 69
Bruce_Brown.player_FGA = 149
Bruce_Brown.player_FT = 24
Bruce_Brown.player_FTA = 28
Bruce_Brown.player_TRB = 66
Bruce_Brown.player_AST = 45
Bruce_Brown.player_STL = 20
Bruce_Brown.player_BLK = 5
Bruce_Brown.player_TOV = 18
Bruce_Brown.player_PF = 40
Bruce_Brown.player_PTS = 183

Jaylen_Brown = Player('Jaylen_Brown')
Jaylen_Brown.hasClubTeam.append(Boston_Celtics)
Jaylen_Brown.hasPosition.append(SF)
Jaylen_Brown.player_Age = 27
Jaylen_Brown.player_G = 17
Jaylen_Brown.player_MP = 586
Jaylen_Brown.player_MP = 586
Jaylen_Brown.player_FG = 141
Jaylen_Brown.player_FGA = 312
Jaylen_Brown.player_FT = 48
Jaylen_Brown.player_FTA = 68
Jaylen_Brown.player_TRB = 85
Jaylen_Brown.player_AST = 61
Jaylen_Brown.player_STL = 18
Jaylen_Brown.player_BLK = 9
Jaylen_Brown.player_TOV = 41
Jaylen_Brown.player_PF = 47
Jaylen_Brown.player_PTS = 372

Kobe_Brown = Player('Kobe_Brown')
Kobe_Brown.hasClubTeam.append(Los_Angeles_Clippers)
Kobe_Brown.hasPosition.append(PF)
Kobe_Brown.player_Age = 24
Kobe_Brown.player_G = 7
Kobe_Brown.player_MP = 57
Kobe_Brown.player_MP = 57
Kobe_Brown.player_FG = 7
Kobe_Brown.player_FGA = 16
Kobe_Brown.player_FT = 0
Kobe_Brown.player_FTA = 0
Kobe_Brown.player_TRB = 11
Kobe_Brown.player_AST = 2
Kobe_Brown.player_STL = 1
Kobe_Brown.player_BLK = 1
Kobe_Brown.player_TOV = 1
Kobe_Brown.player_PF = 8
Kobe_Brown.player_PTS = 17

Moses_Brown = Player('Moses_Brown')
Moses_Brown.hasClubTeam.append(Portland_Trail_Blazers)
Moses_Brown.hasPosition.append(CE)
Moses_Brown.player_Age = 24
Moses_Brown.player_G = 3
Moses_Brown.player_MP = 14
Moses_Brown.player_MP = 14
Moses_Brown.player_FG = 3
Moses_Brown.player_FGA = 5
Moses_Brown.player_FT = 0
Moses_Brown.player_FTA = 2
Moses_Brown.player_TRB = 5
Moses_Brown.player_AST = 1
Moses_Brown.player_STL = 1
Moses_Brown.player_BLK = 1
Moses_Brown.player_TOV = 0
Moses_Brown.player_PF = 1
Moses_Brown.player_PTS = 6

Troy_Brown_Jr = Player('Troy_Brown_Jr.')
Troy_Brown_Jr.hasClubTeam.append(Minnesota_Timberwolves)
Troy_Brown_Jr.hasPosition.append(SF)
Troy_Brown_Jr.player_Age = 24
Troy_Brown_Jr.player_G = 13
Troy_Brown_Jr.player_MP = 146
Troy_Brown_Jr.player_MP = 146
Troy_Brown_Jr.player_FG = 15
Troy_Brown_Jr.player_FGA = 37
Troy_Brown_Jr.player_FT = 17
Troy_Brown_Jr.player_FTA = 20
Troy_Brown_Jr.player_TRB = 36
Troy_Brown_Jr.player_AST = 7
Troy_Brown_Jr.player_STL = 3
Troy_Brown_Jr.player_BLK = 1
Troy_Brown_Jr.player_TOV = 5
Troy_Brown_Jr.player_PF = 8
Troy_Brown_Jr.player_PTS = 54

Jalen_Brunson = Player('Jalen_Brunson')
Jalen_Brunson.hasClubTeam.append(New_York_Knicks)
Jalen_Brunson.hasPosition.append(PG)
Jalen_Brunson.player_Age = 27
Jalen_Brunson.player_G = 17
Jalen_Brunson.player_MP = 599
Jalen_Brunson.player_MP = 599
Jalen_Brunson.player_FG = 147
Jalen_Brunson.player_FGA = 317
Jalen_Brunson.player_FT = 63
Jalen_Brunson.player_FTA = 77
Jalen_Brunson.player_TRB = 60
Jalen_Brunson.player_AST = 89
Jalen_Brunson.player_STL = 17
Jalen_Brunson.player_BLK = 1
Jalen_Brunson.player_TOV = 34
Jalen_Brunson.player_PF = 36
Jalen_Brunson.player_PTS = 410

Thomas_Bryant = Player('Thomas_Bryant')
Thomas_Bryant.hasClubTeam.append(Miami_Heat)
Thomas_Bryant.hasPosition.append(CE)
Thomas_Bryant.player_Age = 26
Thomas_Bryant.player_G = 12
Thomas_Bryant.player_MP = 162
Thomas_Bryant.player_MP = 162
Thomas_Bryant.player_FG = 26
Thomas_Bryant.player_FGA = 53
Thomas_Bryant.player_FT = 12
Thomas_Bryant.player_FTA = 15
Thomas_Bryant.player_TRB = 45
Thomas_Bryant.player_AST = 7
Thomas_Bryant.player_STL = 6
Thomas_Bryant.player_BLK = 4
Thomas_Bryant.player_TOV = 12
Thomas_Bryant.player_PF = 16
Thomas_Bryant.player_PTS = 64

Kobe_Bufkin = Player('Kobe_Bufkin')
Kobe_Bufkin.hasClubTeam.append(Atlanta_Hawks)
Kobe_Bufkin.hasPosition.append(SG)
Kobe_Bufkin.player_Age = 20
Kobe_Bufkin.player_G = 2
Kobe_Bufkin.player_MP = 4
Kobe_Bufkin.player_MP = 4
Kobe_Bufkin.player_FG = 0
Kobe_Bufkin.player_FGA = 3
Kobe_Bufkin.player_FT = 1
Kobe_Bufkin.player_FTA = 2
Kobe_Bufkin.player_TRB = 2
Kobe_Bufkin.player_AST = 0
Kobe_Bufkin.player_STL = 0
Kobe_Bufkin.player_BLK = 0
Kobe_Bufkin.player_TOV = 0
Kobe_Bufkin.player_PF = 0
Kobe_Bufkin.player_PTS = 1

Reggie_Bullock = Player('Reggie_Bullock')
Reggie_Bullock.hasClubTeam.append(Houston_Rockets)
Reggie_Bullock.hasPosition.append(SF)
Reggie_Bullock.player_Age = 32
Reggie_Bullock.player_G = 7
Reggie_Bullock.player_MP = 64
Reggie_Bullock.player_MP = 64
Reggie_Bullock.player_FG = 2
Reggie_Bullock.player_FGA = 11
Reggie_Bullock.player_FT = 0
Reggie_Bullock.player_FTA = 0
Reggie_Bullock.player_TRB = 12
Reggie_Bullock.player_AST = 3
Reggie_Bullock.player_STL = 1
Reggie_Bullock.player_BLK = 1
Reggie_Bullock.player_TOV = 2
Reggie_Bullock.player_PF = 4
Reggie_Bullock.player_PTS = 6

Alec_Burks = Player('Alec_Burks')
Alec_Burks.hasClubTeam.append(Detroit_Pistons)
Alec_Burks.hasPosition.append(SG)
Alec_Burks.player_Age = 32
Alec_Burks.player_G = 11
Alec_Burks.player_MP = 236
Alec_Burks.player_MP = 236
Alec_Burks.player_FG = 36
Alec_Burks.player_FGA = 100
Alec_Burks.player_FT = 36
Alec_Burks.player_FTA = 42
Alec_Burks.player_TRB = 30
Alec_Burks.player_AST = 24
Alec_Burks.player_STL = 5
Alec_Burks.player_BLK = 4
Alec_Burks.player_TOV = 5
Alec_Burks.player_PF = 20
Alec_Burks.player_PTS = 133

Jared_Butler = Player('Jared_Butler')
Jared_Butler.hasClubTeam.append(Washington_Wizards)
Jared_Butler.hasPosition.append(SG)
Jared_Butler.player_Age = 23
Jared_Butler.player_G = 6
Jared_Butler.player_MP = 31
Jared_Butler.player_MP = 31
Jared_Butler.player_FG = 6
Jared_Butler.player_FGA = 13
Jared_Butler.player_FT = 1
Jared_Butler.player_FTA = 1
Jared_Butler.player_TRB = 3
Jared_Butler.player_AST = 6
Jared_Butler.player_STL = 2
Jared_Butler.player_BLK = 1
Jared_Butler.player_TOV = 3
Jared_Butler.player_PF = 5
Jared_Butler.player_PTS = 16

Jimmy_Butler = Player('Jimmy_Butler')
Jimmy_Butler.hasClubTeam.append(Miami_Heat)
Jimmy_Butler.hasPosition.append(PF)
Jimmy_Butler.player_Age = 34
Jimmy_Butler.player_G = 14
Jimmy_Butler.player_MP = 466
Jimmy_Butler.player_MP = 466
Jimmy_Butler.player_FG = 90
Jimmy_Butler.player_FGA = 195
Jimmy_Butler.player_FT = 93
Jimmy_Butler.player_FTA = 106
Jimmy_Butler.player_TRB = 70
Jimmy_Butler.player_AST = 56
Jimmy_Butler.player_STL = 19
Jimmy_Butler.player_BLK = 8
Jimmy_Butler.player_TOV = 24
Jimmy_Butler.player_PF = 11
Jimmy_Butler.player_PTS = 290

Jamal_Cain = Player('Jamal_Cain')
Jamal_Cain.hasClubTeam.append(Miami_Heat)
Jamal_Cain.hasPosition.append(PF)
Jamal_Cain.player_Age = 24
Jamal_Cain.player_G = 5
Jamal_Cain.player_MP = 70
Jamal_Cain.player_MP = 70
Jamal_Cain.player_FG = 8
Jamal_Cain.player_FGA = 17
Jamal_Cain.player_FT = 2
Jamal_Cain.player_FTA = 5
Jamal_Cain.player_TRB = 9
Jamal_Cain.player_AST = 0
Jamal_Cain.player_STL = 4
Jamal_Cain.player_BLK = 0
Jamal_Cain.player_TOV = 2
Jamal_Cain.player_PF = 3
Jamal_Cain.player_PTS = 20

Kentavious_Caldwell_Pope = Player('Kentavious_Caldwell-Pope')
Kentavious_Caldwell_Pope.hasClubTeam.append(Denver_Nuggets)
Kentavious_Caldwell_Pope.hasPosition.append(SG)
Kentavious_Caldwell_Pope.player_Age = 30
Kentavious_Caldwell_Pope.player_G = 18
Kentavious_Caldwell_Pope.player_MP = 616
Kentavious_Caldwell_Pope.player_MP = 616
Kentavious_Caldwell_Pope.player_FG = 68
Kentavious_Caldwell_Pope.player_FGA = 154
Kentavious_Caldwell_Pope.player_FT = 37
Kentavious_Caldwell_Pope.player_FTA = 39
Kentavious_Caldwell_Pope.player_TRB = 36
Kentavious_Caldwell_Pope.player_AST = 47
Kentavious_Caldwell_Pope.player_STL = 28
Kentavious_Caldwell_Pope.player_BLK = 9
Kentavious_Caldwell_Pope.player_TOV = 24
Kentavious_Caldwell_Pope.player_PF = 42
Kentavious_Caldwell_Pope.player_PTS = 201

Toumani_Camara = Player('Toumani_Camara')
Toumani_Camara.hasClubTeam.append(Portland_Trail_Blazers)
Toumani_Camara.hasPosition.append(PF)
Toumani_Camara.player_Age = 23
Toumani_Camara.player_G = 17
Toumani_Camara.player_MP = 419
Toumani_Camara.player_MP = 419
Toumani_Camara.player_FG = 35
Toumani_Camara.player_FGA = 91
Toumani_Camara.player_FT = 20
Toumani_Camara.player_FTA = 27
Toumani_Camara.player_TRB = 72
Toumani_Camara.player_AST = 19
Toumani_Camara.player_STL = 12
Toumani_Camara.player_BLK = 10
Toumani_Camara.player_TOV = 19
Toumani_Camara.player_PF = 44
Toumani_Camara.player_PTS = 103

Clint_Capela = Player('Clint_Capela')
Clint_Capela.hasClubTeam.append(Atlanta_Hawks)
Clint_Capela.hasPosition.append(CE)
Clint_Capela.player_Age = 29
Clint_Capela.player_G = 17
Clint_Capela.player_MP = 413
Clint_Capela.player_MP = 413
Clint_Capela.player_FG = 77
Clint_Capela.player_FGA = 131
Clint_Capela.player_FT = 26
Clint_Capela.player_FTA = 44
Clint_Capela.player_TRB = 166
Clint_Capela.player_AST = 15
Clint_Capela.player_STL = 13
Clint_Capela.player_BLK = 28
Clint_Capela.player_TOV = 12
Clint_Capela.player_PF = 35
Clint_Capela.player_PTS = 180

Jevon_Carter = Player('Jevon_Carter')
Jevon_Carter.hasClubTeam.append(Chicago_Bulls)
Jevon_Carter.hasPosition.append(PG)
Jevon_Carter.player_Age = 28
Jevon_Carter.player_G = 19
Jevon_Carter.player_MP = 271
Jevon_Carter.player_MP = 271
Jevon_Carter.player_FG = 39
Jevon_Carter.player_FGA = 102
Jevon_Carter.player_FT = 0
Jevon_Carter.player_FTA = 1
Jevon_Carter.player_TRB = 10
Jevon_Carter.player_AST = 22
Jevon_Carter.player_STL = 8
Jevon_Carter.player_BLK = 6
Jevon_Carter.player_TOV = 13
Jevon_Carter.player_PF = 21
Jevon_Carter.player_PTS = 102

Wendell_Carter_Jr = Player('Wendell_Carter_Jr.')
Wendell_Carter_Jr.hasClubTeam.append(Orlando_Magic)
Wendell_Carter_Jr.hasPosition.append(CE)
Wendell_Carter_Jr.player_Age = 24
Wendell_Carter_Jr.player_G = 5
Wendell_Carter_Jr.player_MP = 147
Wendell_Carter_Jr.player_MP = 147
Wendell_Carter_Jr.player_FG = 17
Wendell_Carter_Jr.player_FGA = 45
Wendell_Carter_Jr.player_FT = 8
Wendell_Carter_Jr.player_FTA = 14
Wendell_Carter_Jr.player_TRB = 43
Wendell_Carter_Jr.player_AST = 8
Wendell_Carter_Jr.player_STL = 3
Wendell_Carter_Jr.player_BLK = 2
Wendell_Carter_Jr.player_TOV = 8
Wendell_Carter_Jr.player_PF = 14
Wendell_Carter_Jr.player_PTS = 47

Alex_Caruso = Player('Alex_Caruso')
Alex_Caruso.hasClubTeam.append(Chicago_Bulls)
Alex_Caruso.hasPosition.append(SG)
Alex_Caruso.player_Age = 29
Alex_Caruso.player_G = 16
Alex_Caruso.player_MP = 379
Alex_Caruso.player_MP = 379
Alex_Caruso.player_FG = 54
Alex_Caruso.player_FGA = 99
Alex_Caruso.player_FT = 21
Alex_Caruso.player_FTA = 27
Alex_Caruso.player_TRB = 56
Alex_Caruso.player_AST = 35
Alex_Caruso.player_STL = 23
Alex_Caruso.player_BLK = 12
Alex_Caruso.player_TOV = 16
Alex_Caruso.player_PF = 38
Alex_Caruso.player_PTS = 155

Colin_Castleton = Player('Colin_Castleton')
Colin_Castleton.hasClubTeam.append(Los_Angeles_Lakers)
Colin_Castleton.hasPosition.append(CE)
Colin_Castleton.player_Age = 23
Colin_Castleton.player_G = 2
Colin_Castleton.player_MP = 19
Colin_Castleton.player_MP = 19
Colin_Castleton.player_FG = 2
Colin_Castleton.player_FGA = 4
Colin_Castleton.player_FT = 0
Colin_Castleton.player_FTA = 0
Colin_Castleton.player_TRB = 3
Colin_Castleton.player_AST = 2
Colin_Castleton.player_STL = 0
Colin_Castleton.player_BLK = 0
Colin_Castleton.player_TOV = 0
Colin_Castleton.player_PF = 5
Colin_Castleton.player_PTS = 4

Malcolm_Cazalon = Player('Malcolm_Cazalon')
Malcolm_Cazalon.hasClubTeam.append(Detroit_Pistons)
Malcolm_Cazalon.hasPosition.append(SG)
Malcolm_Cazalon.player_Age = 22
Malcolm_Cazalon.player_G = 1
Malcolm_Cazalon.player_MP = 3
Malcolm_Cazalon.player_MP = 3
Malcolm_Cazalon.player_FG = 0
Malcolm_Cazalon.player_FGA = 0
Malcolm_Cazalon.player_FT = 0
Malcolm_Cazalon.player_FTA = 0
Malcolm_Cazalon.player_TRB = 0
Malcolm_Cazalon.player_AST = 0
Malcolm_Cazalon.player_STL = 0
Malcolm_Cazalon.player_BLK = 0
Malcolm_Cazalon.player_TOV = 0
Malcolm_Cazalon.player_PF = 0
Malcolm_Cazalon.player_PTS = 0

Julian_Champagnie = Player('Julian_Champagnie')
Julian_Champagnie.hasClubTeam.append(San_Antonio_Spurs)
Julian_Champagnie.hasPosition.append(SF)
Julian_Champagnie.player_Age = 22
Julian_Champagnie.player_G = 10
Julian_Champagnie.player_MP = 152
Julian_Champagnie.player_MP = 152
Julian_Champagnie.player_FG = 18
Julian_Champagnie.player_FGA = 58
Julian_Champagnie.player_FT = 7
Julian_Champagnie.player_FTA = 10
Julian_Champagnie.player_TRB = 16
Julian_Champagnie.player_AST = 10
Julian_Champagnie.player_STL = 6
Julian_Champagnie.player_BLK = 9
Julian_Champagnie.player_TOV = 9
Julian_Champagnie.player_PF = 6
Julian_Champagnie.player_PTS = 55

Max_Christie = Player('Max_Christie')
Max_Christie.hasClubTeam.append(Los_Angeles_Lakers)
Max_Christie.hasPosition.append(SG)
Max_Christie.player_Age = 20
Max_Christie.player_G = 13
Max_Christie.player_MP = 220
Max_Christie.player_MP = 220
Max_Christie.player_FG = 23
Max_Christie.player_FGA = 58
Max_Christie.player_FT = 4
Max_Christie.player_FTA = 5
Max_Christie.player_TRB = 38
Max_Christie.player_AST = 13
Max_Christie.player_STL = 5
Max_Christie.player_BLK = 2
Max_Christie.player_TOV = 9
Max_Christie.player_PF = 17
Max_Christie.player_PTS = 56

Sidy_Cissoko = Player('Sidy_Cissoko')
Sidy_Cissoko.hasClubTeam.append(San_Antonio_Spurs)
Sidy_Cissoko.hasPosition.append(SF)
Sidy_Cissoko.player_Age = 19
Sidy_Cissoko.player_G = 1
Sidy_Cissoko.player_MP = 4
Sidy_Cissoko.player_MP = 4
Sidy_Cissoko.player_FG = 0
Sidy_Cissoko.player_FGA = 0
Sidy_Cissoko.player_FT = 0
Sidy_Cissoko.player_FTA = 0
Sidy_Cissoko.player_TRB = 0
Sidy_Cissoko.player_AST = 0
Sidy_Cissoko.player_STL = 0
Sidy_Cissoko.player_BLK = 0
Sidy_Cissoko.player_TOV = 1
Sidy_Cissoko.player_PF = 0
Sidy_Cissoko.player_PTS = 0

Jordan_Clarkson = Player('Jordan_Clarkson')
Jordan_Clarkson.hasClubTeam.append(Utah_Jazz)
Jordan_Clarkson.hasPosition.append(SG)
Jordan_Clarkson.player_Age = 31
Jordan_Clarkson.player_G = 16
Jordan_Clarkson.player_MP = 509
Jordan_Clarkson.player_MP = 509
Jordan_Clarkson.player_FG = 106
Jordan_Clarkson.player_FGA = 256
Jordan_Clarkson.player_FT = 49
Jordan_Clarkson.player_FTA = 58
Jordan_Clarkson.player_TRB = 53
Jordan_Clarkson.player_AST = 79
Jordan_Clarkson.player_STL = 14
Jordan_Clarkson.player_BLK = 2
Jordan_Clarkson.player_TOV = 50
Jordan_Clarkson.player_PF = 24
Jordan_Clarkson.player_PTS = 290

Nic_Claxton = Player('Nic_Claxton')
Nic_Claxton.hasClubTeam.append(Brooklyn_Nets)
Nic_Claxton.hasPosition.append(CE)
Nic_Claxton.player_Age = 24
Nic_Claxton.player_G = 8
Nic_Claxton.player_MP = 218
Nic_Claxton.player_MP = 218
Nic_Claxton.player_FG = 45
Nic_Claxton.player_FGA = 67
Nic_Claxton.player_FT = 11
Nic_Claxton.player_FTA = 20
Nic_Claxton.player_TRB = 66
Nic_Claxton.player_AST = 12
Nic_Claxton.player_STL = 5
Nic_Claxton.player_BLK = 23
Nic_Claxton.player_TOV = 6
Nic_Claxton.player_PF = 20
Nic_Claxton.player_PTS = 101

Noah_Clowney = Player('Noah_Clowney')
Noah_Clowney.hasClubTeam.append(Brooklyn_Nets)
Noah_Clowney.hasPosition.append(PF)
Noah_Clowney.player_Age = 19
Noah_Clowney.player_G = 1
Noah_Clowney.player_MP = 3
Noah_Clowney.player_MP = 3
Noah_Clowney.player_FG = 0
Noah_Clowney.player_FGA = 0
Noah_Clowney.player_FT = 0
Noah_Clowney.player_FTA = 0
Noah_Clowney.player_TRB = 1
Noah_Clowney.player_AST = 0
Noah_Clowney.player_STL = 0
Noah_Clowney.player_BLK = 0
Noah_Clowney.player_TOV = 0
Noah_Clowney.player_PF = 0
Noah_Clowney.player_PTS = 0

Amir_Coffey = Player('Amir_Coffey')
Amir_Coffey.hasClubTeam.append(Los_Angeles_Clippers)
Amir_Coffey.hasPosition.append(SF)
Amir_Coffey.player_Age = 26
Amir_Coffey.player_G = 8
Amir_Coffey.player_MP = 56
Amir_Coffey.player_MP = 56
Amir_Coffey.player_FG = 4
Amir_Coffey.player_FGA = 12
Amir_Coffey.player_FT = 4
Amir_Coffey.player_FTA = 4
Amir_Coffey.player_TRB = 7
Amir_Coffey.player_AST = 3
Amir_Coffey.player_STL = 1
Amir_Coffey.player_BLK = 0
Amir_Coffey.player_TOV = 2
Amir_Coffey.player_PF = 3
Amir_Coffey.player_PTS = 12

John_Collins = Player('John_Collins')
John_Collins.hasClubTeam.append(Utah_Jazz)
John_Collins.hasPosition.append(PF)
John_Collins.player_Age = 26
John_Collins.player_G = 17
John_Collins.player_MP = 531
John_Collins.player_MP = 531
John_Collins.player_FG = 93
John_Collins.player_FGA = 188
John_Collins.player_FT = 34
John_Collins.player_FTA = 47
John_Collins.player_TRB = 143
John_Collins.player_AST = 14
John_Collins.player_STL = 10
John_Collins.player_BLK = 14
John_Collins.player_TOV = 20
John_Collins.player_PF = 51
John_Collins.player_PTS = 245

Zach_Collins = Player('Zach_Collins')
Zach_Collins.hasClubTeam.append(San_Antonio_Spurs)
Zach_Collins.hasPosition.append(CE)
Zach_Collins.player_Age = 26
Zach_Collins.player_G = 17
Zach_Collins.player_MP = 496
Zach_Collins.player_MP = 496
Zach_Collins.player_FG = 92
Zach_Collins.player_FGA = 183
Zach_Collins.player_FT = 37
Zach_Collins.player_FTA = 47
Zach_Collins.player_TRB = 107
Zach_Collins.player_AST = 64
Zach_Collins.player_STL = 12
Zach_Collins.player_BLK = 13
Zach_Collins.player_TOV = 47
Zach_Collins.player_PF = 62
Zach_Collins.player_PTS = 240

Mike_Conley = Player('Mike_Conley')
Mike_Conley.hasClubTeam.append(Minnesota_Timberwolves)
Mike_Conley.hasPosition.append(PG)
Mike_Conley.player_Age = 36
Mike_Conley.player_G = 17
Mike_Conley.player_MP = 496
Mike_Conley.player_MP = 496
Mike_Conley.player_FG = 62
Mike_Conley.player_FGA = 138
Mike_Conley.player_FT = 14
Mike_Conley.player_FTA = 14
Mike_Conley.player_TRB = 47
Mike_Conley.player_AST = 101
Mike_Conley.player_STL = 16
Mike_Conley.player_BLK = 2
Mike_Conley.player_TOV = 14
Mike_Conley.player_PF = 30
Mike_Conley.player_PTS = 175

Pat_Connaughton = Player('Pat_Connaughton')
Pat_Connaughton.hasClubTeam.append(Milwaukee_Bucks)
Pat_Connaughton.hasPosition.append(SF)
Pat_Connaughton.player_Age = 31
Pat_Connaughton.player_G = 18
Pat_Connaughton.player_MP = 416
Pat_Connaughton.player_MP = 416
Pat_Connaughton.player_FG = 38
Pat_Connaughton.player_FGA = 90
Pat_Connaughton.player_FT = 8
Pat_Connaughton.player_FTA = 12
Pat_Connaughton.player_TRB = 63
Pat_Connaughton.player_AST = 36
Pat_Connaughton.player_STL = 9
Pat_Connaughton.player_BLK = 3
Pat_Connaughton.player_TOV = 14
Pat_Connaughton.player_PF = 19
Pat_Connaughton.player_PTS = 104

Bilal_Coulibaly = Player('Bilal_Coulibaly')
Bilal_Coulibaly.hasClubTeam.append(Washington_Wizards)
Bilal_Coulibaly.hasPosition.append(SF)
Bilal_Coulibaly.player_Age = 19
Bilal_Coulibaly.player_G = 16
Bilal_Coulibaly.player_MP = 417
Bilal_Coulibaly.player_MP = 417
Bilal_Coulibaly.player_FG = 48
Bilal_Coulibaly.player_FGA = 96
Bilal_Coulibaly.player_FT = 14
Bilal_Coulibaly.player_FTA = 22
Bilal_Coulibaly.player_TRB = 58
Bilal_Coulibaly.player_AST = 29
Bilal_Coulibaly.player_STL = 16
Bilal_Coulibaly.player_BLK = 13
Bilal_Coulibaly.player_TOV = 22
Bilal_Coulibaly.player_PF = 31
Bilal_Coulibaly.player_PTS = 129

Robert_Covington = Player('Robert_Covington')
Robert_Covington.hasClubTeam.append(Toronto_Raptors)
Robert_Covington.hasPosition.append(SF)
Robert_Covington.player_Age = 33
Robert_Covington.player_G = 17
Robert_Covington.player_MP = 296
Robert_Covington.player_MP = 296
Robert_Covington.player_FG = 26
Robert_Covington.player_FGA = 63
Robert_Covington.player_FT = 11
Robert_Covington.player_FTA = 14
Robert_Covington.player_TRB = 57
Robert_Covington.player_AST = 16
Robert_Covington.player_STL = 24
Robert_Covington.player_BLK = 13
Robert_Covington.player_TOV = 4
Robert_Covington.player_PF = 31
Robert_Covington.player_PTS = 73

Torrey_Craig = Player('Torrey_Craig')
Torrey_Craig.hasClubTeam.append(Chicago_Bulls)
Torrey_Craig.hasPosition.append(SF)
Torrey_Craig.player_Age = 33
Torrey_Craig.player_G = 19
Torrey_Craig.player_MP = 403
Torrey_Craig.player_MP = 403
Torrey_Craig.player_FG = 33
Torrey_Craig.player_FGA = 84
Torrey_Craig.player_FT = 10
Torrey_Craig.player_FTA = 11
Torrey_Craig.player_TRB = 89
Torrey_Craig.player_AST = 20
Torrey_Craig.player_STL = 11
Torrey_Craig.player_BLK = 7
Torrey_Craig.player_TOV = 11
Torrey_Craig.player_PF = 43
Torrey_Craig.player_PTS = 88

Jae_Crowder = Player('Jae_Crowder')
Jae_Crowder.hasClubTeam.append(Milwaukee_Bucks)
Jae_Crowder.hasPosition.append(PF)
Jae_Crowder.player_Age = 33
Jae_Crowder.player_G = 9
Jae_Crowder.player_MP = 240
Jae_Crowder.player_MP = 240
Jae_Crowder.player_FG = 25
Jae_Crowder.player_FGA = 47
Jae_Crowder.player_FT = 7
Jae_Crowder.player_FTA = 12
Jae_Crowder.player_TRB = 35
Jae_Crowder.player_AST = 15
Jae_Crowder.player_STL = 7
Jae_Crowder.player_BLK = 3
Jae_Crowder.player_TOV = 4
Jae_Crowder.player_PF = 14
Jae_Crowder.player_PTS = 73

Cade_Cunningham = Player('Cade_Cunningham')
Cade_Cunningham.hasClubTeam.append(Detroit_Pistons)
Cade_Cunningham.hasPosition.append(PG)
Cade_Cunningham.player_Age = 22
Cade_Cunningham.player_G = 17
Cade_Cunningham.player_MP = 603
Cade_Cunningham.player_MP = 603
Cade_Cunningham.player_FG = 139
Cade_Cunningham.player_FGA = 342
Cade_Cunningham.player_FT = 67
Cade_Cunningham.player_FTA = 75
Cade_Cunningham.player_TRB = 63
Cade_Cunningham.player_AST = 121
Cade_Cunningham.player_STL = 13
Cade_Cunningham.player_BLK = 4
Cade_Cunningham.player_TOV = 77
Cade_Cunningham.player_PF = 50
Cade_Cunningham.player_PTS = 378

Seth_Curry = Player('Seth_Curry')
Seth_Curry.hasClubTeam.append(Dallas_Mavericks)
Seth_Curry.hasPosition.append(SG)
Seth_Curry.player_Age = 33
Seth_Curry.player_G = 12
Seth_Curry.player_MP = 109
Seth_Curry.player_MP = 109
Seth_Curry.player_FG = 13
Seth_Curry.player_FGA = 33
Seth_Curry.player_FT = 6
Seth_Curry.player_FTA = 7
Seth_Curry.player_TRB = 13
Seth_Curry.player_AST = 8
Seth_Curry.player_STL = 6
Seth_Curry.player_BLK = 1
Seth_Curry.player_TOV = 4
Seth_Curry.player_PF = 8
Seth_Curry.player_PTS = 37

Stephen_Curry = Player('Stephen_Curry')
Stephen_Curry.hasClubTeam.append(Golden_State_Warriors)
Stephen_Curry.hasPosition.append(PG)
Stephen_Curry.player_Age = 35
Stephen_Curry.player_G = 16
Stephen_Curry.player_MP = 532
Stephen_Curry.player_MP = 532
Stephen_Curry.player_FG = 146
Stephen_Curry.player_FGA = 305
Stephen_Curry.player_FT = 99
Stephen_Curry.player_FTA = 105
Stephen_Curry.player_TRB = 79
Stephen_Curry.player_AST = 65
Stephen_Curry.player_STL = 12
Stephen_Curry.player_BLK = 3
Stephen_Curry.player_TOV = 60
Stephen_Curry.player_PF = 30
Stephen_Curry.player_PTS = 475

Dyson_Daniels = Player('Dyson_Daniels')
Dyson_Daniels.hasClubTeam.append(New_Orleans_Pelicans)
Dyson_Daniels.hasPosition.append(PG)
Dyson_Daniels.player_Age = 20
Dyson_Daniels.player_G = 18
Dyson_Daniels.player_MP = 506
Dyson_Daniels.player_MP = 506
Dyson_Daniels.player_FG = 56
Dyson_Daniels.player_FGA = 137
Dyson_Daniels.player_FT = 15
Dyson_Daniels.player_FTA = 24
Dyson_Daniels.player_TRB = 92
Dyson_Daniels.player_AST = 68
Dyson_Daniels.player_STL = 28
Dyson_Daniels.player_BLK = 7
Dyson_Daniels.player_TOV = 27
Dyson_Daniels.player_PF = 37
Dyson_Daniels.player_PTS = 142

Anthony_Davis = Player('Anthony_Davis')
Anthony_Davis.hasClubTeam.append(Los_Angeles_Lakers)
Anthony_Davis.hasPosition.append(CE)
Anthony_Davis.player_Age = 30
Anthony_Davis.player_G = 17
Anthony_Davis.player_MP = 600
Anthony_Davis.player_MP = 600
Anthony_Davis.player_FG = 142
Anthony_Davis.player_FGA = 260
Anthony_Davis.player_FT = 84
Anthony_Davis.player_FTA = 99
Anthony_Davis.player_TRB = 205
Anthony_Davis.player_AST = 56
Anthony_Davis.player_STL = 18
Anthony_Davis.player_BLK = 48
Anthony_Davis.player_TOV = 41
Anthony_Davis.player_PF = 53
Anthony_Davis.player_PTS = 371

Johnny_Davis = Player('Johnny_Davis')
Johnny_Davis.hasClubTeam.append(Washington_Wizards)
Johnny_Davis.hasPosition.append(SG)
Johnny_Davis.player_Age = 21
Johnny_Davis.player_G = 12
Johnny_Davis.player_MP = 112
Johnny_Davis.player_MP = 112
Johnny_Davis.player_FG = 19
Johnny_Davis.player_FGA = 37
Johnny_Davis.player_FT = 4
Johnny_Davis.player_FTA = 5
Johnny_Davis.player_TRB = 17
Johnny_Davis.player_AST = 5
Johnny_Davis.player_STL = 6
Johnny_Davis.player_BLK = 1
Johnny_Davis.player_TOV = 5
Johnny_Davis.player_PF = 8
Johnny_Davis.player_PTS = 43

DeMar_DeRozan = Player('DeMar_DeRozan')
DeMar_DeRozan.hasClubTeam.append(Chicago_Bulls)
DeMar_DeRozan.hasPosition.append(SF)
DeMar_DeRozan.player_Age = 34
DeMar_DeRozan.player_G = 18
DeMar_DeRozan.player_MP = 633
DeMar_DeRozan.player_MP = 633
DeMar_DeRozan.player_FG = 135
DeMar_DeRozan.player_FGA = 300
DeMar_DeRozan.player_FT = 98
DeMar_DeRozan.player_FTA = 121
DeMar_DeRozan.player_TRB = 58
DeMar_DeRozan.player_AST = 83
DeMar_DeRozan.player_STL = 18
DeMar_DeRozan.player_BLK = 15
DeMar_DeRozan.player_TOV = 21
DeMar_DeRozan.player_PF = 37
DeMar_DeRozan.player_PTS = 384

Moussa_Diabaté = Player('Moussa_Diabaté')
Moussa_Diabaté.hasClubTeam.append(Los_Angeles_Clippers)
Moussa_Diabaté.hasPosition.append(CE)
Moussa_Diabaté.player_Age = 22
Moussa_Diabaté.player_G = 8
Moussa_Diabaté.player_MP = 54
Moussa_Diabaté.player_MP = 54
Moussa_Diabaté.player_FG = 9
Moussa_Diabaté.player_FGA = 18
Moussa_Diabaté.player_FT = 7
Moussa_Diabaté.player_FTA = 10
Moussa_Diabaté.player_TRB = 19
Moussa_Diabaté.player_AST = 4
Moussa_Diabaté.player_STL = 4
Moussa_Diabaté.player_BLK = 0
Moussa_Diabaté.player_TOV = 2
Moussa_Diabaté.player_PF = 4
Moussa_Diabaté.player_PTS = 25

Gradey_Dick = Player('Gradey_Dick')
Gradey_Dick.hasClubTeam.append(Toronto_Raptors)
Gradey_Dick.hasPosition.append(SG)
Gradey_Dick.player_Age = 20
Gradey_Dick.player_G = 15
Gradey_Dick.player_MP = 220
Gradey_Dick.player_MP = 220
Gradey_Dick.player_FG = 17
Gradey_Dick.player_FGA = 63
Gradey_Dick.player_FT = 14
Gradey_Dick.player_FTA = 14
Gradey_Dick.player_TRB = 22
Gradey_Dick.player_AST = 15
Gradey_Dick.player_STL = 4
Gradey_Dick.player_BLK = 0
Gradey_Dick.player_TOV = 12
Gradey_Dick.player_PF = 23
Gradey_Dick.player_PTS = 58

Ousmane_Dieng = Player('Ousmane_Dieng')
Ousmane_Dieng.hasClubTeam.append(Oklahoma_City_Thunder)
Ousmane_Dieng.hasPosition.append(PF)
Ousmane_Dieng.player_Age = 20
Ousmane_Dieng.player_G = 12
Ousmane_Dieng.player_MP = 122
Ousmane_Dieng.player_MP = 122
Ousmane_Dieng.player_FG = 13
Ousmane_Dieng.player_FGA = 37
Ousmane_Dieng.player_FT = 3
Ousmane_Dieng.player_FTA = 4
Ousmane_Dieng.player_TRB = 22
Ousmane_Dieng.player_AST = 11
Ousmane_Dieng.player_STL = 1
Ousmane_Dieng.player_BLK = 0
Ousmane_Dieng.player_TOV = 4
Ousmane_Dieng.player_PF = 7
Ousmane_Dieng.player_PTS = 36

Spencer_Dinwiddie = Player('Spencer_Dinwiddie')
Spencer_Dinwiddie.hasClubTeam.append(Brooklyn_Nets)
Spencer_Dinwiddie.hasPosition.append(PG)
Spencer_Dinwiddie.player_Age = 30
Spencer_Dinwiddie.player_G = 16
Spencer_Dinwiddie.player_MP = 496
Spencer_Dinwiddie.player_MP = 496
Spencer_Dinwiddie.player_FG = 72
Spencer_Dinwiddie.player_FGA = 179
Spencer_Dinwiddie.player_FT = 52
Spencer_Dinwiddie.player_FTA = 65
Spencer_Dinwiddie.player_TRB = 64
Spencer_Dinwiddie.player_AST = 102
Spencer_Dinwiddie.player_STL = 11
Spencer_Dinwiddie.player_BLK = 2
Spencer_Dinwiddie.player_TOV = 27
Spencer_Dinwiddie.player_PF = 26
Spencer_Dinwiddie.player_PTS = 234

Donte_DiVincenzo = Player('Donte_DiVincenzo')
Donte_DiVincenzo.hasClubTeam.append(New_York_Knicks)
Donte_DiVincenzo.hasPosition.append(SG)
Donte_DiVincenzo.player_Age = 27
Donte_DiVincenzo.player_G = 17
Donte_DiVincenzo.player_MP = 344
Donte_DiVincenzo.player_MP = 344
Donte_DiVincenzo.player_FG = 49
Donte_DiVincenzo.player_FGA = 123
Donte_DiVincenzo.player_FT = 11
Donte_DiVincenzo.player_FTA = 17
Donte_DiVincenzo.player_TRB = 50
Donte_DiVincenzo.player_AST = 29
Donte_DiVincenzo.player_STL = 18
Donte_DiVincenzo.player_BLK = 5
Donte_DiVincenzo.player_TOV = 21
Donte_DiVincenzo.player_PF = 25
Donte_DiVincenzo.player_PTS = 141

Luka_Doncic = Player('Luka_Doncic')
Luka_Doncic.hasClubTeam.append(Dallas_Mavericks)
Luka_Doncic.hasPosition.append(PG)
Luka_Doncic.player_Age = 24
Luka_Doncic.player_G = 17
Luka_Doncic.player_MP = 599
Luka_Doncic.player_MP = 599
Luka_Doncic.player_FG = 183
Luka_Doncic.player_FGA = 374
Luka_Doncic.player_FT = 99
Luka_Doncic.player_FTA = 128
Luka_Doncic.player_TRB = 136
Luka_Doncic.player_AST = 134
Luka_Doncic.player_STL = 22
Luka_Doncic.player_BLK = 7
Luka_Doncic.player_TOV = 62
Luka_Doncic.player_PF = 31
Luka_Doncic.player_PTS = 529

Luguentz_Dort = Player('Luguentz_Dort')
Luguentz_Dort.hasClubTeam.append(Oklahoma_City_Thunder)
Luguentz_Dort.hasPosition.append(SF)
Luguentz_Dort.player_Age = 24
Luguentz_Dort.player_G = 17
Luguentz_Dort.player_MP = 477
Luguentz_Dort.player_MP = 477
Luguentz_Dort.player_FG = 57
Luguentz_Dort.player_FGA = 127
Luguentz_Dort.player_FT = 30
Luguentz_Dort.player_FTA = 38
Luguentz_Dort.player_TRB = 66
Luguentz_Dort.player_AST = 19
Luguentz_Dort.player_STL = 16
Luguentz_Dort.player_BLK = 14
Luguentz_Dort.player_TOV = 17
Luguentz_Dort.player_PF = 51
Luguentz_Dort.player_PTS = 174

Ayo_Dosunmu = Player('Ayo_Dosunmu')
Ayo_Dosunmu.hasClubTeam.append(Chicago_Bulls)
Ayo_Dosunmu.hasPosition.append(SG)
Ayo_Dosunmu.player_Age = 24
Ayo_Dosunmu.player_G = 17
Ayo_Dosunmu.player_MP = 263
Ayo_Dosunmu.player_MP = 263
Ayo_Dosunmu.player_FG = 35
Ayo_Dosunmu.player_FGA = 75
Ayo_Dosunmu.player_FT = 11
Ayo_Dosunmu.player_FTA = 14
Ayo_Dosunmu.player_TRB = 25
Ayo_Dosunmu.player_AST = 23
Ayo_Dosunmu.player_STL = 8
Ayo_Dosunmu.player_BLK = 2
Ayo_Dosunmu.player_TOV = 9
Ayo_Dosunmu.player_PF = 26
Ayo_Dosunmu.player_PTS = 94

Andre_Drummond = Player('Andre_Drummond')
Andre_Drummond.hasClubTeam.append(Chicago_Bulls)
Andre_Drummond.hasPosition.append(CE)
Andre_Drummond.player_Age = 30
Andre_Drummond.player_G = 19
Andre_Drummond.player_MP = 248
Andre_Drummond.player_MP = 248
Andre_Drummond.player_FG = 43
Andre_Drummond.player_FGA = 82
Andre_Drummond.player_FT = 19
Andre_Drummond.player_FTA = 34
Andre_Drummond.player_TRB = 114
Andre_Drummond.player_AST = 11
Andre_Drummond.player_STL = 20
Andre_Drummond.player_BLK = 6
Andre_Drummond.player_TOV = 19
Andre_Drummond.player_PF = 31
Andre_Drummond.player_PTS = 105

Chris_Duarte = Player('Chris_Duarte')
Chris_Duarte.hasClubTeam.append(Sacramento_Kings)
Chris_Duarte.hasPosition.append(SF)
Chris_Duarte.player_Age = 26
Chris_Duarte.player_G = 16
Chris_Duarte.player_MP = 243
Chris_Duarte.player_MP = 243
Chris_Duarte.player_FG = 25
Chris_Duarte.player_FGA = 65
Chris_Duarte.player_FT = 9
Chris_Duarte.player_FTA = 13
Chris_Duarte.player_TRB = 31
Chris_Duarte.player_AST = 16
Chris_Duarte.player_STL = 12
Chris_Duarte.player_BLK = 1
Chris_Duarte.player_TOV = 11
Chris_Duarte.player_PF = 45
Chris_Duarte.player_PTS = 73

Kris_Dunn = Player('Kris_Dunn')
Kris_Dunn.hasClubTeam.append(Utah_Jazz)
Kris_Dunn.hasPosition.append(PG)
Kris_Dunn.player_Age = 29
Kris_Dunn.player_G = 13
Kris_Dunn.player_MP = 134
Kris_Dunn.player_MP = 134
Kris_Dunn.player_FG = 19
Kris_Dunn.player_FGA = 44
Kris_Dunn.player_FT = 5
Kris_Dunn.player_FTA = 8
Kris_Dunn.player_TRB = 23
Kris_Dunn.player_AST = 25
Kris_Dunn.player_STL = 7
Kris_Dunn.player_BLK = 1
Kris_Dunn.player_TOV = 15
Kris_Dunn.player_PF = 17
Kris_Dunn.player_PTS = 47

Kevin_Durant = Player('Kevin_Durant')
Kevin_Durant.hasClubTeam.append(Phoenix_Suns)
Kevin_Durant.hasPosition.append(PF)
Kevin_Durant.player_Age = 35
Kevin_Durant.player_G = 15
Kevin_Durant.player_MP = 554
Kevin_Durant.player_MP = 554
Kevin_Durant.player_FG = 161
Kevin_Durant.player_FGA = 302
Kevin_Durant.player_FT = 114
Kevin_Durant.player_FTA = 128
Kevin_Durant.player_TRB = 106
Kevin_Durant.player_AST = 82
Kevin_Durant.player_STL = 11
Kevin_Durant.player_BLK = 18
Kevin_Durant.player_TOV = 60
Kevin_Durant.player_PF = 28
Kevin_Durant.player_PTS = 471

Jalen_Duren = Player('Jalen_Duren')
Jalen_Duren.hasClubTeam.append(Detroit_Pistons)
Jalen_Duren.hasPosition.append(CE)
Jalen_Duren.player_Age = 20
Jalen_Duren.player_G = 10
Jalen_Duren.player_MP = 293
Jalen_Duren.player_MP = 293
Jalen_Duren.player_FG = 56
Jalen_Duren.player_FGA = 92
Jalen_Duren.player_FT = 14
Jalen_Duren.player_FTA = 21
Jalen_Duren.player_TRB = 112
Jalen_Duren.player_AST = 32
Jalen_Duren.player_STL = 7
Jalen_Duren.player_BLK = 15
Jalen_Duren.player_TOV = 30
Jalen_Duren.player_PF = 38
Jalen_Duren.player_PTS = 126

Tari_Eason = Player('Tari_Eason')
Tari_Eason.hasClubTeam.append(Houston_Rockets)
Tari_Eason.hasPosition.append(PF)
Tari_Eason.player_Age = 22
Tari_Eason.player_G = 8
Tari_Eason.player_MP = 142
Tari_Eason.player_MP = 142
Tari_Eason.player_FG = 24
Tari_Eason.player_FGA = 50
Tari_Eason.player_FT = 3
Tari_Eason.player_FTA = 7
Tari_Eason.player_TRB = 48
Tari_Eason.player_AST = 7
Tari_Eason.player_STL = 4
Tari_Eason.player_BLK = 9
Tari_Eason.player_TOV = 6
Tari_Eason.player_PF = 18
Tari_Eason.player_PTS = 57

Anthony_Edwards = Player('Anthony_Edwards')
Anthony_Edwards.hasClubTeam.append(Minnesota_Timberwolves)
Anthony_Edwards.hasPosition.append(SG)
Anthony_Edwards.player_Age = 22
Anthony_Edwards.player_G = 17
Anthony_Edwards.player_MP = 597
Anthony_Edwards.player_MP = 597
Anthony_Edwards.player_FG = 157
Anthony_Edwards.player_FGA = 338
Anthony_Edwards.player_FT = 89
Anthony_Edwards.player_FTA = 103
Anthony_Edwards.player_TRB = 100
Anthony_Edwards.player_AST = 85
Anthony_Edwards.player_STL = 22
Anthony_Edwards.player_BLK = 8
Anthony_Edwards.player_TOV = 55
Anthony_Edwards.player_PF = 33
Anthony_Edwards.player_PTS = 446

Kessler_Edwards = Player('Kessler_Edwards')
Kessler_Edwards.hasClubTeam.append(Sacramento_Kings)
Kessler_Edwards.hasPosition.append(SF)
Kessler_Edwards.player_Age = 23
Kessler_Edwards.player_G = 13
Kessler_Edwards.player_MP = 84
Kessler_Edwards.player_MP = 84
Kessler_Edwards.player_FG = 6
Kessler_Edwards.player_FGA = 20
Kessler_Edwards.player_FT = 1
Kessler_Edwards.player_FTA = 2
Kessler_Edwards.player_TRB = 14
Kessler_Edwards.player_AST = 5
Kessler_Edwards.player_STL = 2
Kessler_Edwards.player_BLK = 2
Kessler_Edwards.player_TOV = 1
Kessler_Edwards.player_PF = 8
Kessler_Edwards.player_PTS = 17

Keon_Ellis = Player('Keon_Ellis')
Keon_Ellis.hasClubTeam.append(Sacramento_Kings)
Keon_Ellis.hasPosition.append(SG)
Keon_Ellis.player_Age = 24
Keon_Ellis.player_G = 10
Keon_Ellis.player_MP = 115
Keon_Ellis.player_MP = 115
Keon_Ellis.player_FG = 11
Keon_Ellis.player_FGA = 28
Keon_Ellis.player_FT = 6
Keon_Ellis.player_FTA = 11
Keon_Ellis.player_TRB = 16
Keon_Ellis.player_AST = 8
Keon_Ellis.player_STL = 6
Keon_Ellis.player_BLK = 4
Keon_Ellis.player_TOV = 6
Keon_Ellis.player_PF = 10
Keon_Ellis.player_PTS = 34

Joel_Embiid = Player('Joel_Embiid')
Joel_Embiid.hasClubTeam.append(Philadelphia_76ers)
Joel_Embiid.hasPosition.append(CE)
Joel_Embiid.player_Age = 29
Joel_Embiid.player_G = 16
Joel_Embiid.player_MP = 552
Joel_Embiid.player_MP = 552
Joel_Embiid.player_FG = 165
Joel_Embiid.player_FGA = 331
Joel_Embiid.player_FT = 165
Joel_Embiid.player_FTA = 188
Joel_Embiid.player_TRB = 180
Joel_Embiid.player_AST = 106
Joel_Embiid.player_STL = 16
Joel_Embiid.player_BLK = 30
Joel_Embiid.player_TOV = 59
Joel_Embiid.player_PF = 48
Joel_Embiid.player_PTS = 512

Drew_Eubanks = Player('Drew_Eubanks')
Drew_Eubanks.hasClubTeam.append(Phoenix_Suns)
Drew_Eubanks.hasPosition.append(CE)
Drew_Eubanks.player_Age = 26
Drew_Eubanks.player_G = 16
Drew_Eubanks.player_MP = 289
Drew_Eubanks.player_MP = 289
Drew_Eubanks.player_FG = 46
Drew_Eubanks.player_FGA = 74
Drew_Eubanks.player_FT = 23
Drew_Eubanks.player_FTA = 28
Drew_Eubanks.player_TRB = 73
Drew_Eubanks.player_AST = 25
Drew_Eubanks.player_STL = 3
Drew_Eubanks.player_BLK = 18
Drew_Eubanks.player_TOV = 19
Drew_Eubanks.player_PF = 35
Drew_Eubanks.player_PTS = 117

Dante_Exum = Player('Dante_Exum')
Dante_Exum.hasClubTeam.append(Dallas_Mavericks)
Dante_Exum.hasPosition.append(PG)
Dante_Exum.player_Age = 28
Dante_Exum.player_G = 16
Dante_Exum.player_MP = 170
Dante_Exum.player_MP = 170
Dante_Exum.player_FG = 32
Dante_Exum.player_FGA = 63
Dante_Exum.player_FT = 9
Dante_Exum.player_FTA = 15
Dante_Exum.player_TRB = 36
Dante_Exum.player_AST = 24
Dante_Exum.player_STL = 5
Dante_Exum.player_BLK = 2
Dante_Exum.player_TOV = 5
Dante_Exum.player_PF = 16
Dante_Exum.player_PTS = 77

Bruno_Fernando = Player('Bruno_Fernando')
Bruno_Fernando.hasClubTeam.append(Atlanta_Hawks)
Bruno_Fernando.hasPosition.append(CE)
Bruno_Fernando.player_Age = 25
Bruno_Fernando.player_G = 5
Bruno_Fernando.player_MP = 16
Bruno_Fernando.player_MP = 16
Bruno_Fernando.player_FG = 3
Bruno_Fernando.player_FGA = 9
Bruno_Fernando.player_FT = 1
Bruno_Fernando.player_FTA = 1
Bruno_Fernando.player_TRB = 4
Bruno_Fernando.player_AST = 0
Bruno_Fernando.player_STL = 0
Bruno_Fernando.player_BLK = 0
Bruno_Fernando.player_TOV = 4
Bruno_Fernando.player_PF = 3
Bruno_Fernando.player_PTS = 7

Dorian_Finney_Smith = Player('Dorian_Finney-Smith')
Dorian_Finney_Smith.hasClubTeam.append(Brooklyn_Nets)
Dorian_Finney_Smith.hasPosition.append(PF)
Dorian_Finney_Smith.player_Age = 30
Dorian_Finney_Smith.player_G = 17
Dorian_Finney_Smith.player_MP = 526
Dorian_Finney_Smith.player_MP = 526
Dorian_Finney_Smith.player_FG = 69
Dorian_Finney_Smith.player_FGA = 152
Dorian_Finney_Smith.player_FT = 1
Dorian_Finney_Smith.player_FTA = 3
Dorian_Finney_Smith.player_TRB = 93
Dorian_Finney_Smith.player_AST = 25
Dorian_Finney_Smith.player_STL = 7
Dorian_Finney_Smith.player_BLK = 11
Dorian_Finney_Smith.player_TOV = 16
Dorian_Finney_Smith.player_PF = 42
Dorian_Finney_Smith.player_PTS = 184

Malachi_Flynn = Player('Malachi_Flynn')
Malachi_Flynn.hasClubTeam.append(Toronto_Raptors)
Malachi_Flynn.hasPosition.append(PG)
Malachi_Flynn.player_Age = 25
Malachi_Flynn.player_G = 18
Malachi_Flynn.player_MP = 306
Malachi_Flynn.player_MP = 306
Malachi_Flynn.player_FG = 38
Malachi_Flynn.player_FGA = 87
Malachi_Flynn.player_FT = 10
Malachi_Flynn.player_FTA = 14
Malachi_Flynn.player_TRB = 35
Malachi_Flynn.player_AST = 38
Malachi_Flynn.player_STL = 13
Malachi_Flynn.player_BLK = 3
Malachi_Flynn.player_TOV = 18
Malachi_Flynn.player_PF = 26
Malachi_Flynn.player_PTS = 104

Simone_Fontecchio = Player('Simone_Fontecchio')
Simone_Fontecchio.hasClubTeam.append(Utah_Jazz)
Simone_Fontecchio.hasPosition.append(SF)
Simone_Fontecchio.player_Age = 28
Simone_Fontecchio.player_G = 15
Simone_Fontecchio.player_MP = 226
Simone_Fontecchio.player_MP = 226
Simone_Fontecchio.player_FG = 34
Simone_Fontecchio.player_FGA = 72
Simone_Fontecchio.player_FT = 5
Simone_Fontecchio.player_FTA = 6
Simone_Fontecchio.player_TRB = 31
Simone_Fontecchio.player_AST = 7
Simone_Fontecchio.player_STL = 5
Simone_Fontecchio.player_BLK = 5
Simone_Fontecchio.player_TOV = 14
Simone_Fontecchio.player_PF = 19
Simone_Fontecchio.player_PTS = 95

Jordan_Ford = Player('Jordan_Ford')
Jordan_Ford.hasClubTeam.append(Sacramento_Kings)
Jordan_Ford.hasPosition.append(PG)
Jordan_Ford.player_Age = 25
Jordan_Ford.player_G = 4
Jordan_Ford.player_MP = 12
Jordan_Ford.player_MP = 12
Jordan_Ford.player_FG = 2
Jordan_Ford.player_FGA = 5
Jordan_Ford.player_FT = 2
Jordan_Ford.player_FTA = 2
Jordan_Ford.player_TRB = 1
Jordan_Ford.player_AST = 1
Jordan_Ford.player_STL = 0
Jordan_Ford.player_BLK = 0
Jordan_Ford.player_TOV = 0
Jordan_Ford.player_PF = 0
Jordan_Ford.player_PTS = 7

Trent_Forrest = Player('Trent_Forrest')
Trent_Forrest.hasClubTeam.append(Atlanta_Hawks)
Trent_Forrest.hasPosition.append(SG)
Trent_Forrest.player_Age = 25
Trent_Forrest.player_G = 4
Trent_Forrest.player_MP = 31
Trent_Forrest.player_MP = 31
Trent_Forrest.player_FG = 1
Trent_Forrest.player_FGA = 4
Trent_Forrest.player_FT = 2
Trent_Forrest.player_FTA = 2
Trent_Forrest.player_TRB = 1
Trent_Forrest.player_AST = 7
Trent_Forrest.player_STL = 0
Trent_Forrest.player_BLK = 0
Trent_Forrest.player_TOV = 1
Trent_Forrest.player_PF = 2
Trent_Forrest.player_PTS = 4

Evan_Fournier = Player('Evan_Fournier')
Evan_Fournier.hasClubTeam.append(New_York_Knicks)
Evan_Fournier.hasPosition.append(SG)
Evan_Fournier.player_Age = 31
Evan_Fournier.player_G = 1
Evan_Fournier.player_MP = 16
Evan_Fournier.player_MP = 16
Evan_Fournier.player_FG = 1
Evan_Fournier.player_FGA = 6
Evan_Fournier.player_FT = 0
Evan_Fournier.player_FTA = 0
Evan_Fournier.player_TRB = 1
Evan_Fournier.player_AST = 1
Evan_Fournier.player_STL = 1
Evan_Fournier.player_BLK = 0
Evan_Fournier.player_TOV = 0
Evan_Fournier.player_PF = 2
Evan_Fournier.player_PTS = 2

DeAaron_Fox = Player('DeAaron_Fox')
DeAaron_Fox.hasClubTeam.append(Sacramento_Kings)
DeAaron_Fox.hasPosition.append(PG)
DeAaron_Fox.player_Age = 26
DeAaron_Fox.player_G = 11
DeAaron_Fox.player_MP = 397
DeAaron_Fox.player_MP = 397
DeAaron_Fox.player_FG = 116
DeAaron_Fox.player_FGA = 243
DeAaron_Fox.player_FT = 62
DeAaron_Fox.player_FTA = 87
DeAaron_Fox.player_TRB = 52
DeAaron_Fox.player_AST = 67
DeAaron_Fox.player_STL = 18
DeAaron_Fox.player_BLK = 3
DeAaron_Fox.player_TOV = 21
DeAaron_Fox.player_PF = 33
DeAaron_Fox.player_PTS = 328

Alex_Fudge = Player('Alex_Fudge')
Alex_Fudge.hasClubTeam.append(Los_Angeles_Lakers)
Alex_Fudge.hasPosition.append(SF)
Alex_Fudge.player_Age = 20
Alex_Fudge.player_G = 2
Alex_Fudge.player_MP = 6
Alex_Fudge.player_MP = 6
Alex_Fudge.player_FG = 1
Alex_Fudge.player_FGA = 2
Alex_Fudge.player_FT = 0
Alex_Fudge.player_FTA = 0
Alex_Fudge.player_TRB = 0
Alex_Fudge.player_AST = 0
Alex_Fudge.player_STL = 0
Alex_Fudge.player_BLK = 0
Alex_Fudge.player_TOV = 1
Alex_Fudge.player_PF = 0
Alex_Fudge.player_PTS = 2

Markelle_Fultz = Player('Markelle_Fultz')
Markelle_Fultz.hasClubTeam.append(Orlando_Magic)
Markelle_Fultz.hasPosition.append(PG)
Markelle_Fultz.player_Age = 25
Markelle_Fultz.player_G = 5
Markelle_Fultz.player_MP = 143
Markelle_Fultz.player_MP = 143
Markelle_Fultz.player_FG = 27
Markelle_Fultz.player_FGA = 56
Markelle_Fultz.player_FT = 3
Markelle_Fultz.player_FTA = 4
Markelle_Fultz.player_TRB = 17
Markelle_Fultz.player_AST = 20
Markelle_Fultz.player_STL = 6
Markelle_Fultz.player_BLK = 2
Markelle_Fultz.player_TOV = 6
Markelle_Fultz.player_PF = 6
Markelle_Fultz.player_PTS = 57

Daniel_Gafford = Player('Daniel_Gafford')
Daniel_Gafford.hasClubTeam.append(Washington_Wizards)
Daniel_Gafford.hasPosition.append(CE)
Daniel_Gafford.player_Age = 25
Daniel_Gafford.player_G = 15
Daniel_Gafford.player_MP = 373
Daniel_Gafford.player_MP = 373
Daniel_Gafford.player_FG = 62
Daniel_Gafford.player_FGA = 89
Daniel_Gafford.player_FT = 21
Daniel_Gafford.player_FTA = 32
Daniel_Gafford.player_TRB = 115
Daniel_Gafford.player_AST = 20
Daniel_Gafford.player_STL = 10
Daniel_Gafford.player_BLK = 30
Daniel_Gafford.player_TOV = 19
Daniel_Gafford.player_PF = 50
Daniel_Gafford.player_PTS = 145

Danilo_Gallinari = Player('Danilo_Gallinari')
Danilo_Gallinari.hasClubTeam.append(Washington_Wizards)
Danilo_Gallinari.hasPosition.append(PF)
Danilo_Gallinari.player_Age = 35
Danilo_Gallinari.player_G = 15
Danilo_Gallinari.player_MP = 234
Danilo_Gallinari.player_MP = 234
Danilo_Gallinari.player_FG = 42
Danilo_Gallinari.player_FGA = 88
Danilo_Gallinari.player_FT = 26
Danilo_Gallinari.player_FTA = 32
Danilo_Gallinari.player_TRB = 47
Danilo_Gallinari.player_AST = 24
Danilo_Gallinari.player_STL = 3
Danilo_Gallinari.player_BLK = 3
Danilo_Gallinari.player_TOV = 7
Danilo_Gallinari.player_PF = 15
Danilo_Gallinari.player_PTS = 123

Darius_Garland = Player('Darius_Garland')
Darius_Garland.hasClubTeam.append(Cleveland_Cavaliers)
Darius_Garland.hasPosition.append(PG)
Darius_Garland.player_Age = 24
Darius_Garland.player_G = 13
Darius_Garland.player_MP = 430
Darius_Garland.player_MP = 430
Darius_Garland.player_FG = 90
Darius_Garland.player_FGA = 186
Darius_Garland.player_FT = 52
Darius_Garland.player_FTA = 63
Darius_Garland.player_TRB = 34
Darius_Garland.player_AST = 76
Darius_Garland.player_STL = 19
Darius_Garland.player_BLK = 3
Darius_Garland.player_TOV = 54
Darius_Garland.player_PF = 22
Darius_Garland.player_PTS = 252

Luka_Garza = Player('Luka_Garza')
Luka_Garza.hasClubTeam.append(Minnesota_Timberwolves)
Luka_Garza.hasPosition.append(CE)
Luka_Garza.player_Age = 25
Luka_Garza.player_G = 4
Luka_Garza.player_MP = 13
Luka_Garza.player_MP = 13
Luka_Garza.player_FG = 4
Luka_Garza.player_FGA = 10
Luka_Garza.player_FT = 5
Luka_Garza.player_FTA = 8
Luka_Garza.player_TRB = 6
Luka_Garza.player_AST = 0
Luka_Garza.player_STL = 0
Luka_Garza.player_BLK = 0
Luka_Garza.player_TOV = 1
Luka_Garza.player_PF = 3
Luka_Garza.player_PTS = 13

Kaiser_Gates = Player('Kaiser_Gates')
Kaiser_Gates.hasClubTeam.append(New_Orleans_Pelicans)
Kaiser_Gates.hasPosition.append(SF)
Kaiser_Gates.player_Age = 27
Kaiser_Gates.player_G = 1
Kaiser_Gates.player_MP = 7
Kaiser_Gates.player_MP = 7
Kaiser_Gates.player_FG = 0
Kaiser_Gates.player_FGA = 4
Kaiser_Gates.player_FT = 0
Kaiser_Gates.player_FTA = 0
Kaiser_Gates.player_TRB = 1
Kaiser_Gates.player_AST = 0
Kaiser_Gates.player_STL = 0
Kaiser_Gates.player_BLK = 0
Kaiser_Gates.player_TOV = 0
Kaiser_Gates.player_PF = 0
Kaiser_Gates.player_PTS = 0

Keyonte_George = Player('Keyonte_George')
Keyonte_George.hasClubTeam.append(Utah_Jazz)
Keyonte_George.hasPosition.append(PG)
Keyonte_George.player_Age = 20
Keyonte_George.player_G = 17
Keyonte_George.player_MP = 429
Keyonte_George.player_MP = 429
Keyonte_George.player_FG = 53
Keyonte_George.player_FGA = 148
Keyonte_George.player_FT = 35
Keyonte_George.player_FTA = 44
Keyonte_George.player_TRB = 52
Keyonte_George.player_AST = 87
Keyonte_George.player_STL = 10
Keyonte_George.player_BLK = 2
Keyonte_George.player_TOV = 36
Keyonte_George.player_PF = 20
Keyonte_George.player_PTS = 169

Paul_George = Player('Paul_George')
Paul_George.hasClubTeam.append(Los_Angeles_Clippers)
Paul_George.hasPosition.append(PF)
Paul_George.player_Age = 33
Paul_George.player_G = 16
Paul_George.player_MP = 560
Paul_George.player_MP = 560
Paul_George.player_FG = 132
Paul_George.player_FGA = 292
Paul_George.player_FT = 73
Paul_George.player_FTA = 78
Paul_George.player_TRB = 101
Paul_George.player_AST = 58
Paul_George.player_STL = 30
Paul_George.player_BLK = 3
Paul_George.player_TOV = 43
Paul_George.player_PF = 46
Paul_George.player_PTS = 387

Josh_Giddey = Player('Josh_Giddey')
Josh_Giddey.hasClubTeam.append(Oklahoma_City_Thunder)
Josh_Giddey.hasPosition.append(SG)
Josh_Giddey.player_Age = 21
Josh_Giddey.player_G = 17
Josh_Giddey.player_MP = 462
Josh_Giddey.player_MP = 462
Josh_Giddey.player_FG = 88
Josh_Giddey.player_FGA = 204
Josh_Giddey.player_FT = 19
Josh_Giddey.player_FTA = 25
Josh_Giddey.player_TRB = 98
Josh_Giddey.player_AST = 77
Josh_Giddey.player_STL = 13
Josh_Giddey.player_BLK = 9
Josh_Giddey.player_TOV = 45
Josh_Giddey.player_PF = 21
Josh_Giddey.player_PTS = 204

Harry_Giles = Player('Harry_Giles')
Harry_Giles.hasClubTeam.append(Brooklyn_Nets)
Harry_Giles.hasPosition.append(CE)
Harry_Giles.player_Age = 25
Harry_Giles.player_G = 2
Harry_Giles.player_MP = 12
Harry_Giles.player_MP = 12
Harry_Giles.player_FG = 5
Harry_Giles.player_FGA = 6
Harry_Giles.player_FT = 1
Harry_Giles.player_FTA = 1
Harry_Giles.player_TRB = 2
Harry_Giles.player_AST = 0
Harry_Giles.player_STL = 0
Harry_Giles.player_BLK = 0
Harry_Giles.player_TOV = 1
Harry_Giles.player_PF = 2
Harry_Giles.player_PTS = 12

Shai_Gilgeous_Alexander = Player('Shai_Gilgeous-Alexander')
Shai_Gilgeous_Alexander.hasClubTeam.append(Oklahoma_City_Thunder)
Shai_Gilgeous_Alexander.hasPosition.append(PG)
Shai_Gilgeous_Alexander.player_Age = 25
Shai_Gilgeous_Alexander.player_G = 16
Shai_Gilgeous_Alexander.player_MP = 548
Shai_Gilgeous_Alexander.player_MP = 548
Shai_Gilgeous_Alexander.player_FG = 179
Shai_Gilgeous_Alexander.player_FGA = 333
Shai_Gilgeous_Alexander.player_FT = 110
Shai_Gilgeous_Alexander.player_FTA = 117
Shai_Gilgeous_Alexander.player_TRB = 96
Shai_Gilgeous_Alexander.player_AST = 97
Shai_Gilgeous_Alexander.player_STL = 38
Shai_Gilgeous_Alexander.player_BLK = 15
Shai_Gilgeous_Alexander.player_TOV = 37
Shai_Gilgeous_Alexander.player_PF = 36
Shai_Gilgeous_Alexander.player_PTS = 488

Anthony_Gill = Player('Anthony_Gill')
Anthony_Gill.hasClubTeam.append(Washington_Wizards)
Anthony_Gill.hasPosition.append(PF)
Anthony_Gill.player_Age = 31
Anthony_Gill.player_G = 10
Anthony_Gill.player_MP = 64
Anthony_Gill.player_MP = 64
Anthony_Gill.player_FG = 10
Anthony_Gill.player_FGA = 19
Anthony_Gill.player_FT = 10
Anthony_Gill.player_FTA = 12
Anthony_Gill.player_TRB = 12
Anthony_Gill.player_AST = 5
Anthony_Gill.player_STL = 3
Anthony_Gill.player_BLK = 3
Anthony_Gill.player_TOV = 7
Anthony_Gill.player_PF = 5
Anthony_Gill.player_PTS = 30

Collin_Gillespie = Player('Collin_Gillespie')
Collin_Gillespie.hasClubTeam.append(Denver_Nuggets)
Collin_Gillespie.hasPosition.append(PG)
Collin_Gillespie.player_Age = 24
Collin_Gillespie.player_G = 9
Collin_Gillespie.player_MP = 78
Collin_Gillespie.player_MP = 78
Collin_Gillespie.player_FG = 8
Collin_Gillespie.player_FGA = 18
Collin_Gillespie.player_FT = 1
Collin_Gillespie.player_FTA = 1
Collin_Gillespie.player_TRB = 3
Collin_Gillespie.player_AST = 8
Collin_Gillespie.player_STL = 5
Collin_Gillespie.player_BLK = 0
Collin_Gillespie.player_TOV = 3
Collin_Gillespie.player_PF = 9
Collin_Gillespie.player_PTS = 20

Jacob_Gilyard = Player('Jacob_Gilyard')
Jacob_Gilyard.hasClubTeam.append(Memphis_Grizzlies)
Jacob_Gilyard.hasPosition.append(PG)
Jacob_Gilyard.player_Age = 25
Jacob_Gilyard.player_G = 13
Jacob_Gilyard.player_MP = 229
Jacob_Gilyard.player_MP = 229
Jacob_Gilyard.player_FG = 19
Jacob_Gilyard.player_FGA = 44
Jacob_Gilyard.player_FT = 1
Jacob_Gilyard.player_FTA = 1
Jacob_Gilyard.player_TRB = 18
Jacob_Gilyard.player_AST = 43
Jacob_Gilyard.player_STL = 9
Jacob_Gilyard.player_BLK = 1
Jacob_Gilyard.player_TOV = 8
Jacob_Gilyard.player_PF = 16
Jacob_Gilyard.player_PTS = 55

Rudy_Gobert = Player('Rudy_Gobert')
Rudy_Gobert.hasClubTeam.append(Minnesota_Timberwolves)
Rudy_Gobert.hasPosition.append(CE)
Rudy_Gobert.player_Age = 31
Rudy_Gobert.player_G = 17
Rudy_Gobert.player_MP = 545
Rudy_Gobert.player_MP = 545
Rudy_Gobert.player_FG = 78
Rudy_Gobert.player_FGA = 133
Rudy_Gobert.player_FT = 55
Rudy_Gobert.player_FTA = 91
Rudy_Gobert.player_TRB = 196
Rudy_Gobert.player_AST = 20
Rudy_Gobert.player_STL = 11
Rudy_Gobert.player_BLK = 39
Rudy_Gobert.player_TOV = 29
Rudy_Gobert.player_PF = 48
Rudy_Gobert.player_PTS = 211

Jordan_Goodwin = Player('Jordan_Goodwin')
Jordan_Goodwin.hasClubTeam.append(Phoenix_Suns)
Jordan_Goodwin.hasPosition.append(PG)
Jordan_Goodwin.player_Age = 25
Jordan_Goodwin.player_G = 17
Jordan_Goodwin.player_MP = 279
Jordan_Goodwin.player_MP = 279
Jordan_Goodwin.player_FG = 39
Jordan_Goodwin.player_FGA = 101
Jordan_Goodwin.player_FT = 11
Jordan_Goodwin.player_FTA = 14
Jordan_Goodwin.player_TRB = 59
Jordan_Goodwin.player_AST = 36
Jordan_Goodwin.player_STL = 15
Jordan_Goodwin.player_BLK = 6
Jordan_Goodwin.player_TOV = 12
Jordan_Goodwin.player_PF = 18
Jordan_Goodwin.player_PTS = 107

Aaron_Gordon = Player('Aaron_Gordon')
Aaron_Gordon.hasClubTeam.append(Denver_Nuggets)
Aaron_Gordon.hasPosition.append(PF)
Aaron_Gordon.player_Age = 28
Aaron_Gordon.player_G = 16
Aaron_Gordon.player_MP = 542
Aaron_Gordon.player_MP = 542
Aaron_Gordon.player_FG = 88
Aaron_Gordon.player_FGA = 181
Aaron_Gordon.player_FT = 26
Aaron_Gordon.player_FTA = 50
Aaron_Gordon.player_TRB = 115
Aaron_Gordon.player_AST = 61
Aaron_Gordon.player_STL = 18
Aaron_Gordon.player_BLK = 14
Aaron_Gordon.player_TOV = 29
Aaron_Gordon.player_PF = 31
Aaron_Gordon.player_PTS = 210

Eric_Gordon = Player('Eric_Gordon')
Eric_Gordon.hasClubTeam.append(Phoenix_Suns)
Eric_Gordon.hasPosition.append(SG)
Eric_Gordon.player_Age = 35
Eric_Gordon.player_G = 16
Eric_Gordon.player_MP = 502
Eric_Gordon.player_MP = 502
Eric_Gordon.player_FG = 91
Eric_Gordon.player_FGA = 194
Eric_Gordon.player_FT = 11
Eric_Gordon.player_FTA = 14
Eric_Gordon.player_TRB = 34
Eric_Gordon.player_AST = 49
Eric_Gordon.player_STL = 16
Eric_Gordon.player_BLK = 9
Eric_Gordon.player_TOV = 24
Eric_Gordon.player_PF = 24
Eric_Gordon.player_PTS = 239

Devonte_Graham = Player('Devonte_Graham')
Devonte_Graham.hasClubTeam.append(San_Antonio_Spurs)
Devonte_Graham.hasPosition.append(PG)
Devonte_Graham.player_Age = 28
Devonte_Graham.player_G = 3
Devonte_Graham.player_MP = 36
Devonte_Graham.player_MP = 36
Devonte_Graham.player_FG = 2
Devonte_Graham.player_FGA = 7
Devonte_Graham.player_FT = 4
Devonte_Graham.player_FTA = 5
Devonte_Graham.player_TRB = 2
Devonte_Graham.player_AST = 11
Devonte_Graham.player_STL = 2
Devonte_Graham.player_BLK = 1
Devonte_Graham.player_TOV = 2
Devonte_Graham.player_PF = 2
Devonte_Graham.player_PTS = 8

Jerami_Grant = Player('Jerami_Grant')
Jerami_Grant.hasClubTeam.append(Portland_Trail_Blazers)
Jerami_Grant.hasPosition.append(PF)
Jerami_Grant.player_Age = 29
Jerami_Grant.player_G = 17
Jerami_Grant.player_MP = 610
Jerami_Grant.player_MP = 610
Jerami_Grant.player_FG = 134
Jerami_Grant.player_FGA = 297
Jerami_Grant.player_FT = 84
Jerami_Grant.player_FTA = 103
Jerami_Grant.player_TRB = 68
Jerami_Grant.player_AST = 39
Jerami_Grant.player_STL = 14
Jerami_Grant.player_BLK = 15
Jerami_Grant.player_TOV = 41
Jerami_Grant.player_PF = 36
Jerami_Grant.player_PTS = 398

AJ_Green = Player('A.J._Green')
AJ_Green.hasClubTeam.append(Milwaukee_Bucks)
AJ_Green.hasPosition.append(SG)
AJ_Green.player_Age = 24
AJ_Green.player_G = 11
AJ_Green.player_MP = 82
AJ_Green.player_MP = 82
AJ_Green.player_FG = 11
AJ_Green.player_FGA = 30
AJ_Green.player_FT = 1
AJ_Green.player_FTA = 1
AJ_Green.player_TRB = 8
AJ_Green.player_AST = 8
AJ_Green.player_STL = 0
AJ_Green.player_BLK = 0
AJ_Green.player_TOV = 0
AJ_Green.player_PF = 8
AJ_Green.player_PTS = 31

Danny_Green = Player('Danny_Green')
Danny_Green.hasClubTeam.append(_)
Danny_Green.hasPosition.append(SG)
Danny_Green.player_Age = 36
Danny_Green.player_G = 2
Danny_Green.player_MP = 18
Danny_Green.player_MP = 18
Danny_Green.player_FG = 0
Danny_Green.player_FGA = 2
Danny_Green.player_FT = 0
Danny_Green.player_FTA = 0
Danny_Green.player_TRB = 2
Danny_Green.player_AST = 1
Danny_Green.player_STL = 1
Danny_Green.player_BLK = 0
Danny_Green.player_TOV = 0
Danny_Green.player_PF = 1
Danny_Green.player_PTS = 0

Draymond_Green = Player('Draymond_Green')
Draymond_Green.hasClubTeam.append(Golden_State_Warriors)
Draymond_Green.hasPosition.append(PF)
Draymond_Green.player_Age = 33
Draymond_Green.player_G = 10
Draymond_Green.player_MP = 233
Draymond_Green.player_MP = 233
Draymond_Green.player_FG = 30
Draymond_Green.player_FGA = 64
Draymond_Green.player_FT = 16
Draymond_Green.player_FTA = 18
Draymond_Green.player_TRB = 52
Draymond_Green.player_AST = 54
Draymond_Green.player_STL = 6
Draymond_Green.player_BLK = 7
Draymond_Green.player_TOV = 20
Draymond_Green.player_PF = 26
Draymond_Green.player_PTS = 87

Jalen_Green = Player('Jalen_Green')
Jalen_Green.hasClubTeam.append(Houston_Rockets)
Jalen_Green.hasPosition.append(SG)
Jalen_Green.player_Age = 21
Jalen_Green.player_G = 15
Jalen_Green.player_MP = 476
Jalen_Green.player_MP = 476
Jalen_Green.player_FG = 96
Jalen_Green.player_FGA = 230
Jalen_Green.player_FT = 64
Jalen_Green.player_FTA = 81
Jalen_Green.player_TRB = 65
Jalen_Green.player_AST = 45
Jalen_Green.player_STL = 10
Jalen_Green.player_BLK = 6
Jalen_Green.player_TOV = 34
Jalen_Green.player_PF = 25
Jalen_Green.player_PTS = 287

Jeff_Green = Player('Jeff_Green')
Jeff_Green.hasClubTeam.append(Houston_Rockets)
Jeff_Green.hasPosition.append(PF)
Jeff_Green.player_Age = 37
Jeff_Green.player_G = 15
Jeff_Green.player_MP = 214
Jeff_Green.player_MP = 214
Jeff_Green.player_FG = 30
Jeff_Green.player_FGA = 55
Jeff_Green.player_FT = 24
Jeff_Green.player_FTA = 31
Jeff_Green.player_TRB = 35
Jeff_Green.player_AST = 8
Jeff_Green.player_STL = 2
Jeff_Green.player_BLK = 6
Jeff_Green.player_TOV = 8
Jeff_Green.player_PF = 14
Jeff_Green.player_PTS = 89

Josh_Green = Player('Josh_Green')
Josh_Green.hasClubTeam.append(Dallas_Mavericks)
Josh_Green.hasPosition.append(SG)
Josh_Green.player_Age = 23
Josh_Green.player_G = 17
Josh_Green.player_MP = 423
Josh_Green.player_MP = 423
Josh_Green.player_FG = 42
Josh_Green.player_FGA = 99
Josh_Green.player_FT = 8
Josh_Green.player_FTA = 16
Josh_Green.player_TRB = 50
Josh_Green.player_AST = 38
Josh_Green.player_STL = 14
Josh_Green.player_BLK = 3
Josh_Green.player_TOV = 14
Josh_Green.player_PF = 31
Josh_Green.player_PTS = 114

AJ_Griffin = Player('AJ_Griffin')
AJ_Griffin.hasClubTeam.append(Atlanta_Hawks)
AJ_Griffin.hasPosition.append(SF)
AJ_Griffin.player_Age = 20
AJ_Griffin.player_G = 11
AJ_Griffin.player_MP = 101
AJ_Griffin.player_MP = 101
AJ_Griffin.player_FG = 10
AJ_Griffin.player_FGA = 33
AJ_Griffin.player_FT = 2
AJ_Griffin.player_FTA = 2
AJ_Griffin.player_TRB = 10
AJ_Griffin.player_AST = 3
AJ_Griffin.player_STL = 1
AJ_Griffin.player_BLK = 0
AJ_Griffin.player_TOV = 4
AJ_Griffin.player_PF = 5
AJ_Griffin.player_PTS = 30

Quentin_Grimes = Player('Quentin_Grimes')
Quentin_Grimes.hasClubTeam.append(New_York_Knicks)
Quentin_Grimes.hasPosition.append(SG)
Quentin_Grimes.player_Age = 23
Quentin_Grimes.player_G = 15
Quentin_Grimes.player_MP = 356
Quentin_Grimes.player_MP = 356
Quentin_Grimes.player_FG = 36
Quentin_Grimes.player_FGA = 94
Quentin_Grimes.player_FT = 0
Quentin_Grimes.player_FTA = 1
Quentin_Grimes.player_TRB = 20
Quentin_Grimes.player_AST = 19
Quentin_Grimes.player_STL = 11
Quentin_Grimes.player_BLK = 0
Quentin_Grimes.player_TOV = 9
Quentin_Grimes.player_PF = 26
Quentin_Grimes.player_PTS = 101

Mouhamed_Gueye = Player('Mouhamed_Gueye')
Mouhamed_Gueye.hasClubTeam.append(Atlanta_Hawks)
Mouhamed_Gueye.hasPosition.append(PF)
Mouhamed_Gueye.player_Age = 21
Mouhamed_Gueye.player_G = 2
Mouhamed_Gueye.player_MP = 4
Mouhamed_Gueye.player_MP = 4
Mouhamed_Gueye.player_FG = 0
Mouhamed_Gueye.player_FGA = 1
Mouhamed_Gueye.player_FT = 0
Mouhamed_Gueye.player_FTA = 0
Mouhamed_Gueye.player_TRB = 0
Mouhamed_Gueye.player_AST = 0
Mouhamed_Gueye.player_STL = 1
Mouhamed_Gueye.player_BLK = 0
Mouhamed_Gueye.player_TOV = 0
Mouhamed_Gueye.player_PF = 1
Mouhamed_Gueye.player_PTS = 0

Rui_Hachimura = Player('Rui_Hachimura')
Rui_Hachimura.hasClubTeam.append(Los_Angeles_Lakers)
Rui_Hachimura.hasPosition.append(PF)
Rui_Hachimura.player_Age = 25
Rui_Hachimura.player_G = 12
Rui_Hachimura.player_MP = 279
Rui_Hachimura.player_MP = 279
Rui_Hachimura.player_FG = 52
Rui_Hachimura.player_FGA = 103
Rui_Hachimura.player_FT = 22
Rui_Hachimura.player_FTA = 28
Rui_Hachimura.player_TRB = 46
Rui_Hachimura.player_AST = 12
Rui_Hachimura.player_STL = 11
Rui_Hachimura.player_BLK = 3
Rui_Hachimura.player_TOV = 12
Rui_Hachimura.player_PF = 18
Rui_Hachimura.player_PTS = 141

Tyrese_Haliburton = Player('Tyrese_Haliburton')
Tyrese_Haliburton.hasClubTeam.append(Indiana_Pacers)
Tyrese_Haliburton.hasPosition.append(PG)
Tyrese_Haliburton.player_Age = 23
Tyrese_Haliburton.player_G = 15
Tyrese_Haliburton.player_MP = 503
Tyrese_Haliburton.player_MP = 503
Tyrese_Haliburton.player_FG = 133
Tyrese_Haliburton.player_FGA = 257
Tyrese_Haliburton.player_FT = 65
Tyrese_Haliburton.player_FTA = 71
Tyrese_Haliburton.player_TRB = 56
Tyrese_Haliburton.player_AST = 179
Tyrese_Haliburton.player_STL = 14
Tyrese_Haliburton.player_BLK = 10
Tyrese_Haliburton.player_TOV = 38
Tyrese_Haliburton.player_PF = 17
Tyrese_Haliburton.player_PTS = 388

RJ_Hampton = Player('R.J._Hampton')
RJ_Hampton.hasClubTeam.append(Miami_Heat)
RJ_Hampton.hasPosition.append(PG)
RJ_Hampton.player_Age = 22
RJ_Hampton.player_G = 1
RJ_Hampton.player_MP = 2
RJ_Hampton.player_MP = 2
RJ_Hampton.player_FG = 0
RJ_Hampton.player_FGA = 1
RJ_Hampton.player_FT = 0
RJ_Hampton.player_FTA = 0
RJ_Hampton.player_TRB = 0
RJ_Hampton.player_AST = 0
RJ_Hampton.player_STL = 0
RJ_Hampton.player_BLK = 0
RJ_Hampton.player_TOV = 0
RJ_Hampton.player_PF = 0
RJ_Hampton.player_PTS = 0

Tim_Hardaway_Jr = Player('Tim_Hardaway_Jr.')
Tim_Hardaway_Jr.hasClubTeam.append(Dallas_Mavericks)
Tim_Hardaway_Jr.hasPosition.append(SF)
Tim_Hardaway_Jr.player_Age = 31
Tim_Hardaway_Jr.player_G = 17
Tim_Hardaway_Jr.player_MP = 468
Tim_Hardaway_Jr.player_MP = 468
Tim_Hardaway_Jr.player_FG = 97
Tim_Hardaway_Jr.player_FGA = 231
Tim_Hardaway_Jr.player_FT = 33
Tim_Hardaway_Jr.player_FTA = 37
Tim_Hardaway_Jr.player_TRB = 57
Tim_Hardaway_Jr.player_AST = 27
Tim_Hardaway_Jr.player_STL = 4
Tim_Hardaway_Jr.player_BLK = 0
Tim_Hardaway_Jr.player_TOV = 14
Tim_Hardaway_Jr.player_PF = 15
Tim_Hardaway_Jr.player_PTS = 285

James_Harden = Player('James_Harden')
James_Harden.hasClubTeam.append(Los_Angeles_Clippers)
James_Harden.hasPosition.append(SG)
James_Harden.player_Age = 34
James_Harden.player_G = 11
James_Harden.player_MP = 361
James_Harden.player_MP = 361
James_Harden.player_FG = 46
James_Harden.player_FGA = 104
James_Harden.player_FT = 41
James_Harden.player_FTA = 49
James_Harden.player_TRB = 51
James_Harden.player_AST = 68
James_Harden.player_STL = 15
James_Harden.player_BLK = 6
James_Harden.player_TOV = 26
James_Harden.player_PF = 18
James_Harden.player_PTS = 155

Jaden_Hardy = Player('Jaden_Hardy')
Jaden_Hardy.hasClubTeam.append(Dallas_Mavericks)
Jaden_Hardy.hasPosition.append(SG)
Jaden_Hardy.player_Age = 21
Jaden_Hardy.player_G = 14
Jaden_Hardy.player_MP = 146
Jaden_Hardy.player_MP = 146
Jaden_Hardy.player_FG = 29
Jaden_Hardy.player_FGA = 76
Jaden_Hardy.player_FT = 17
Jaden_Hardy.player_FTA = 23
Jaden_Hardy.player_TRB = 20
Jaden_Hardy.player_AST = 14
Jaden_Hardy.player_STL = 4
Jaden_Hardy.player_BLK = 0
Jaden_Hardy.player_TOV = 8
Jaden_Hardy.player_PF = 11
Jaden_Hardy.player_PTS = 85

Ron_Harper_Jr = Player('Ron_Harper_Jr.')
Ron_Harper_Jr.hasClubTeam.append(Toronto_Raptors)
Ron_Harper_Jr.hasPosition.append(PF)
Ron_Harper_Jr.player_Age = 23
Ron_Harper_Jr.player_G = 1
Ron_Harper_Jr.player_MP = 4
Ron_Harper_Jr.player_MP = 4
Ron_Harper_Jr.player_FG = 0
Ron_Harper_Jr.player_FGA = 0
Ron_Harper_Jr.player_FT = 0
Ron_Harper_Jr.player_FTA = 0
Ron_Harper_Jr.player_TRB = 0
Ron_Harper_Jr.player_AST = 1
Ron_Harper_Jr.player_STL = 0
Ron_Harper_Jr.player_BLK = 0
Ron_Harper_Jr.player_TOV = 0
Ron_Harper_Jr.player_PF = 2
Ron_Harper_Jr.player_PTS = 0

Gary_Harris = Player('Gary_Harris')
Gary_Harris.hasClubTeam.append(Orlando_Magic)
Gary_Harris.hasPosition.append(SG)
Gary_Harris.player_Age = 29
Gary_Harris.player_G = 12
Gary_Harris.player_MP = 250
Gary_Harris.player_MP = 250
Gary_Harris.player_FG = 34
Gary_Harris.player_FGA = 69
Gary_Harris.player_FT = 9
Gary_Harris.player_FTA = 12
Gary_Harris.player_TRB = 24
Gary_Harris.player_AST = 21
Gary_Harris.player_STL = 11
Gary_Harris.player_BLK = 4
Gary_Harris.player_TOV = 6
Gary_Harris.player_PF = 14
Gary_Harris.player_PTS = 98

Joe_Harris = Player('Joe_Harris')
Joe_Harris.hasClubTeam.append(Detroit_Pistons)
Joe_Harris.hasPosition.append(SG)
Joe_Harris.player_Age = 32
Joe_Harris.player_G = 7
Joe_Harris.player_MP = 98
Joe_Harris.player_MP = 98
Joe_Harris.player_FG = 9
Joe_Harris.player_FGA = 25
Joe_Harris.player_FT = 0
Joe_Harris.player_FTA = 0
Joe_Harris.player_TRB = 7
Joe_Harris.player_AST = 6
Joe_Harris.player_STL = 2
Joe_Harris.player_BLK = 0
Joe_Harris.player_TOV = 3
Joe_Harris.player_PF = 12
Joe_Harris.player_PTS = 24

Tobias_Harris = Player('Tobias_Harris')
Tobias_Harris.hasClubTeam.append(Philadelphia_76ers)
Tobias_Harris.hasPosition.append(PF)
Tobias_Harris.player_Age = 31
Tobias_Harris.player_G = 17
Tobias_Harris.player_MP = 602
Tobias_Harris.player_MP = 602
Tobias_Harris.player_FG = 119
Tobias_Harris.player_FGA = 226
Tobias_Harris.player_FT = 59
Tobias_Harris.player_FTA = 65
Tobias_Harris.player_TRB = 106
Tobias_Harris.player_AST = 46
Tobias_Harris.player_STL = 14
Tobias_Harris.player_BLK = 6
Tobias_Harris.player_TOV = 28
Tobias_Harris.player_PF = 28
Tobias_Harris.player_PTS = 316

Shaquille_Harrison = Player('Shaquille_Harrison')
Shaquille_Harrison.hasClubTeam.append(Memphis_Grizzlies)
Shaquille_Harrison.hasPosition.append(SG)
Shaquille_Harrison.player_Age = 30
Shaquille_Harrison.player_G = 2
Shaquille_Harrison.player_MP = 4
Shaquille_Harrison.player_MP = 4
Shaquille_Harrison.player_FG = 1
Shaquille_Harrison.player_FGA = 2
Shaquille_Harrison.player_FT = 0
Shaquille_Harrison.player_FTA = 0
Shaquille_Harrison.player_TRB = 1
Shaquille_Harrison.player_AST = 0
Shaquille_Harrison.player_STL = 0
Shaquille_Harrison.player_BLK = 1
Shaquille_Harrison.player_TOV = 0
Shaquille_Harrison.player_PF = 0
Shaquille_Harrison.player_PTS = 2

Josh_Hart = Player('Josh_Hart')
Josh_Hart.hasClubTeam.append(New_York_Knicks)
Josh_Hart.hasPosition.append(SF)
Josh_Hart.player_Age = 28
Josh_Hart.player_G = 17
Josh_Hart.player_MP = 482
Josh_Hart.player_MP = 482
Josh_Hart.player_FG = 53
Josh_Hart.player_FGA = 119
Josh_Hart.player_FT = 9
Josh_Hart.player_FTA = 11
Josh_Hart.player_TRB = 103
Josh_Hart.player_AST = 45
Josh_Hart.player_STL = 16
Josh_Hart.player_BLK = 5
Josh_Hart.player_TOV = 15
Josh_Hart.player_PF = 28
Josh_Hart.player_PTS = 131

Isaiah_Hartenstein = Player('Isaiah_Hartenstein')
Isaiah_Hartenstein.hasClubTeam.append(New_York_Knicks)
Isaiah_Hartenstein.hasPosition.append(CE)
Isaiah_Hartenstein.player_Age = 25
Isaiah_Hartenstein.player_G = 17
Isaiah_Hartenstein.player_MP = 289
Isaiah_Hartenstein.player_MP = 289
Isaiah_Hartenstein.player_FG = 39
Isaiah_Hartenstein.player_FGA = 69
Isaiah_Hartenstein.player_FT = 18
Isaiah_Hartenstein.player_FTA = 27
Isaiah_Hartenstein.player_TRB = 83
Isaiah_Hartenstein.player_AST = 17
Isaiah_Hartenstein.player_STL = 16
Isaiah_Hartenstein.player_BLK = 8
Isaiah_Hartenstein.player_TOV = 13
Isaiah_Hartenstein.player_PF = 47
Isaiah_Hartenstein.player_PTS = 97

Sam_Hauser = Player('Sam_Hauser')
Sam_Hauser.hasClubTeam.append(Boston_Celtics)
Sam_Hauser.hasPosition.append(SF)
Sam_Hauser.player_Age = 26
Sam_Hauser.player_G = 18
Sam_Hauser.player_MP = 410
Sam_Hauser.player_MP = 410
Sam_Hauser.player_FG = 60
Sam_Hauser.player_FGA = 129
Sam_Hauser.player_FT = 5
Sam_Hauser.player_FTA = 6
Sam_Hauser.player_TRB = 61
Sam_Hauser.player_AST = 15
Sam_Hauser.player_STL = 9
Sam_Hauser.player_BLK = 6
Sam_Hauser.player_TOV = 9
Sam_Hauser.player_PF = 27
Sam_Hauser.player_PTS = 174

Jordan_Hawkins = Player('Jordan_Hawkins')
Jordan_Hawkins.hasClubTeam.append(New_Orleans_Pelicans)
Jordan_Hawkins.hasPosition.append(SG)
Jordan_Hawkins.player_Age = 21
Jordan_Hawkins.player_G = 18
Jordan_Hawkins.player_MP = 520
Jordan_Hawkins.player_MP = 520
Jordan_Hawkins.player_FG = 80
Jordan_Hawkins.player_FGA = 202
Jordan_Hawkins.player_FT = 31
Jordan_Hawkins.player_FTA = 36
Jordan_Hawkins.player_TRB = 73
Jordan_Hawkins.player_AST = 36
Jordan_Hawkins.player_STL = 10
Jordan_Hawkins.player_BLK = 0
Jordan_Hawkins.player_TOV = 19
Jordan_Hawkins.player_PF = 37
Jordan_Hawkins.player_PTS = 241

Jaxson_Hayes = Player('Jaxson_Hayes')
Jaxson_Hayes.hasClubTeam.append(Los_Angeles_Lakers)
Jaxson_Hayes.hasPosition.append(CE)
Jaxson_Hayes.player_Age = 23
Jaxson_Hayes.player_G = 16
Jaxson_Hayes.player_MP = 184
Jaxson_Hayes.player_MP = 184
Jaxson_Hayes.player_FG = 22
Jaxson_Hayes.player_FGA = 31
Jaxson_Hayes.player_FT = 12
Jaxson_Hayes.player_FTA = 21
Jaxson_Hayes.player_TRB = 27
Jaxson_Hayes.player_AST = 7
Jaxson_Hayes.player_STL = 4
Jaxson_Hayes.player_BLK = 8
Jaxson_Hayes.player_TOV = 13
Jaxson_Hayes.player_PF = 30
Jaxson_Hayes.player_PTS = 56

Killian_Hayes = Player('Killian_Hayes')
Killian_Hayes.hasClubTeam.append(Detroit_Pistons)
Killian_Hayes.hasPosition.append(PG)
Killian_Hayes.player_Age = 22
Killian_Hayes.player_G = 16
Killian_Hayes.player_MP = 427
Killian_Hayes.player_MP = 427
Killian_Hayes.player_FG = 53
Killian_Hayes.player_FGA = 135
Killian_Hayes.player_FT = 18
Killian_Hayes.player_FTA = 24
Killian_Hayes.player_TRB = 44
Killian_Hayes.player_AST = 67
Killian_Hayes.player_STL = 18
Killian_Hayes.player_BLK = 11
Killian_Hayes.player_TOV = 13
Killian_Hayes.player_PF = 32
Killian_Hayes.player_PTS = 138

Gordon_Hayward = Player('Gordon_Hayward')
Gordon_Hayward.hasClubTeam.append(Charlotte_Hornets)
Gordon_Hayward.hasPosition.append(SF)
Gordon_Hayward.player_Age = 33
Gordon_Hayward.player_G = 15
Gordon_Hayward.player_MP = 485
Gordon_Hayward.player_MP = 485
Gordon_Hayward.player_FG = 76
Gordon_Hayward.player_FGA = 185
Gordon_Hayward.player_FT = 35
Gordon_Hayward.player_FTA = 49
Gordon_Hayward.player_TRB = 79
Gordon_Hayward.player_AST = 69
Gordon_Hayward.player_STL = 18
Gordon_Hayward.player_BLK = 8
Gordon_Hayward.player_TOV = 27
Gordon_Hayward.player_PF = 29
Gordon_Hayward.player_PTS = 199

Scoot_Henderson = Player('Scoot_Henderson')
Scoot_Henderson.hasClubTeam.append(Portland_Trail_Blazers)
Scoot_Henderson.hasPosition.append(PG)
Scoot_Henderson.player_Age = 19
Scoot_Henderson.player_G = 8
Scoot_Henderson.player_MP = 208
Scoot_Henderson.player_MP = 208
Scoot_Henderson.player_FG = 28
Scoot_Henderson.player_FGA = 79
Scoot_Henderson.player_FT = 10
Scoot_Henderson.player_FTA = 15
Scoot_Henderson.player_TRB = 21
Scoot_Henderson.player_AST = 32
Scoot_Henderson.player_STL = 4
Scoot_Henderson.player_BLK = 1
Scoot_Henderson.player_TOV = 29
Scoot_Henderson.player_PF = 34
Scoot_Henderson.player_PTS = 73

Taylor_Hendricks = Player('Taylor_Hendricks')
Taylor_Hendricks.hasClubTeam.append(Utah_Jazz)
Taylor_Hendricks.hasPosition.append(PF)
Taylor_Hendricks.player_Age = 20
Taylor_Hendricks.player_G = 1
Taylor_Hendricks.player_MP = 2
Taylor_Hendricks.player_MP = 2
Taylor_Hendricks.player_FG = 0
Taylor_Hendricks.player_FGA = 0
Taylor_Hendricks.player_FT = 1
Taylor_Hendricks.player_FTA = 2
Taylor_Hendricks.player_TRB = 1
Taylor_Hendricks.player_AST = 0
Taylor_Hendricks.player_STL = 0
Taylor_Hendricks.player_BLK = 0
Taylor_Hendricks.player_TOV = 0
Taylor_Hendricks.player_PF = 0
Taylor_Hendricks.player_PTS = 1

Tyler_Herro = Player('Tyler_Herro')
Tyler_Herro.hasClubTeam.append(Miami_Heat)
Tyler_Herro.hasPosition.append(SG)
Tyler_Herro.player_Age = 24
Tyler_Herro.player_G = 8
Tyler_Herro.player_MP = 272
Tyler_Herro.player_MP = 272
Tyler_Herro.player_FG = 68
Tyler_Herro.player_FGA = 152
Tyler_Herro.player_FT = 22
Tyler_Herro.player_FTA = 25
Tyler_Herro.player_TRB = 40
Tyler_Herro.player_AST = 37
Tyler_Herro.player_STL = 11
Tyler_Herro.player_BLK = 0
Tyler_Herro.player_TOV = 20
Tyler_Herro.player_PF = 13
Tyler_Herro.player_PTS = 183

Buddy_Hield = Player('Buddy_Hield')
Buddy_Hield.hasClubTeam.append(Indiana_Pacers)
Buddy_Hield.hasPosition.append(SF)
Buddy_Hield.player_Age = 31
Buddy_Hield.player_G = 16
Buddy_Hield.player_MP = 391
Buddy_Hield.player_MP = 391
Buddy_Hield.player_FG = 81
Buddy_Hield.player_FGA = 175
Buddy_Hield.player_FT = 6
Buddy_Hield.player_FTA = 7
Buddy_Hield.player_TRB = 46
Buddy_Hield.player_AST = 42
Buddy_Hield.player_STL = 10
Buddy_Hield.player_BLK = 9
Buddy_Hield.player_TOV = 25
Buddy_Hield.player_PF = 27
Buddy_Hield.player_PTS = 218

Haywood_Highsmith = Player('Haywood_Highsmith')
Haywood_Highsmith.hasClubTeam.append(Miami_Heat)
Haywood_Highsmith.hasPosition.append(PF)
Haywood_Highsmith.player_Age = 27
Haywood_Highsmith.player_G = 13
Haywood_Highsmith.player_MP = 316
Haywood_Highsmith.player_MP = 316
Haywood_Highsmith.player_FG = 34
Haywood_Highsmith.player_FGA = 79
Haywood_Highsmith.player_FT = 11
Haywood_Highsmith.player_FTA = 13
Haywood_Highsmith.player_TRB = 40
Haywood_Highsmith.player_AST = 22
Haywood_Highsmith.player_STL = 17
Haywood_Highsmith.player_BLK = 11
Haywood_Highsmith.player_TOV = 13
Haywood_Highsmith.player_PF = 27
Haywood_Highsmith.player_PTS = 95

Nate_Hinton = Player('Nate_Hinton')
Nate_Hinton.hasClubTeam.append(Houston_Rockets)
Nate_Hinton.hasPosition.append(SG)
Nate_Hinton.player_Age = 24
Nate_Hinton.player_G = 2
Nate_Hinton.player_MP = 8
Nate_Hinton.player_MP = 8
Nate_Hinton.player_FG = 2
Nate_Hinton.player_FGA = 4
Nate_Hinton.player_FT = 0
Nate_Hinton.player_FTA = 0
Nate_Hinton.player_TRB = 0
Nate_Hinton.player_AST = 0
Nate_Hinton.player_STL = 0
Nate_Hinton.player_BLK = 0
Nate_Hinton.player_TOV = 0
Nate_Hinton.player_PF = 1
Nate_Hinton.player_PTS = 6

DMoi_Hodge = Player('DMoi_Hodge')
DMoi_Hodge.hasClubTeam.append(Los_Angeles_Lakers)
DMoi_Hodge.hasPosition.append(SG)
DMoi_Hodge.player_Age = 25
DMoi_Hodge.player_G = 4
DMoi_Hodge.player_MP = 24
DMoi_Hodge.player_MP = 24
DMoi_Hodge.player_FG = 2
DMoi_Hodge.player_FGA = 8
DMoi_Hodge.player_FT = 1
DMoi_Hodge.player_FTA = 2
DMoi_Hodge.player_TRB = 0
DMoi_Hodge.player_AST = 2
DMoi_Hodge.player_STL = 0
DMoi_Hodge.player_BLK = 1
DMoi_Hodge.player_TOV = 1
DMoi_Hodge.player_PF = 3
DMoi_Hodge.player_PTS = 6

Aaron_Holiday = Player('Aaron_Holiday')
Aaron_Holiday.hasClubTeam.append(Houston_Rockets)
Aaron_Holiday.hasPosition.append(PG)
Aaron_Holiday.player_Age = 27
Aaron_Holiday.player_G = 13
Aaron_Holiday.player_MP = 223
Aaron_Holiday.player_MP = 223
Aaron_Holiday.player_FG = 29
Aaron_Holiday.player_FGA = 63
Aaron_Holiday.player_FT = 5
Aaron_Holiday.player_FTA = 6
Aaron_Holiday.player_TRB = 23
Aaron_Holiday.player_AST = 23
Aaron_Holiday.player_STL = 8
Aaron_Holiday.player_BLK = 1
Aaron_Holiday.player_TOV = 6
Aaron_Holiday.player_PF = 24
Aaron_Holiday.player_PTS = 76

Jrue_Holiday = Player('Jrue_Holiday')
Jrue_Holiday.hasClubTeam.append(Boston_Celtics)
Jrue_Holiday.hasPosition.append(PG)
Jrue_Holiday.player_Age = 33
Jrue_Holiday.player_G = 16
Jrue_Holiday.player_MP = 552
Jrue_Holiday.player_MP = 552
Jrue_Holiday.player_FG = 76
Jrue_Holiday.player_FGA = 177
Jrue_Holiday.player_FT = 19
Jrue_Holiday.player_FTA = 24
Jrue_Holiday.player_TRB = 118
Jrue_Holiday.player_AST = 82
Jrue_Holiday.player_STL = 10
Jrue_Holiday.player_BLK = 15
Jrue_Holiday.player_TOV = 35
Jrue_Holiday.player_PF = 27
Jrue_Holiday.player_PTS = 198

Justin_Holiday = Player('Justin_Holiday')
Justin_Holiday.hasClubTeam.append(Denver_Nuggets)
Justin_Holiday.hasPosition.append(SG)
Justin_Holiday.player_Age = 34
Justin_Holiday.player_G = 9
Justin_Holiday.player_MP = 110
Justin_Holiday.player_MP = 110
Justin_Holiday.player_FG = 12
Justin_Holiday.player_FGA = 22
Justin_Holiday.player_FT = 0
Justin_Holiday.player_FTA = 0
Justin_Holiday.player_TRB = 13
Justin_Holiday.player_AST = 6
Justin_Holiday.player_STL = 3
Justin_Holiday.player_BLK = 0
Justin_Holiday.player_TOV = 3
Justin_Holiday.player_PF = 9
Justin_Holiday.player_PTS = 32

Richaun_Holmes = Player('Richaun_Holmes')
Richaun_Holmes.hasClubTeam.append(Dallas_Mavericks)
Richaun_Holmes.hasPosition.append(CE)
Richaun_Holmes.player_Age = 30
Richaun_Holmes.player_G = 8
Richaun_Holmes.player_MP = 88
Richaun_Holmes.player_MP = 88
Richaun_Holmes.player_FG = 10
Richaun_Holmes.player_FGA = 20
Richaun_Holmes.player_FT = 3
Richaun_Holmes.player_FTA = 8
Richaun_Holmes.player_TRB = 31
Richaun_Holmes.player_AST = 3
Richaun_Holmes.player_STL = 0
Richaun_Holmes.player_BLK = 3
Richaun_Holmes.player_TOV = 5
Richaun_Holmes.player_PF = 16
Richaun_Holmes.player_PTS = 23

Chet_Holmgren = Player('Chet_Holmgren')
Chet_Holmgren.hasClubTeam.append(Oklahoma_City_Thunder)
Chet_Holmgren.hasPosition.append(CE)
Chet_Holmgren.player_Age = 21
Chet_Holmgren.player_G = 17
Chet_Holmgren.player_MP = 512
Chet_Holmgren.player_MP = 512
Chet_Holmgren.player_FG = 107
Chet_Holmgren.player_FGA = 199
Chet_Holmgren.player_FT = 60
Chet_Holmgren.player_FTA = 69
Chet_Holmgren.player_TRB = 136
Chet_Holmgren.player_AST = 46
Chet_Holmgren.player_STL = 15
Chet_Holmgren.player_BLK = 38
Chet_Holmgren.player_TOV = 33
Chet_Holmgren.player_PF = 48
Chet_Holmgren.player_PTS = 305

Jalen_Hood_Schifino = Player('Jalen_Hood-Schifino')
Jalen_Hood_Schifino.hasClubTeam.append(Los_Angeles_Lakers)
Jalen_Hood_Schifino.hasPosition.append(SG)
Jalen_Hood_Schifino.player_Age = 20
Jalen_Hood_Schifino.player_G = 1
Jalen_Hood_Schifino.player_MP = 11
Jalen_Hood_Schifino.player_MP = 11
Jalen_Hood_Schifino.player_FG = 0
Jalen_Hood_Schifino.player_FGA = 3
Jalen_Hood_Schifino.player_FT = 0
Jalen_Hood_Schifino.player_FTA = 0
Jalen_Hood_Schifino.player_TRB = 0
Jalen_Hood_Schifino.player_AST = 2
Jalen_Hood_Schifino.player_STL = 0
Jalen_Hood_Schifino.player_BLK = 0
Jalen_Hood_Schifino.player_TOV = 1
Jalen_Hood_Schifino.player_PF = 1
Jalen_Hood_Schifino.player_PTS = 0

Al_Horford = Player('Al_Horford')
Al_Horford.hasClubTeam.append(Boston_Celtics)
Al_Horford.hasPosition.append(CE)
Al_Horford.player_Age = 37
Al_Horford.player_G = 16
Al_Horford.player_MP = 413
Al_Horford.player_MP = 413
Al_Horford.player_FG = 43
Al_Horford.player_FGA = 94
Al_Horford.player_FT = 3
Al_Horford.player_FTA = 3
Al_Horford.player_TRB = 106
Al_Horford.player_AST = 44
Al_Horford.player_STL = 8
Al_Horford.player_BLK = 16
Al_Horford.player_TOV = 15
Al_Horford.player_PF = 28
Al_Horford.player_PTS = 110

Talen_Horton_Tucker = Player('Talen_Horton-Tucker')
Talen_Horton_Tucker.hasClubTeam.append(Utah_Jazz)
Talen_Horton_Tucker.hasPosition.append(PG)
Talen_Horton_Tucker.player_Age = 23
Talen_Horton_Tucker.player_G = 17
Talen_Horton_Tucker.player_MP = 382
Talen_Horton_Tucker.player_MP = 382
Talen_Horton_Tucker.player_FG = 59
Talen_Horton_Tucker.player_FGA = 156
Talen_Horton_Tucker.player_FT = 22
Talen_Horton_Tucker.player_FTA = 25
Talen_Horton_Tucker.player_TRB = 51
Talen_Horton_Tucker.player_AST = 81
Talen_Horton_Tucker.player_STL = 15
Talen_Horton_Tucker.player_BLK = 8
Talen_Horton_Tucker.player_TOV = 35
Talen_Horton_Tucker.player_PF = 40
Talen_Horton_Tucker.player_PTS = 159

Danuel_House_Jr = Player('Danuel_House_Jr.')
Danuel_House_Jr.hasClubTeam.append(Philadelphia_76ers)
Danuel_House_Jr.hasPosition.append(SF)
Danuel_House_Jr.player_Age = 30
Danuel_House_Jr.player_G = 10
Danuel_House_Jr.player_MP = 127
Danuel_House_Jr.player_MP = 127
Danuel_House_Jr.player_FG = 13
Danuel_House_Jr.player_FGA = 31
Danuel_House_Jr.player_FT = 8
Danuel_House_Jr.player_FTA = 10
Danuel_House_Jr.player_TRB = 14
Danuel_House_Jr.player_AST = 8
Danuel_House_Jr.player_STL = 5
Danuel_House_Jr.player_BLK = 1
Danuel_House_Jr.player_TOV = 9
Danuel_House_Jr.player_PF = 10
Danuel_House_Jr.player_PTS = 38

Caleb_Houstan = Player('Caleb_Houstan')
Caleb_Houstan.hasClubTeam.append(Orlando_Magic)
Caleb_Houstan.hasPosition.append(SF)
Caleb_Houstan.player_Age = 21
Caleb_Houstan.player_G = 10
Caleb_Houstan.player_MP = 69
Caleb_Houstan.player_MP = 69
Caleb_Houstan.player_FG = 7
Caleb_Houstan.player_FGA = 15
Caleb_Houstan.player_FT = 4
Caleb_Houstan.player_FTA = 4
Caleb_Houstan.player_TRB = 10
Caleb_Houstan.player_AST = 4
Caleb_Houstan.player_STL = 2
Caleb_Houstan.player_BLK = 0
Caleb_Houstan.player_TOV = 2
Caleb_Houstan.player_PF = 5
Caleb_Houstan.player_PTS = 24

Jett_Howard = Player('Jett_Howard')
Jett_Howard.hasClubTeam.append(Orlando_Magic)
Jett_Howard.hasPosition.append(SF)
Jett_Howard.player_Age = 20
Jett_Howard.player_G = 5
Jett_Howard.player_MP = 23
Jett_Howard.player_MP = 23
Jett_Howard.player_FG = 1
Jett_Howard.player_FGA = 10
Jett_Howard.player_FT = 0
Jett_Howard.player_FTA = 0
Jett_Howard.player_TRB = 2
Jett_Howard.player_AST = 2
Jett_Howard.player_STL = 0
Jett_Howard.player_BLK = 0
Jett_Howard.player_TOV = 2
Jett_Howard.player_PF = 0
Jett_Howard.player_PTS = 2

Kevin_Huerter = Player('Kevin_Huerter')
Kevin_Huerter.hasClubTeam.append(Sacramento_Kings)
Kevin_Huerter.hasPosition.append(SG)
Kevin_Huerter.player_Age = 25
Kevin_Huerter.player_G = 15
Kevin_Huerter.player_MP = 415
Kevin_Huerter.player_MP = 415
Kevin_Huerter.player_FG = 73
Kevin_Huerter.player_FGA = 165
Kevin_Huerter.player_FT = 13
Kevin_Huerter.player_FTA = 16
Kevin_Huerter.player_TRB = 69
Kevin_Huerter.player_AST = 45
Kevin_Huerter.player_STL = 13
Kevin_Huerter.player_BLK = 5
Kevin_Huerter.player_TOV = 12
Kevin_Huerter.player_PF = 36
Kevin_Huerter.player_PTS = 198

Jay_Huff = Player('Jay_Huff')
Jay_Huff.hasClubTeam.append(Denver_Nuggets)
Jay_Huff.hasPosition.append(CE)
Jay_Huff.player_Age = 25
Jay_Huff.player_G = 1
Jay_Huff.player_MP = 2
Jay_Huff.player_MP = 2
Jay_Huff.player_FG = 1
Jay_Huff.player_FGA = 1
Jay_Huff.player_FT = 0
Jay_Huff.player_FTA = 0
Jay_Huff.player_TRB = 0
Jay_Huff.player_AST = 0
Jay_Huff.player_STL = 0
Jay_Huff.player_BLK = 0
Jay_Huff.player_TOV = 0
Jay_Huff.player_PF = 0
Jay_Huff.player_PTS = 2

DeAndre_Hunter = Player('DeAndre_Hunter')
DeAndre_Hunter.hasClubTeam.append(Atlanta_Hawks)
DeAndre_Hunter.hasPosition.append(SF)
DeAndre_Hunter.player_Age = 26
DeAndre_Hunter.player_G = 17
DeAndre_Hunter.player_MP = 517
DeAndre_Hunter.player_MP = 517
DeAndre_Hunter.player_FG = 84
DeAndre_Hunter.player_FGA = 182
DeAndre_Hunter.player_FT = 49
DeAndre_Hunter.player_FTA = 56
DeAndre_Hunter.player_TRB = 71
DeAndre_Hunter.player_AST = 23
DeAndre_Hunter.player_STL = 15
DeAndre_Hunter.player_BLK = 7
DeAndre_Hunter.player_TOV = 24
DeAndre_Hunter.player_PF = 54
DeAndre_Hunter.player_PTS = 248

Bones_Hyland = Player('Bones_Hyland')
Bones_Hyland.hasClubTeam.append(Los_Angeles_Clippers)
Bones_Hyland.hasPosition.append(PG)
Bones_Hyland.player_Age = 23
Bones_Hyland.player_G = 10
Bones_Hyland.player_MP = 196
Bones_Hyland.player_MP = 196
Bones_Hyland.player_FG = 37
Bones_Hyland.player_FGA = 87
Bones_Hyland.player_FT = 9
Bones_Hyland.player_FTA = 10
Bones_Hyland.player_TRB = 14
Bones_Hyland.player_AST = 24
Bones_Hyland.player_STL = 6
Bones_Hyland.player_BLK = 0
Bones_Hyland.player_TOV = 19
Bones_Hyland.player_PF = 21
Bones_Hyland.player_PTS = 100

Joe_Ingles = Player('Joe_Ingles')
Joe_Ingles.hasClubTeam.append(Orlando_Magic)
Joe_Ingles.hasPosition.append(SF)
Joe_Ingles.player_Age = 36
Joe_Ingles.player_G = 17
Joe_Ingles.player_MP = 317
Joe_Ingles.player_MP = 317
Joe_Ingles.player_FG = 23
Joe_Ingles.player_FGA = 61
Joe_Ingles.player_FT = 7
Joe_Ingles.player_FTA = 8
Joe_Ingles.player_TRB = 43
Joe_Ingles.player_AST = 54
Joe_Ingles.player_STL = 15
Joe_Ingles.player_BLK = 2
Joe_Ingles.player_TOV = 16
Joe_Ingles.player_PF = 25
Joe_Ingles.player_PTS = 68

Brandon_Ingram = Player('Brandon_Ingram')
Brandon_Ingram.hasClubTeam.append(New_Orleans_Pelicans)
Brandon_Ingram.hasPosition.append(SF)
Brandon_Ingram.player_Age = 26
Brandon_Ingram.player_G = 15
Brandon_Ingram.player_MP = 507
Brandon_Ingram.player_MP = 507
Brandon_Ingram.player_FG = 149
Brandon_Ingram.player_FGA = 297
Brandon_Ingram.player_FT = 51
Brandon_Ingram.player_FTA = 67
Brandon_Ingram.player_TRB = 78
Brandon_Ingram.player_AST = 76
Brandon_Ingram.player_STL = 9
Brandon_Ingram.player_BLK = 2
Brandon_Ingram.player_TOV = 40
Brandon_Ingram.player_PF = 32
Brandon_Ingram.player_PTS = 369

Kyrie_Irving = Player('Kyrie_Irving')
Kyrie_Irving.hasClubTeam.append(Dallas_Mavericks)
Kyrie_Irving.hasPosition.append(SG)
Kyrie_Irving.player_Age = 31
Kyrie_Irving.player_G = 14
Kyrie_Irving.player_MP = 464
Kyrie_Irving.player_MP = 464
Kyrie_Irving.player_FG = 128
Kyrie_Irving.player_FGA = 273
Kyrie_Irving.player_FT = 49
Kyrie_Irving.player_FTA = 54
Kyrie_Irving.player_TRB = 57
Kyrie_Irving.player_AST = 77
Kyrie_Irving.player_STL = 16
Kyrie_Irving.player_BLK = 5
Kyrie_Irving.player_TOV = 21
Kyrie_Irving.player_PF = 26
Kyrie_Irving.player_PTS = 344

Jonathan_Isaac = Player('Jonathan_Isaac')
Jonathan_Isaac.hasClubTeam.append(Orlando_Magic)
Jonathan_Isaac.hasPosition.append(PF)
Jonathan_Isaac.player_Age = 26
Jonathan_Isaac.player_G = 14
Jonathan_Isaac.player_MP = 194
Jonathan_Isaac.player_MP = 194
Jonathan_Isaac.player_FG = 31
Jonathan_Isaac.player_FGA = 71
Jonathan_Isaac.player_FT = 22
Jonathan_Isaac.player_FTA = 28
Jonathan_Isaac.player_TRB = 62
Jonathan_Isaac.player_AST = 5
Jonathan_Isaac.player_STL = 13
Jonathan_Isaac.player_BLK = 18
Jonathan_Isaac.player_TOV = 10
Jonathan_Isaac.player_PF = 20
Jonathan_Isaac.player_PTS = 92

Jaden_Ivey = Player('Jaden_Ivey')
Jaden_Ivey.hasClubTeam.append(Detroit_Pistons)
Jaden_Ivey.hasPosition.append(SG)
Jaden_Ivey.player_Age = 21
Jaden_Ivey.player_G = 13
Jaden_Ivey.player_MP = 308
Jaden_Ivey.player_MP = 308
Jaden_Ivey.player_FG = 61
Jaden_Ivey.player_FGA = 116
Jaden_Ivey.player_FT = 28
Jaden_Ivey.player_FTA = 37
Jaden_Ivey.player_TRB = 38
Jaden_Ivey.player_AST = 42
Jaden_Ivey.player_STL = 10
Jaden_Ivey.player_BLK = 5
Jaden_Ivey.player_TOV = 30
Jaden_Ivey.player_PF = 33
Jaden_Ivey.player_PTS = 165

Andre_Jackson_Jr = Player('Andre_Jackson_Jr.')
Andre_Jackson_Jr.hasClubTeam.append(Milwaukee_Bucks)
Andre_Jackson_Jr.hasPosition.append(SG)
Andre_Jackson_Jr.player_Age = 22
Andre_Jackson_Jr.player_G = 14
Andre_Jackson_Jr.player_MP = 117
Andre_Jackson_Jr.player_MP = 117
Andre_Jackson_Jr.player_FG = 12
Andre_Jackson_Jr.player_FGA = 19
Andre_Jackson_Jr.player_FT = 0
Andre_Jackson_Jr.player_FTA = 0
Andre_Jackson_Jr.player_TRB = 19
Andre_Jackson_Jr.player_AST = 10
Andre_Jackson_Jr.player_STL = 3
Andre_Jackson_Jr.player_BLK = 0
Andre_Jackson_Jr.player_TOV = 7
Andre_Jackson_Jr.player_PF = 22
Andre_Jackson_Jr.player_PTS = 30

Gregory_Jackson_II = Player('Gregory_Jackson_II')
Gregory_Jackson_II.hasClubTeam.append(Memphis_Grizzlies)
Gregory_Jackson_II.hasPosition.append(PF)
Gregory_Jackson_II.player_Age = 19
Gregory_Jackson_II.player_G = 3
Gregory_Jackson_II.player_MP = 7
Gregory_Jackson_II.player_MP = 7
Gregory_Jackson_II.player_FG = 0
Gregory_Jackson_II.player_FGA = 4
Gregory_Jackson_II.player_FT = 0
Gregory_Jackson_II.player_FTA = 0
Gregory_Jackson_II.player_TRB = 3
Gregory_Jackson_II.player_AST = 0
Gregory_Jackson_II.player_STL = 1
Gregory_Jackson_II.player_BLK = 0
Gregory_Jackson_II.player_TOV = 1
Gregory_Jackson_II.player_PF = 0
Gregory_Jackson_II.player_PTS = 0

Isaiah_Jackson = Player('Isaiah_Jackson')
Isaiah_Jackson.hasClubTeam.append(Indiana_Pacers)
Isaiah_Jackson.hasPosition.append(CE)
Isaiah_Jackson.player_Age = 22
Isaiah_Jackson.player_G = 9
Isaiah_Jackson.player_MP = 126
Isaiah_Jackson.player_MP = 126
Isaiah_Jackson.player_FG = 16
Isaiah_Jackson.player_FGA = 31
Isaiah_Jackson.player_FT = 14
Isaiah_Jackson.player_FTA = 21
Isaiah_Jackson.player_TRB = 41
Isaiah_Jackson.player_AST = 8
Isaiah_Jackson.player_STL = 4
Isaiah_Jackson.player_BLK = 18
Isaiah_Jackson.player_TOV = 5
Isaiah_Jackson.player_PF = 29
Isaiah_Jackson.player_PTS = 46

Jaren_Jackson_Jr = Player('Jaren_Jackson_Jr.')
Jaren_Jackson_Jr.hasClubTeam.append(Memphis_Grizzlies)
Jaren_Jackson_Jr.hasPosition.append(CE)
Jaren_Jackson_Jr.player_Age = 24
Jaren_Jackson_Jr.player_G = 16
Jaren_Jackson_Jr.player_MP = 501
Jaren_Jackson_Jr.player_MP = 501
Jaren_Jackson_Jr.player_FG = 102
Jaren_Jackson_Jr.player_FGA = 248
Jaren_Jackson_Jr.player_FT = 83
Jaren_Jackson_Jr.player_FTA = 102
Jaren_Jackson_Jr.player_TRB = 98
Jaren_Jackson_Jr.player_AST = 31
Jaren_Jackson_Jr.player_STL = 9
Jaren_Jackson_Jr.player_BLK = 25
Jaren_Jackson_Jr.player_TOV = 31
Jaren_Jackson_Jr.player_PF = 55
Jaren_Jackson_Jr.player_PTS = 311

Reggie_Jackson = Player('Reggie_Jackson')
Reggie_Jackson.hasClubTeam.append(Denver_Nuggets)
Reggie_Jackson.hasPosition.append(PG)
Reggie_Jackson.player_Age = 33
Reggie_Jackson.player_G = 18
Reggie_Jackson.player_MP = 478
Reggie_Jackson.player_MP = 478
Reggie_Jackson.player_FG = 93
Reggie_Jackson.player_FGA = 185
Reggie_Jackson.player_FT = 17
Reggie_Jackson.player_FTA = 26
Reggie_Jackson.player_TRB = 46
Reggie_Jackson.player_AST = 81
Reggie_Jackson.player_STL = 15
Reggie_Jackson.player_BLK = 6
Reggie_Jackson.player_TOV = 32
Reggie_Jackson.player_PF = 33
Reggie_Jackson.player_PTS = 231

Trayce_Jackson_Davis = Player('Trayce_Jackson-Davis')
Trayce_Jackson_Davis.hasClubTeam.append(Golden_State_Warriors)
Trayce_Jackson_Davis.hasPosition.append(PF)
Trayce_Jackson_Davis.player_Age = 23
Trayce_Jackson_Davis.player_G = 13
Trayce_Jackson_Davis.player_MP = 102
Trayce_Jackson_Davis.player_MP = 102
Trayce_Jackson_Davis.player_FG = 12
Trayce_Jackson_Davis.player_FGA = 22
Trayce_Jackson_Davis.player_FT = 15
Trayce_Jackson_Davis.player_FTA = 25
Trayce_Jackson_Davis.player_TRB = 23
Trayce_Jackson_Davis.player_AST = 6
Trayce_Jackson_Davis.player_STL = 2
Trayce_Jackson_Davis.player_BLK = 7
Trayce_Jackson_Davis.player_TOV = 6
Trayce_Jackson_Davis.player_PF = 18
Trayce_Jackson_Davis.player_PTS = 39

LeBron_James = Player('LeBron_James')
LeBron_James.hasClubTeam.append(Los_Angeles_Lakers)
LeBron_James.hasPosition.append(PF)
LeBron_James.player_Age = 39
LeBron_James.player_G = 17
LeBron_James.player_MP = 572
LeBron_James.player_MP = 572
LeBron_James.player_FG = 160
LeBron_James.player_FGA = 284
LeBron_James.player_FT = 68
LeBron_James.player_FTA = 99
LeBron_James.player_TRB = 128
LeBron_James.player_AST = 111
LeBron_James.player_STL = 25
LeBron_James.player_BLK = 13
LeBron_James.player_TOV = 62
LeBron_James.player_PF = 20
LeBron_James.player_PTS = 426

Jaime_Jaquez_Jr = Player('Jaime_Jaquez_Jr.')
Jaime_Jaquez_Jr.hasClubTeam.append(Miami_Heat)
Jaime_Jaquez_Jr.hasPosition.append(SF)
Jaime_Jaquez_Jr.player_Age = 22
Jaime_Jaquez_Jr.player_G = 18
Jaime_Jaquez_Jr.player_MP = 472
Jaime_Jaquez_Jr.player_MP = 472
Jaime_Jaquez_Jr.player_FG = 84
Jaime_Jaquez_Jr.player_FGA = 161
Jaime_Jaquez_Jr.player_FT = 14
Jaime_Jaquez_Jr.player_FTA = 17
Jaime_Jaquez_Jr.player_TRB = 69
Jaime_Jaquez_Jr.player_AST = 47
Jaime_Jaquez_Jr.player_STL = 19
Jaime_Jaquez_Jr.player_BLK = 4
Jaime_Jaquez_Jr.player_TOV = 26
Jaime_Jaquez_Jr.player_PF = 42
Jaime_Jaquez_Jr.player_PTS = 204

DaQuan_Jeffries = Player('DaQuan_Jeffries')
DaQuan_Jeffries.hasClubTeam.append(New_York_Knicks)
DaQuan_Jeffries.hasPosition.append(SG)
DaQuan_Jeffries.player_Age = 26
DaQuan_Jeffries.player_G = 7
DaQuan_Jeffries.player_MP = 19
DaQuan_Jeffries.player_MP = 19
DaQuan_Jeffries.player_FG = 3
DaQuan_Jeffries.player_FGA = 8
DaQuan_Jeffries.player_FT = 0
DaQuan_Jeffries.player_FTA = 2
DaQuan_Jeffries.player_TRB = 3
DaQuan_Jeffries.player_AST = 1
DaQuan_Jeffries.player_STL = 0
DaQuan_Jeffries.player_BLK = 0
DaQuan_Jeffries.player_TOV = 1
DaQuan_Jeffries.player_PF = 1
DaQuan_Jeffries.player_PTS = 7

Ty_Jerome = Player('Ty_Jerome')
Ty_Jerome.hasClubTeam.append(Cleveland_Cavaliers)
Ty_Jerome.hasPosition.append(SG)
Ty_Jerome.player_Age = 26
Ty_Jerome.player_G = 2
Ty_Jerome.player_MP = 15
Ty_Jerome.player_MP = 15
Ty_Jerome.player_FG = 2
Ty_Jerome.player_FGA = 4
Ty_Jerome.player_FT = 0
Ty_Jerome.player_FTA = 0
Ty_Jerome.player_TRB = 1
Ty_Jerome.player_AST = 3
Ty_Jerome.player_STL = 0
Ty_Jerome.player_BLK = 0
Ty_Jerome.player_TOV = 1
Ty_Jerome.player_PF = 2
Ty_Jerome.player_PTS = 4

Isaiah_Joe = Player('Isaiah_Joe')
Isaiah_Joe.hasClubTeam.append(Oklahoma_City_Thunder)
Isaiah_Joe.hasPosition.append(SG)
Isaiah_Joe.player_Age = 24
Isaiah_Joe.player_G = 17
Isaiah_Joe.player_MP = 352
Isaiah_Joe.player_MP = 352
Isaiah_Joe.player_FG = 59
Isaiah_Joe.player_FGA = 128
Isaiah_Joe.player_FT = 20
Isaiah_Joe.player_FTA = 24
Isaiah_Joe.player_TRB = 36
Isaiah_Joe.player_AST = 21
Isaiah_Joe.player_STL = 15
Isaiah_Joe.player_BLK = 3
Isaiah_Joe.player_TOV = 9
Isaiah_Joe.player_PF = 22
Isaiah_Joe.player_PTS = 186

Cameron_Johnson = Player('Cameron_Johnson')
Cameron_Johnson.hasClubTeam.append(Brooklyn_Nets)
Cameron_Johnson.hasPosition.append(PF)
Cameron_Johnson.player_Age = 27
Cameron_Johnson.player_G = 10
Cameron_Johnson.player_MP = 292
Cameron_Johnson.player_MP = 292
Cameron_Johnson.player_FG = 55
Cameron_Johnson.player_FGA = 117
Cameron_Johnson.player_FT = 19
Cameron_Johnson.player_FTA = 22
Cameron_Johnson.player_TRB = 58
Cameron_Johnson.player_AST = 30
Cameron_Johnson.player_STL = 10
Cameron_Johnson.player_BLK = 1
Cameron_Johnson.player_TOV = 15
Cameron_Johnson.player_PF = 18
Cameron_Johnson.player_PTS = 152

Jalen_Johnson = Player('Jalen_Johnson')
Jalen_Johnson.hasClubTeam.append(Atlanta_Hawks)
Jalen_Johnson.hasPosition.append(SF)
Jalen_Johnson.player_Age = 22
Jalen_Johnson.player_G = 15
Jalen_Johnson.player_MP = 449
Jalen_Johnson.player_MP = 449
Jalen_Johnson.player_FG = 85
Jalen_Johnson.player_FGA = 143
Jalen_Johnson.player_FT = 25
Jalen_Johnson.player_FTA = 33
Jalen_Johnson.player_TRB = 109
Jalen_Johnson.player_AST = 36
Jalen_Johnson.player_STL = 17
Jalen_Johnson.player_BLK = 15
Jalen_Johnson.player_TOV = 30
Jalen_Johnson.player_PF = 33
Jalen_Johnson.player_PTS = 212

Keldon_Johnson = Player('Keldon_Johnson')
Keldon_Johnson.hasClubTeam.append(San_Antonio_Spurs)
Keldon_Johnson.hasPosition.append(SF)
Keldon_Johnson.player_Age = 24
Keldon_Johnson.player_G = 16
Keldon_Johnson.player_MP = 525
Keldon_Johnson.player_MP = 525
Keldon_Johnson.player_FG = 100
Keldon_Johnson.player_FGA = 215
Keldon_Johnson.player_FT = 33
Keldon_Johnson.player_FTA = 47
Keldon_Johnson.player_TRB = 99
Keldon_Johnson.player_AST = 68
Keldon_Johnson.player_STL = 12
Keldon_Johnson.player_BLK = 5
Keldon_Johnson.player_TOV = 19
Keldon_Johnson.player_PF = 41
Keldon_Johnson.player_PTS = 265

Keyontae_Johnson = Player('Keyontae_Johnson')
Keyontae_Johnson.hasClubTeam.append(Oklahoma_City_Thunder)
Keyontae_Johnson.hasPosition.append(SF)
Keyontae_Johnson.player_Age = 23
Keyontae_Johnson.player_G = 1
Keyontae_Johnson.player_MP = 6
Keyontae_Johnson.player_MP = 6
Keyontae_Johnson.player_FG = 0
Keyontae_Johnson.player_FGA = 1
Keyontae_Johnson.player_FT = 0
Keyontae_Johnson.player_FTA = 0
Keyontae_Johnson.player_TRB = 0
Keyontae_Johnson.player_AST = 0
Keyontae_Johnson.player_STL = 0
Keyontae_Johnson.player_BLK = 0
Keyontae_Johnson.player_TOV = 0
Keyontae_Johnson.player_PF = 0
Keyontae_Johnson.player_PTS = 0

Nikola_Jokic = Player('Nikola_Jokic')
Nikola_Jokic.hasClubTeam.append(Denver_Nuggets)
Nikola_Jokic.hasPosition.append(CE)
Nikola_Jokic.player_Age = 28
Nikola_Jokic.player_G = 17
Nikola_Jokic.player_MP = 574
Nikola_Jokic.player_MP = 574
Nikola_Jokic.player_FG = 193
Nikola_Jokic.player_FGA = 340
Nikola_Jokic.player_FT = 81
Nikola_Jokic.player_FTA = 102
Nikola_Jokic.player_TRB = 227
Nikola_Jokic.player_AST = 151
Nikola_Jokic.player_STL = 20
Nikola_Jokic.player_BLK = 13
Nikola_Jokic.player_TOV = 55
Nikola_Jokic.player_PF = 42
Nikola_Jokic.player_PTS = 490

Colby_Jones = Player('Colby_Jones')
Colby_Jones.hasClubTeam.append(Sacramento_Kings)
Colby_Jones.hasPosition.append(SG)
Colby_Jones.player_Age = 21
Colby_Jones.player_G = 8
Colby_Jones.player_MP = 69
Colby_Jones.player_MP = 69
Colby_Jones.player_FG = 12
Colby_Jones.player_FGA = 26
Colby_Jones.player_FT = 2
Colby_Jones.player_FTA = 3
Colby_Jones.player_TRB = 13
Colby_Jones.player_AST = 2
Colby_Jones.player_STL = 2
Colby_Jones.player_BLK = 1
Colby_Jones.player_TOV = 3
Colby_Jones.player_PF = 9
Colby_Jones.player_PTS = 27

Damian_Jones = Player('Damian_Jones')
Damian_Jones.hasClubTeam.append(Cleveland_Cavaliers)
Damian_Jones.hasPosition.append(CE)
Damian_Jones.player_Age = 28
Damian_Jones.player_G = 10
Damian_Jones.player_MP = 51
Damian_Jones.player_MP = 51
Damian_Jones.player_FG = 4
Damian_Jones.player_FGA = 8
Damian_Jones.player_FT = 1
Damian_Jones.player_FTA = 2
Damian_Jones.player_TRB = 10
Damian_Jones.player_AST = 3
Damian_Jones.player_STL = 1
Damian_Jones.player_BLK = 2
Damian_Jones.player_TOV = 3
Damian_Jones.player_PF = 3
Damian_Jones.player_PTS = 9

Derrick_Jones_Jr = Player('Derrick_Jones_Jr.')
Derrick_Jones_Jr.hasClubTeam.append(Dallas_Mavericks)
Derrick_Jones_Jr.hasPosition.append(SF)
Derrick_Jones_Jr.player_Age = 26
Derrick_Jones_Jr.player_G = 17
Derrick_Jones_Jr.player_MP = 381
Derrick_Jones_Jr.player_MP = 381
Derrick_Jones_Jr.player_FG = 53
Derrick_Jones_Jr.player_FGA = 109
Derrick_Jones_Jr.player_FT = 17
Derrick_Jones_Jr.player_FTA = 23
Derrick_Jones_Jr.player_TRB = 61
Derrick_Jones_Jr.player_AST = 17
Derrick_Jones_Jr.player_STL = 9
Derrick_Jones_Jr.player_BLK = 12
Derrick_Jones_Jr.player_TOV = 15
Derrick_Jones_Jr.player_PF = 26
Derrick_Jones_Jr.player_PTS = 147

Herbert_Jones = Player('Herbert_Jones')
Herbert_Jones.hasClubTeam.append(New_Orleans_Pelicans)
Herbert_Jones.hasPosition.append(SF)
Herbert_Jones.player_Age = 25
Herbert_Jones.player_G = 15
Herbert_Jones.player_MP = 462
Herbert_Jones.player_MP = 462
Herbert_Jones.player_FG = 59
Herbert_Jones.player_FGA = 114
Herbert_Jones.player_FT = 36
Herbert_Jones.player_FTA = 42
Herbert_Jones.player_TRB = 61
Herbert_Jones.player_AST = 40
Herbert_Jones.player_STL = 28
Herbert_Jones.player_BLK = 21
Herbert_Jones.player_TOV = 22
Herbert_Jones.player_PF = 57
Herbert_Jones.player_PTS = 172

Tre_Jones = Player('Tre_Jones')
Tre_Jones.hasClubTeam.append(San_Antonio_Spurs)
Tre_Jones.hasPosition.append(PG)
Tre_Jones.player_Age = 24
Tre_Jones.player_G = 14
Tre_Jones.player_MP = 336
Tre_Jones.player_MP = 336
Tre_Jones.player_FG = 43
Tre_Jones.player_FGA = 99
Tre_Jones.player_FT = 20
Tre_Jones.player_FTA = 22
Tre_Jones.player_TRB = 42
Tre_Jones.player_AST = 71
Tre_Jones.player_STL = 12
Tre_Jones.player_BLK = 4
Tre_Jones.player_TOV = 20
Tre_Jones.player_PF = 18
Tre_Jones.player_PTS = 113

Tyus_Jones = Player('Tyus_Jones')
Tyus_Jones.hasClubTeam.append(Washington_Wizards)
Tyus_Jones.hasPosition.append(PG)
Tyus_Jones.player_Age = 27
Tyus_Jones.player_G = 17
Tyus_Jones.player_MP = 462
Tyus_Jones.player_MP = 462
Tyus_Jones.player_FG = 80
Tyus_Jones.player_FGA = 159
Tyus_Jones.player_FT = 8
Tyus_Jones.player_FTA = 11
Tyus_Jones.player_TRB = 47
Tyus_Jones.player_AST = 83
Tyus_Jones.player_STL = 14
Tyus_Jones.player_BLK = 2
Tyus_Jones.player_TOV = 12
Tyus_Jones.player_PF = 15
Tyus_Jones.player_PTS = 186

DeAndre_Jordan = Player('DeAndre_Jordan')
DeAndre_Jordan.hasClubTeam.append(Denver_Nuggets)
DeAndre_Jordan.hasPosition.append(CE)
DeAndre_Jordan.player_Age = 35
DeAndre_Jordan.player_G = 3
DeAndre_Jordan.player_MP = 58
DeAndre_Jordan.player_MP = 58
DeAndre_Jordan.player_FG = 11
DeAndre_Jordan.player_FGA = 14
DeAndre_Jordan.player_FT = 6
DeAndre_Jordan.player_FTA = 16
DeAndre_Jordan.player_TRB = 20
DeAndre_Jordan.player_AST = 7
DeAndre_Jordan.player_STL = 2
DeAndre_Jordan.player_BLK = 1
DeAndre_Jordan.player_TOV = 4
DeAndre_Jordan.player_PF = 8
DeAndre_Jordan.player_PTS = 28

Cory_Joseph = Player('Cory_Joseph')
Cory_Joseph.hasClubTeam.append(Golden_State_Warriors)
Cory_Joseph.hasPosition.append(PG)
Cory_Joseph.player_Age = 32
Cory_Joseph.player_G = 8
Cory_Joseph.player_MP = 71
Cory_Joseph.player_MP = 71
Cory_Joseph.player_FG = 6
Cory_Joseph.player_FGA = 21
Cory_Joseph.player_FT = 3
Cory_Joseph.player_FTA = 5
Cory_Joseph.player_TRB = 7
Cory_Joseph.player_AST = 16
Cory_Joseph.player_STL = 3
Cory_Joseph.player_BLK = 1
Cory_Joseph.player_TOV = 5
Cory_Joseph.player_PF = 7
Cory_Joseph.player_PTS = 19

Nikola_Jovic = Player('Nikola_Jovic')
Nikola_Jovic.hasClubTeam.append(Miami_Heat)
Nikola_Jovic.hasPosition.append(PF)
Nikola_Jovic.player_Age = 20
Nikola_Jovic.player_G = 3
Nikola_Jovic.player_MP = 45
Nikola_Jovic.player_MP = 45
Nikola_Jovic.player_FG = 4
Nikola_Jovic.player_FGA = 11
Nikola_Jovic.player_FT = 3
Nikola_Jovic.player_FTA = 4
Nikola_Jovic.player_TRB = 21
Nikola_Jovic.player_AST = 9
Nikola_Jovic.player_STL = 1
Nikola_Jovic.player_BLK = 0
Nikola_Jovic.player_TOV = 4
Nikola_Jovic.player_PF = 7
Nikola_Jovic.player_PTS = 14

Luke_Kennard = Player('Luke_Kennard')
Luke_Kennard.hasClubTeam.append(Memphis_Grizzlies)
Luke_Kennard.hasPosition.append(SG)
Luke_Kennard.player_Age = 27
Luke_Kennard.player_G = 8
Luke_Kennard.player_MP = 172
Luke_Kennard.player_MP = 172
Luke_Kennard.player_FG = 21
Luke_Kennard.player_FGA = 58
Luke_Kennard.player_FT = 7
Luke_Kennard.player_FTA = 7
Luke_Kennard.player_TRB = 23
Luke_Kennard.player_AST = 16
Luke_Kennard.player_STL = 5
Luke_Kennard.player_BLK = 1
Luke_Kennard.player_TOV = 5
Luke_Kennard.player_PF = 4
Luke_Kennard.player_PTS = 66

Walker_Kessler = Player('Walker_Kessler')
Walker_Kessler.hasClubTeam.append(Utah_Jazz)
Walker_Kessler.hasPosition.append(CE)
Walker_Kessler.player_Age = 22
Walker_Kessler.player_G = 10
Walker_Kessler.player_MP = 239
Walker_Kessler.player_MP = 239
Walker_Kessler.player_FG = 40
Walker_Kessler.player_FGA = 70
Walker_Kessler.player_FT = 9
Walker_Kessler.player_FTA = 15
Walker_Kessler.player_TRB = 82
Walker_Kessler.player_AST = 5
Walker_Kessler.player_STL = 1
Walker_Kessler.player_BLK = 21
Walker_Kessler.player_TOV = 11
Walker_Kessler.player_PF = 26
Walker_Kessler.player_PTS = 91

Braxton_Key = Player('Braxton_Key')
Braxton_Key.hasClubTeam.append(Denver_Nuggets)
Braxton_Key.hasPosition.append(SF)
Braxton_Key.player_Age = 26
Braxton_Key.player_G = 5
Braxton_Key.player_MP = 12
Braxton_Key.player_MP = 12
Braxton_Key.player_FG = 1
Braxton_Key.player_FGA = 5
Braxton_Key.player_FT = 0
Braxton_Key.player_FTA = 0
Braxton_Key.player_TRB = 2
Braxton_Key.player_AST = 4
Braxton_Key.player_STL = 0
Braxton_Key.player_BLK = 0
Braxton_Key.player_TOV = 0
Braxton_Key.player_PF = 2
Braxton_Key.player_PTS = 2

Corey_Kispert = Player('Corey_Kispert')
Corey_Kispert.hasClubTeam.append(Washington_Wizards)
Corey_Kispert.hasPosition.append(SF)
Corey_Kispert.player_Age = 24
Corey_Kispert.player_G = 16
Corey_Kispert.player_MP = 369
Corey_Kispert.player_MP = 369
Corey_Kispert.player_FG = 58
Corey_Kispert.player_FGA = 130
Corey_Kispert.player_FT = 23
Corey_Kispert.player_FTA = 28
Corey_Kispert.player_TRB = 44
Corey_Kispert.player_AST = 24
Corey_Kispert.player_STL = 6
Corey_Kispert.player_BLK = 0
Corey_Kispert.player_TOV = 16
Corey_Kispert.player_PF = 29
Corey_Kispert.player_PTS = 168

Maxi_Kleber = Player('Maxi_Kleber')
Maxi_Kleber.hasClubTeam.append(Dallas_Mavericks)
Maxi_Kleber.hasPosition.append(CE)
Maxi_Kleber.player_Age = 32
Maxi_Kleber.player_G = 5
Maxi_Kleber.player_MP = 90
Maxi_Kleber.player_MP = 90
Maxi_Kleber.player_FG = 4
Maxi_Kleber.player_FGA = 16
Maxi_Kleber.player_FT = 6
Maxi_Kleber.player_FTA = 10
Maxi_Kleber.player_TRB = 21
Maxi_Kleber.player_AST = 10
Maxi_Kleber.player_STL = 1
Maxi_Kleber.player_BLK = 1
Maxi_Kleber.player_TOV = 4
Maxi_Kleber.player_PF = 8
Maxi_Kleber.player_PTS = 17

Kevin_Knox = Player('Kevin_Knox')
Kevin_Knox.hasClubTeam.append(Detroit_Pistons)
Kevin_Knox.hasPosition.append(SF)
Kevin_Knox.player_Age = 24
Kevin_Knox.player_G = 4
Kevin_Knox.player_MP = 110
Kevin_Knox.player_MP = 110
Kevin_Knox.player_FG = 19
Kevin_Knox.player_FGA = 37
Kevin_Knox.player_FT = 1
Kevin_Knox.player_FTA = 2
Kevin_Knox.player_TRB = 21
Kevin_Knox.player_AST = 3
Kevin_Knox.player_STL = 4
Kevin_Knox.player_BLK = 1
Kevin_Knox.player_TOV = 4
Kevin_Knox.player_PF = 11
Kevin_Knox.player_PTS = 47

John_Konchar = Player('John_Konchar')
John_Konchar.hasClubTeam.append(Memphis_Grizzlies)
John_Konchar.hasPosition.append(SF)
John_Konchar.player_Age = 27
John_Konchar.player_G = 13
John_Konchar.player_MP = 243
John_Konchar.player_MP = 243
John_Konchar.player_FG = 15
John_Konchar.player_FGA = 43
John_Konchar.player_FT = 1
John_Konchar.player_FTA = 2
John_Konchar.player_TRB = 55
John_Konchar.player_AST = 22
John_Konchar.player_STL = 8
John_Konchar.player_BLK = 9
John_Konchar.player_TOV = 4
John_Konchar.player_PF = 15
John_Konchar.player_PTS = 39

Furkan_Korkmaz = Player('Furkan_Korkmaz')
Furkan_Korkmaz.hasClubTeam.append(Philadelphia_76ers)
Furkan_Korkmaz.hasPosition.append(SG)
Furkan_Korkmaz.player_Age = 26
Furkan_Korkmaz.player_G = 12
Furkan_Korkmaz.player_MP = 86
Furkan_Korkmaz.player_MP = 86
Furkan_Korkmaz.player_FG = 11
Furkan_Korkmaz.player_FGA = 26
Furkan_Korkmaz.player_FT = 5
Furkan_Korkmaz.player_FTA = 7
Furkan_Korkmaz.player_TRB = 7
Furkan_Korkmaz.player_AST = 6
Furkan_Korkmaz.player_STL = 8
Furkan_Korkmaz.player_BLK = 0
Furkan_Korkmaz.player_TOV = 6
Furkan_Korkmaz.player_PF = 4
Furkan_Korkmaz.player_PTS = 31

Luke_Kornet = Player('Luke_Kornet')
Luke_Kornet.hasClubTeam.append(Boston_Celtics)
Luke_Kornet.hasPosition.append(CE)
Luke_Kornet.player_Age = 28
Luke_Kornet.player_G = 13
Luke_Kornet.player_MP = 176
Luke_Kornet.player_MP = 176
Luke_Kornet.player_FG = 26
Luke_Kornet.player_FGA = 32
Luke_Kornet.player_FT = 8
Luke_Kornet.player_FTA = 10
Luke_Kornet.player_TRB = 46
Luke_Kornet.player_AST = 7
Luke_Kornet.player_STL = 7
Luke_Kornet.player_BLK = 9
Luke_Kornet.player_TOV = 5
Luke_Kornet.player_PF = 16
Luke_Kornet.player_PTS = 60

Jonathan_Kuminga = Player('Jonathan_Kuminga')
Jonathan_Kuminga.hasClubTeam.append(Golden_State_Warriors)
Jonathan_Kuminga.hasPosition.append(PF)
Jonathan_Kuminga.player_Age = 21
Jonathan_Kuminga.player_G = 17
Jonathan_Kuminga.player_MP = 337
Jonathan_Kuminga.player_MP = 337
Jonathan_Kuminga.player_FG = 67
Jonathan_Kuminga.player_FGA = 153
Jonathan_Kuminga.player_FT = 45
Jonathan_Kuminga.player_FTA = 64
Jonathan_Kuminga.player_TRB = 49
Jonathan_Kuminga.player_AST = 16
Jonathan_Kuminga.player_STL = 9
Jonathan_Kuminga.player_BLK = 6
Jonathan_Kuminga.player_TOV = 24
Jonathan_Kuminga.player_PF = 43
Jonathan_Kuminga.player_PTS = 186

Kyle_Kuzma = Player('Kyle_Kuzma')
Kyle_Kuzma.hasClubTeam.append(Washington_Wizards)
Kyle_Kuzma.hasPosition.append(PF)
Kyle_Kuzma.player_Age = 28
Kyle_Kuzma.player_G = 17
Kyle_Kuzma.player_MP = 522
Kyle_Kuzma.player_MP = 522
Kyle_Kuzma.player_FG = 155
Kyle_Kuzma.player_FGA = 329
Kyle_Kuzma.player_FT = 47
Kyle_Kuzma.player_FTA = 57
Kyle_Kuzma.player_TRB = 106
Kyle_Kuzma.player_AST = 81
Kyle_Kuzma.player_STL = 5
Kyle_Kuzma.player_BLK = 10
Kyle_Kuzma.player_TOV = 37
Kyle_Kuzma.player_PF = 31
Kyle_Kuzma.player_PTS = 398

Jock_Landale = Player('Jock_Landale')
Jock_Landale.hasClubTeam.append(Houston_Rockets)
Jock_Landale.hasPosition.append(CE)
Jock_Landale.player_Age = 28
Jock_Landale.player_G = 11
Jock_Landale.player_MP = 96
Jock_Landale.player_MP = 96
Jock_Landale.player_FG = 7
Jock_Landale.player_FGA = 22
Jock_Landale.player_FT = 2
Jock_Landale.player_FTA = 2
Jock_Landale.player_TRB = 22
Jock_Landale.player_AST = 8
Jock_Landale.player_STL = 3
Jock_Landale.player_BLK = 2
Jock_Landale.player_TOV = 7
Jock_Landale.player_PF = 7
Jock_Landale.player_PTS = 18

Jake_LaRavia = Player('Jake_LaRavia')
Jake_LaRavia.hasClubTeam.append(Memphis_Grizzlies)
Jake_LaRavia.hasPosition.append(PF)
Jake_LaRavia.player_Age = 22
Jake_LaRavia.player_G = 5
Jake_LaRavia.player_MP = 61
Jake_LaRavia.player_MP = 61
Jake_LaRavia.player_FG = 7
Jake_LaRavia.player_FGA = 20
Jake_LaRavia.player_FT = 1
Jake_LaRavia.player_FTA = 2
Jake_LaRavia.player_TRB = 8
Jake_LaRavia.player_AST = 2
Jake_LaRavia.player_STL = 1
Jake_LaRavia.player_BLK = 0
Jake_LaRavia.player_TOV = 2
Jake_LaRavia.player_PF = 8
Jake_LaRavia.player_PTS = 17

Zach_LaVine = Player('Zach_LaVine')
Zach_LaVine.hasClubTeam.append(Chicago_Bulls)
Zach_LaVine.hasPosition.append(SG)
Zach_LaVine.player_Age = 28
Zach_LaVine.player_G = 18
Zach_LaVine.player_MP = 635
Zach_LaVine.player_MP = 635
Zach_LaVine.player_FG = 132
Zach_LaVine.player_FGA = 298
Zach_LaVine.player_FT = 71
Zach_LaVine.player_FTA = 82
Zach_LaVine.player_TRB = 88
Zach_LaVine.player_AST = 61
Zach_LaVine.player_STL = 17
Zach_LaVine.player_BLK = 4
Zach_LaVine.player_TOV = 36
Zach_LaVine.player_PF = 37
Zach_LaVine.player_PTS = 378

Saben_Lee = Player('Saben_Lee')
Saben_Lee.hasClubTeam.append(Phoenix_Suns)
Saben_Lee.hasPosition.append(PG)
Saben_Lee.player_Age = 24
Saben_Lee.player_G = 3
Saben_Lee.player_MP = 10
Saben_Lee.player_MP = 10
Saben_Lee.player_FG = 3
Saben_Lee.player_FGA = 6
Saben_Lee.player_FT = 0
Saben_Lee.player_FTA = 0
Saben_Lee.player_TRB = 3
Saben_Lee.player_AST = 3
Saben_Lee.player_STL = 0
Saben_Lee.player_BLK = 1
Saben_Lee.player_TOV = 0
Saben_Lee.player_PF = 1
Saben_Lee.player_PTS = 6

Alex_Len = Player('Alex_Len')
Alex_Len.hasClubTeam.append(Sacramento_Kings)
Alex_Len.hasPosition.append(CE)
Alex_Len.player_Age = 30
Alex_Len.player_G = 6
Alex_Len.player_MP = 41
Alex_Len.player_MP = 41
Alex_Len.player_FG = 6
Alex_Len.player_FGA = 8
Alex_Len.player_FT = 3
Alex_Len.player_FTA = 7
Alex_Len.player_TRB = 16
Alex_Len.player_AST = 5
Alex_Len.player_STL = 1
Alex_Len.player_BLK = 5
Alex_Len.player_TOV = 2
Alex_Len.player_PF = 2
Alex_Len.player_PTS = 15

Kawhi_Leonard = Player('Kawhi_Leonard')
Kawhi_Leonard.hasClubTeam.append(Los_Angeles_Clippers)
Kawhi_Leonard.hasPosition.append(SF)
Kawhi_Leonard.player_Age = 32
Kawhi_Leonard.player_G = 16
Kawhi_Leonard.player_MP = 542
Kawhi_Leonard.player_MP = 542
Kawhi_Leonard.player_FG = 123
Kawhi_Leonard.player_FGA = 273
Kawhi_Leonard.player_FT = 56
Kawhi_Leonard.player_FTA = 66
Kawhi_Leonard.player_TRB = 90
Kawhi_Leonard.player_AST = 55
Kawhi_Leonard.player_STL = 27
Kawhi_Leonard.player_BLK = 11
Kawhi_Leonard.player_TOV = 26
Kawhi_Leonard.player_PF = 24
Kawhi_Leonard.player_PTS = 337

Caris_LeVert = Player('Caris_LeVert')
Caris_LeVert.hasClubTeam.append(Cleveland_Cavaliers)
Caris_LeVert.hasPosition.append(SG)
Caris_LeVert.player_Age = 29
Caris_LeVert.player_G = 15
Caris_LeVert.player_MP = 460
Caris_LeVert.player_MP = 460
Caris_LeVert.player_FG = 85
Caris_LeVert.player_FGA = 204
Caris_LeVert.player_FT = 37
Caris_LeVert.player_FTA = 50
Caris_LeVert.player_TRB = 57
Caris_LeVert.player_AST = 55
Caris_LeVert.player_STL = 16
Caris_LeVert.player_BLK = 6
Caris_LeVert.player_TOV = 20
Caris_LeVert.player_PF = 26
Caris_LeVert.player_PTS = 233

Kira_Lewis_Jr = Player('Kira_Lewis_Jr.')
Kira_Lewis_Jr.hasClubTeam.append(New_Orleans_Pelicans)
Kira_Lewis_Jr.hasPosition.append(PG)
Kira_Lewis_Jr.player_Age = 22
Kira_Lewis_Jr.player_G = 11
Kira_Lewis_Jr.player_MP = 121
Kira_Lewis_Jr.player_MP = 121
Kira_Lewis_Jr.player_FG = 14
Kira_Lewis_Jr.player_FGA = 43
Kira_Lewis_Jr.player_FT = 8
Kira_Lewis_Jr.player_FTA = 9
Kira_Lewis_Jr.player_TRB = 10
Kira_Lewis_Jr.player_AST = 18
Kira_Lewis_Jr.player_STL = 5
Kira_Lewis_Jr.player_BLK = 1
Kira_Lewis_Jr.player_TOV = 5
Kira_Lewis_Jr.player_PF = 8
Kira_Lewis_Jr.player_PTS = 38

Maxwell_Lewis = Player('Maxwell_Lewis')
Maxwell_Lewis.hasClubTeam.append(Los_Angeles_Lakers)
Maxwell_Lewis.hasPosition.append(SF)
Maxwell_Lewis.player_Age = 21
Maxwell_Lewis.player_G = 7
Maxwell_Lewis.player_MP = 29
Maxwell_Lewis.player_MP = 29
Maxwell_Lewis.player_FG = 0
Maxwell_Lewis.player_FGA = 4
Maxwell_Lewis.player_FT = 0
Maxwell_Lewis.player_FTA = 0
Maxwell_Lewis.player_TRB = 2
Maxwell_Lewis.player_AST = 0
Maxwell_Lewis.player_STL = 0
Maxwell_Lewis.player_BLK = 0
Maxwell_Lewis.player_TOV = 4
Maxwell_Lewis.player_PF = 0
Maxwell_Lewis.player_PTS = 0

EJ_Liddell = Player('E.J._Liddell')
EJ_Liddell.hasClubTeam.append(New_Orleans_Pelicans)
EJ_Liddell.hasPosition.append(PF)
EJ_Liddell.player_Age = 23
EJ_Liddell.player_G = 3
EJ_Liddell.player_MP = 9
EJ_Liddell.player_MP = 9
EJ_Liddell.player_FG = 1
EJ_Liddell.player_FGA = 4
EJ_Liddell.player_FT = 2
EJ_Liddell.player_FTA = 2
EJ_Liddell.player_TRB = 2
EJ_Liddell.player_AST = 0
EJ_Liddell.player_STL = 0
EJ_Liddell.player_BLK = 1
EJ_Liddell.player_TOV = 1
EJ_Liddell.player_PF = 1
EJ_Liddell.player_PTS = 4

Damian_Lillard = Player('Damian_Lillard')
Damian_Lillard.hasClubTeam.append(Milwaukee_Bucks)
Damian_Lillard.hasPosition.append(PG)
Damian_Lillard.player_Age = 33
Damian_Lillard.player_G = 16
Damian_Lillard.player_MP = 549
Damian_Lillard.player_MP = 549
Damian_Lillard.player_FG = 115
Damian_Lillard.player_FGA = 276
Damian_Lillard.player_FT = 139
Damian_Lillard.player_FTA = 150
Damian_Lillard.player_TRB = 71
Damian_Lillard.player_AST = 103
Damian_Lillard.player_STL = 16
Damian_Lillard.player_BLK = 1
Damian_Lillard.player_TOV = 39
Damian_Lillard.player_PF = 21
Damian_Lillard.player_PTS = 416

Nassir_Little = Player('Nassir_Little')
Nassir_Little.hasClubTeam.append(Phoenix_Suns)
Nassir_Little.hasPosition.append(PF)
Nassir_Little.player_Age = 23
Nassir_Little.player_G = 12
Nassir_Little.player_MP = 177
Nassir_Little.player_MP = 177
Nassir_Little.player_FG = 25
Nassir_Little.player_FGA = 50
Nassir_Little.player_FT = 12
Nassir_Little.player_FTA = 14
Nassir_Little.player_TRB = 27
Nassir_Little.player_AST = 7
Nassir_Little.player_STL = 9
Nassir_Little.player_BLK = 7
Nassir_Little.player_TOV = 4
Nassir_Little.player_PF = 18
Nassir_Little.player_PTS = 72

Dereck_Lively_II = Player('Dereck_Lively_II')
Dereck_Lively_II.hasClubTeam.append(Dallas_Mavericks)
Dereck_Lively_II.hasPosition.append(CE)
Dereck_Lively_II.player_Age = 19
Dereck_Lively_II.player_G = 15
Dereck_Lively_II.player_MP = 365
Dereck_Lively_II.player_MP = 365
Dereck_Lively_II.player_FG = 54
Dereck_Lively_II.player_FGA = 76
Dereck_Lively_II.player_FT = 14
Dereck_Lively_II.player_FTA = 22
Dereck_Lively_II.player_TRB = 112
Dereck_Lively_II.player_AST = 20
Dereck_Lively_II.player_STL = 8
Dereck_Lively_II.player_BLK = 17
Dereck_Lively_II.player_TOV = 15
Dereck_Lively_II.player_PF = 51
Dereck_Lively_II.player_PTS = 122

Isaiah_Livers = Player('Isaiah_Livers')
Isaiah_Livers.hasClubTeam.append(Detroit_Pistons)
Isaiah_Livers.hasPosition.append(PF)
Isaiah_Livers.player_Age = 25
Isaiah_Livers.player_G = 3
Isaiah_Livers.player_MP = 72
Isaiah_Livers.player_MP = 72
Isaiah_Livers.player_FG = 7
Isaiah_Livers.player_FGA = 23
Isaiah_Livers.player_FT = 4
Isaiah_Livers.player_FTA = 4
Isaiah_Livers.player_TRB = 7
Isaiah_Livers.player_AST = 4
Isaiah_Livers.player_STL = 1
Isaiah_Livers.player_BLK = 0
Isaiah_Livers.player_TOV = 4
Isaiah_Livers.player_PF = 5
Isaiah_Livers.player_PTS = 22

Chris_Livingston = Player('Chris_Livingston')
Chris_Livingston.hasClubTeam.append(Milwaukee_Bucks)
Chris_Livingston.hasPosition.append(SF)
Chris_Livingston.player_Age = 20
Chris_Livingston.player_G = 2
Chris_Livingston.player_MP = 9
Chris_Livingston.player_MP = 9
Chris_Livingston.player_FG = 2
Chris_Livingston.player_FGA = 2
Chris_Livingston.player_FT = 0
Chris_Livingston.player_FTA = 0
Chris_Livingston.player_TRB = 0
Chris_Livingston.player_AST = 1
Chris_Livingston.player_STL = 0
Chris_Livingston.player_BLK = 0
Chris_Livingston.player_TOV = 0
Chris_Livingston.player_PF = 0
Chris_Livingston.player_PTS = 5

Kenneth_Lofton_Jr = Player('Kenneth_Lofton_Jr.')
Kenneth_Lofton_Jr.hasClubTeam.append(Memphis_Grizzlies)
Kenneth_Lofton_Jr.hasPosition.append(PF)
Kenneth_Lofton_Jr.player_Age = 21
Kenneth_Lofton_Jr.player_G = 12
Kenneth_Lofton_Jr.player_MP = 92
Kenneth_Lofton_Jr.player_MP = 92
Kenneth_Lofton_Jr.player_FG = 13
Kenneth_Lofton_Jr.player_FGA = 32
Kenneth_Lofton_Jr.player_FT = 6
Kenneth_Lofton_Jr.player_FTA = 13
Kenneth_Lofton_Jr.player_TRB = 12
Kenneth_Lofton_Jr.player_AST = 12
Kenneth_Lofton_Jr.player_STL = 2
Kenneth_Lofton_Jr.player_BLK = 3
Kenneth_Lofton_Jr.player_TOV = 6
Kenneth_Lofton_Jr.player_PF = 15
Kenneth_Lofton_Jr.player_PTS = 34

Kevon_Looney = Player('Kevon_Looney')
Kevon_Looney.hasClubTeam.append(Golden_State_Warriors)
Kevon_Looney.hasPosition.append(CE)
Kevon_Looney.player_Age = 27
Kevon_Looney.player_G = 18
Kevon_Looney.player_MP = 433
Kevon_Looney.player_MP = 433
Kevon_Looney.player_FG = 45
Kevon_Looney.player_FGA = 75
Kevon_Looney.player_FT = 16
Kevon_Looney.player_FTA = 23
Kevon_Looney.player_TRB = 160
Kevon_Looney.player_AST = 51
Kevon_Looney.player_STL = 15
Kevon_Looney.player_BLK = 6
Kevon_Looney.player_TOV = 18
Kevon_Looney.player_PF = 52
Kevon_Looney.player_PTS = 106

Brook_Lopez = Player('Brook_Lopez')
Brook_Lopez.hasClubTeam.append(Milwaukee_Bucks)
Brook_Lopez.hasPosition.append(CE)
Brook_Lopez.player_Age = 35
Brook_Lopez.player_G = 18
Brook_Lopez.player_MP = 523
Brook_Lopez.player_MP = 523
Brook_Lopez.player_FG = 91
Brook_Lopez.player_FGA = 180
Brook_Lopez.player_FT = 26
Brook_Lopez.player_FTA = 31
Brook_Lopez.player_TRB = 92
Brook_Lopez.player_AST = 23
Brook_Lopez.player_STL = 16
Brook_Lopez.player_BLK = 51
Brook_Lopez.player_TOV = 16
Brook_Lopez.player_PF = 40
Brook_Lopez.player_PTS = 238

Robin_Lopez = Player('Robin_Lopez')
Robin_Lopez.hasClubTeam.append(Milwaukee_Bucks)
Robin_Lopez.hasPosition.append(CE)
Robin_Lopez.player_Age = 35
Robin_Lopez.player_G = 3
Robin_Lopez.player_MP = 9
Robin_Lopez.player_MP = 9
Robin_Lopez.player_FG = 0
Robin_Lopez.player_FGA = 0
Robin_Lopez.player_FT = 2
Robin_Lopez.player_FTA = 2
Robin_Lopez.player_TRB = 0
Robin_Lopez.player_AST = 1
Robin_Lopez.player_STL = 0
Robin_Lopez.player_BLK = 0
Robin_Lopez.player_TOV = 1
Robin_Lopez.player_PF = 2
Robin_Lopez.player_PTS = 2

Kevin_Love = Player('Kevin_Love')
Kevin_Love.hasClubTeam.append(Miami_Heat)
Kevin_Love.hasPosition.append(PF)
Kevin_Love.player_Age = 35
Kevin_Love.player_G = 12
Kevin_Love.player_MP = 212
Kevin_Love.player_MP = 212
Kevin_Love.player_FG = 28
Kevin_Love.player_FGA = 78
Kevin_Love.player_FT = 18
Kevin_Love.player_FTA = 22
Kevin_Love.player_TRB = 82
Kevin_Love.player_AST = 24
Kevin_Love.player_STL = 1
Kevin_Love.player_BLK = 0
Kevin_Love.player_TOV = 8
Kevin_Love.player_PF = 21
Kevin_Love.player_PTS = 91

Kyle_Lowry = Player('Kyle_Lowry')
Kyle_Lowry.hasClubTeam.append(Miami_Heat)
Kyle_Lowry.hasPosition.append(PG)
Kyle_Lowry.player_Age = 37
Kyle_Lowry.player_G = 17
Kyle_Lowry.player_MP = 503
Kyle_Lowry.player_MP = 503
Kyle_Lowry.player_FG = 53
Kyle_Lowry.player_FGA = 119
Kyle_Lowry.player_FT = 16
Kyle_Lowry.player_FTA = 18
Kyle_Lowry.player_TRB = 69
Kyle_Lowry.player_AST = 77
Kyle_Lowry.player_STL = 23
Kyle_Lowry.player_BLK = 4
Kyle_Lowry.player_TOV = 25
Kyle_Lowry.player_PF = 47
Kyle_Lowry.player_PTS = 159

Trey_Lyles = Player('Trey_Lyles')
Trey_Lyles.hasClubTeam.append(Sacramento_Kings)
Trey_Lyles.hasPosition.append(PF)
Trey_Lyles.player_Age = 28
Trey_Lyles.player_G = 3
Trey_Lyles.player_MP = 71
Trey_Lyles.player_MP = 71
Trey_Lyles.player_FG = 9
Trey_Lyles.player_FGA = 20
Trey_Lyles.player_FT = 7
Trey_Lyles.player_FTA = 10
Trey_Lyles.player_TRB = 21
Trey_Lyles.player_AST = 0
Trey_Lyles.player_STL = 0
Trey_Lyles.player_BLK = 1
Trey_Lyles.player_TOV = 5
Trey_Lyles.player_PF = 8
Trey_Lyles.player_PTS = 32

Theo_Maledon = Player('Theo_Maledon')
Theo_Maledon.hasClubTeam.append(Charlotte_Hornets)
Theo_Maledon.hasPosition.append(PG)
Theo_Maledon.player_Age = 22
Theo_Maledon.player_G = 13
Theo_Maledon.player_MP = 200
Theo_Maledon.player_MP = 200
Theo_Maledon.player_FG = 19
Theo_Maledon.player_FGA = 66
Theo_Maledon.player_FT = 11
Theo_Maledon.player_FTA = 12
Theo_Maledon.player_TRB = 23
Theo_Maledon.player_AST = 28
Theo_Maledon.player_STL = 7
Theo_Maledon.player_BLK = 0
Theo_Maledon.player_TOV = 15
Theo_Maledon.player_PF = 18
Theo_Maledon.player_PTS = 54

Sandro_Mamukelashvili = Player('Sandro_Mamukelashvili')
Sandro_Mamukelashvili.hasClubTeam.append(San_Antonio_Spurs)
Sandro_Mamukelashvili.hasPosition.append(CE)
Sandro_Mamukelashvili.player_Age = 24
Sandro_Mamukelashvili.player_G = 6
Sandro_Mamukelashvili.player_MP = 49
Sandro_Mamukelashvili.player_MP = 49
Sandro_Mamukelashvili.player_FG = 5
Sandro_Mamukelashvili.player_FGA = 12
Sandro_Mamukelashvili.player_FT = 5
Sandro_Mamukelashvili.player_FTA = 6
Sandro_Mamukelashvili.player_TRB = 12
Sandro_Mamukelashvili.player_AST = 7
Sandro_Mamukelashvili.player_STL = 2
Sandro_Mamukelashvili.player_BLK = 1
Sandro_Mamukelashvili.player_TOV = 3
Sandro_Mamukelashvili.player_PF = 7
Sandro_Mamukelashvili.player_PTS = 16

Terance_Mann = Player('Terance_Mann')
Terance_Mann.hasClubTeam.append(Los_Angeles_Clippers)
Terance_Mann.hasPosition.append(SG)
Terance_Mann.player_Age = 27
Terance_Mann.player_G = 10
Terance_Mann.player_MP = 257
Terance_Mann.player_MP = 257
Terance_Mann.player_FG = 22
Terance_Mann.player_FGA = 53
Terance_Mann.player_FT = 7
Terance_Mann.player_FTA = 12
Terance_Mann.player_TRB = 41
Terance_Mann.player_AST = 24
Terance_Mann.player_STL = 9
Terance_Mann.player_BLK = 5
Terance_Mann.player_TOV = 7
Terance_Mann.player_PF = 23
Terance_Mann.player_PTS = 54

Tre_Mann = Player('Tre_Mann')
Tre_Mann.hasClubTeam.append(Oklahoma_City_Thunder)
Tre_Mann.hasPosition.append(PG)
Tre_Mann.player_Age = 22
Tre_Mann.player_G = 5
Tre_Mann.player_MP = 44
Tre_Mann.player_MP = 44
Tre_Mann.player_FG = 10
Tre_Mann.player_FGA = 18
Tre_Mann.player_FT = 1
Tre_Mann.player_FTA = 1
Tre_Mann.player_TRB = 11
Tre_Mann.player_AST = 6
Tre_Mann.player_STL = 1
Tre_Mann.player_BLK = 0
Tre_Mann.player_TOV = 5
Tre_Mann.player_PF = 1
Tre_Mann.player_PTS = 24

Boban_Marjanovic = Player('Boban_Marjanovic')
Boban_Marjanovic.hasClubTeam.append(Houston_Rockets)
Boban_Marjanovic.hasPosition.append(CE)
Boban_Marjanovic.player_Age = 35
Boban_Marjanovic.player_G = 3
Boban_Marjanovic.player_MP = 20
Boban_Marjanovic.player_MP = 20
Boban_Marjanovic.player_FG = 5
Boban_Marjanovic.player_FGA = 9
Boban_Marjanovic.player_FT = 0
Boban_Marjanovic.player_FTA = 1
Boban_Marjanovic.player_TRB = 8
Boban_Marjanovic.player_AST = 3
Boban_Marjanovic.player_STL = 0
Boban_Marjanovic.player_BLK = 1
Boban_Marjanovic.player_TOV = 0
Boban_Marjanovic.player_PF = 2
Boban_Marjanovic.player_PTS = 10

Lauri_Markkanen = Player('Lauri_Markkanen')
Lauri_Markkanen.hasClubTeam.append(Utah_Jazz)
Lauri_Markkanen.hasPosition.append(PF)
Lauri_Markkanen.player_Age = 26
Lauri_Markkanen.player_G = 15
Lauri_Markkanen.player_MP = 512
Lauri_Markkanen.player_MP = 512
Lauri_Markkanen.player_FG = 122
Lauri_Markkanen.player_FGA = 252
Lauri_Markkanen.player_FT = 63
Lauri_Markkanen.player_FTA = 75
Lauri_Markkanen.player_TRB = 130
Lauri_Markkanen.player_AST = 16
Lauri_Markkanen.player_STL = 17
Lauri_Markkanen.player_BLK = 13
Lauri_Markkanen.player_TOV = 20
Lauri_Markkanen.player_PF = 34
Lauri_Markkanen.player_PTS = 356

Naji_Marshall = Player('Naji_Marshall')
Naji_Marshall.hasClubTeam.append(New_Orleans_Pelicans)
Naji_Marshall.hasPosition.append(SF)
Naji_Marshall.player_Age = 26
Naji_Marshall.player_G = 9
Naji_Marshall.player_MP = 199
Naji_Marshall.player_MP = 199
Naji_Marshall.player_FG = 30
Naji_Marshall.player_FGA = 63
Naji_Marshall.player_FT = 18
Naji_Marshall.player_FTA = 22
Naji_Marshall.player_TRB = 45
Naji_Marshall.player_AST = 22
Naji_Marshall.player_STL = 8
Naji_Marshall.player_BLK = 3
Naji_Marshall.player_TOV = 12
Naji_Marshall.player_PF = 13
Naji_Marshall.player_PTS = 90

Caleb_Martin = Player('Caleb_Martin')
Caleb_Martin.hasClubTeam.append(Miami_Heat)
Caleb_Martin.hasPosition.append(SF)
Caleb_Martin.player_Age = 28
Caleb_Martin.player_G = 8
Caleb_Martin.player_MP = 169
Caleb_Martin.player_MP = 169
Caleb_Martin.player_FG = 27
Caleb_Martin.player_FGA = 72
Caleb_Martin.player_FT = 5
Caleb_Martin.player_FTA = 5
Caleb_Martin.player_TRB = 24
Caleb_Martin.player_AST = 11
Caleb_Martin.player_STL = 8
Caleb_Martin.player_BLK = 0
Caleb_Martin.player_TOV = 5
Caleb_Martin.player_PF = 12
Caleb_Martin.player_PTS = 67

KJ_Martin = Player('KJ_Martin')
KJ_Martin.hasClubTeam.append(Toronto_Raptors)
KJ_Martin.hasPosition.append(SF)
KJ_Martin.player_Age = 23
KJ_Martin.player_G = 9
KJ_Martin.player_MP = 55
KJ_Martin.player_MP = 55
KJ_Martin.player_FG = 5
KJ_Martin.player_FGA = 13
KJ_Martin.player_FT = 3
KJ_Martin.player_FTA = 6
KJ_Martin.player_TRB = 8
KJ_Martin.player_AST = 2
KJ_Martin.player_STL = 3
KJ_Martin.player_BLK = 1
KJ_Martin.player_TOV = 3
KJ_Martin.player_PF = 9
KJ_Martin.player_PTS = 14

Garrison_Mathews = Player('Garrison_Mathews')
Garrison_Mathews.hasClubTeam.append(Atlanta_Hawks)
Garrison_Mathews.hasPosition.append(SG)
Garrison_Mathews.player_Age = 27
Garrison_Mathews.player_G = 5
Garrison_Mathews.player_MP = 28
Garrison_Mathews.player_MP = 28
Garrison_Mathews.player_FG = 3
Garrison_Mathews.player_FGA = 7
Garrison_Mathews.player_FT = 0
Garrison_Mathews.player_FTA = 0
Garrison_Mathews.player_TRB = 5
Garrison_Mathews.player_AST = 1
Garrison_Mathews.player_STL = 0
Garrison_Mathews.player_BLK = 0
Garrison_Mathews.player_TOV = 0
Garrison_Mathews.player_PF = 2
Garrison_Mathews.player_PTS = 9

Bennedict_Mathurin = Player('Bennedict_Mathurin')
Bennedict_Mathurin.hasClubTeam.append(Indiana_Pacers)
Bennedict_Mathurin.hasPosition.append(SF)
Bennedict_Mathurin.player_Age = 21
Bennedict_Mathurin.player_G = 16
Bennedict_Mathurin.player_MP = 394
Bennedict_Mathurin.player_MP = 394
Bennedict_Mathurin.player_FG = 76
Bennedict_Mathurin.player_FGA = 175
Bennedict_Mathurin.player_FT = 36
Bennedict_Mathurin.player_FTA = 47
Bennedict_Mathurin.player_TRB = 59
Bennedict_Mathurin.player_AST = 31
Bennedict_Mathurin.player_STL = 11
Bennedict_Mathurin.player_BLK = 3
Bennedict_Mathurin.player_TOV = 19
Bennedict_Mathurin.player_PF = 30
Bennedict_Mathurin.player_PTS = 206

Wesley_Matthews = Player('Wesley_Matthews')
Wesley_Matthews.hasClubTeam.append(Atlanta_Hawks)
Wesley_Matthews.hasPosition.append(SG)
Wesley_Matthews.player_Age = 37
Wesley_Matthews.player_G = 7
Wesley_Matthews.player_MP = 68
Wesley_Matthews.player_MP = 68
Wesley_Matthews.player_FG = 5
Wesley_Matthews.player_FGA = 14
Wesley_Matthews.player_FT = 3
Wesley_Matthews.player_FTA = 6
Wesley_Matthews.player_TRB = 9
Wesley_Matthews.player_AST = 5
Wesley_Matthews.player_STL = 1
Wesley_Matthews.player_BLK = 0
Wesley_Matthews.player_TOV = 2
Wesley_Matthews.player_PF = 11
Wesley_Matthews.player_PTS = 17

Tyrese_Maxey = Player('Tyrese_Maxey')
Tyrese_Maxey.hasClubTeam.append(Philadelphia_76ers)
Tyrese_Maxey.hasPosition.append(PG)
Tyrese_Maxey.player_Age = 23
Tyrese_Maxey.player_G = 17
Tyrese_Maxey.player_MP = 653
Tyrese_Maxey.player_MP = 653
Tyrese_Maxey.player_FG = 156
Tyrese_Maxey.player_FGA = 339
Tyrese_Maxey.player_FT = 85
Tyrese_Maxey.player_FTA = 95
Tyrese_Maxey.player_TRB = 82
Tyrese_Maxey.player_AST = 117
Tyrese_Maxey.player_STL = 13
Tyrese_Maxey.player_BLK = 12
Tyrese_Maxey.player_TOV = 24
Tyrese_Maxey.player_PF = 32
Tyrese_Maxey.player_PTS = 453

Skylar_Mays = Player('Skylar_Mays')
Skylar_Mays.hasClubTeam.append(Portland_Trail_Blazers)
Skylar_Mays.hasPosition.append(PG)
Skylar_Mays.player_Age = 26
Skylar_Mays.player_G = 14
Skylar_Mays.player_MP = 273
Skylar_Mays.player_MP = 273
Skylar_Mays.player_FG = 43
Skylar_Mays.player_FGA = 106
Skylar_Mays.player_FT = 11
Skylar_Mays.player_FTA = 13
Skylar_Mays.player_TRB = 24
Skylar_Mays.player_AST = 63
Skylar_Mays.player_STL = 11
Skylar_Mays.player_BLK = 2
Skylar_Mays.player_TOV = 15
Skylar_Mays.player_PF = 19
Skylar_Mays.player_PTS = 109

Miles_McBride = Player('Miles_McBride')
Miles_McBride.hasClubTeam.append(New_York_Knicks)
Miles_McBride.hasPosition.append(PG)
Miles_McBride.player_Age = 23
Miles_McBride.player_G = 12
Miles_McBride.player_MP = 54
Miles_McBride.player_MP = 54
Miles_McBride.player_FG = 8
Miles_McBride.player_FGA = 17
Miles_McBride.player_FT = 1
Miles_McBride.player_FTA = 2
Miles_McBride.player_TRB = 3
Miles_McBride.player_AST = 3
Miles_McBride.player_STL = 4
Miles_McBride.player_BLK = 0
Miles_McBride.player_TOV = 0
Miles_McBride.player_PF = 7
Miles_McBride.player_PTS = 21

CJ_McCollum = Player('CJ_McCollum')
CJ_McCollum.hasClubTeam.append(New_Orleans_Pelicans)
CJ_McCollum.hasPosition.append(PG)
CJ_McCollum.player_Age = 32
CJ_McCollum.player_G = 6
CJ_McCollum.player_MP = 206
CJ_McCollum.player_MP = 206
CJ_McCollum.player_FG = 44
CJ_McCollum.player_FGA = 100
CJ_McCollum.player_FT = 23
CJ_McCollum.player_FTA = 31
CJ_McCollum.player_TRB = 29
CJ_McCollum.player_AST = 34
CJ_McCollum.player_STL = 9
CJ_McCollum.player_BLK = 5
CJ_McCollum.player_TOV = 8
CJ_McCollum.player_PF = 14
CJ_McCollum.player_PTS = 130

TJ_McConnell = Player('T.J._McConnell')
TJ_McConnell.hasClubTeam.append(Indiana_Pacers)
TJ_McConnell.hasPosition.append(PG)
TJ_McConnell.player_Age = 31
TJ_McConnell.player_G = 11
TJ_McConnell.player_MP = 154
TJ_McConnell.player_MP = 154
TJ_McConnell.player_FG = 31
TJ_McConnell.player_FGA = 59
TJ_McConnell.player_FT = 10
TJ_McConnell.player_FTA = 14
TJ_McConnell.player_TRB = 28
TJ_McConnell.player_AST = 41
TJ_McConnell.player_STL = 8
TJ_McConnell.player_BLK = 2
TJ_McConnell.player_TOV = 10
TJ_McConnell.player_PF = 16
TJ_McConnell.player_PTS = 73

Jaden_McDaniels = Player('Jaden_McDaniels')
Jaden_McDaniels.hasClubTeam.append(Minnesota_Timberwolves)
Jaden_McDaniels.hasPosition.append(SF)
Jaden_McDaniels.player_Age = 23
Jaden_McDaniels.player_G = 11
Jaden_McDaniels.player_MP = 260
Jaden_McDaniels.player_MP = 260
Jaden_McDaniels.player_FG = 46
Jaden_McDaniels.player_FGA = 79
Jaden_McDaniels.player_FT = 2
Jaden_McDaniels.player_FTA = 2
Jaden_McDaniels.player_TRB = 24
Jaden_McDaniels.player_AST = 14
Jaden_McDaniels.player_STL = 6
Jaden_McDaniels.player_BLK = 4
Jaden_McDaniels.player_TOV = 11
Jaden_McDaniels.player_PF = 36
Jaden_McDaniels.player_PTS = 105

Jalen_McDaniels = Player('Jalen_McDaniels')
Jalen_McDaniels.hasClubTeam.append(Toronto_Raptors)
Jalen_McDaniels.hasPosition.append(SF)
Jalen_McDaniels.player_Age = 26
Jalen_McDaniels.player_G = 13
Jalen_McDaniels.player_MP = 122
Jalen_McDaniels.player_MP = 122
Jalen_McDaniels.player_FG = 12
Jalen_McDaniels.player_FGA = 41
Jalen_McDaniels.player_FT = 2
Jalen_McDaniels.player_FTA = 2
Jalen_McDaniels.player_TRB = 16
Jalen_McDaniels.player_AST = 8
Jalen_McDaniels.player_STL = 5
Jalen_McDaniels.player_BLK = 3
Jalen_McDaniels.player_TOV = 4
Jalen_McDaniels.player_PF = 10
Jalen_McDaniels.player_PTS = 30

Doug_McDermott = Player('Doug_McDermott')
Doug_McDermott.hasClubTeam.append(San_Antonio_Spurs)
Doug_McDermott.hasPosition.append(SF)
Doug_McDermott.player_Age = 32
Doug_McDermott.player_G = 17
Doug_McDermott.player_MP = 283
Doug_McDermott.player_MP = 283
Doug_McDermott.player_FG = 38
Doug_McDermott.player_FGA = 79
Doug_McDermott.player_FT = 4
Doug_McDermott.player_FTA = 6
Doug_McDermott.player_TRB = 19
Doug_McDermott.player_AST = 31
Doug_McDermott.player_STL = 6
Doug_McDermott.player_BLK = 2
Doug_McDermott.player_TOV = 12
Doug_McDermott.player_PF = 22
Doug_McDermott.player_PTS = 108

JaVale_McGee = Player('JaVale_McGee')
JaVale_McGee.hasClubTeam.append(Sacramento_Kings)
JaVale_McGee.hasPosition.append(CE)
JaVale_McGee.player_Age = 36
JaVale_McGee.player_G = 14
JaVale_McGee.player_MP = 140
JaVale_McGee.player_MP = 140
JaVale_McGee.player_FG = 35
JaVale_McGee.player_FGA = 53
JaVale_McGee.player_FT = 11
JaVale_McGee.player_FTA = 19
JaVale_McGee.player_TRB = 52
JaVale_McGee.player_AST = 7
JaVale_McGee.player_STL = 4
JaVale_McGee.player_BLK = 8
JaVale_McGee.player_TOV = 16
JaVale_McGee.player_PF = 16
JaVale_McGee.player_PTS = 81

Bryce_McGowens = Player('Bryce_McGowens')
Bryce_McGowens.hasClubTeam.append(Charlotte_Hornets)
Bryce_McGowens.hasPosition.append(SG)
Bryce_McGowens.player_Age = 21
Bryce_McGowens.player_G = 11
Bryce_McGowens.player_MP = 167
Bryce_McGowens.player_MP = 167
Bryce_McGowens.player_FG = 14
Bryce_McGowens.player_FGA = 35
Bryce_McGowens.player_FT = 8
Bryce_McGowens.player_FTA = 10
Bryce_McGowens.player_TRB = 22
Bryce_McGowens.player_AST = 8
Bryce_McGowens.player_STL = 6
Bryce_McGowens.player_BLK = 1
Bryce_McGowens.player_TOV = 7
Bryce_McGowens.player_PF = 16
Bryce_McGowens.player_PTS = 45

Jordan_McLaughlin = Player('Jordan_McLaughlin')
Jordan_McLaughlin.hasClubTeam.append(Minnesota_Timberwolves)
Jordan_McLaughlin.hasPosition.append(PG)
Jordan_McLaughlin.player_Age = 27
Jordan_McLaughlin.player_G = 5
Jordan_McLaughlin.player_MP = 19
Jordan_McLaughlin.player_MP = 19
Jordan_McLaughlin.player_FG = 1
Jordan_McLaughlin.player_FGA = 4
Jordan_McLaughlin.player_FT = 2
Jordan_McLaughlin.player_FTA = 2
Jordan_McLaughlin.player_TRB = 0
Jordan_McLaughlin.player_AST = 5
Jordan_McLaughlin.player_STL = 0
Jordan_McLaughlin.player_BLK = 2
Jordan_McLaughlin.player_TOV = 0
Jordan_McLaughlin.player_PF = 2
Jordan_McLaughlin.player_PTS = 5

DeAnthony_Melton = Player('DeAnthony_Melton')
DeAnthony_Melton.hasClubTeam.append(Philadelphia_76ers)
DeAnthony_Melton.hasPosition.append(SG)
DeAnthony_Melton.player_Age = 25
DeAnthony_Melton.player_G = 17
DeAnthony_Melton.player_MP = 507
DeAnthony_Melton.player_MP = 507
DeAnthony_Melton.player_FG = 67
DeAnthony_Melton.player_FGA = 166
DeAnthony_Melton.player_FT = 34
DeAnthony_Melton.player_FTA = 43
DeAnthony_Melton.player_TRB = 69
DeAnthony_Melton.player_AST = 62
DeAnthony_Melton.player_STL = 21
DeAnthony_Melton.player_BLK = 6
DeAnthony_Melton.player_TOV = 19
DeAnthony_Melton.player_PF = 43
DeAnthony_Melton.player_PTS = 206

Sam_Merrill = Player('Sam_Merrill')
Sam_Merrill.hasClubTeam.append(Cleveland_Cavaliers)
Sam_Merrill.hasPosition.append(SG)
Sam_Merrill.player_Age = 27
Sam_Merrill.player_G = 9
Sam_Merrill.player_MP = 73
Sam_Merrill.player_MP = 73
Sam_Merrill.player_FG = 8
Sam_Merrill.player_FGA = 24
Sam_Merrill.player_FT = 0
Sam_Merrill.player_FTA = 0
Sam_Merrill.player_TRB = 6
Sam_Merrill.player_AST = 5
Sam_Merrill.player_STL = 2
Sam_Merrill.player_BLK = 0
Sam_Merrill.player_TOV = 2
Sam_Merrill.player_PF = 5
Sam_Merrill.player_PTS = 24

Chimezie_Metu = Player('Chimezie_Metu')
Chimezie_Metu.hasClubTeam.append(Phoenix_Suns)
Chimezie_Metu.hasPosition.append(CE)
Chimezie_Metu.player_Age = 26
Chimezie_Metu.player_G = 9
Chimezie_Metu.player_MP = 59
Chimezie_Metu.player_MP = 59
Chimezie_Metu.player_FG = 9
Chimezie_Metu.player_FGA = 17
Chimezie_Metu.player_FT = 3
Chimezie_Metu.player_FTA = 4
Chimezie_Metu.player_TRB = 12
Chimezie_Metu.player_AST = 3
Chimezie_Metu.player_STL = 1
Chimezie_Metu.player_BLK = 3
Chimezie_Metu.player_TOV = 2
Chimezie_Metu.player_PF = 10
Chimezie_Metu.player_PTS = 23

Vasilije_Micic = Player('Vasilije_Micic')
Vasilije_Micic.hasClubTeam.append(Oklahoma_City_Thunder)
Vasilije_Micic.hasPosition.append(PG)
Vasilije_Micic.player_Age = 30
Vasilije_Micic.player_G = 8
Vasilije_Micic.player_MP = 98
Vasilije_Micic.player_MP = 98
Vasilije_Micic.player_FG = 9
Vasilije_Micic.player_FGA = 24
Vasilije_Micic.player_FT = 4
Vasilije_Micic.player_FTA = 6
Vasilije_Micic.player_TRB = 4
Vasilije_Micic.player_AST = 22
Vasilije_Micic.player_STL = 1
Vasilije_Micic.player_BLK = 0
Vasilije_Micic.player_TOV = 10
Vasilije_Micic.player_PF = 6
Vasilije_Micic.player_PTS = 27

Khris_Middleton = Player('Khris_Middleton')
Khris_Middleton.hasClubTeam.append(Milwaukee_Bucks)
Khris_Middleton.hasPosition.append(SF)
Khris_Middleton.player_Age = 32
Khris_Middleton.player_G = 14
Khris_Middleton.player_MP = 281
Khris_Middleton.player_MP = 281
Khris_Middleton.player_FG = 64
Khris_Middleton.player_FGA = 137
Khris_Middleton.player_FT = 23
Khris_Middleton.player_FTA = 27
Khris_Middleton.player_TRB = 59
Khris_Middleton.player_AST = 56
Khris_Middleton.player_STL = 9
Khris_Middleton.player_BLK = 1
Khris_Middleton.player_TOV = 22
Khris_Middleton.player_PF = 27
Khris_Middleton.player_PTS = 168

Brandon_Miller = Player('Brandon_Miller')
Brandon_Miller.hasClubTeam.append(Charlotte_Hornets)
Brandon_Miller.hasPosition.append(SF)
Brandon_Miller.player_Age = 21
Brandon_Miller.player_G = 15
Brandon_Miller.player_MP = 461
Brandon_Miller.player_MP = 461
Brandon_Miller.player_FG = 83
Brandon_Miller.player_FGA = 179
Brandon_Miller.player_FT = 25
Brandon_Miller.player_FTA = 32
Brandon_Miller.player_TRB = 60
Brandon_Miller.player_AST = 29
Brandon_Miller.player_STL = 10
Brandon_Miller.player_BLK = 6
Brandon_Miller.player_TOV = 18
Brandon_Miller.player_PF = 45
Brandon_Miller.player_PTS = 216

Jordan_Miller = Player('Jordan_Miller')
Jordan_Miller.hasClubTeam.append(Los_Angeles_Clippers)
Jordan_Miller.hasPosition.append(SF)
Jordan_Miller.player_Age = 24
Jordan_Miller.player_G = 2
Jordan_Miller.player_MP = 7
Jordan_Miller.player_MP = 7
Jordan_Miller.player_FG = 2
Jordan_Miller.player_FGA = 3
Jordan_Miller.player_FT = 0
Jordan_Miller.player_FTA = 0
Jordan_Miller.player_TRB = 0
Jordan_Miller.player_AST = 0
Jordan_Miller.player_STL = 0
Jordan_Miller.player_BLK = 0
Jordan_Miller.player_TOV = 0
Jordan_Miller.player_PF = 2
Jordan_Miller.player_PTS = 5

Leonard_Miller = Player('Leonard_Miller')
Leonard_Miller.hasClubTeam.append(Minnesota_Timberwolves)
Leonard_Miller.hasPosition.append(SF)
Leonard_Miller.player_Age = 20
Leonard_Miller.player_G = 3
Leonard_Miller.player_MP = 6
Leonard_Miller.player_MP = 6
Leonard_Miller.player_FG = 1
Leonard_Miller.player_FGA = 2
Leonard_Miller.player_FT = 0
Leonard_Miller.player_FTA = 0
Leonard_Miller.player_TRB = 6
Leonard_Miller.player_AST = 1
Leonard_Miller.player_STL = 0
Leonard_Miller.player_BLK = 0
Leonard_Miller.player_TOV = 0
Leonard_Miller.player_PF = 1
Leonard_Miller.player_PTS = 2

Dariq_Whitehead = Player('Dariq_Whitehead')
Dariq_Whitehead.hasClubTeam.append(Brooklyn_Nets)
Dariq_Whitehead.hasPosition.append(SF)
Dariq_Whitehead.player_Age = 19
Dariq_Whitehead.player_G = 1
Dariq_Whitehead.player_MP = 3
Dariq_Whitehead.player_MP = 3
Dariq_Whitehead.player_FG = 0
Dariq_Whitehead.player_FGA = 0
Dariq_Whitehead.player_FT = 1
Dariq_Whitehead.player_FTA = 2
Dariq_Whitehead.player_TRB = 0
Dariq_Whitehead.player_AST = 0
Dariq_Whitehead.player_STL = 0
Dariq_Whitehead.player_BLK = 1
Dariq_Whitehead.player_TOV = 0
Dariq_Whitehead.player_PF = 0
Dariq_Whitehead.player_PTS = 1

Patty_Mills = Player('Patty_Mills')
Patty_Mills.hasClubTeam.append(Atlanta_Hawks)
Patty_Mills.hasPosition.append(PG)
Patty_Mills.player_Age = 35
Patty_Mills.player_G = 1
Patty_Mills.player_MP = 5
Patty_Mills.player_MP = 5
Patty_Mills.player_FG = 1
Patty_Mills.player_FGA = 2
Patty_Mills.player_FT = 0
Patty_Mills.player_FTA = 0
Patty_Mills.player_TRB = 1
Patty_Mills.player_AST = 0
Patty_Mills.player_STL = 0
Patty_Mills.player_BLK = 0
Patty_Mills.player_TOV = 0
Patty_Mills.player_PF = 0
Patty_Mills.player_PTS = 3

Shake_Milton = Player('Shake_Milton')
Shake_Milton.hasClubTeam.append(Minnesota_Timberwolves)
Shake_Milton.hasPosition.append(SG)
Shake_Milton.player_Age = 27
Shake_Milton.player_G = 17
Shake_Milton.player_MP = 267
Shake_Milton.player_MP = 267
Shake_Milton.player_FG = 31
Shake_Milton.player_FGA = 82
Shake_Milton.player_FT = 25
Shake_Milton.player_FTA = 31
Shake_Milton.player_TRB = 34
Shake_Milton.player_AST = 24
Shake_Milton.player_STL = 11
Shake_Milton.player_BLK = 3
Shake_Milton.player_TOV = 20
Shake_Milton.player_PF = 28
Shake_Milton.player_PTS = 95

Justin_Minaya = Player('Justin_Minaya')
Justin_Minaya.hasClubTeam.append(Portland_Trail_Blazers)
Justin_Minaya.hasPosition.append(SF)
Justin_Minaya.player_Age = 24
Justin_Minaya.player_G = 5
Justin_Minaya.player_MP = 30
Justin_Minaya.player_MP = 30
Justin_Minaya.player_FG = 2
Justin_Minaya.player_FGA = 6
Justin_Minaya.player_FT = 1
Justin_Minaya.player_FTA = 2
Justin_Minaya.player_TRB = 5
Justin_Minaya.player_AST = 0
Justin_Minaya.player_STL = 0
Justin_Minaya.player_BLK = 1
Justin_Minaya.player_TOV = 1
Justin_Minaya.player_PF = 1
Justin_Minaya.player_PTS = 7

Josh_Minott = Player('Josh_Minott')
Josh_Minott.hasClubTeam.append(Minnesota_Timberwolves)
Josh_Minott.hasPosition.append(SF)
Josh_Minott.player_Age = 21
Josh_Minott.player_G = 9
Josh_Minott.player_MP = 23
Josh_Minott.player_MP = 23
Josh_Minott.player_FG = 6
Josh_Minott.player_FGA = 12
Josh_Minott.player_FT = 2
Josh_Minott.player_FTA = 4
Josh_Minott.player_TRB = 3
Josh_Minott.player_AST = 1
Josh_Minott.player_STL = 0
Josh_Minott.player_BLK = 1
Josh_Minott.player_TOV = 0
Josh_Minott.player_PF = 4
Josh_Minott.player_PTS = 14

Davion_Mitchell = Player('Davion_Mitchell')
Davion_Mitchell.hasClubTeam.append(Sacramento_Kings)
Davion_Mitchell.hasPosition.append(PG)
Davion_Mitchell.player_Age = 25
Davion_Mitchell.player_G = 13
Davion_Mitchell.player_MP = 223
Davion_Mitchell.player_MP = 223
Davion_Mitchell.player_FG = 22
Davion_Mitchell.player_FGA = 62
Davion_Mitchell.player_FT = 7
Davion_Mitchell.player_FTA = 7
Davion_Mitchell.player_TRB = 14
Davion_Mitchell.player_AST = 34
Davion_Mitchell.player_STL = 5
Davion_Mitchell.player_BLK = 2
Davion_Mitchell.player_TOV = 12
Davion_Mitchell.player_PF = 23
Davion_Mitchell.player_PTS = 62

Donovan_Mitchell = Player('Donovan_Mitchell')
Donovan_Mitchell.hasClubTeam.append(Cleveland_Cavaliers)
Donovan_Mitchell.hasPosition.append(SG)
Donovan_Mitchell.player_Age = 27
Donovan_Mitchell.player_G = 13
Donovan_Mitchell.player_MP = 466
Donovan_Mitchell.player_MP = 466
Donovan_Mitchell.player_FG = 127
Donovan_Mitchell.player_FGA = 276
Donovan_Mitchell.player_FT = 70
Donovan_Mitchell.player_FTA = 78
Donovan_Mitchell.player_TRB = 70
Donovan_Mitchell.player_AST = 68
Donovan_Mitchell.player_STL = 25
Donovan_Mitchell.player_BLK = 7
Donovan_Mitchell.player_TOV = 33
Donovan_Mitchell.player_PF = 26
Donovan_Mitchell.player_PTS = 364

Evan_Mobley = Player('Evan_Mobley')
Evan_Mobley.hasClubTeam.append(Cleveland_Cavaliers)
Evan_Mobley.hasPosition.append(PF)
Evan_Mobley.player_Age = 22
Evan_Mobley.player_G = 18
Evan_Mobley.player_MP = 599
Evan_Mobley.player_MP = 599
Evan_Mobley.player_FG = 123
Evan_Mobley.player_FGA = 217
Evan_Mobley.player_FT = 46
Evan_Mobley.player_FTA = 60
Evan_Mobley.player_TRB = 196
Evan_Mobley.player_AST = 55
Evan_Mobley.player_STL = 14
Evan_Mobley.player_BLK = 34
Evan_Mobley.player_TOV = 39
Evan_Mobley.player_PF = 51
Evan_Mobley.player_PTS = 294

Isaiah_Mobley = Player('Isaiah_Mobley')
Isaiah_Mobley.hasClubTeam.append(Cleveland_Cavaliers)
Isaiah_Mobley.hasPosition.append(PF)
Isaiah_Mobley.player_Age = 24
Isaiah_Mobley.player_G = 2
Isaiah_Mobley.player_MP = 10
Isaiah_Mobley.player_MP = 10
Isaiah_Mobley.player_FG = 1
Isaiah_Mobley.player_FGA = 3
Isaiah_Mobley.player_FT = 0
Isaiah_Mobley.player_FTA = 0
Isaiah_Mobley.player_TRB = 2
Isaiah_Mobley.player_AST = 3
Isaiah_Mobley.player_STL = 1
Isaiah_Mobley.player_BLK = 0
Isaiah_Mobley.player_TOV = 1
Isaiah_Mobley.player_PF = 2
Isaiah_Mobley.player_PTS = 2

Malik_Monk = Player('Malik_Monk')
Malik_Monk.hasClubTeam.append(Sacramento_Kings)
Malik_Monk.hasPosition.append(SG)
Malik_Monk.player_Age = 25
Malik_Monk.player_G = 16
Malik_Monk.player_MP = 385
Malik_Monk.player_MP = 385
Malik_Monk.player_FG = 70
Malik_Monk.player_FGA = 173
Malik_Monk.player_FT = 40
Malik_Monk.player_FTA = 46
Malik_Monk.player_TRB = 45
Malik_Monk.player_AST = 76
Malik_Monk.player_STL = 11
Malik_Monk.player_BLK = 9
Malik_Monk.player_TOV = 35
Malik_Monk.player_PF = 29
Malik_Monk.player_PTS = 219

Moses_Moody = Player('Moses_Moody')
Moses_Moody.hasClubTeam.append(Golden_State_Warriors)
Moses_Moody.hasPosition.append(SG)
Moses_Moody.player_Age = 21
Moses_Moody.player_G = 18
Moses_Moody.player_MP = 317
Moses_Moody.player_MP = 317
Moses_Moody.player_FG = 52
Moses_Moody.player_FGA = 105
Moses_Moody.player_FT = 14
Moses_Moody.player_FTA = 21
Moses_Moody.player_TRB = 60
Moses_Moody.player_AST = 20
Moses_Moody.player_STL = 14
Moses_Moody.player_BLK = 5
Moses_Moody.player_TOV = 11
Moses_Moody.player_PF = 22
Moses_Moody.player_PTS = 139

Wendell_Moore_Jr = Player('Wendell_Moore_Jr.')
Wendell_Moore_Jr.hasClubTeam.append(Minnesota_Timberwolves)
Wendell_Moore_Jr.hasPosition.append(SG)
Wendell_Moore_Jr.player_Age = 22
Wendell_Moore_Jr.player_G = 1
Wendell_Moore_Jr.player_MP = 2
Wendell_Moore_Jr.player_MP = 2
Wendell_Moore_Jr.player_FG = 0
Wendell_Moore_Jr.player_FGA = 1
Wendell_Moore_Jr.player_FT = 0
Wendell_Moore_Jr.player_FTA = 0
Wendell_Moore_Jr.player_TRB = 0
Wendell_Moore_Jr.player_AST = 0
Wendell_Moore_Jr.player_STL = 0
Wendell_Moore_Jr.player_BLK = 0
Wendell_Moore_Jr.player_TOV = 0
Wendell_Moore_Jr.player_PF = 0
Wendell_Moore_Jr.player_PTS = 0

Marcus_Morris = Player('Marcus_Morris')
Marcus_Morris.hasClubTeam.append(Philadelphia_76ers)
Marcus_Morris.hasPosition.append(PF)
Marcus_Morris.player_Age = 34
Marcus_Morris.player_G = 10
Marcus_Morris.player_MP = 100
Marcus_Morris.player_MP = 100
Marcus_Morris.player_FG = 15
Marcus_Morris.player_FGA = 32
Marcus_Morris.player_FT = 2
Marcus_Morris.player_FTA = 2
Marcus_Morris.player_TRB = 15
Marcus_Morris.player_AST = 3
Marcus_Morris.player_STL = 2
Marcus_Morris.player_BLK = 3
Marcus_Morris.player_TOV = 4
Marcus_Morris.player_PF = 14
Marcus_Morris.player_PTS = 40

Markieff_Morris = Player('Markieff_Morris')
Markieff_Morris.hasClubTeam.append(Dallas_Mavericks)
Markieff_Morris.hasPosition.append(PF)
Markieff_Morris.player_Age = 34
Markieff_Morris.player_G = 2
Markieff_Morris.player_MP = 9
Markieff_Morris.player_MP = 9
Markieff_Morris.player_FG = 1
Markieff_Morris.player_FGA = 6
Markieff_Morris.player_FT = 0
Markieff_Morris.player_FTA = 0
Markieff_Morris.player_TRB = 1
Markieff_Morris.player_AST = 1
Markieff_Morris.player_STL = 0
Markieff_Morris.player_BLK = 0
Markieff_Morris.player_TOV = 0
Markieff_Morris.player_PF = 0
Markieff_Morris.player_PTS = 2

Dejounte_Murray = Player('Dejounte_Murray')
Dejounte_Murray.hasClubTeam.append(Atlanta_Hawks)
Dejounte_Murray.hasPosition.append(SG)
Dejounte_Murray.player_Age = 27
Dejounte_Murray.player_G = 17
Dejounte_Murray.player_MP = 580
Dejounte_Murray.player_MP = 580
Dejounte_Murray.player_FG = 124
Dejounte_Murray.player_FGA = 279
Dejounte_Murray.player_FT = 47
Dejounte_Murray.player_FTA = 55
Dejounte_Murray.player_TRB = 73
Dejounte_Murray.player_AST = 92
Dejounte_Murray.player_STL = 27
Dejounte_Murray.player_BLK = 5
Dejounte_Murray.player_TOV = 43
Dejounte_Murray.player_PF = 25
Dejounte_Murray.player_PTS = 333

Jamal_Murray = Player('Jamal_Murray')
Jamal_Murray.hasClubTeam.append(Denver_Nuggets)
Jamal_Murray.hasPosition.append(PG)
Jamal_Murray.player_Age = 26
Jamal_Murray.player_G = 7
Jamal_Murray.player_MP = 216
Jamal_Murray.player_MP = 216
Jamal_Murray.player_FG = 42
Jamal_Murray.player_FGA = 97
Jamal_Murray.player_FT = 16
Jamal_Murray.player_FTA = 19
Jamal_Murray.player_TRB = 18
Jamal_Murray.player_AST = 52
Jamal_Murray.player_STL = 2
Jamal_Murray.player_BLK = 5
Jamal_Murray.player_TOV = 16
Jamal_Murray.player_PF = 13
Jamal_Murray.player_PTS = 114

Keegan_Murray = Player('Keegan_Murray')
Keegan_Murray.hasClubTeam.append(Sacramento_Kings)
Keegan_Murray.hasPosition.append(SF)
Keegan_Murray.player_Age = 23
Keegan_Murray.player_G = 13
Keegan_Murray.player_MP = 430
Keegan_Murray.player_MP = 430
Keegan_Murray.player_FG = 64
Keegan_Murray.player_FGA = 164
Keegan_Murray.player_FT = 17
Keegan_Murray.player_FTA = 20
Keegan_Murray.player_TRB = 80
Keegan_Murray.player_AST = 26
Keegan_Murray.player_STL = 18
Keegan_Murray.player_BLK = 8
Keegan_Murray.player_TOV = 15
Keegan_Murray.player_PF = 31
Keegan_Murray.player_PTS = 172

Kris_Murray = Player('Kris_Murray')
Kris_Murray.hasClubTeam.append(Portland_Trail_Blazers)
Kris_Murray.hasPosition.append(SF)
Kris_Murray.player_Age = 23
Kris_Murray.player_G = 10
Kris_Murray.player_MP = 88
Kris_Murray.player_MP = 88
Kris_Murray.player_FG = 6
Kris_Murray.player_FGA = 20
Kris_Murray.player_FT = 3
Kris_Murray.player_FTA = 5
Kris_Murray.player_TRB = 8
Kris_Murray.player_AST = 3
Kris_Murray.player_STL = 5
Kris_Murray.player_BLK = 1
Kris_Murray.player_TOV = 1
Kris_Murray.player_PF = 8
Kris_Murray.player_PTS = 18

Mike_Muscala = Player('Mike_Muscala')
Mike_Muscala.hasClubTeam.append(Washington_Wizards)
Mike_Muscala.hasPosition.append(CE)
Mike_Muscala.player_Age = 32
Mike_Muscala.player_G = 7
Mike_Muscala.player_MP = 82
Mike_Muscala.player_MP = 82
Mike_Muscala.player_FG = 8
Mike_Muscala.player_FGA = 19
Mike_Muscala.player_FT = 4
Mike_Muscala.player_FTA = 4
Mike_Muscala.player_TRB = 19
Mike_Muscala.player_AST = 8
Mike_Muscala.player_STL = 1
Mike_Muscala.player_BLK = 3
Mike_Muscala.player_TOV = 7
Mike_Muscala.player_PF = 7
Mike_Muscala.player_PTS = 23

Svi_Mykhailiuk = Player('Svi_Mykhailiuk')
Svi_Mykhailiuk.hasClubTeam.append(Boston_Celtics)
Svi_Mykhailiuk.hasPosition.append(SF)
Svi_Mykhailiuk.player_Age = 26
Svi_Mykhailiuk.player_G = 8
Svi_Mykhailiuk.player_MP = 59
Svi_Mykhailiuk.player_MP = 59
Svi_Mykhailiuk.player_FG = 6
Svi_Mykhailiuk.player_FGA = 17
Svi_Mykhailiuk.player_FT = 0
Svi_Mykhailiuk.player_FTA = 0
Svi_Mykhailiuk.player_TRB = 5
Svi_Mykhailiuk.player_AST = 1
Svi_Mykhailiuk.player_STL = 3
Svi_Mykhailiuk.player_BLK = 0
Svi_Mykhailiuk.player_TOV = 4
Svi_Mykhailiuk.player_PF = 4
Svi_Mykhailiuk.player_PTS = 16

Larry_Nance_Jr = Player('Larry_Nance_Jr.')
Larry_Nance_Jr.hasClubTeam.append(New_Orleans_Pelicans)
Larry_Nance_Jr.hasPosition.append(CE)
Larry_Nance_Jr.player_Age = 31
Larry_Nance_Jr.player_G = 14
Larry_Nance_Jr.player_MP = 211
Larry_Nance_Jr.player_MP = 211
Larry_Nance_Jr.player_FG = 21
Larry_Nance_Jr.player_FGA = 42
Larry_Nance_Jr.player_FT = 4
Larry_Nance_Jr.player_FTA = 8
Larry_Nance_Jr.player_TRB = 58
Larry_Nance_Jr.player_AST = 10
Larry_Nance_Jr.player_STL = 9
Larry_Nance_Jr.player_BLK = 4
Larry_Nance_Jr.player_TOV = 13
Larry_Nance_Jr.player_PF = 19
Larry_Nance_Jr.player_PTS = 49

Andrew_Nembhard = Player('Andrew_Nembhard')
Andrew_Nembhard.hasClubTeam.append(Indiana_Pacers)
Andrew_Nembhard.hasPosition.append(PG)
Andrew_Nembhard.player_Age = 24
Andrew_Nembhard.player_G = 13
Andrew_Nembhard.player_MP = 243
Andrew_Nembhard.player_MP = 243
Andrew_Nembhard.player_FG = 46
Andrew_Nembhard.player_FGA = 94
Andrew_Nembhard.player_FT = 3
Andrew_Nembhard.player_FTA = 5
Andrew_Nembhard.player_TRB = 26
Andrew_Nembhard.player_AST = 51
Andrew_Nembhard.player_STL = 11
Andrew_Nembhard.player_BLK = 0
Andrew_Nembhard.player_TOV = 20
Andrew_Nembhard.player_PF = 25
Andrew_Nembhard.player_PTS = 104

Aaron_Nesmith = Player('Aaron_Nesmith')
Aaron_Nesmith.hasClubTeam.append(Indiana_Pacers)
Aaron_Nesmith.hasPosition.append(SF)
Aaron_Nesmith.player_Age = 24
Aaron_Nesmith.player_G = 14
Aaron_Nesmith.player_MP = 328
Aaron_Nesmith.player_MP = 328
Aaron_Nesmith.player_FG = 53
Aaron_Nesmith.player_FGA = 103
Aaron_Nesmith.player_FT = 16
Aaron_Nesmith.player_FTA = 25
Aaron_Nesmith.player_TRB = 44
Aaron_Nesmith.player_AST = 14
Aaron_Nesmith.player_STL = 13
Aaron_Nesmith.player_BLK = 8
Aaron_Nesmith.player_TOV = 8
Aaron_Nesmith.player_PF = 43
Aaron_Nesmith.player_PTS = 147

Georges_Niang = Player('Georges_Niang')
Georges_Niang.hasClubTeam.append(Cleveland_Cavaliers)
Georges_Niang.hasPosition.append(PF)
Georges_Niang.player_Age = 30
Georges_Niang.player_G = 18
Georges_Niang.player_MP = 405
Georges_Niang.player_MP = 405
Georges_Niang.player_FG = 54
Georges_Niang.player_FGA = 136
Georges_Niang.player_FT = 10
Georges_Niang.player_FTA = 10
Georges_Niang.player_TRB = 75
Georges_Niang.player_AST = 20
Georges_Niang.player_STL = 5
Georges_Niang.player_BLK = 2
Georges_Niang.player_TOV = 11
Georges_Niang.player_PF = 45
Georges_Niang.player_PTS = 147

Daishen_Nix = Player('Daishen_Nix')
Daishen_Nix.hasClubTeam.append(Minnesota_Timberwolves)
Daishen_Nix.hasPosition.append(PG)
Daishen_Nix.player_Age = 21
Daishen_Nix.player_G = 4
Daishen_Nix.player_MP = 10
Daishen_Nix.player_MP = 10
Daishen_Nix.player_FG = 2
Daishen_Nix.player_FGA = 3
Daishen_Nix.player_FT = 0
Daishen_Nix.player_FTA = 0
Daishen_Nix.player_TRB = 0
Daishen_Nix.player_AST = 0
Daishen_Nix.player_STL = 1
Daishen_Nix.player_BLK = 0
Daishen_Nix.player_TOV = 0
Daishen_Nix.player_PF = 0
Daishen_Nix.player_PTS = 5

Zeke_Nnaji = Player('Zeke_Nnaji')
Zeke_Nnaji.hasClubTeam.append(Denver_Nuggets)
Zeke_Nnaji.hasPosition.append(PF)
Zeke_Nnaji.player_Age = 23
Zeke_Nnaji.player_G = 18
Zeke_Nnaji.player_MP = 181
Zeke_Nnaji.player_MP = 181
Zeke_Nnaji.player_FG = 23
Zeke_Nnaji.player_FGA = 47
Zeke_Nnaji.player_FT = 14
Zeke_Nnaji.player_FTA = 24
Zeke_Nnaji.player_TRB = 41
Zeke_Nnaji.player_AST = 8
Zeke_Nnaji.player_STL = 3
Zeke_Nnaji.player_BLK = 9
Zeke_Nnaji.player_TOV = 10
Zeke_Nnaji.player_PF = 24
Zeke_Nnaji.player_PTS = 63

Jaylen_Nowell = Player('Jaylen_Nowell')
Jaylen_Nowell.hasClubTeam.append(Memphis_Grizzlies)
Jaylen_Nowell.hasPosition.append(SG)
Jaylen_Nowell.player_Age = 24
Jaylen_Nowell.player_G = 2
Jaylen_Nowell.player_MP = 15
Jaylen_Nowell.player_MP = 15
Jaylen_Nowell.player_FG = 2
Jaylen_Nowell.player_FGA = 4
Jaylen_Nowell.player_FT = 0
Jaylen_Nowell.player_FTA = 0
Jaylen_Nowell.player_TRB = 5
Jaylen_Nowell.player_AST = 3
Jaylen_Nowell.player_STL = 0
Jaylen_Nowell.player_BLK = 0
Jaylen_Nowell.player_TOV = 0
Jaylen_Nowell.player_PF = 1
Jaylen_Nowell.player_PTS = 4

Markquis_Nowell = Player('Markquis_Nowell')
Markquis_Nowell.hasClubTeam.append(Toronto_Raptors)
Markquis_Nowell.hasPosition.append(SG)
Markquis_Nowell.player_Age = 24
Markquis_Nowell.player_G = 1
Markquis_Nowell.player_MP = 4
Markquis_Nowell.player_MP = 4
Markquis_Nowell.player_FG = 0
Markquis_Nowell.player_FGA = 1
Markquis_Nowell.player_FT = 2
Markquis_Nowell.player_FTA = 2
Markquis_Nowell.player_TRB = 2
Markquis_Nowell.player_AST = 2
Markquis_Nowell.player_STL = 1
Markquis_Nowell.player_BLK = 0
Markquis_Nowell.player_TOV = 0
Markquis_Nowell.player_PF = 0
Markquis_Nowell.player_PTS = 2

Jusuf_Nurkic = Player('Jusuf_Nurkic')
Jusuf_Nurkic.hasClubTeam.append(Phoenix_Suns)
Jusuf_Nurkic.hasPosition.append(CE)
Jusuf_Nurkic.player_Age = 29
Jusuf_Nurkic.player_G = 17
Jusuf_Nurkic.player_MP = 468
Jusuf_Nurkic.player_MP = 468
Jusuf_Nurkic.player_FG = 62
Jusuf_Nurkic.player_FGA = 138
Jusuf_Nurkic.player_FT = 44
Jusuf_Nurkic.player_FTA = 59
Jusuf_Nurkic.player_TRB = 154
Jusuf_Nurkic.player_AST = 66
Jusuf_Nurkic.player_STL = 19
Jusuf_Nurkic.player_BLK = 22
Jusuf_Nurkic.player_TOV = 33
Jusuf_Nurkic.player_PF = 58
Jusuf_Nurkic.player_PTS = 178

Jordan_Nwora = Player('Jordan_Nwora')
Jordan_Nwora.hasClubTeam.append(Indiana_Pacers)
Jordan_Nwora.hasPosition.append(SF)
Jordan_Nwora.player_Age = 25
Jordan_Nwora.player_G = 5
Jordan_Nwora.player_MP = 73
Jordan_Nwora.player_MP = 73
Jordan_Nwora.player_FG = 14
Jordan_Nwora.player_FGA = 34
Jordan_Nwora.player_FT = 3
Jordan_Nwora.player_FTA = 4
Jordan_Nwora.player_TRB = 15
Jordan_Nwora.player_AST = 6
Jordan_Nwora.player_STL = 4
Jordan_Nwora.player_BLK = 1
Jordan_Nwora.player_TOV = 7
Jordan_Nwora.player_PF = 8
Jordan_Nwora.player_PTS = 35

Royce_ONeale = Player('Royce_ONeale')
Royce_ONeale.hasClubTeam.append(Brooklyn_Nets)
Royce_ONeale.hasPosition.append(SF)
Royce_ONeale.player_Age = 30
Royce_ONeale.player_G = 17
Royce_ONeale.player_MP = 508
Royce_ONeale.player_MP = 508
Royce_ONeale.player_FG = 49
Royce_ONeale.player_FGA = 128
Royce_ONeale.player_FT = 2
Royce_ONeale.player_FTA = 6
Royce_ONeale.player_TRB = 92
Royce_ONeale.player_AST = 55
Royce_ONeale.player_STL = 14
Royce_ONeale.player_BLK = 15
Royce_ONeale.player_TOV = 18
Royce_ONeale.player_PF = 53
Royce_ONeale.player_PTS = 144

Chuma_Okeke = Player('Chuma_Okeke')
Chuma_Okeke.hasClubTeam.append(Orlando_Magic)
Chuma_Okeke.hasPosition.append(SF)
Chuma_Okeke.player_Age = 25
Chuma_Okeke.player_G = 7
Chuma_Okeke.player_MP = 27
Chuma_Okeke.player_MP = 27
Chuma_Okeke.player_FG = 4
Chuma_Okeke.player_FGA = 9
Chuma_Okeke.player_FT = 0
Chuma_Okeke.player_FTA = 0
Chuma_Okeke.player_TRB = 7
Chuma_Okeke.player_AST = 1
Chuma_Okeke.player_STL = 0
Chuma_Okeke.player_BLK = 0
Chuma_Okeke.player_TOV = 1
Chuma_Okeke.player_PF = 0
Chuma_Okeke.player_PTS = 11

Josh_Okogie = Player('Josh_Okogie')
Josh_Okogie.hasClubTeam.append(Phoenix_Suns)
Josh_Okogie.hasPosition.append(SG)
Josh_Okogie.player_Age = 25
Josh_Okogie.player_G = 17
Josh_Okogie.player_MP = 367
Josh_Okogie.player_MP = 367
Josh_Okogie.player_FG = 34
Josh_Okogie.player_FGA = 83
Josh_Okogie.player_FT = 36
Josh_Okogie.player_FTA = 44
Josh_Okogie.player_TRB = 55
Josh_Okogie.player_AST = 19
Josh_Okogie.player_STL = 15
Josh_Okogie.player_BLK = 6
Josh_Okogie.player_TOV = 15
Josh_Okogie.player_PF = 21
Josh_Okogie.player_PTS = 114

Onyeka_Okongwu = Player('Onyeka_Okongwu')
Onyeka_Okongwu.hasClubTeam.append(Atlanta_Hawks)
Onyeka_Okongwu.hasPosition.append(CE)
Onyeka_Okongwu.player_Age = 23
Onyeka_Okongwu.player_G = 17
Onyeka_Okongwu.player_MP = 387
Onyeka_Okongwu.player_MP = 387
Onyeka_Okongwu.player_FG = 56
Onyeka_Okongwu.player_FGA = 97
Onyeka_Okongwu.player_FT = 36
Onyeka_Okongwu.player_FTA = 40
Onyeka_Okongwu.player_TRB = 114
Onyeka_Okongwu.player_AST = 24
Onyeka_Okongwu.player_STL = 10
Onyeka_Okongwu.player_BLK = 15
Onyeka_Okongwu.player_TOV = 14
Onyeka_Okongwu.player_PF = 45
Onyeka_Okongwu.player_PTS = 152

Isaac_Okoro = Player('Isaac_Okoro')
Isaac_Okoro.hasClubTeam.append(Cleveland_Cavaliers)
Isaac_Okoro.hasPosition.append(SF)
Isaac_Okoro.player_Age = 23
Isaac_Okoro.player_G = 9
Isaac_Okoro.player_MP = 218
Isaac_Okoro.player_MP = 218
Isaac_Okoro.player_FG = 27
Isaac_Okoro.player_FGA = 55
Isaac_Okoro.player_FT = 10
Isaac_Okoro.player_FTA = 15
Isaac_Okoro.player_TRB = 34
Isaac_Okoro.player_AST = 15
Isaac_Okoro.player_STL = 7
Isaac_Okoro.player_BLK = 6
Isaac_Okoro.player_TOV = 9
Isaac_Okoro.player_PF = 24
Isaac_Okoro.player_PTS = 70

Kelly_Olynyk = Player('Kelly_Olynyk')
Kelly_Olynyk.hasClubTeam.append(Utah_Jazz)
Kelly_Olynyk.hasPosition.append(CE)
Kelly_Olynyk.player_Age = 32
Kelly_Olynyk.player_G = 17
Kelly_Olynyk.player_MP = 368
Kelly_Olynyk.player_MP = 368
Kelly_Olynyk.player_FG = 45
Kelly_Olynyk.player_FGA = 79
Kelly_Olynyk.player_FT = 29
Kelly_Olynyk.player_FTA = 33
Kelly_Olynyk.player_TRB = 99
Kelly_Olynyk.player_AST = 66
Kelly_Olynyk.player_STL = 14
Kelly_Olynyk.player_BLK = 4
Kelly_Olynyk.player_TOV = 34
Kelly_Olynyk.player_PF = 49
Kelly_Olynyk.player_PTS = 132

Eugene_Omoruyi = Player('Eugene_Omoruyi')
Eugene_Omoruyi.hasClubTeam.append(Washington_Wizards)
Eugene_Omoruyi.hasPosition.append(SF)
Eugene_Omoruyi.player_Age = 26
Eugene_Omoruyi.player_G = 10
Eugene_Omoruyi.player_MP = 65
Eugene_Omoruyi.player_MP = 65
Eugene_Omoruyi.player_FG = 20
Eugene_Omoruyi.player_FGA = 31
Eugene_Omoruyi.player_FT = 9
Eugene_Omoruyi.player_FTA = 12
Eugene_Omoruyi.player_TRB = 20
Eugene_Omoruyi.player_AST = 7
Eugene_Omoruyi.player_STL = 4
Eugene_Omoruyi.player_BLK = 1
Eugene_Omoruyi.player_TOV = 6
Eugene_Omoruyi.player_PF = 7
Eugene_Omoruyi.player_PTS = 53

Cedi_Osman = Player('Cedi_Osman')
Cedi_Osman.hasClubTeam.append(San_Antonio_Spurs)
Cedi_Osman.hasPosition.append(SF)
Cedi_Osman.player_Age = 28
Cedi_Osman.player_G = 17
Cedi_Osman.player_MP = 326
Cedi_Osman.player_MP = 326
Cedi_Osman.player_FG = 53
Cedi_Osman.player_FGA = 110
Cedi_Osman.player_FT = 10
Cedi_Osman.player_FTA = 12
Cedi_Osman.player_TRB = 35
Cedi_Osman.player_AST = 21
Cedi_Osman.player_STL = 8
Cedi_Osman.player_BLK = 3
Cedi_Osman.player_TOV = 11
Cedi_Osman.player_PF = 27
Cedi_Osman.player_PTS = 142

Kelly_Oubre_Jr = Player('Kelly_Oubre_Jr.')
Kelly_Oubre_Jr.hasClubTeam.append(Philadelphia_76ers)
Kelly_Oubre_Jr.hasPosition.append(SF)
Kelly_Oubre_Jr.player_Age = 28
Kelly_Oubre_Jr.player_G = 8
Kelly_Oubre_Jr.player_MP = 232
Kelly_Oubre_Jr.player_MP = 232
Kelly_Oubre_Jr.player_FG = 47
Kelly_Oubre_Jr.player_FGA = 94
Kelly_Oubre_Jr.player_FT = 22
Kelly_Oubre_Jr.player_FTA = 28
Kelly_Oubre_Jr.player_TRB = 41
Kelly_Oubre_Jr.player_AST = 5
Kelly_Oubre_Jr.player_STL = 11
Kelly_Oubre_Jr.player_BLK = 3
Kelly_Oubre_Jr.player_TOV = 7
Kelly_Oubre_Jr.player_PF = 19
Kelly_Oubre_Jr.player_PTS = 130

Chris_Paul = Player('Chris_Paul')
Chris_Paul.hasClubTeam.append(Golden_State_Warriors)
Chris_Paul.hasPosition.append(PG)
Chris_Paul.player_Age = 38
Chris_Paul.player_G = 18
Chris_Paul.player_MP = 483
Chris_Paul.player_MP = 483
Chris_Paul.player_FG = 57
Chris_Paul.player_FGA = 143
Chris_Paul.player_FT = 26
Chris_Paul.player_FTA = 28
Chris_Paul.player_TRB = 65
Chris_Paul.player_AST = 131
Chris_Paul.player_STL = 27
Chris_Paul.player_BLK = 1
Chris_Paul.player_TOV = 20
Chris_Paul.player_PF = 29
Chris_Paul.player_PTS = 161

Cameron_Payne = Player('Cameron_Payne')
Cameron_Payne.hasClubTeam.append(Milwaukee_Bucks)
Cameron_Payne.hasPosition.append(PG)
Cameron_Payne.player_Age = 29
Cameron_Payne.player_G = 18
Cameron_Payne.player_MP = 313
Cameron_Payne.player_MP = 313
Cameron_Payne.player_FG = 39
Cameron_Payne.player_FGA = 82
Cameron_Payne.player_FT = 6
Cameron_Payne.player_FTA = 6
Cameron_Payne.player_TRB = 24
Cameron_Payne.player_AST = 44
Cameron_Payne.player_STL = 8
Cameron_Payne.player_BLK = 2
Cameron_Payne.player_TOV = 15
Cameron_Payne.player_PF = 38
Cameron_Payne.player_PTS = 106

Gary_Payton_II = Player('Gary_Payton_II')
Gary_Payton_II.hasClubTeam.append(Golden_State_Warriors)
Gary_Payton_II.hasPosition.append(SG)
Gary_Payton_II.player_Age = 31
Gary_Payton_II.player_G = 14
Gary_Payton_II.player_MP = 242
Gary_Payton_II.player_MP = 242
Gary_Payton_II.player_FG = 34
Gary_Payton_II.player_FGA = 71
Gary_Payton_II.player_FT = 6
Gary_Payton_II.player_FTA = 9
Gary_Payton_II.player_TRB = 44
Gary_Payton_II.player_AST = 13
Gary_Payton_II.player_STL = 17
Gary_Payton_II.player_BLK = 4
Gary_Payton_II.player_TOV = 9
Gary_Payton_II.player_PF = 26
Gary_Payton_II.player_PTS = 83

Filip_Petrusev = Player('Filip_Petrusev')
Filip_Petrusev.hasClubTeam.append(Toronto_Raptors)
Filip_Petrusev.hasPosition.append(CE)
Filip_Petrusev.player_Age = 23
Filip_Petrusev.player_G = 3
Filip_Petrusev.player_MP = 10
Filip_Petrusev.player_MP = 10
Filip_Petrusev.player_FG = 1
Filip_Petrusev.player_FGA = 2
Filip_Petrusev.player_FT = 1
Filip_Petrusev.player_FTA = 2
Filip_Petrusev.player_TRB = 1
Filip_Petrusev.player_AST = 0
Filip_Petrusev.player_STL = 0
Filip_Petrusev.player_BLK = 0
Filip_Petrusev.player_TOV = 0
Filip_Petrusev.player_PF = 1
Filip_Petrusev.player_PTS = 3

Julian_Phillips = Player('Julian_Phillips')
Julian_Phillips.hasClubTeam.append(Chicago_Bulls)
Julian_Phillips.hasPosition.append(SF)
Julian_Phillips.player_Age = 20
Julian_Phillips.player_G = 8
Julian_Phillips.player_MP = 31
Julian_Phillips.player_MP = 31
Julian_Phillips.player_FG = 2
Julian_Phillips.player_FGA = 9
Julian_Phillips.player_FT = 1
Julian_Phillips.player_FTA = 4
Julian_Phillips.player_TRB = 4
Julian_Phillips.player_AST = 1
Julian_Phillips.player_STL = 0
Julian_Phillips.player_BLK = 0
Julian_Phillips.player_TOV = 1
Julian_Phillips.player_PF = 3
Julian_Phillips.player_PTS = 5

Jalen_Pickett = Player('Jalen_Pickett')
Jalen_Pickett.hasClubTeam.append(Denver_Nuggets)
Jalen_Pickett.hasPosition.append(SG)
Jalen_Pickett.player_Age = 24
Jalen_Pickett.player_G = 10
Jalen_Pickett.player_MP = 71
Jalen_Pickett.player_MP = 71
Jalen_Pickett.player_FG = 9
Jalen_Pickett.player_FGA = 19
Jalen_Pickett.player_FT = 2
Jalen_Pickett.player_FTA = 2
Jalen_Pickett.player_TRB = 10
Jalen_Pickett.player_AST = 7
Jalen_Pickett.player_STL = 3
Jalen_Pickett.player_BLK = 0
Jalen_Pickett.player_TOV = 6
Jalen_Pickett.player_PF = 7
Jalen_Pickett.player_PTS = 25

Mason_Plumlee = Player('Mason_Plumlee')
Mason_Plumlee.hasClubTeam.append(Los_Angeles_Clippers)
Mason_Plumlee.hasPosition.append(CE)
Mason_Plumlee.player_Age = 33
Mason_Plumlee.player_G = 6
Mason_Plumlee.player_MP = 102
Mason_Plumlee.player_MP = 102
Mason_Plumlee.player_FG = 12
Mason_Plumlee.player_FGA = 19
Mason_Plumlee.player_FT = 6
Mason_Plumlee.player_FTA = 14
Mason_Plumlee.player_TRB = 33
Mason_Plumlee.player_AST = 6
Mason_Plumlee.player_STL = 4
Mason_Plumlee.player_BLK = 1
Mason_Plumlee.player_TOV = 5
Mason_Plumlee.player_PF = 6
Mason_Plumlee.player_PTS = 30

Brandin_Podziemski = Player('Brandin_Podziemski')
Brandin_Podziemski.hasClubTeam.append(Golden_State_Warriors)
Brandin_Podziemski.hasPosition.append(SG)
Brandin_Podziemski.player_Age = 20
Brandin_Podziemski.player_G = 12
Brandin_Podziemski.player_MP = 195
Brandin_Podziemski.player_MP = 195
Brandin_Podziemski.player_FG = 28
Brandin_Podziemski.player_FGA = 64
Brandin_Podziemski.player_FT = 10
Brandin_Podziemski.player_FTA = 13
Brandin_Podziemski.player_TRB = 46
Brandin_Podziemski.player_AST = 26
Brandin_Podziemski.player_STL = 6
Brandin_Podziemski.player_BLK = 0
Brandin_Podziemski.player_TOV = 13
Brandin_Podziemski.player_PF = 19
Brandin_Podziemski.player_PTS = 77

Jakob_Poeltl = Player('Jakob_Poeltl')
Jakob_Poeltl.hasClubTeam.append(Toronto_Raptors)
Jakob_Poeltl.hasPosition.append(CE)
Jakob_Poeltl.player_Age = 28
Jakob_Poeltl.player_G = 18
Jakob_Poeltl.player_MP = 475
Jakob_Poeltl.player_MP = 475
Jakob_Poeltl.player_FG = 91
Jakob_Poeltl.player_FGA = 126
Jakob_Poeltl.player_FT = 16
Jakob_Poeltl.player_FTA = 33
Jakob_Poeltl.player_TRB = 154
Jakob_Poeltl.player_AST = 44
Jakob_Poeltl.player_STL = 17
Jakob_Poeltl.player_BLK = 18
Jakob_Poeltl.player_TOV = 31
Jakob_Poeltl.player_PF = 47
Jakob_Poeltl.player_PTS = 198

Aleksej_Pokusevski = Player('Aleksej_Pokusevski')
Aleksej_Pokusevski.hasClubTeam.append(Oklahoma_City_Thunder)
Aleksej_Pokusevski.hasPosition.append(PF)
Aleksej_Pokusevski.player_Age = 22
Aleksej_Pokusevski.player_G = 5
Aleksej_Pokusevski.player_MP = 31
Aleksej_Pokusevski.player_MP = 31
Aleksej_Pokusevski.player_FG = 2
Aleksej_Pokusevski.player_FGA = 8
Aleksej_Pokusevski.player_FT = 1
Aleksej_Pokusevski.player_FTA = 2
Aleksej_Pokusevski.player_TRB = 7
Aleksej_Pokusevski.player_AST = 5
Aleksej_Pokusevski.player_STL = 0
Aleksej_Pokusevski.player_BLK = 1
Aleksej_Pokusevski.player_TOV = 3
Aleksej_Pokusevski.player_PF = 4
Aleksej_Pokusevski.player_PTS = 6

Jordan_Poole = Player('Jordan_Poole')
Jordan_Poole.hasClubTeam.append(Washington_Wizards)
Jordan_Poole.hasPosition.append(SG)
Jordan_Poole.player_Age = 24
Jordan_Poole.player_G = 16
Jordan_Poole.player_MP = 472
Jordan_Poole.player_MP = 472
Jordan_Poole.player_FG = 100
Jordan_Poole.player_FGA = 252
Jordan_Poole.player_FT = 46
Jordan_Poole.player_FTA = 54
Jordan_Poole.player_TRB = 41
Jordan_Poole.player_AST = 57
Jordan_Poole.player_STL = 18
Jordan_Poole.player_BLK = 6
Jordan_Poole.player_TOV = 47
Jordan_Poole.player_PF = 50
Jordan_Poole.player_PTS = 276

Craig_Porter_Jr = Player('Craig_Porter_Jr.')
Craig_Porter_Jr.hasClubTeam.append(Cleveland_Cavaliers)
Craig_Porter_Jr.hasPosition.append(PG)
Craig_Porter_Jr.player_Age = 23
Craig_Porter_Jr.player_G = 12
Craig_Porter_Jr.player_MP = 174
Craig_Porter_Jr.player_MP = 174
Craig_Porter_Jr.player_FG = 37
Craig_Porter_Jr.player_FGA = 66
Craig_Porter_Jr.player_FT = 16
Craig_Porter_Jr.player_FTA = 22
Craig_Porter_Jr.player_TRB = 23
Craig_Porter_Jr.player_AST = 30
Craig_Porter_Jr.player_STL = 7
Craig_Porter_Jr.player_BLK = 5
Craig_Porter_Jr.player_TOV = 14
Craig_Porter_Jr.player_PF = 14
Craig_Porter_Jr.player_PTS = 93

Michael_Porter_Jr = Player('Michael_Porter_Jr.')
Michael_Porter_Jr.hasClubTeam.append(Denver_Nuggets)
Michael_Porter_Jr.hasPosition.append(SF)
Michael_Porter_Jr.player_Age = 25
Michael_Porter_Jr.player_G = 18
Michael_Porter_Jr.player_MP = 558
Michael_Porter_Jr.player_MP = 558
Michael_Porter_Jr.player_FG = 116
Michael_Porter_Jr.player_FGA = 251
Michael_Porter_Jr.player_FT = 19
Michael_Porter_Jr.player_FTA = 25
Michael_Porter_Jr.player_TRB = 141
Michael_Porter_Jr.player_AST = 26
Michael_Porter_Jr.player_STL = 8
Michael_Porter_Jr.player_BLK = 14
Michael_Porter_Jr.player_TOV = 22
Michael_Porter_Jr.player_PF = 44
Michael_Porter_Jr.player_PTS = 304

Otto_Porter_Jr = Player('Otto_Porter_Jr.')
Otto_Porter_Jr.hasClubTeam.append(Toronto_Raptors)
Otto_Porter_Jr.hasPosition.append(SF)
Otto_Porter_Jr.player_Age = 30
Otto_Porter_Jr.player_G = 9
Otto_Porter_Jr.player_MP = 110
Otto_Porter_Jr.player_MP = 110
Otto_Porter_Jr.player_FG = 10
Otto_Porter_Jr.player_FGA = 23
Otto_Porter_Jr.player_FT = 1
Otto_Porter_Jr.player_FTA = 1
Otto_Porter_Jr.player_TRB = 22
Otto_Porter_Jr.player_AST = 1
Otto_Porter_Jr.player_STL = 3
Otto_Porter_Jr.player_BLK = 3
Otto_Porter_Jr.player_TOV = 1
Otto_Porter_Jr.player_PF = 10
Otto_Porter_Jr.player_PTS = 28

Bobby_Portis = Player('Bobby_Portis')
Bobby_Portis.hasClubTeam.append(Milwaukee_Bucks)
Bobby_Portis.hasPosition.append(PF)
Bobby_Portis.player_Age = 28
Bobby_Portis.player_G = 18
Bobby_Portis.player_MP = 425
Bobby_Portis.player_MP = 425
Bobby_Portis.player_FG = 84
Bobby_Portis.player_FGA = 175
Bobby_Portis.player_FT = 25
Bobby_Portis.player_FTA = 33
Bobby_Portis.player_TRB = 114
Bobby_Portis.player_AST = 22
Bobby_Portis.player_STL = 15
Bobby_Portis.player_BLK = 10
Bobby_Portis.player_TOV = 18
Bobby_Portis.player_PF = 40
Bobby_Portis.player_PTS = 207

Kristaps_Porzingis = Player('Kristaps_Porzingis')
Kristaps_Porzingis.hasClubTeam.append(Boston_Celtics)
Kristaps_Porzingis.hasPosition.append(CE)
Kristaps_Porzingis.player_Age = 28
Kristaps_Porzingis.player_G = 15
Kristaps_Porzingis.player_MP = 454
Kristaps_Porzingis.player_MP = 454
Kristaps_Porzingis.player_FG = 98
Kristaps_Porzingis.player_FGA = 179
Kristaps_Porzingis.player_FT = 64
Kristaps_Porzingis.player_FTA = 80
Kristaps_Porzingis.player_TRB = 100
Kristaps_Porzingis.player_AST = 28
Kristaps_Porzingis.player_STL = 10
Kristaps_Porzingis.player_BLK = 25
Kristaps_Porzingis.player_TOV = 19
Kristaps_Porzingis.player_PF = 51
Kristaps_Porzingis.player_PTS = 284

Dwight_Powell = Player('Dwight_Powell')
Dwight_Powell.hasClubTeam.append(Dallas_Mavericks)
Dwight_Powell.hasPosition.append(CE)
Dwight_Powell.player_Age = 32
Dwight_Powell.player_G = 16
Dwight_Powell.player_MP = 238
Dwight_Powell.player_MP = 238
Dwight_Powell.player_FG = 21
Dwight_Powell.player_FGA = 29
Dwight_Powell.player_FT = 28
Dwight_Powell.player_FTA = 36
Dwight_Powell.player_TRB = 51
Dwight_Powell.player_AST = 22
Dwight_Powell.player_STL = 5
Dwight_Powell.player_BLK = 8
Dwight_Powell.player_TOV = 6
Dwight_Powell.player_PF = 28
Dwight_Powell.player_PTS = 71

Norman_Powell = Player('Norman_Powell')
Norman_Powell.hasClubTeam.append(Los_Angeles_Clippers)
Norman_Powell.hasPosition.append(SG)
Norman_Powell.player_Age = 30
Norman_Powell.player_G = 16
Norman_Powell.player_MP = 391
Norman_Powell.player_MP = 391
Norman_Powell.player_FG = 69
Norman_Powell.player_FGA = 138
Norman_Powell.player_FT = 37
Norman_Powell.player_FTA = 46
Norman_Powell.player_TRB = 34
Norman_Powell.player_AST = 19
Norman_Powell.player_STL = 12
Norman_Powell.player_BLK = 9
Norman_Powell.player_TOV = 16
Norman_Powell.player_PF = 36
Norman_Powell.player_PTS = 207

Taurean_Prince = Player('Taurean_Prince')
Taurean_Prince.hasClubTeam.append(Los_Angeles_Lakers)
Taurean_Prince.hasPosition.append(PF)
Taurean_Prince.player_Age = 29
Taurean_Prince.player_G = 16
Taurean_Prince.player_MP = 485
Taurean_Prince.player_MP = 485
Taurean_Prince.player_FG = 53
Taurean_Prince.player_FGA = 131
Taurean_Prince.player_FT = 12
Taurean_Prince.player_FTA = 16
Taurean_Prince.player_TRB = 38
Taurean_Prince.player_AST = 24
Taurean_Prince.player_STL = 9
Taurean_Prince.player_BLK = 8
Taurean_Prince.player_TOV = 10
Taurean_Prince.player_PF = 38
Taurean_Prince.player_PTS = 139

Payton_Pritchard = Player('Payton_Pritchard')
Payton_Pritchard.hasClubTeam.append(Boston_Celtics)
Payton_Pritchard.hasPosition.append(PG)
Payton_Pritchard.player_Age = 26
Payton_Pritchard.player_G = 18
Payton_Pritchard.player_MP = 371
Payton_Pritchard.player_MP = 371
Payton_Pritchard.player_FG = 42
Payton_Pritchard.player_FGA = 108
Payton_Pritchard.player_FT = 8
Payton_Pritchard.player_FTA = 11
Payton_Pritchard.player_TRB = 58
Payton_Pritchard.player_AST = 51
Payton_Pritchard.player_STL = 6
Payton_Pritchard.player_BLK = 0
Payton_Pritchard.player_TOV = 11
Payton_Pritchard.player_PF = 19
Payton_Pritchard.player_PTS = 114

Olivier_Maxence_Prosper = Player('Olivier-Maxence_Prosper')
Olivier_Maxence_Prosper.hasClubTeam.append(Dallas_Mavericks)
Olivier_Maxence_Prosper.hasPosition.append(PF)
Olivier_Maxence_Prosper.player_Age = 21
Olivier_Maxence_Prosper.player_G = 7
Olivier_Maxence_Prosper.player_MP = 41
Olivier_Maxence_Prosper.player_MP = 41
Olivier_Maxence_Prosper.player_FG = 4
Olivier_Maxence_Prosper.player_FGA = 13
Olivier_Maxence_Prosper.player_FT = 4
Olivier_Maxence_Prosper.player_FTA = 8
Olivier_Maxence_Prosper.player_TRB = 9
Olivier_Maxence_Prosper.player_AST = 1
Olivier_Maxence_Prosper.player_STL = 1
Olivier_Maxence_Prosper.player_BLK = 0
Olivier_Maxence_Prosper.player_TOV = 0
Olivier_Maxence_Prosper.player_PF = 3
Olivier_Maxence_Prosper.player_PTS = 13

Neemias_Queta = Player('Neemias_Queta')
Neemias_Queta.hasClubTeam.append(Boston_Celtics)
Neemias_Queta.hasPosition.append(CE)
Neemias_Queta.player_Age = 24
Neemias_Queta.player_G = 2
Neemias_Queta.player_MP = 20
Neemias_Queta.player_MP = 20
Neemias_Queta.player_FG = 3
Neemias_Queta.player_FGA = 9
Neemias_Queta.player_FT = 1
Neemias_Queta.player_FTA = 1
Neemias_Queta.player_TRB = 12
Neemias_Queta.player_AST = 0
Neemias_Queta.player_STL = 1
Neemias_Queta.player_BLK = 0
Neemias_Queta.player_TOV = 0
Neemias_Queta.player_PF = 1
Neemias_Queta.player_PTS = 7

Immanuel_Quickley = Player('Immanuel_Quickley')
Immanuel_Quickley.hasClubTeam.append(New_York_Knicks)
Immanuel_Quickley.hasPosition.append(SG)
Immanuel_Quickley.player_Age = 24
Immanuel_Quickley.player_G = 17
Immanuel_Quickley.player_MP = 426
Immanuel_Quickley.player_MP = 426
Immanuel_Quickley.player_FG = 95
Immanuel_Quickley.player_FGA = 213
Immanuel_Quickley.player_FT = 50
Immanuel_Quickley.player_FTA = 56
Immanuel_Quickley.player_TRB = 57
Immanuel_Quickley.player_AST = 51
Immanuel_Quickley.player_STL = 8
Immanuel_Quickley.player_BLK = 2
Immanuel_Quickley.player_TOV = 20
Immanuel_Quickley.player_PF = 31
Immanuel_Quickley.player_PTS = 277

Lester_Quinones = Player('Lester_Quinones')
Lester_Quinones.hasClubTeam.append(Golden_State_Warriors)
Lester_Quinones.hasPosition.append(SG)
Lester_Quinones.player_Age = 23
Lester_Quinones.player_G = 2
Lester_Quinones.player_MP = 9
Lester_Quinones.player_MP = 9
Lester_Quinones.player_FG = 2
Lester_Quinones.player_FGA = 6
Lester_Quinones.player_FT = 0
Lester_Quinones.player_FTA = 0
Lester_Quinones.player_TRB = 0
Lester_Quinones.player_AST = 0
Lester_Quinones.player_STL = 0
Lester_Quinones.player_BLK = 0
Lester_Quinones.player_TOV = 1
Lester_Quinones.player_PF = 1
Lester_Quinones.player_PTS = 5

Julius_Randle = Player('Julius_Randle')
Julius_Randle.hasClubTeam.append(New_York_Knicks)
Julius_Randle.hasPosition.append(PF)
Julius_Randle.player_Age = 29
Julius_Randle.player_G = 17
Julius_Randle.player_MP = 591
Julius_Randle.player_MP = 591
Julius_Randle.player_FG = 116
Julius_Randle.player_FGA = 294
Julius_Randle.player_FT = 79
Julius_Randle.player_FTA = 112
Julius_Randle.player_TRB = 173
Julius_Randle.player_AST = 88
Julius_Randle.player_STL = 14
Julius_Randle.player_BLK = 2
Julius_Randle.player_TOV = 55
Julius_Randle.player_PF = 43
Julius_Randle.player_PTS = 339

Duop_Reath = Player('Duop_Reath')
Duop_Reath.hasClubTeam.append(Portland_Trail_Blazers)
Duop_Reath.hasPosition.append(CE)
Duop_Reath.player_Age = 27
Duop_Reath.player_G = 9
Duop_Reath.player_MP = 121
Duop_Reath.player_MP = 121
Duop_Reath.player_FG = 20
Duop_Reath.player_FGA = 52
Duop_Reath.player_FT = 5
Duop_Reath.player_FTA = 6
Duop_Reath.player_TRB = 17
Duop_Reath.player_AST = 9
Duop_Reath.player_STL = 4
Duop_Reath.player_BLK = 2
Duop_Reath.player_TOV = 7
Duop_Reath.player_PF = 15
Duop_Reath.player_PTS = 56

Austin_Reaves = Player('Austin_Reaves')
Austin_Reaves.hasClubTeam.append(Los_Angeles_Lakers)
Austin_Reaves.hasPosition.append(SG)
Austin_Reaves.player_Age = 25
Austin_Reaves.player_G = 18
Austin_Reaves.player_MP = 545
Austin_Reaves.player_MP = 545
Austin_Reaves.player_FG = 86
Austin_Reaves.player_FGA = 187
Austin_Reaves.player_FT = 54
Austin_Reaves.player_FTA = 64
Austin_Reaves.player_TRB = 89
Austin_Reaves.player_AST = 91
Austin_Reaves.player_STL = 19
Austin_Reaves.player_BLK = 1
Austin_Reaves.player_TOV = 45
Austin_Reaves.player_PF = 25
Austin_Reaves.player_PTS = 250

Cam_Reddish = Player('Cam_Reddish')
Cam_Reddish.hasClubTeam.append(Los_Angeles_Lakers)
Cam_Reddish.hasPosition.append(SF)
Cam_Reddish.player_Age = 24
Cam_Reddish.player_G = 15
Cam_Reddish.player_MP = 359
Cam_Reddish.player_MP = 359
Cam_Reddish.player_FG = 38
Cam_Reddish.player_FGA = 90
Cam_Reddish.player_FT = 20
Cam_Reddish.player_FTA = 25
Cam_Reddish.player_TRB = 38
Cam_Reddish.player_AST = 16
Cam_Reddish.player_STL = 25
Cam_Reddish.player_BLK = 4
Cam_Reddish.player_TOV = 9
Cam_Reddish.player_PF = 23
Cam_Reddish.player_PTS = 111

Paul_Reed = Player('Paul_Reed')
Paul_Reed.hasClubTeam.append(Philadelphia_76ers)
Paul_Reed.hasPosition.append(CE)
Paul_Reed.player_Age = 24
Paul_Reed.player_G = 17
Paul_Reed.player_MP = 232
Paul_Reed.player_MP = 232
Paul_Reed.player_FG = 38
Paul_Reed.player_FGA = 68
Paul_Reed.player_FT = 2
Paul_Reed.player_FTA = 4
Paul_Reed.player_TRB = 75
Paul_Reed.player_AST = 14
Paul_Reed.player_STL = 9
Paul_Reed.player_BLK = 11
Paul_Reed.player_TOV = 12
Paul_Reed.player_PF = 33
Paul_Reed.player_PTS = 81

Naz_Reid = Player('Naz_Reid')
Naz_Reid.hasClubTeam.append(Minnesota_Timberwolves)
Naz_Reid.hasPosition.append(CE)
Naz_Reid.player_Age = 24
Naz_Reid.player_G = 17
Naz_Reid.player_MP = 360
Naz_Reid.player_MP = 360
Naz_Reid.player_FG = 77
Naz_Reid.player_FGA = 150
Naz_Reid.player_FT = 27
Naz_Reid.player_FTA = 30
Naz_Reid.player_TRB = 68
Naz_Reid.player_AST = 11
Naz_Reid.player_STL = 12
Naz_Reid.player_BLK = 10
Naz_Reid.player_TOV = 19
Naz_Reid.player_PF = 26
Naz_Reid.player_PTS = 210

Jared_Rhoden = Player('Jared_Rhoden')
Jared_Rhoden.hasClubTeam.append(Detroit_Pistons)
Jared_Rhoden.hasPosition.append(SG)
Jared_Rhoden.player_Age = 24
Jared_Rhoden.player_G = 5
Jared_Rhoden.player_MP = 30
Jared_Rhoden.player_MP = 30
Jared_Rhoden.player_FG = 5
Jared_Rhoden.player_FGA = 9
Jared_Rhoden.player_FT = 2
Jared_Rhoden.player_FTA = 2
Jared_Rhoden.player_TRB = 4
Jared_Rhoden.player_AST = 3
Jared_Rhoden.player_STL = 0
Jared_Rhoden.player_BLK = 0
Jared_Rhoden.player_TOV = 2
Jared_Rhoden.player_PF = 4
Jared_Rhoden.player_PTS = 13

Nick_Richards = Player('Nick_Richards')
Nick_Richards.hasClubTeam.append(Charlotte_Hornets)
Nick_Richards.hasPosition.append(CE)
Nick_Richards.player_Age = 26
Nick_Richards.player_G = 11
Nick_Richards.player_MP = 192
Nick_Richards.player_MP = 192
Nick_Richards.player_FG = 33
Nick_Richards.player_FGA = 42
Nick_Richards.player_FT = 27
Nick_Richards.player_FTA = 34
Nick_Richards.player_TRB = 65
Nick_Richards.player_AST = 4
Nick_Richards.player_STL = 4
Nick_Richards.player_BLK = 13
Nick_Richards.player_TOV = 13
Nick_Richards.player_PF = 32
Nick_Richards.player_PTS = 93

Josh_Richardson = Player('Josh_Richardson')
Josh_Richardson.hasClubTeam.append(Miami_Heat)
Josh_Richardson.hasPosition.append(SG)
Josh_Richardson.player_Age = 30
Josh_Richardson.player_G = 15
Josh_Richardson.player_MP = 415
Josh_Richardson.player_MP = 415
Josh_Richardson.player_FG = 53
Josh_Richardson.player_FGA = 125
Josh_Richardson.player_FT = 19
Josh_Richardson.player_FTA = 21
Josh_Richardson.player_TRB = 39
Josh_Richardson.player_AST = 47
Josh_Richardson.player_STL = 10
Josh_Richardson.player_BLK = 4
Josh_Richardson.player_TOV = 16
Josh_Richardson.player_PF = 26
Josh_Richardson.player_PTS = 144

Duncan_Robinson = Player('Duncan_Robinson')
Duncan_Robinson.hasClubTeam.append(Miami_Heat)
Duncan_Robinson.hasPosition.append(SF)
Duncan_Robinson.player_Age = 29
Duncan_Robinson.player_G = 16
Duncan_Robinson.player_MP = 472
Duncan_Robinson.player_MP = 472
Duncan_Robinson.player_FG = 82
Duncan_Robinson.player_FGA = 172
Duncan_Robinson.player_FT = 18
Duncan_Robinson.player_FTA = 22
Duncan_Robinson.player_TRB = 43
Duncan_Robinson.player_AST = 44
Duncan_Robinson.player_STL = 5
Duncan_Robinson.player_BLK = 3
Duncan_Robinson.player_TOV = 15
Duncan_Robinson.player_PF = 37
Duncan_Robinson.player_PTS = 231

Jerome_Robinson = Player('Jerome_Robinson')
Jerome_Robinson.hasClubTeam.append(Golden_State_Warriors)
Jerome_Robinson.hasPosition.append(SG)
Jerome_Robinson.player_Age = 26
Jerome_Robinson.player_G = 1
Jerome_Robinson.player_MP = 5
Jerome_Robinson.player_MP = 5
Jerome_Robinson.player_FG = 0
Jerome_Robinson.player_FGA = 2
Jerome_Robinson.player_FT = 0
Jerome_Robinson.player_FTA = 0
Jerome_Robinson.player_TRB = 2
Jerome_Robinson.player_AST = 0
Jerome_Robinson.player_STL = 0
Jerome_Robinson.player_BLK = 0
Jerome_Robinson.player_TOV = 0
Jerome_Robinson.player_PF = 0
Jerome_Robinson.player_PTS = 0

Mitchell_Robinson = Player('Mitchell_Robinson')
Mitchell_Robinson.hasClubTeam.append(New_York_Knicks)
Mitchell_Robinson.hasPosition.append(CE)
Mitchell_Robinson.player_Age = 25
Mitchell_Robinson.player_G = 17
Mitchell_Robinson.player_MP = 505
Mitchell_Robinson.player_MP = 505
Mitchell_Robinson.player_FG = 47
Mitchell_Robinson.player_FGA = 83
Mitchell_Robinson.player_FT = 12
Mitchell_Robinson.player_FTA = 34
Mitchell_Robinson.player_TRB = 190
Mitchell_Robinson.player_AST = 8
Mitchell_Robinson.player_STL = 24
Mitchell_Robinson.player_BLK = 24
Mitchell_Robinson.player_TOV = 15
Mitchell_Robinson.player_PF = 31
Mitchell_Robinson.player_PTS = 106

Orlando_Robinson = Player('Orlando_Robinson')
Orlando_Robinson.hasClubTeam.append(Miami_Heat)
Orlando_Robinson.hasPosition.append(CE)
Orlando_Robinson.player_Age = 23
Orlando_Robinson.player_G = 4
Orlando_Robinson.player_MP = 60
Orlando_Robinson.player_MP = 60
Orlando_Robinson.player_FG = 10
Orlando_Robinson.player_FGA = 18
Orlando_Robinson.player_FT = 3
Orlando_Robinson.player_FTA = 4
Orlando_Robinson.player_TRB = 17
Orlando_Robinson.player_AST = 9
Orlando_Robinson.player_STL = 2
Orlando_Robinson.player_BLK = 3
Orlando_Robinson.player_TOV = 5
Orlando_Robinson.player_PF = 9
Orlando_Robinson.player_PTS = 25

Jeremiah_Robinson_Earl = Player('Jeremiah_Robinson-Earl')
Jeremiah_Robinson_Earl.hasClubTeam.append(New_Orleans_Pelicans)
Jeremiah_Robinson_Earl.hasPosition.append(PF)
Jeremiah_Robinson_Earl.player_Age = 23
Jeremiah_Robinson_Earl.player_G = 7
Jeremiah_Robinson_Earl.player_MP = 98
Jeremiah_Robinson_Earl.player_MP = 98
Jeremiah_Robinson_Earl.player_FG = 13
Jeremiah_Robinson_Earl.player_FGA = 25
Jeremiah_Robinson_Earl.player_FT = 6
Jeremiah_Robinson_Earl.player_FTA = 6
Jeremiah_Robinson_Earl.player_TRB = 22
Jeremiah_Robinson_Earl.player_AST = 5
Jeremiah_Robinson_Earl.player_STL = 2
Jeremiah_Robinson_Earl.player_BLK = 0
Jeremiah_Robinson_Earl.player_TOV = 6
Jeremiah_Robinson_Earl.player_PF = 9
Jeremiah_Robinson_Earl.player_PTS = 38

David_Roddy = Player('David_Roddy')
David_Roddy.hasClubTeam.append(Memphis_Grizzlies)
David_Roddy.hasPosition.append(PF)
David_Roddy.player_Age = 22
David_Roddy.player_G = 16
David_Roddy.player_MP = 372
David_Roddy.player_MP = 372
David_Roddy.player_FG = 52
David_Roddy.player_FGA = 121
David_Roddy.player_FT = 10
David_Roddy.player_FTA = 15
David_Roddy.player_TRB = 61
David_Roddy.player_AST = 16
David_Roddy.player_STL = 10
David_Roddy.player_BLK = 7
David_Roddy.player_TOV = 15
David_Roddy.player_PF = 25
David_Roddy.player_PTS = 126

Ryan_Rollins = Player('Ryan_Rollins')
Ryan_Rollins.hasClubTeam.append(Washington_Wizards)
Ryan_Rollins.hasPosition.append(PG)
Ryan_Rollins.player_Age = 21
Ryan_Rollins.player_G = 8
Ryan_Rollins.player_MP = 49
Ryan_Rollins.player_MP = 49
Ryan_Rollins.player_FG = 9
Ryan_Rollins.player_FGA = 18
Ryan_Rollins.player_FT = 13
Ryan_Rollins.player_FTA = 16
Ryan_Rollins.player_TRB = 10
Ryan_Rollins.player_AST = 10
Ryan_Rollins.player_STL = 8
Ryan_Rollins.player_BLK = 2
Ryan_Rollins.player_TOV = 7
Ryan_Rollins.player_PF = 6
Ryan_Rollins.player_PTS = 32

Derrick_Rose = Player('Derrick_Rose')
Derrick_Rose.hasClubTeam.append(Memphis_Grizzlies)
Derrick_Rose.hasPosition.append(PG)
Derrick_Rose.player_Age = 35
Derrick_Rose.player_G = 8
Derrick_Rose.player_MP = 142
Derrick_Rose.player_MP = 142
Derrick_Rose.player_FG = 29
Derrick_Rose.player_FGA = 65
Derrick_Rose.player_FT = 11
Derrick_Rose.player_FTA = 13
Derrick_Rose.player_TRB = 14
Derrick_Rose.player_AST = 19
Derrick_Rose.player_STL = 4
Derrick_Rose.player_BLK = 1
Derrick_Rose.player_TOV = 10
Derrick_Rose.player_PF = 6
Derrick_Rose.player_PTS = 77

Terry_Rozier = Player('Terry_Rozier')
Terry_Rozier.hasClubTeam.append(Charlotte_Hornets)
Terry_Rozier.hasPosition.append(SG)
Terry_Rozier.player_Age = 29
Terry_Rozier.player_G = 7
Terry_Rozier.player_MP = 249
Terry_Rozier.player_MP = 249
Terry_Rozier.player_FG = 56
Terry_Rozier.player_FGA = 121
Terry_Rozier.player_FT = 21
Terry_Rozier.player_FTA = 27
Terry_Rozier.player_TRB = 23
Terry_Rozier.player_AST = 39
Terry_Rozier.player_STL = 5
Terry_Rozier.player_BLK = 3
Terry_Rozier.player_TOV = 19
Terry_Rozier.player_PF = 8
Terry_Rozier.player_PTS = 143

Rayan_Rupert = Player('Rayan_Rupert')
Rayan_Rupert.hasClubTeam.append(Portland_Trail_Blazers)
Rayan_Rupert.hasPosition.append(SG)
Rayan_Rupert.player_Age = 19
Rayan_Rupert.player_G = 7
Rayan_Rupert.player_MP = 31
Rayan_Rupert.player_MP = 31
Rayan_Rupert.player_FG = 1
Rayan_Rupert.player_FGA = 12
Rayan_Rupert.player_FT = 2
Rayan_Rupert.player_FTA = 4
Rayan_Rupert.player_TRB = 1
Rayan_Rupert.player_AST = 2
Rayan_Rupert.player_STL = 2
Rayan_Rupert.player_BLK = 0
Rayan_Rupert.player_TOV = 2
Rayan_Rupert.player_PF = 1
Rayan_Rupert.player_PTS = 5

DAngelo_Russell = Player('DAngelo_Russell')
DAngelo_Russell.hasClubTeam.append(Los_Angeles_Lakers)
DAngelo_Russell.hasPosition.append(PG)
DAngelo_Russell.player_Age = 27
DAngelo_Russell.player_G = 18
DAngelo_Russell.player_MP = 556
DAngelo_Russell.player_MP = 556
DAngelo_Russell.player_FG = 112
DAngelo_Russell.player_FGA = 237
DAngelo_Russell.player_FT = 37
DAngelo_Russell.player_FTA = 48
DAngelo_Russell.player_TRB = 62
DAngelo_Russell.player_AST = 112
DAngelo_Russell.player_STL = 10
DAngelo_Russell.player_BLK = 10
DAngelo_Russell.player_TOV = 33
DAngelo_Russell.player_PF = 37
DAngelo_Russell.player_PTS = 300

Matt_Ryan = Player('Matt_Ryan')
Matt_Ryan.hasClubTeam.append(New_Orleans_Pelicans)
Matt_Ryan.hasPosition.append(SF)
Matt_Ryan.player_Age = 26
Matt_Ryan.player_G = 13
Matt_Ryan.player_MP = 298
Matt_Ryan.player_MP = 298
Matt_Ryan.player_FG = 38
Matt_Ryan.player_FGA = 83
Matt_Ryan.player_FT = 13
Matt_Ryan.player_FTA = 14
Matt_Ryan.player_TRB = 30
Matt_Ryan.player_AST = 14
Matt_Ryan.player_STL = 5
Matt_Ryan.player_BLK = 1
Matt_Ryan.player_TOV = 16
Matt_Ryan.player_PF = 24
Matt_Ryan.player_PTS = 121

Domantas_Sabonis = Player('Domantas_Sabonis')
Domantas_Sabonis.hasClubTeam.append(Sacramento_Kings)
Domantas_Sabonis.hasPosition.append(CE)
Domantas_Sabonis.player_Age = 27
Domantas_Sabonis.player_G = 16
Domantas_Sabonis.player_MP = 564
Domantas_Sabonis.player_MP = 564
Domantas_Sabonis.player_FG = 118
Domantas_Sabonis.player_FGA = 194
Domantas_Sabonis.player_FT = 64
Domantas_Sabonis.player_FTA = 99
Domantas_Sabonis.player_TRB = 193
Domantas_Sabonis.player_AST = 115
Domantas_Sabonis.player_STL = 14
Domantas_Sabonis.player_BLK = 15
Domantas_Sabonis.player_TOV = 52
Domantas_Sabonis.player_PF = 57
Domantas_Sabonis.player_PTS = 307

Luka_samanic = Player('Luka_samanic')
Luka_samanic.hasClubTeam.append(Utah_Jazz)
Luka_samanic.hasPosition.append(PF)
Luka_samanic.player_Age = 24
Luka_samanic.player_G = 6
Luka_samanic.player_MP = 26
Luka_samanic.player_MP = 26
Luka_samanic.player_FG = 5
Luka_samanic.player_FGA = 13
Luka_samanic.player_FT = 1
Luka_samanic.player_FTA = 1
Luka_samanic.player_TRB = 7
Luka_samanic.player_AST = 2
Luka_samanic.player_STL = 1
Luka_samanic.player_BLK = 0
Luka_samanic.player_TOV = 1
Luka_samanic.player_PF = 2
Luka_samanic.player_PTS = 13

Jermaine_Samuels = Player('Jermaine_Samuels')
Jermaine_Samuels.hasClubTeam.append(Houston_Rockets)
Jermaine_Samuels.hasPosition.append(SF)
Jermaine_Samuels.player_Age = 25
Jermaine_Samuels.player_G = 3
Jermaine_Samuels.player_MP = 20
Jermaine_Samuels.player_MP = 20
Jermaine_Samuels.player_FG = 2
Jermaine_Samuels.player_FGA = 3
Jermaine_Samuels.player_FT = 2
Jermaine_Samuels.player_FTA = 2
Jermaine_Samuels.player_TRB = 3
Jermaine_Samuels.player_AST = 0
Jermaine_Samuels.player_STL = 0
Jermaine_Samuels.player_BLK = 1
Jermaine_Samuels.player_TOV = 0
Jermaine_Samuels.player_PF = 3
Jermaine_Samuels.player_PTS = 6

Gui_Santos = Player('Gui_Santos')
Gui_Santos.hasClubTeam.append(Golden_State_Warriors)
Gui_Santos.hasPosition.append(PF)
Gui_Santos.player_Age = 21
Gui_Santos.player_G = 2
Gui_Santos.player_MP = 12
Gui_Santos.player_MP = 12
Gui_Santos.player_FG = 2
Gui_Santos.player_FGA = 4
Gui_Santos.player_FT = 0
Gui_Santos.player_FTA = 0
Gui_Santos.player_TRB = 4
Gui_Santos.player_AST = 1
Gui_Santos.player_STL = 0
Gui_Santos.player_BLK = 0
Gui_Santos.player_TOV = 2
Gui_Santos.player_PF = 2
Gui_Santos.player_PTS = 4

Dario_saric = Player('Dario_saric')
Dario_saric.hasClubTeam.append(Golden_State_Warriors)
Dario_saric.hasPosition.append(CE)
Dario_saric.player_Age = 29
Dario_saric.player_G = 18
Dario_saric.player_MP = 386
Dario_saric.player_MP = 386
Dario_saric.player_FG = 67
Dario_saric.player_FGA = 149
Dario_saric.player_FT = 29
Dario_saric.player_FTA = 34
Dario_saric.player_TRB = 110
Dario_saric.player_AST = 41
Dario_saric.player_STL = 12
Dario_saric.player_BLK = 6
Dario_saric.player_TOV = 18
Dario_saric.player_PF = 43
Dario_saric.player_PTS = 193

Olivier_Sarr = Player('Olivier_Sarr')
Olivier_Sarr.hasClubTeam.append(Oklahoma_City_Thunder)
Olivier_Sarr.hasPosition.append(CE)
Olivier_Sarr.player_Age = 24
Olivier_Sarr.player_G = 5
Olivier_Sarr.player_MP = 54
Olivier_Sarr.player_MP = 54
Olivier_Sarr.player_FG = 3
Olivier_Sarr.player_FGA = 6
Olivier_Sarr.player_FT = 4
Olivier_Sarr.player_FTA = 6
Olivier_Sarr.player_TRB = 20
Olivier_Sarr.player_AST = 1
Olivier_Sarr.player_STL = 0
Olivier_Sarr.player_BLK = 5
Olivier_Sarr.player_TOV = 2
Olivier_Sarr.player_PF = 10
Olivier_Sarr.player_PTS = 12

Marcus_Sasser = Player('Marcus_Sasser')
Marcus_Sasser.hasClubTeam.append(Detroit_Pistons)
Marcus_Sasser.hasPosition.append(PG)
Marcus_Sasser.player_Age = 23
Marcus_Sasser.player_G = 17
Marcus_Sasser.player_MP = 308
Marcus_Sasser.player_MP = 308
Marcus_Sasser.player_FG = 54
Marcus_Sasser.player_FGA = 117
Marcus_Sasser.player_FT = 7
Marcus_Sasser.player_FTA = 7
Marcus_Sasser.player_TRB = 34
Marcus_Sasser.player_AST = 44
Marcus_Sasser.player_STL = 11
Marcus_Sasser.player_BLK = 2
Marcus_Sasser.player_TOV = 13
Marcus_Sasser.player_PF = 24
Marcus_Sasser.player_PTS = 136

Admiral_Schofield = Player('Admiral_Schofield')
Admiral_Schofield.hasClubTeam.append(Orlando_Magic)
Admiral_Schofield.hasPosition.append(PF)
Admiral_Schofield.player_Age = 26
Admiral_Schofield.player_G = 3
Admiral_Schofield.player_MP = 10
Admiral_Schofield.player_MP = 10
Admiral_Schofield.player_FG = 2
Admiral_Schofield.player_FGA = 5
Admiral_Schofield.player_FT = 0
Admiral_Schofield.player_FTA = 2
Admiral_Schofield.player_TRB = 0
Admiral_Schofield.player_AST = 0
Admiral_Schofield.player_STL = 0
Admiral_Schofield.player_BLK = 0
Admiral_Schofield.player_TOV = 1
Admiral_Schofield.player_PF = 1
Admiral_Schofield.player_PTS = 5

Dennis_Schroder = Player('Dennis_Schroder')
Dennis_Schroder.hasClubTeam.append(Toronto_Raptors)
Dennis_Schroder.hasPosition.append(PG)
Dennis_Schroder.player_Age = 30
Dennis_Schroder.player_G = 18
Dennis_Schroder.player_MP = 561
Dennis_Schroder.player_MP = 561
Dennis_Schroder.player_FG = 107
Dennis_Schroder.player_FGA = 239
Dennis_Schroder.player_FT = 51
Dennis_Schroder.player_FTA = 59
Dennis_Schroder.player_TRB = 53
Dennis_Schroder.player_AST = 119
Dennis_Schroder.player_STL = 17
Dennis_Schroder.player_BLK = 2
Dennis_Schroder.player_TOV = 33
Dennis_Schroder.player_PF = 36
Dennis_Schroder.player_PTS = 299

Dereon_Seabron = Player('Dereon_Seabron')
Dereon_Seabron.hasClubTeam.append(New_Orleans_Pelicans)
Dereon_Seabron.hasPosition.append(SG)
Dereon_Seabron.player_Age = 23
Dereon_Seabron.player_G = 5
Dereon_Seabron.player_MP = 52
Dereon_Seabron.player_MP = 52
Dereon_Seabron.player_FG = 4
Dereon_Seabron.player_FGA = 13
Dereon_Seabron.player_FT = 5
Dereon_Seabron.player_FTA = 6
Dereon_Seabron.player_TRB = 7
Dereon_Seabron.player_AST = 4
Dereon_Seabron.player_STL = 2
Dereon_Seabron.player_BLK = 1
Dereon_Seabron.player_TOV = 0
Dereon_Seabron.player_PF = 4
Dereon_Seabron.player_PTS = 14

Alperen_sengun = Player('Alperen_sengun')
Alperen_sengun.hasClubTeam.append(Houston_Rockets)
Alperen_sengun.hasPosition.append(CE)
Alperen_sengun.player_Age = 21
Alperen_sengun.player_G = 15
Alperen_sengun.player_MP = 494
Alperen_sengun.player_MP = 494
Alperen_sengun.player_FG = 129
Alperen_sengun.player_FGA = 229
Alperen_sengun.player_FT = 46
Alperen_sengun.player_FTA = 69
Alperen_sengun.player_TRB = 136
Alperen_sengun.player_AST = 85
Alperen_sengun.player_STL = 13
Alperen_sengun.player_BLK = 11
Alperen_sengun.player_TOV = 42
Alperen_sengun.player_PF = 48
Alperen_sengun.player_PTS = 314

Brice_Sensabaugh = Player('Brice_Sensabaugh')
Brice_Sensabaugh.hasClubTeam.append(Utah_Jazz)
Brice_Sensabaugh.hasPosition.append(SF)
Brice_Sensabaugh.player_Age = 20
Brice_Sensabaugh.player_G = 1
Brice_Sensabaugh.player_MP = 2
Brice_Sensabaugh.player_MP = 2
Brice_Sensabaugh.player_FG = 0
Brice_Sensabaugh.player_FGA = 2
Brice_Sensabaugh.player_FT = 0
Brice_Sensabaugh.player_FTA = 0
Brice_Sensabaugh.player_TRB = 2
Brice_Sensabaugh.player_AST = 0
Brice_Sensabaugh.player_STL = 0
Brice_Sensabaugh.player_BLK = 0
Brice_Sensabaugh.player_TOV = 0
Brice_Sensabaugh.player_PF = 0
Brice_Sensabaugh.player_PTS = 0

Collin_Sexton = Player('Collin_Sexton')
Collin_Sexton.hasClubTeam.append(Utah_Jazz)
Collin_Sexton.hasPosition.append(SG)
Collin_Sexton.player_Age = 25
Collin_Sexton.player_G = 17
Collin_Sexton.player_MP = 338
Collin_Sexton.player_MP = 338
Collin_Sexton.player_FG = 69
Collin_Sexton.player_FGA = 157
Collin_Sexton.player_FT = 44
Collin_Sexton.player_FTA = 51
Collin_Sexton.player_TRB = 44
Collin_Sexton.player_AST = 52
Collin_Sexton.player_STL = 7
Collin_Sexton.player_BLK = 4
Collin_Sexton.player_TOV = 33
Collin_Sexton.player_PF = 28
Collin_Sexton.player_PTS = 203

Landry_Shamet = Player('Landry_Shamet')
Landry_Shamet.hasClubTeam.append(Washington_Wizards)
Landry_Shamet.hasPosition.append(SG)
Landry_Shamet.player_Age = 26
Landry_Shamet.player_G = 13
Landry_Shamet.player_MP = 217
Landry_Shamet.player_MP = 217
Landry_Shamet.player_FG = 41
Landry_Shamet.player_FGA = 87
Landry_Shamet.player_FT = 5
Landry_Shamet.player_FTA = 8
Landry_Shamet.player_TRB = 20
Landry_Shamet.player_AST = 19
Landry_Shamet.player_STL = 8
Landry_Shamet.player_BLK = 2
Landry_Shamet.player_TOV = 6
Landry_Shamet.player_PF = 23
Landry_Shamet.player_PTS = 107

DayRon_Sharpe = Player('DayRon_Sharpe')
DayRon_Sharpe.hasClubTeam.append(Brooklyn_Nets)
DayRon_Sharpe.hasPosition.append(CE)
DayRon_Sharpe.player_Age = 22
DayRon_Sharpe.player_G = 17
DayRon_Sharpe.player_MP = 256
DayRon_Sharpe.player_MP = 256
DayRon_Sharpe.player_FG = 43
DayRon_Sharpe.player_FGA = 79
DayRon_Sharpe.player_FT = 24
DayRon_Sharpe.player_FTA = 35
DayRon_Sharpe.player_TRB = 111
DayRon_Sharpe.player_AST = 13
DayRon_Sharpe.player_STL = 6
DayRon_Sharpe.player_BLK = 12
DayRon_Sharpe.player_TOV = 19
DayRon_Sharpe.player_PF = 35
DayRon_Sharpe.player_PTS = 110

Shaedon_Sharpe = Player('Shaedon_Sharpe')
Shaedon_Sharpe.hasClubTeam.append(Portland_Trail_Blazers)
Shaedon_Sharpe.hasPosition.append(SG)
Shaedon_Sharpe.player_Age = 20
Shaedon_Sharpe.player_G = 17
Shaedon_Sharpe.player_MP = 620
Shaedon_Sharpe.player_MP = 620
Shaedon_Sharpe.player_FG = 97
Shaedon_Sharpe.player_FGA = 248
Shaedon_Sharpe.player_FT = 58
Shaedon_Sharpe.player_FTA = 70
Shaedon_Sharpe.player_TRB = 91
Shaedon_Sharpe.player_AST = 55
Shaedon_Sharpe.player_STL = 18
Shaedon_Sharpe.player_BLK = 8
Shaedon_Sharpe.player_TOV = 53
Shaedon_Sharpe.player_PF = 50
Shaedon_Sharpe.player_PTS = 282

Ben_Sheppard = Player('Ben_Sheppard')
Ben_Sheppard.hasClubTeam.append(Indiana_Pacers)
Ben_Sheppard.hasPosition.append(SG)
Ben_Sheppard.player_Age = 22
Ben_Sheppard.player_G = 7
Ben_Sheppard.player_MP = 55
Ben_Sheppard.player_MP = 55
Ben_Sheppard.player_FG = 9
Ben_Sheppard.player_FGA = 22
Ben_Sheppard.player_FT = 2
Ben_Sheppard.player_FTA = 2
Ben_Sheppard.player_TRB = 5
Ben_Sheppard.player_AST = 5
Ben_Sheppard.player_STL = 1
Ben_Sheppard.player_BLK = 0
Ben_Sheppard.player_TOV = 1
Ben_Sheppard.player_PF = 4
Ben_Sheppard.player_PTS = 25

Pascal_Siakam = Player('Pascal_Siakam')
Pascal_Siakam.hasClubTeam.append(Toronto_Raptors)
Pascal_Siakam.hasPosition.append(PF)
Pascal_Siakam.player_Age = 29
Pascal_Siakam.player_G = 18
Pascal_Siakam.player_MP = 616
Pascal_Siakam.player_MP = 616
Pascal_Siakam.player_FG = 138
Pascal_Siakam.player_FGA = 286
Pascal_Siakam.player_FT = 66
Pascal_Siakam.player_FTA = 91
Pascal_Siakam.player_TRB = 126
Pascal_Siakam.player_AST = 94
Pascal_Siakam.player_STL = 14
Pascal_Siakam.player_BLK = 4
Pascal_Siakam.player_TOV = 47
Pascal_Siakam.player_PF = 39
Pascal_Siakam.player_PTS = 357

Ben_Simmons = Player('Ben_Simmons')
Ben_Simmons.hasClubTeam.append(Brooklyn_Nets)
Ben_Simmons.hasPosition.append(PG)
Ben_Simmons.player_Age = 27
Ben_Simmons.player_G = 6
Ben_Simmons.player_MP = 191
Ben_Simmons.player_MP = 191
Ben_Simmons.player_FG = 19
Ben_Simmons.player_FGA = 36
Ben_Simmons.player_FT = 1
Ben_Simmons.player_FTA = 4
Ben_Simmons.player_TRB = 65
Ben_Simmons.player_AST = 40
Ben_Simmons.player_STL = 3
Ben_Simmons.player_BLK = 5
Ben_Simmons.player_TOV = 15
Ben_Simmons.player_PF = 16
Ben_Simmons.player_PTS = 39

Anfernee_Simons = Player('Anfernee_Simons')
Anfernee_Simons.hasClubTeam.append(Portland_Trail_Blazers)
Anfernee_Simons.hasPosition.append(SG)
Anfernee_Simons.player_Age = 24
Anfernee_Simons.player_G = 1
Anfernee_Simons.player_MP = 27
Anfernee_Simons.player_MP = 27
Anfernee_Simons.player_FG = 6
Anfernee_Simons.player_FGA = 14
Anfernee_Simons.player_FT = 4
Anfernee_Simons.player_FTA = 4
Anfernee_Simons.player_TRB = 2
Anfernee_Simons.player_AST = 4
Anfernee_Simons.player_STL = 2
Anfernee_Simons.player_BLK = 0
Anfernee_Simons.player_TOV = 0
Anfernee_Simons.player_PF = 2
Anfernee_Simons.player_PTS = 18

Jericho_Sims = Player('Jericho_Sims')
Jericho_Sims.hasClubTeam.append(New_York_Knicks)
Jericho_Sims.hasPosition.append(CE)
Jericho_Sims.player_Age = 25
Jericho_Sims.player_G = 8
Jericho_Sims.player_MP = 22
Jericho_Sims.player_MP = 22
Jericho_Sims.player_FG = 2
Jericho_Sims.player_FGA = 3
Jericho_Sims.player_FT = 1
Jericho_Sims.player_FTA = 3
Jericho_Sims.player_TRB = 10
Jericho_Sims.player_AST = 1
Jericho_Sims.player_STL = 0
Jericho_Sims.player_BLK = 0
Jericho_Sims.player_TOV = 0
Jericho_Sims.player_PF = 1
Jericho_Sims.player_PTS = 5

Jalen_Slawson = Player('Jalen_Slawson')
Jalen_Slawson.hasClubTeam.append(Sacramento_Kings)
Jalen_Slawson.hasPosition.append(SF)
Jalen_Slawson.player_Age = 24
Jalen_Slawson.player_G = 3
Jalen_Slawson.player_MP = 16
Jalen_Slawson.player_MP = 16
Jalen_Slawson.player_FG = 2
Jalen_Slawson.player_FGA = 3
Jalen_Slawson.player_FT = 0
Jalen_Slawson.player_FTA = 0
Jalen_Slawson.player_TRB = 4
Jalen_Slawson.player_AST = 2
Jalen_Slawson.player_STL = 0
Jalen_Slawson.player_BLK = 1
Jalen_Slawson.player_TOV = 1
Jalen_Slawson.player_PF = 1
Jalen_Slawson.player_PTS = 4

Marcus_Smart = Player('Marcus_Smart')
Marcus_Smart.hasClubTeam.append(Memphis_Grizzlies)
Marcus_Smart.hasPosition.append(PG)
Marcus_Smart.player_Age = 29
Marcus_Smart.player_G = 11
Marcus_Smart.player_MP = 329
Marcus_Smart.player_MP = 329
Marcus_Smart.player_FG = 51
Marcus_Smart.player_FGA = 119
Marcus_Smart.player_FT = 17
Marcus_Smart.player_FTA = 21
Marcus_Smart.player_TRB = 27
Marcus_Smart.player_AST = 55
Marcus_Smart.player_STL = 22
Marcus_Smart.player_BLK = 4
Marcus_Smart.player_TOV = 37
Marcus_Smart.player_PF = 35
Marcus_Smart.player_PTS = 137

Dennis_Smith_Jr = Player('Dennis_Smith_Jr.')
Dennis_Smith_Jr.hasClubTeam.append(Brooklyn_Nets)
Dennis_Smith_Jr.hasPosition.append(PG)
Dennis_Smith_Jr.player_Age = 26
Dennis_Smith_Jr.player_G = 11
Dennis_Smith_Jr.player_MP = 187
Dennis_Smith_Jr.player_MP = 187
Dennis_Smith_Jr.player_FG = 25
Dennis_Smith_Jr.player_FGA = 63
Dennis_Smith_Jr.player_FT = 7
Dennis_Smith_Jr.player_FTA = 8
Dennis_Smith_Jr.player_TRB = 25
Dennis_Smith_Jr.player_AST = 35
Dennis_Smith_Jr.player_STL = 7
Dennis_Smith_Jr.player_BLK = 2
Dennis_Smith_Jr.player_TOV = 11
Dennis_Smith_Jr.player_PF = 25
Dennis_Smith_Jr.player_PTS = 64

Dru_Smith = Player('Dru_Smith')
Dru_Smith.hasClubTeam.append(Miami_Heat)
Dru_Smith.hasPosition.append(SG)
Dru_Smith.player_Age = 26
Dru_Smith.player_G = 9
Dru_Smith.player_MP = 131
Dru_Smith.player_MP = 131
Dru_Smith.player_FG = 15
Dru_Smith.player_FGA = 33
Dru_Smith.player_FT = 2
Dru_Smith.player_FTA = 2
Dru_Smith.player_TRB = 14
Dru_Smith.player_AST = 14
Dru_Smith.player_STL = 9
Dru_Smith.player_BLK = 3
Dru_Smith.player_TOV = 5
Dru_Smith.player_PF = 12
Dru_Smith.player_PTS = 39

Ish_Smith = Player('Ish_Smith')
Ish_Smith.hasClubTeam.append(Charlotte_Hornets)
Ish_Smith.hasPosition.append(PG)
Ish_Smith.player_Age = 35
Ish_Smith.player_G = 10
Ish_Smith.player_MP = 162
Ish_Smith.player_MP = 162
Ish_Smith.player_FG = 17
Ish_Smith.player_FGA = 31
Ish_Smith.player_FT = 0
Ish_Smith.player_FTA = 0
Ish_Smith.player_TRB = 18
Ish_Smith.player_AST = 23
Ish_Smith.player_STL = 5
Ish_Smith.player_BLK = 1
Ish_Smith.player_TOV = 13
Ish_Smith.player_PF = 10
Ish_Smith.player_PTS = 35

Jabari_Smith_Jr = Player('Jabari_Smith_Jr.')
Jabari_Smith_Jr.hasClubTeam.append(Houston_Rockets)
Jabari_Smith_Jr.hasPosition.append(PF)
Jabari_Smith_Jr.player_Age = 20
Jabari_Smith_Jr.player_G = 15
Jabari_Smith_Jr.player_MP = 451
Jabari_Smith_Jr.player_MP = 451
Jabari_Smith_Jr.player_FG = 80
Jabari_Smith_Jr.player_FGA = 157
Jabari_Smith_Jr.player_FT = 14
Jabari_Smith_Jr.player_FTA = 19
Jabari_Smith_Jr.player_TRB = 117
Jabari_Smith_Jr.player_AST = 20
Jabari_Smith_Jr.player_STL = 9
Jabari_Smith_Jr.player_BLK = 10
Jabari_Smith_Jr.player_TOV = 19
Jabari_Smith_Jr.player_PF = 49
Jabari_Smith_Jr.player_PTS = 201

Jalen_Smith = Player('Jalen_Smith')
Jalen_Smith.hasClubTeam.append(Indiana_Pacers)
Jalen_Smith.hasPosition.append(CE)
Jalen_Smith.player_Age = 23
Jalen_Smith.player_G = 14
Jalen_Smith.player_MP = 216
Jalen_Smith.player_MP = 216
Jalen_Smith.player_FG = 53
Jalen_Smith.player_FGA = 75
Jalen_Smith.player_FT = 20
Jalen_Smith.player_FTA = 27
Jalen_Smith.player_TRB = 77
Jalen_Smith.player_AST = 12
Jalen_Smith.player_STL = 5
Jalen_Smith.player_BLK = 4
Jalen_Smith.player_TOV = 15
Jalen_Smith.player_PF = 29
Jalen_Smith.player_PTS = 140

Nick_Smith_Jr = Player('Nick_Smith_Jr.')
Nick_Smith_Jr.hasClubTeam.append(Charlotte_Hornets)
Nick_Smith_Jr.hasPosition.append(SG)
Nick_Smith_Jr.player_Age = 19
Nick_Smith_Jr.player_G = 7
Nick_Smith_Jr.player_MP = 43
Nick_Smith_Jr.player_MP = 43
Nick_Smith_Jr.player_FG = 9
Nick_Smith_Jr.player_FGA = 21
Nick_Smith_Jr.player_FT = 0
Nick_Smith_Jr.player_FTA = 0
Nick_Smith_Jr.player_TRB = 4
Nick_Smith_Jr.player_AST = 2
Nick_Smith_Jr.player_STL = 1
Nick_Smith_Jr.player_BLK = 1
Nick_Smith_Jr.player_TOV = 2
Nick_Smith_Jr.player_PF = 3
Nick_Smith_Jr.player_PTS = 23

Jeremy_Sochan = Player('Jeremy_Sochan')
Jeremy_Sochan.hasClubTeam.append(San_Antonio_Spurs)
Jeremy_Sochan.hasPosition.append(PG)
Jeremy_Sochan.player_Age = 20
Jeremy_Sochan.player_G = 17
Jeremy_Sochan.player_MP = 484
Jeremy_Sochan.player_MP = 484
Jeremy_Sochan.player_FG = 69
Jeremy_Sochan.player_FGA = 163
Jeremy_Sochan.player_FT = 25
Jeremy_Sochan.player_FTA = 33
Jeremy_Sochan.player_TRB = 91
Jeremy_Sochan.player_AST = 74
Jeremy_Sochan.player_STL = 13
Jeremy_Sochan.player_BLK = 4
Jeremy_Sochan.player_TOV = 39
Jeremy_Sochan.player_PF = 49
Jeremy_Sochan.player_PTS = 176

Jaden_Springer = Player('Jaden_Springer')
Jaden_Springer.hasClubTeam.append(Philadelphia_76ers)
Jaden_Springer.hasPosition.append(SG)
Jaden_Springer.player_Age = 21
Jaden_Springer.player_G = 11
Jaden_Springer.player_MP = 127
Jaden_Springer.player_MP = 127
Jaden_Springer.player_FG = 13
Jaden_Springer.player_FGA = 37
Jaden_Springer.player_FT = 6
Jaden_Springer.player_FTA = 8
Jaden_Springer.player_TRB = 22
Jaden_Springer.player_AST = 10
Jaden_Springer.player_STL = 5
Jaden_Springer.player_BLK = 6
Jaden_Springer.player_TOV = 12
Jaden_Springer.player_PF = 18
Jaden_Springer.player_PTS = 35

Lamar_Stevens = Player('Lamar_Stevens')
Lamar_Stevens.hasClubTeam.append(Boston_Celtics)
Lamar_Stevens.hasPosition.append(PF)
Lamar_Stevens.player_Age = 26
Lamar_Stevens.player_G = 6
Lamar_Stevens.player_MP = 20
Lamar_Stevens.player_MP = 20
Lamar_Stevens.player_FG = 4
Lamar_Stevens.player_FGA = 7
Lamar_Stevens.player_FT = 0
Lamar_Stevens.player_FTA = 0
Lamar_Stevens.player_TRB = 6
Lamar_Stevens.player_AST = 2
Lamar_Stevens.player_STL = 1
Lamar_Stevens.player_BLK = 1
Lamar_Stevens.player_TOV = 3
Lamar_Stevens.player_PF = 4
Lamar_Stevens.player_PTS = 9

Isaiah_Stewart = Player('Isaiah_Stewart')
Isaiah_Stewart.hasClubTeam.append(Detroit_Pistons)
Isaiah_Stewart.hasPosition.append(PF)
Isaiah_Stewart.player_Age = 22
Isaiah_Stewart.player_G = 17
Isaiah_Stewart.player_MP = 538
Isaiah_Stewart.player_MP = 538
Isaiah_Stewart.player_FG = 73
Isaiah_Stewart.player_FGA = 161
Isaiah_Stewart.player_FT = 24
Isaiah_Stewart.player_FTA = 31
Isaiah_Stewart.player_TRB = 126
Isaiah_Stewart.player_AST = 23
Isaiah_Stewart.player_STL = 5
Isaiah_Stewart.player_BLK = 13
Isaiah_Stewart.player_TOV = 28
Isaiah_Stewart.player_PF = 43
Isaiah_Stewart.player_PTS = 195

Julian_Strawther = Player('Julian_Strawther')
Julian_Strawther.hasClubTeam.append(Denver_Nuggets)
Julian_Strawther.hasPosition.append(SF)
Julian_Strawther.player_Age = 21
Julian_Strawther.player_G = 15
Julian_Strawther.player_MP = 183
Julian_Strawther.player_MP = 183
Julian_Strawther.player_FG = 29
Julian_Strawther.player_FGA = 73
Julian_Strawther.player_FT = 6
Julian_Strawther.player_FTA = 8
Julian_Strawther.player_TRB = 17
Julian_Strawther.player_AST = 15
Julian_Strawther.player_STL = 5
Julian_Strawther.player_BLK = 4
Julian_Strawther.player_TOV = 3
Julian_Strawther.player_PF = 25
Julian_Strawther.player_PTS = 80

Max_Strus = Player('Max_Strus')
Max_Strus.hasClubTeam.append(Cleveland_Cavaliers)
Max_Strus.hasPosition.append(SF)
Max_Strus.player_Age = 27
Max_Strus.player_G = 18
Max_Strus.player_MP = 632
Max_Strus.player_MP = 632
Max_Strus.player_FG = 92
Max_Strus.player_FGA = 212
Max_Strus.player_FT = 19
Max_Strus.player_FTA = 23
Max_Strus.player_TRB = 102
Max_Strus.player_AST = 72
Max_Strus.player_STL = 17
Max_Strus.player_BLK = 13
Max_Strus.player_TOV = 29
Max_Strus.player_PF = 44
Max_Strus.player_PTS = 256

Jalen_Suggs = Player('Jalen_Suggs')
Jalen_Suggs.hasClubTeam.append(Orlando_Magic)
Jalen_Suggs.hasPosition.append(SG)
Jalen_Suggs.player_Age = 22
Jalen_Suggs.player_G = 16
Jalen_Suggs.player_MP = 433
Jalen_Suggs.player_MP = 433
Jalen_Suggs.player_FG = 67
Jalen_Suggs.player_FGA = 154
Jalen_Suggs.player_FT = 40
Jalen_Suggs.player_FTA = 48
Jalen_Suggs.player_TRB = 64
Jalen_Suggs.player_AST = 43
Jalen_Suggs.player_STL = 30
Jalen_Suggs.player_BLK = 8
Jalen_Suggs.player_TOV = 31
Jalen_Suggs.player_PF = 44
Jalen_Suggs.player_PTS = 199

Cole_Swider = Player('Cole_Swider')
Cole_Swider.hasClubTeam.append(Miami_Heat)
Cole_Swider.hasPosition.append(SF)
Cole_Swider.player_Age = 24
Cole_Swider.player_G = 3
Cole_Swider.player_MP = 29
Cole_Swider.player_MP = 29
Cole_Swider.player_FG = 6
Cole_Swider.player_FGA = 14
Cole_Swider.player_FT = 0
Cole_Swider.player_FTA = 0
Cole_Swider.player_TRB = 1
Cole_Swider.player_AST = 3
Cole_Swider.player_STL = 1
Cole_Swider.player_BLK = 1
Cole_Swider.player_TOV = 1
Cole_Swider.player_PF = 1
Cole_Swider.player_PTS = 16

JaeSean_Tate = Player('JaeSean_Tate')
JaeSean_Tate.hasClubTeam.append(Houston_Rockets)
JaeSean_Tate.hasPosition.append(SF)
JaeSean_Tate.player_Age = 28
JaeSean_Tate.player_G = 15
JaeSean_Tate.player_MP = 282
JaeSean_Tate.player_MP = 282
JaeSean_Tate.player_FG = 36
JaeSean_Tate.player_FGA = 71
JaeSean_Tate.player_FT = 8
JaeSean_Tate.player_FTA = 10
JaeSean_Tate.player_TRB = 58
JaeSean_Tate.player_AST = 20
JaeSean_Tate.player_STL = 17
JaeSean_Tate.player_BLK = 5
JaeSean_Tate.player_TOV = 5
JaeSean_Tate.player_PF = 42
JaeSean_Tate.player_PTS = 91

Jayson_Tatum = Player('Jayson_Tatum')
Jayson_Tatum.hasClubTeam.append(Boston_Celtics)
Jayson_Tatum.hasPosition.append(PF)
Jayson_Tatum.player_Age = 25
Jayson_Tatum.player_G = 18
Jayson_Tatum.player_MP = 666
Jayson_Tatum.player_MP = 666
Jayson_Tatum.player_FG = 175
Jayson_Tatum.player_FGA = 354
Jayson_Tatum.player_FT = 92
Jayson_Tatum.player_FTA = 114
Jayson_Tatum.player_TRB = 158
Jayson_Tatum.player_AST = 73
Jayson_Tatum.player_STL = 20
Jayson_Tatum.player_BLK = 6
Jayson_Tatum.player_TOV = 58
Jayson_Tatum.player_PF = 41
Jayson_Tatum.player_PTS = 499

Terry_Taylor = Player('Terry_Taylor')
Terry_Taylor.hasClubTeam.append(Chicago_Bulls)
Terry_Taylor.hasPosition.append(PF)
Terry_Taylor.player_Age = 24
Terry_Taylor.player_G = 5
Terry_Taylor.player_MP = 12
Terry_Taylor.player_MP = 12
Terry_Taylor.player_FG = 1
Terry_Taylor.player_FGA = 1
Terry_Taylor.player_FT = 0
Terry_Taylor.player_FTA = 0
Terry_Taylor.player_TRB = 1
Terry_Taylor.player_AST = 0
Terry_Taylor.player_STL = 1
Terry_Taylor.player_BLK = 0
Terry_Taylor.player_TOV = 0
Terry_Taylor.player_PF = 0
Terry_Taylor.player_PTS = 2

Garrett_Temple = Player('Garrett_Temple')
Garrett_Temple.hasClubTeam.append(Toronto_Raptors)
Garrett_Temple.hasPosition.append(SG)
Garrett_Temple.player_Age = 37
Garrett_Temple.player_G = 5
Garrett_Temple.player_MP = 16
Garrett_Temple.player_MP = 16
Garrett_Temple.player_FG = 4
Garrett_Temple.player_FGA = 5
Garrett_Temple.player_FT = 2
Garrett_Temple.player_FTA = 2
Garrett_Temple.player_TRB = 2
Garrett_Temple.player_AST = 2
Garrett_Temple.player_STL = 1
Garrett_Temple.player_BLK = 0
Garrett_Temple.player_TOV = 0
Garrett_Temple.player_PF = 0
Garrett_Temple.player_PTS = 11

Dalen_Terry = Player('Dalen_Terry')
Dalen_Terry.hasClubTeam.append(Chicago_Bulls)
Dalen_Terry.hasPosition.append(SG)
Dalen_Terry.player_Age = 21
Dalen_Terry.player_G = 5
Dalen_Terry.player_MP = 19
Dalen_Terry.player_MP = 19
Dalen_Terry.player_FG = 3
Dalen_Terry.player_FGA = 8
Dalen_Terry.player_FT = 0
Dalen_Terry.player_FTA = 2
Dalen_Terry.player_TRB = 9
Dalen_Terry.player_AST = 4
Dalen_Terry.player_STL = 0
Dalen_Terry.player_BLK = 1
Dalen_Terry.player_TOV = 1
Dalen_Terry.player_PF = 2
Dalen_Terry.player_PTS = 7

Daniel_Theis = Player('Daniel_Theis')
Daniel_Theis.hasClubTeam.append(Toronto_Raptors)
Daniel_Theis.hasPosition.append(CE)
Daniel_Theis.player_Age = 31
Daniel_Theis.player_G = 7
Daniel_Theis.player_MP = 109
Daniel_Theis.player_MP = 109
Daniel_Theis.player_FG = 19
Daniel_Theis.player_FGA = 41
Daniel_Theis.player_FT = 3
Daniel_Theis.player_FTA = 6
Daniel_Theis.player_TRB = 29
Daniel_Theis.player_AST = 9
Daniel_Theis.player_STL = 2
Daniel_Theis.player_BLK = 6
Daniel_Theis.player_TOV = 5
Daniel_Theis.player_PF = 16
Daniel_Theis.player_PTS = 43

Cam_Thomas = Player('Cam_Thomas')
Cam_Thomas.hasClubTeam.append(Brooklyn_Nets)
Cam_Thomas.hasPosition.append(SG)
Cam_Thomas.player_Age = 22
Cam_Thomas.player_G = 8
Cam_Thomas.player_MP = 259
Cam_Thomas.player_MP = 259
Cam_Thomas.player_FG = 79
Cam_Thomas.player_FGA = 165
Cam_Thomas.player_FT = 40
Cam_Thomas.player_FTA = 47
Cam_Thomas.player_TRB = 30
Cam_Thomas.player_AST = 17
Cam_Thomas.player_STL = 7
Cam_Thomas.player_BLK = 5
Cam_Thomas.player_TOV = 10
Cam_Thomas.player_PF = 15
Cam_Thomas.player_PTS = 215

Amen_Thompson = Player('Amen_Thompson')
Amen_Thompson.hasClubTeam.append(Houston_Rockets)
Amen_Thompson.hasPosition.append(SF)
Amen_Thompson.player_Age = 21
Amen_Thompson.player_G = 4
Amen_Thompson.player_MP = 67
Amen_Thompson.player_MP = 67
Amen_Thompson.player_FG = 9
Amen_Thompson.player_FGA = 22
Amen_Thompson.player_FT = 5
Amen_Thompson.player_FTA = 8
Amen_Thompson.player_TRB = 11
Amen_Thompson.player_AST = 6
Amen_Thompson.player_STL = 2
Amen_Thompson.player_BLK = 1
Amen_Thompson.player_TOV = 6
Amen_Thompson.player_PF = 9
Amen_Thompson.player_PTS = 25

Ausar_Thompson = Player('Ausar_Thompson')
Ausar_Thompson.hasClubTeam.append(Detroit_Pistons)
Ausar_Thompson.hasPosition.append(SF)
Ausar_Thompson.player_Age = 21
Ausar_Thompson.player_G = 17
Ausar_Thompson.player_MP = 515
Ausar_Thompson.player_MP = 515
Ausar_Thompson.player_FG = 80
Ausar_Thompson.player_FGA = 174
Ausar_Thompson.player_FT = 30
Ausar_Thompson.player_FTA = 43
Ausar_Thompson.player_TRB = 161
Ausar_Thompson.player_AST = 53
Ausar_Thompson.player_STL = 19
Ausar_Thompson.player_BLK = 29
Ausar_Thompson.player_TOV = 38
Ausar_Thompson.player_PF = 61
Ausar_Thompson.player_PTS = 194

Klay_Thompson = Player('Klay_Thompson')
Klay_Thompson.hasClubTeam.append(Golden_State_Warriors)
Klay_Thompson.hasPosition.append(SF)
Klay_Thompson.player_Age = 33
Klay_Thompson.player_G = 17
Klay_Thompson.player_MP = 500
Klay_Thompson.player_MP = 500
Klay_Thompson.player_FG = 90
Klay_Thompson.player_FGA = 223
Klay_Thompson.player_FT = 33
Klay_Thompson.player_FTA = 38
Klay_Thompson.player_TRB = 61
Klay_Thompson.player_AST = 39
Klay_Thompson.player_STL = 7
Klay_Thompson.player_BLK = 10
Klay_Thompson.player_TOV = 34
Klay_Thompson.player_PF = 39
Klay_Thompson.player_PTS = 260

Tristan_Thompson = Player('Tristan_Thompson')
Tristan_Thompson.hasClubTeam.append(Cleveland_Cavaliers)
Tristan_Thompson.hasPosition.append(PF)
Tristan_Thompson.player_Age = 32
Tristan_Thompson.player_G = 14
Tristan_Thompson.player_MP = 130
Tristan_Thompson.player_MP = 130
Tristan_Thompson.player_FG = 15
Tristan_Thompson.player_FGA = 21
Tristan_Thompson.player_FT = 5
Tristan_Thompson.player_FTA = 13
Tristan_Thompson.player_TRB = 35
Tristan_Thompson.player_AST = 11
Tristan_Thompson.player_STL = 2
Tristan_Thompson.player_BLK = 5
Tristan_Thompson.player_TOV = 7
Tristan_Thompson.player_PF = 13
Tristan_Thompson.player_PTS = 35

JT_Thor = Player('JT_Thor')
JT_Thor.hasClubTeam.append(Charlotte_Hornets)
JT_Thor.hasPosition.append(PF)
JT_Thor.player_Age = 21
JT_Thor.player_G = 16
JT_Thor.player_MP = 264
JT_Thor.player_MP = 264
JT_Thor.player_FG = 25
JT_Thor.player_FGA = 59
JT_Thor.player_FT = 0
JT_Thor.player_FTA = 4
JT_Thor.player_TRB = 47
JT_Thor.player_AST = 10
JT_Thor.player_STL = 4
JT_Thor.player_BLK = 5
JT_Thor.player_TOV = 4
JT_Thor.player_PF = 20
JT_Thor.player_PTS = 62

Matisse_Thybulle = Player('Matisse_Thybulle')
Matisse_Thybulle.hasClubTeam.append(Portland_Trail_Blazers)
Matisse_Thybulle.hasPosition.append(SF)
Matisse_Thybulle.player_Age = 26
Matisse_Thybulle.player_G = 17
Matisse_Thybulle.player_MP = 374
Matisse_Thybulle.player_MP = 374
Matisse_Thybulle.player_FG = 36
Matisse_Thybulle.player_FGA = 76
Matisse_Thybulle.player_FT = 6
Matisse_Thybulle.player_FTA = 8
Matisse_Thybulle.player_TRB = 26
Matisse_Thybulle.player_AST = 20
Matisse_Thybulle.player_STL = 25
Matisse_Thybulle.player_BLK = 13
Matisse_Thybulle.player_TOV = 14
Matisse_Thybulle.player_PF = 20
Matisse_Thybulle.player_PTS = 101

Xavier_Tillman_Sr = Player('Xavier_Tillman_Sr.')
Xavier_Tillman_Sr.hasClubTeam.append(Memphis_Grizzlies)
Xavier_Tillman_Sr.hasPosition.append(CE)
Xavier_Tillman_Sr.player_Age = 25
Xavier_Tillman_Sr.player_G = 7
Xavier_Tillman_Sr.player_MP = 181
Xavier_Tillman_Sr.player_MP = 181
Xavier_Tillman_Sr.player_FG = 27
Xavier_Tillman_Sr.player_FGA = 64
Xavier_Tillman_Sr.player_FT = 4
Xavier_Tillman_Sr.player_FTA = 9
Xavier_Tillman_Sr.player_TRB = 47
Xavier_Tillman_Sr.player_AST = 17
Xavier_Tillman_Sr.player_STL = 11
Xavier_Tillman_Sr.player_BLK = 6
Xavier_Tillman_Sr.player_TOV = 10
Xavier_Tillman_Sr.player_PF = 20
Xavier_Tillman_Sr.player_PTS = 65

Obi_Toppin = Player('Obi_Toppin')
Obi_Toppin.hasClubTeam.append(Indiana_Pacers)
Obi_Toppin.hasPosition.append(PF)
Obi_Toppin.player_Age = 25
Obi_Toppin.player_G = 16
Obi_Toppin.player_MP = 380
Obi_Toppin.player_MP = 380
Obi_Toppin.player_FG = 77
Obi_Toppin.player_FGA = 131
Obi_Toppin.player_FT = 20
Obi_Toppin.player_FTA = 23
Obi_Toppin.player_TRB = 51
Obi_Toppin.player_AST = 19
Obi_Toppin.player_STL = 12
Obi_Toppin.player_BLK = 5
Obi_Toppin.player_TOV = 13
Obi_Toppin.player_PF = 26
Obi_Toppin.player_PTS = 189

Karl_Anthony_Towns = Player('Karl-Anthony_Towns')
Karl_Anthony_Towns.hasClubTeam.append(Minnesota_Timberwolves)
Karl_Anthony_Towns.hasPosition.append(PF)
Karl_Anthony_Towns.player_Age = 28
Karl_Anthony_Towns.player_G = 17
Karl_Anthony_Towns.player_MP = 567
Karl_Anthony_Towns.player_MP = 567
Karl_Anthony_Towns.player_FG = 130
Karl_Anthony_Towns.player_FGA = 261
Karl_Anthony_Towns.player_FT = 68
Karl_Anthony_Towns.player_FTA = 74
Karl_Anthony_Towns.player_TRB = 153
Karl_Anthony_Towns.player_AST = 50
Karl_Anthony_Towns.player_STL = 16
Karl_Anthony_Towns.player_BLK = 13
Karl_Anthony_Towns.player_TOV = 49
Karl_Anthony_Towns.player_PF = 59
Karl_Anthony_Towns.player_PTS = 361

Gary_Trent_Jr = Player('Gary_Trent_Jr.')
Gary_Trent_Jr.hasClubTeam.append(Toronto_Raptors)
Gary_Trent_Jr.hasPosition.append(SG)
Gary_Trent_Jr.player_Age = 25
Gary_Trent_Jr.player_G = 15
Gary_Trent_Jr.player_MP = 391
Gary_Trent_Jr.player_MP = 391
Gary_Trent_Jr.player_FG = 62
Gary_Trent_Jr.player_FGA = 154
Gary_Trent_Jr.player_FT = 17
Gary_Trent_Jr.player_FTA = 29
Gary_Trent_Jr.player_TRB = 28
Gary_Trent_Jr.player_AST = 16
Gary_Trent_Jr.player_STL = 14
Gary_Trent_Jr.player_BLK = 2
Gary_Trent_Jr.player_TOV = 11
Gary_Trent_Jr.player_PF = 17
Gary_Trent_Jr.player_PTS = 170

PJ_Tucker = Player('P.J._Tucker')
PJ_Tucker.hasClubTeam.append(Toronto_Raptors)
PJ_Tucker.hasPosition.append(PF)
PJ_Tucker.player_Age = 38
PJ_Tucker.player_G = 15
PJ_Tucker.player_MP = 239
PJ_Tucker.player_MP = 239
PJ_Tucker.player_FG = 6
PJ_Tucker.player_FGA = 19
PJ_Tucker.player_FT = 3
PJ_Tucker.player_FTA = 3
PJ_Tucker.player_TRB = 43
PJ_Tucker.player_AST = 8
PJ_Tucker.player_STL = 9
PJ_Tucker.player_BLK = 3
PJ_Tucker.player_TOV = 4
PJ_Tucker.player_PF = 35
PJ_Tucker.player_PTS = 20

Myles_Turner = Player('Myles_Turner')
Myles_Turner.hasClubTeam.append(Indiana_Pacers)
Myles_Turner.hasPosition.append(CE)
Myles_Turner.player_Age = 27
Myles_Turner.player_G = 16
Myles_Turner.player_MP = 423
Myles_Turner.player_MP = 423
Myles_Turner.player_FG = 96
Myles_Turner.player_FGA = 187
Myles_Turner.player_FT = 53
Myles_Turner.player_FTA = 67
Myles_Turner.player_TRB = 121
Myles_Turner.player_AST = 22
Myles_Turner.player_STL = 11
Myles_Turner.player_BLK = 35
Myles_Turner.player_TOV = 25
Myles_Turner.player_PF = 56
Myles_Turner.player_PTS = 269

Hunter_Tyson = Player('Hunter_Tyson')
Hunter_Tyson.hasClubTeam.append(Denver_Nuggets)
Hunter_Tyson.hasPosition.append(PF)
Hunter_Tyson.player_Age = 23
Hunter_Tyson.player_G = 6
Hunter_Tyson.player_MP = 15
Hunter_Tyson.player_MP = 15
Hunter_Tyson.player_FG = 1
Hunter_Tyson.player_FGA = 4
Hunter_Tyson.player_FT = 0
Hunter_Tyson.player_FTA = 0
Hunter_Tyson.player_TRB = 4
Hunter_Tyson.player_AST = 1
Hunter_Tyson.player_STL = 0
Hunter_Tyson.player_BLK = 0
Hunter_Tyson.player_TOV = 0
Hunter_Tyson.player_PF = 4
Hunter_Tyson.player_PTS = 2

Stanley_Umude = Player('Stanley_Umude')
Stanley_Umude.hasClubTeam.append(Detroit_Pistons)
Stanley_Umude.hasPosition.append(SG)
Stanley_Umude.player_Age = 24
Stanley_Umude.player_G = 13
Stanley_Umude.player_MP = 133
Stanley_Umude.player_MP = 133
Stanley_Umude.player_FG = 18
Stanley_Umude.player_FGA = 35
Stanley_Umude.player_FT = 19
Stanley_Umude.player_FTA = 21
Stanley_Umude.player_TRB = 23
Stanley_Umude.player_AST = 6
Stanley_Umude.player_STL = 3
Stanley_Umude.player_BLK = 5
Stanley_Umude.player_TOV = 7
Stanley_Umude.player_PF = 19
Stanley_Umude.player_PTS = 67

Jonas_Valančiūnas = Player('Jonas_Valančiūnas')
Jonas_Valančiūnas.hasClubTeam.append(New_Orleans_Pelicans)
Jonas_Valančiūnas.hasPosition.append(CE)
Jonas_Valančiūnas.player_Age = 31
Jonas_Valančiūnas.player_G = 18
Jonas_Valančiūnas.player_MP = 463
Jonas_Valančiūnas.player_MP = 463
Jonas_Valančiūnas.player_FG = 92
Jonas_Valančiūnas.player_FGA = 172
Jonas_Valančiūnas.player_FT = 39
Jonas_Valančiūnas.player_FTA = 49
Jonas_Valančiūnas.player_TRB = 161
Jonas_Valančiūnas.player_AST = 45
Jonas_Valančiūnas.player_STL = 7
Jonas_Valančiūnas.player_BLK = 25
Jonas_Valančiūnas.player_TOV = 22
Jonas_Valančiūnas.player_PF = 54
Jonas_Valančiūnas.player_PTS = 236

Fred_VanVleet = Player('Fred_VanVleet')
Fred_VanVleet.hasClubTeam.append(Houston_Rockets)
Fred_VanVleet.hasPosition.append(PG)
Fred_VanVleet.player_Age = 29
Fred_VanVleet.player_G = 15
Fred_VanVleet.player_MP = 564
Fred_VanVleet.player_MP = 564
Fred_VanVleet.player_FG = 82
Fred_VanVleet.player_FGA = 212
Fred_VanVleet.player_FT = 33
Fred_VanVleet.player_FTA = 37
Fred_VanVleet.player_TRB = 62
Fred_VanVleet.player_AST = 138
Fred_VanVleet.player_STL = 11
Fred_VanVleet.player_BLK = 7
Fred_VanVleet.player_TOV = 22
Fred_VanVleet.player_PF = 28
Fred_VanVleet.player_PTS = 242

Devin_Vassell = Player('Devin_Vassell')
Devin_Vassell.hasClubTeam.append(San_Antonio_Spurs)
Devin_Vassell.hasPosition.append(SG)
Devin_Vassell.player_Age = 23
Devin_Vassell.player_G = 12
Devin_Vassell.player_MP = 340
Devin_Vassell.player_MP = 340
Devin_Vassell.player_FG = 79
Devin_Vassell.player_FGA = 160
Devin_Vassell.player_FT = 27
Devin_Vassell.player_FTA = 36
Devin_Vassell.player_TRB = 41
Devin_Vassell.player_AST = 33
Devin_Vassell.player_STL = 12
Devin_Vassell.player_BLK = 1
Devin_Vassell.player_TOV = 16
Devin_Vassell.player_PF = 13
Devin_Vassell.player_PTS = 217

Sasha_Vezenkov = Player('Sasha_Vezenkov')
Sasha_Vezenkov.hasClubTeam.append(Sacramento_Kings)
Sasha_Vezenkov.hasPosition.append(PF)
Sasha_Vezenkov.player_Age = 28
Sasha_Vezenkov.player_G = 13
Sasha_Vezenkov.player_MP = 180
Sasha_Vezenkov.player_MP = 180
Sasha_Vezenkov.player_FG = 29
Sasha_Vezenkov.player_FGA = 70
Sasha_Vezenkov.player_FT = 3
Sasha_Vezenkov.player_FTA = 3
Sasha_Vezenkov.player_TRB = 27
Sasha_Vezenkov.player_AST = 4
Sasha_Vezenkov.player_STL = 6
Sasha_Vezenkov.player_BLK = 5
Sasha_Vezenkov.player_TOV = 4
Sasha_Vezenkov.player_PF = 16
Sasha_Vezenkov.player_PTS = 77

Gabe_Vincent = Player('Gabe_Vincent')
Gabe_Vincent.hasClubTeam.append(Los_Angeles_Lakers)
Gabe_Vincent.hasPosition.append(PG)
Gabe_Vincent.player_Age = 27
Gabe_Vincent.player_G = 4
Gabe_Vincent.player_MP = 113
Gabe_Vincent.player_MP = 113
Gabe_Vincent.player_FG = 11
Gabe_Vincent.player_FGA = 28
Gabe_Vincent.player_FT = 1
Gabe_Vincent.player_FTA = 2
Gabe_Vincent.player_TRB = 4
Gabe_Vincent.player_AST = 12
Gabe_Vincent.player_STL = 6
Gabe_Vincent.player_BLK = 0
Gabe_Vincent.player_TOV = 2
Gabe_Vincent.player_PF = 10
Gabe_Vincent.player_PTS = 24

Nikola_Vucevic = Player('Nikola_Vucevic')
Nikola_Vucevic.hasClubTeam.append(Chicago_Bulls)
Nikola_Vucevic.hasPosition.append(CE)
Nikola_Vucevic.player_Age = 33
Nikola_Vucevic.player_G = 19
Nikola_Vucevic.player_MP = 648
Nikola_Vucevic.player_MP = 648
Nikola_Vucevic.player_FG = 126
Nikola_Vucevic.player_FGA = 276
Nikola_Vucevic.player_FT = 25
Nikola_Vucevic.player_FTA = 30
Nikola_Vucevic.player_TRB = 192
Nikola_Vucevic.player_AST = 58
Nikola_Vucevic.player_STL = 18
Nikola_Vucevic.player_BLK = 11
Nikola_Vucevic.player_TOV = 33
Nikola_Vucevic.player_PF = 58
Nikola_Vucevic.player_PTS = 293

Dean_Wade = Player('Dean_Wade')
Dean_Wade.hasClubTeam.append(Cleveland_Cavaliers)
Dean_Wade.hasPosition.append(PF)
Dean_Wade.player_Age = 27
Dean_Wade.player_G = 13
Dean_Wade.player_MP = 264
Dean_Wade.player_MP = 264
Dean_Wade.player_FG = 13
Dean_Wade.player_FGA = 40
Dean_Wade.player_FT = 2
Dean_Wade.player_FTA = 4
Dean_Wade.player_TRB = 53
Dean_Wade.player_AST = 11
Dean_Wade.player_STL = 11
Dean_Wade.player_BLK = 3
Dean_Wade.player_TOV = 5
Dean_Wade.player_PF = 29
Dean_Wade.player_PTS = 40

Franz_Wagner = Player('Franz_Wagner')
Franz_Wagner.hasClubTeam.append(Orlando_Magic)
Franz_Wagner.hasPosition.append(SF)
Franz_Wagner.player_Age = 22
Franz_Wagner.player_G = 17
Franz_Wagner.player_MP = 558
Franz_Wagner.player_MP = 558
Franz_Wagner.player_FG = 127
Franz_Wagner.player_FGA = 281
Franz_Wagner.player_FT = 52
Franz_Wagner.player_FTA = 63
Franz_Wagner.player_TRB = 95
Franz_Wagner.player_AST = 54
Franz_Wagner.player_STL = 21
Franz_Wagner.player_BLK = 6
Franz_Wagner.player_TOV = 32
Franz_Wagner.player_PF = 37
Franz_Wagner.player_PTS = 332

Moritz_Wagner = Player('Moritz_Wagner')
Moritz_Wagner.hasClubTeam.append(Orlando_Magic)
Moritz_Wagner.hasPosition.append(CE)
Moritz_Wagner.player_Age = 26
Moritz_Wagner.player_G = 17
Moritz_Wagner.player_MP = 326
Moritz_Wagner.player_MP = 326
Moritz_Wagner.player_FG = 81
Moritz_Wagner.player_FGA = 129
Moritz_Wagner.player_FT = 40
Moritz_Wagner.player_FTA = 48
Moritz_Wagner.player_TRB = 74
Moritz_Wagner.player_AST = 21
Moritz_Wagner.player_STL = 8
Moritz_Wagner.player_BLK = 6
Moritz_Wagner.player_TOV = 21
Moritz_Wagner.player_PF = 45
Moritz_Wagner.player_PTS = 213

Ish_Wainright = Player('Ish_Wainright')
Ish_Wainright.hasClubTeam.append(Portland_Trail_Blazers)
Ish_Wainright.hasPosition.append(SF)
Ish_Wainright.player_Age = 29
Ish_Wainright.player_G = 2
Ish_Wainright.player_MP = 5
Ish_Wainright.player_MP = 5
Ish_Wainright.player_FG = 0
Ish_Wainright.player_FGA = 1
Ish_Wainright.player_FT = 0
Ish_Wainright.player_FTA = 0
Ish_Wainright.player_TRB = 0
Ish_Wainright.player_AST = 0
Ish_Wainright.player_STL = 1
Ish_Wainright.player_BLK = 0
Ish_Wainright.player_TOV = 0
Ish_Wainright.player_PF = 1
Ish_Wainright.player_PTS = 0

Jabari_Walker = Player('Jabari_Walker')
Jabari_Walker.hasClubTeam.append(Portland_Trail_Blazers)
Jabari_Walker.hasPosition.append(SF)
Jabari_Walker.player_Age = 21
Jabari_Walker.player_G = 17
Jabari_Walker.player_MP = 282
Jabari_Walker.player_MP = 282
Jabari_Walker.player_FG = 47
Jabari_Walker.player_FGA = 102
Jabari_Walker.player_FT = 19
Jabari_Walker.player_FTA = 27
Jabari_Walker.player_TRB = 74
Jabari_Walker.player_AST = 10
Jabari_Walker.player_STL = 13
Jabari_Walker.player_BLK = 8
Jabari_Walker.player_TOV = 16
Jabari_Walker.player_PF = 39
Jabari_Walker.player_PTS = 123

Jarace_Walker = Player('Jarace_Walker')
Jarace_Walker.hasClubTeam.append(Indiana_Pacers)
Jarace_Walker.hasPosition.append(PF)
Jarace_Walker.player_Age = 20
Jarace_Walker.player_G = 4
Jarace_Walker.player_MP = 41
Jarace_Walker.player_MP = 41
Jarace_Walker.player_FG = 7
Jarace_Walker.player_FGA = 18
Jarace_Walker.player_FT = 3
Jarace_Walker.player_FTA = 3
Jarace_Walker.player_TRB = 8
Jarace_Walker.player_AST = 6
Jarace_Walker.player_STL = 2
Jarace_Walker.player_BLK = 2
Jarace_Walker.player_TOV = 1
Jarace_Walker.player_PF = 4
Jarace_Walker.player_PTS = 17

Lonnie_Walker_IV = Player('Lonnie_Walker_IV')
Lonnie_Walker_IV.hasClubTeam.append(Brooklyn_Nets)
Lonnie_Walker_IV.hasPosition.append(SG)
Lonnie_Walker_IV.player_Age = 25
Lonnie_Walker_IV.player_G = 16
Lonnie_Walker_IV.player_MP = 348
Lonnie_Walker_IV.player_MP = 348
Lonnie_Walker_IV.player_FG = 86
Lonnie_Walker_IV.player_FGA = 175
Lonnie_Walker_IV.player_FT = 28
Lonnie_Walker_IV.player_FTA = 36
Lonnie_Walker_IV.player_TRB = 43
Lonnie_Walker_IV.player_AST = 27
Lonnie_Walker_IV.player_STL = 10
Lonnie_Walker_IV.player_BLK = 7
Lonnie_Walker_IV.player_TOV = 24
Lonnie_Walker_IV.player_PF = 15
Lonnie_Walker_IV.player_PTS = 242

Cason_Wallace = Player('Cason_Wallace')
Cason_Wallace.hasClubTeam.append(Oklahoma_City_Thunder)
Cason_Wallace.hasPosition.append(SG)
Cason_Wallace.player_Age = 20
Cason_Wallace.player_G = 17
Cason_Wallace.player_MP = 374
Cason_Wallace.player_MP = 374
Cason_Wallace.player_FG = 45
Cason_Wallace.player_FGA = 73
Cason_Wallace.player_FT = 10
Cason_Wallace.player_FTA = 11
Cason_Wallace.player_TRB = 36
Cason_Wallace.player_AST = 25
Cason_Wallace.player_STL = 10
Cason_Wallace.player_BLK = 6
Cason_Wallace.player_TOV = 9
Cason_Wallace.player_PF = 27
Cason_Wallace.player_PTS = 117

PJ_Washington = Player('P.J._Washington')
PJ_Washington.hasClubTeam.append(Charlotte_Hornets)
PJ_Washington.hasPosition.append(PF)
PJ_Washington.player_Age = 25
PJ_Washington.player_G = 15
PJ_Washington.player_MP = 473
PJ_Washington.player_MP = 473
PJ_Washington.player_FG = 84
PJ_Washington.player_FGA = 189
PJ_Washington.player_FT = 21
PJ_Washington.player_FTA = 31
PJ_Washington.player_TRB = 77
PJ_Washington.player_AST = 30
PJ_Washington.player_STL = 8
PJ_Washington.player_BLK = 13
PJ_Washington.player_TOV = 23
PJ_Washington.player_PF = 43
PJ_Washington.player_PTS = 217

TyTy_Washington_Jr = Player('TyTy_Washington_Jr.')
TyTy_Washington_Jr.hasClubTeam.append(Milwaukee_Bucks)
TyTy_Washington_Jr.hasPosition.append(PG)
TyTy_Washington_Jr.player_Age = 22
TyTy_Washington_Jr.player_G = 2
TyTy_Washington_Jr.player_MP = 6
TyTy_Washington_Jr.player_MP = 6
TyTy_Washington_Jr.player_FG = 1
TyTy_Washington_Jr.player_FGA = 3
TyTy_Washington_Jr.player_FT = 0
TyTy_Washington_Jr.player_FTA = 0
TyTy_Washington_Jr.player_TRB = 1
TyTy_Washington_Jr.player_AST = 0
TyTy_Washington_Jr.player_STL = 1
TyTy_Washington_Jr.player_BLK = 0
TyTy_Washington_Jr.player_TOV = 2
TyTy_Washington_Jr.player_PF = 0
TyTy_Washington_Jr.player_PTS = 3

Yuta_Watanabe = Player('Yuta_Watanabe')
Yuta_Watanabe.hasClubTeam.append(Phoenix_Suns)
Yuta_Watanabe.hasPosition.append(SF)
Yuta_Watanabe.player_Age = 29
Yuta_Watanabe.player_G = 13
Yuta_Watanabe.player_MP = 238
Yuta_Watanabe.player_MP = 238
Yuta_Watanabe.player_FG = 23
Yuta_Watanabe.player_FGA = 59
Yuta_Watanabe.player_FT = 7
Yuta_Watanabe.player_FTA = 9
Yuta_Watanabe.player_TRB = 32
Yuta_Watanabe.player_AST = 8
Yuta_Watanabe.player_STL = 4
Yuta_Watanabe.player_BLK = 4
Yuta_Watanabe.player_TOV = 10
Yuta_Watanabe.player_PF = 22
Yuta_Watanabe.player_PTS = 71

Lindy_Waters_III = Player('Lindy_Waters_III')
Lindy_Waters_III.hasClubTeam.append(Oklahoma_City_Thunder)
Lindy_Waters_III.hasPosition.append(SG)
Lindy_Waters_III.player_Age = 26
Lindy_Waters_III.player_G = 7
Lindy_Waters_III.player_MP = 49
Lindy_Waters_III.player_MP = 49
Lindy_Waters_III.player_FG = 6
Lindy_Waters_III.player_FGA = 13
Lindy_Waters_III.player_FT = 0
Lindy_Waters_III.player_FTA = 0
Lindy_Waters_III.player_TRB = 5
Lindy_Waters_III.player_AST = 4
Lindy_Waters_III.player_STL = 0
Lindy_Waters_III.player_BLK = 1
Lindy_Waters_III.player_TOV = 0
Lindy_Waters_III.player_PF = 1
Lindy_Waters_III.player_PTS = 18

Trendon_Watford = Player('Trendon_Watford')
Trendon_Watford.hasClubTeam.append(Brooklyn_Nets)
Trendon_Watford.hasPosition.append(PF)
Trendon_Watford.player_Age = 23
Trendon_Watford.player_G = 11
Trendon_Watford.player_MP = 163
Trendon_Watford.player_MP = 163
Trendon_Watford.player_FG = 31
Trendon_Watford.player_FGA = 61
Trendon_Watford.player_FT = 8
Trendon_Watford.player_FTA = 9
Trendon_Watford.player_TRB = 41
Trendon_Watford.player_AST = 20
Trendon_Watford.player_STL = 7
Trendon_Watford.player_BLK = 2
Trendon_Watford.player_TOV = 15
Trendon_Watford.player_PF = 25
Trendon_Watford.player_PTS = 75

Peyton_Watson = Player('Peyton_Watson')
Peyton_Watson.hasClubTeam.append(Denver_Nuggets)
Peyton_Watson.hasPosition.append(SF)
Peyton_Watson.player_Age = 21
Peyton_Watson.player_G = 17
Peyton_Watson.player_MP = 246
Peyton_Watson.player_MP = 246
Peyton_Watson.player_FG = 32
Peyton_Watson.player_FGA = 63
Peyton_Watson.player_FT = 6
Peyton_Watson.player_FTA = 14
Peyton_Watson.player_TRB = 32
Peyton_Watson.player_AST = 13
Peyton_Watson.player_STL = 9
Peyton_Watson.player_BLK = 17
Peyton_Watson.player_TOV = 11
Peyton_Watson.player_PF = 20
Peyton_Watson.player_PTS = 74

Victor_Wembanyama = Player('Victor_Wembanyama')
Victor_Wembanyama.hasClubTeam.append(San_Antonio_Spurs)
Victor_Wembanyama.hasPosition.append(PF)
Victor_Wembanyama.player_Age = 20
Victor_Wembanyama.player_G = 17
Victor_Wembanyama.player_MP = 511
Victor_Wembanyama.player_MP = 511
Victor_Wembanyama.player_FG = 120
Victor_Wembanyama.player_FGA = 279
Victor_Wembanyama.player_FT = 61
Victor_Wembanyama.player_FTA = 74
Victor_Wembanyama.player_TRB = 162
Victor_Wembanyama.player_AST = 44
Victor_Wembanyama.player_STL = 22
Victor_Wembanyama.player_BLK = 45
Victor_Wembanyama.player_TOV = 61
Victor_Wembanyama.player_PF = 45
Victor_Wembanyama.player_PTS = 326

Blake_Wesley = Player('Blake_Wesley')
Blake_Wesley.hasClubTeam.append(San_Antonio_Spurs)
Blake_Wesley.hasPosition.append(SG)
Blake_Wesley.player_Age = 20
Blake_Wesley.player_G = 4
Blake_Wesley.player_MP = 21
Blake_Wesley.player_MP = 21
Blake_Wesley.player_FG = 3
Blake_Wesley.player_FGA = 8
Blake_Wesley.player_FT = 1
Blake_Wesley.player_FTA = 2
Blake_Wesley.player_TRB = 2
Blake_Wesley.player_AST = 3
Blake_Wesley.player_STL = 0
Blake_Wesley.player_BLK = 1
Blake_Wesley.player_TOV = 1
Blake_Wesley.player_PF = 3
Blake_Wesley.player_PTS = 7

Russell_Westbrook = Player('Russell_Westbrook')
Russell_Westbrook.hasClubTeam.append(Los_Angeles_Clippers)
Russell_Westbrook.hasPosition.append(PG)
Russell_Westbrook.player_Age = 35
Russell_Westbrook.player_G = 16
Russell_Westbrook.player_MP = 443
Russell_Westbrook.player_MP = 443
Russell_Westbrook.player_FG = 81
Russell_Westbrook.player_FGA = 183
Russell_Westbrook.player_FT = 23
Russell_Westbrook.player_FTA = 38
Russell_Westbrook.player_TRB = 104
Russell_Westbrook.player_AST = 84
Russell_Westbrook.player_STL = 24
Russell_Westbrook.player_BLK = 5
Russell_Westbrook.player_TOV = 43
Russell_Westbrook.player_PF = 43
Russell_Westbrook.player_PTS = 197

Coby_White = Player('Coby_White')
Coby_White.hasClubTeam.append(Chicago_Bulls)
Coby_White.hasPosition.append(PG)
Coby_White.player_Age = 23
Coby_White.player_G = 19
Coby_White.player_MP = 612
Coby_White.player_MP = 612
Coby_White.player_FG = 94
Coby_White.player_FGA = 223
Coby_White.player_FT = 25
Coby_White.player_FTA = 30
Coby_White.player_TRB = 53
Coby_White.player_AST = 76
Coby_White.player_STL = 17
Coby_White.player_BLK = 5
Coby_White.player_TOV = 34
Coby_White.player_PF = 53
Coby_White.player_PTS = 261

Derrick_White = Player('Derrick_White')
Derrick_White.hasClubTeam.append(Boston_Celtics)
Derrick_White.hasPosition.append(SG)
Derrick_White.player_Age = 29
Derrick_White.player_G = 15
Derrick_White.player_MP = 483
Derrick_White.player_MP = 483
Derrick_White.player_FG = 67
Derrick_White.player_FGA = 143
Derrick_White.player_FT = 42
Derrick_White.player_FTA = 50
Derrick_White.player_TRB = 56
Derrick_White.player_AST = 77
Derrick_White.player_STL = 16
Derrick_White.player_BLK = 12
Derrick_White.player_TOV = 27
Derrick_White.player_PF = 34
Derrick_White.player_PTS = 208

Cam_Whitmore = Player('Cam_Whitmore')
Cam_Whitmore.hasClubTeam.append(Houston_Rockets)
Cam_Whitmore.hasPosition.append(SF)
Cam_Whitmore.player_Age = 19
Cam_Whitmore.player_G = 3
Cam_Whitmore.player_MP = 23
Cam_Whitmore.player_MP = 23
Cam_Whitmore.player_FG = 3
Cam_Whitmore.player_FGA = 9
Cam_Whitmore.player_FT = 1
Cam_Whitmore.player_FTA = 2
Cam_Whitmore.player_TRB = 3
Cam_Whitmore.player_AST = 1
Cam_Whitmore.player_STL = 1
Cam_Whitmore.player_BLK = 0
Cam_Whitmore.player_TOV = 2
Cam_Whitmore.player_PF = 1
Cam_Whitmore.player_PTS = 7

Aaron_Wiggins = Player('Aaron_Wiggins')
Aaron_Wiggins.hasClubTeam.append(Oklahoma_City_Thunder)
Aaron_Wiggins.hasPosition.append(SG)
Aaron_Wiggins.player_Age = 25
Aaron_Wiggins.player_G = 15
Aaron_Wiggins.player_MP = 177
Aaron_Wiggins.player_MP = 177
Aaron_Wiggins.player_FG = 27
Aaron_Wiggins.player_FGA = 47
Aaron_Wiggins.player_FT = 11
Aaron_Wiggins.player_FTA = 15
Aaron_Wiggins.player_TRB = 31
Aaron_Wiggins.player_AST = 11
Aaron_Wiggins.player_STL = 6
Aaron_Wiggins.player_BLK = 1
Aaron_Wiggins.player_TOV = 9
Aaron_Wiggins.player_PF = 14
Aaron_Wiggins.player_PTS = 73

Andrew_Wiggins = Player('Andrew_Wiggins')
Andrew_Wiggins.hasClubTeam.append(Golden_State_Warriors)
Andrew_Wiggins.hasPosition.append(SF)
Andrew_Wiggins.player_Age = 28
Andrew_Wiggins.player_G = 18
Andrew_Wiggins.player_MP = 490
Andrew_Wiggins.player_MP = 490
Andrew_Wiggins.player_FG = 91
Andrew_Wiggins.player_FGA = 210
Andrew_Wiggins.player_FT = 32
Andrew_Wiggins.player_FTA = 54
Andrew_Wiggins.player_TRB = 79
Andrew_Wiggins.player_AST = 21
Andrew_Wiggins.player_STL = 6
Andrew_Wiggins.player_BLK = 7
Andrew_Wiggins.player_TOV = 32
Andrew_Wiggins.player_PF = 46
Andrew_Wiggins.player_PTS = 230

Lindell_Wigginton = Player('Lindell_Wigginton')
Lindell_Wigginton.hasClubTeam.append(Milwaukee_Bucks)
Lindell_Wigginton.hasPosition.append(PG)
Lindell_Wigginton.player_Age = 25
Lindell_Wigginton.player_G = 1
Lindell_Wigginton.player_MP = 2
Lindell_Wigginton.player_MP = 2
Lindell_Wigginton.player_FG = 0
Lindell_Wigginton.player_FGA = 1
Lindell_Wigginton.player_FT = 0
Lindell_Wigginton.player_FTA = 0
Lindell_Wigginton.player_TRB = 0
Lindell_Wigginton.player_AST = 0
Lindell_Wigginton.player_STL = 0
Lindell_Wigginton.player_BLK = 0
Lindell_Wigginton.player_TOV = 1
Lindell_Wigginton.player_PF = 1
Lindell_Wigginton.player_PTS = 0

Grant_Williams = Player('Grant_Williams')
Grant_Williams.hasClubTeam.append(Dallas_Mavericks)
Grant_Williams.hasPosition.append(PF)
Grant_Williams.player_Age = 25
Grant_Williams.player_G = 17
Grant_Williams.player_MP = 489
Grant_Williams.player_MP = 489
Grant_Williams.player_FG = 57
Grant_Williams.player_FGA = 129
Grant_Williams.player_FT = 12
Grant_Williams.player_FTA = 21
Grant_Williams.player_TRB = 62
Grant_Williams.player_AST = 28
Grant_Williams.player_STL = 4
Grant_Williams.player_BLK = 10
Grant_Williams.player_TOV = 16
Grant_Williams.player_PF = 44
Grant_Williams.player_PTS = 166

Jalen_Williams = Player('Jalen_Williams')
Jalen_Williams.hasClubTeam.append(Oklahoma_City_Thunder)
Jalen_Williams.hasPosition.append(PF)
Jalen_Williams.player_Age = 22
Jalen_Williams.player_G = 14
Jalen_Williams.player_MP = 465
Jalen_Williams.player_MP = 465
Jalen_Williams.player_FG = 87
Jalen_Williams.player_FGA = 174
Jalen_Williams.player_FT = 50
Jalen_Williams.player_FTA = 57
Jalen_Williams.player_TRB = 56
Jalen_Williams.player_AST = 50
Jalen_Williams.player_STL = 11
Jalen_Williams.player_BLK = 4
Jalen_Williams.player_TOV = 29
Jalen_Williams.player_PF = 43
Jalen_Williams.player_PTS = 238

Jaylin_Williams = Player('Jaylin_Williams')
Jaylin_Williams.hasClubTeam.append(Oklahoma_City_Thunder)
Jaylin_Williams.hasPosition.append(CE)
Jaylin_Williams.player_Age = 21
Jaylin_Williams.player_G = 12
Jaylin_Williams.player_MP = 166
Jaylin_Williams.player_MP = 166
Jaylin_Williams.player_FG = 17
Jaylin_Williams.player_FGA = 48
Jaylin_Williams.player_FT = 5
Jaylin_Williams.player_FTA = 6
Jaylin_Williams.player_TRB = 49
Jaylin_Williams.player_AST = 21
Jaylin_Williams.player_STL = 5
Jaylin_Williams.player_BLK = 2
Jaylin_Williams.player_TOV = 5
Jaylin_Williams.player_PF = 24
Jaylin_Williams.player_PTS = 46

Jeenathan_Williams = Player('Jeenathan_Williams')
Jeenathan_Williams.hasClubTeam.append(Houston_Rockets)
Jeenathan_Williams.hasPosition.append(SG)
Jeenathan_Williams.player_Age = 24
Jeenathan_Williams.player_G = 3
Jeenathan_Williams.player_MP = 16
Jeenathan_Williams.player_MP = 16
Jeenathan_Williams.player_FG = 5
Jeenathan_Williams.player_FGA = 9
Jeenathan_Williams.player_FT = 1
Jeenathan_Williams.player_FTA = 2
Jeenathan_Williams.player_TRB = 0
Jeenathan_Williams.player_AST = 1
Jeenathan_Williams.player_STL = 1
Jeenathan_Williams.player_BLK = 0
Jeenathan_Williams.player_TOV = 0
Jeenathan_Williams.player_PF = 1
Jeenathan_Williams.player_PTS = 11

Kenrich_Williams = Player('Kenrich_Williams')
Kenrich_Williams.hasClubTeam.append(Oklahoma_City_Thunder)
Kenrich_Williams.hasPosition.append(PF)
Kenrich_Williams.player_Age = 29
Kenrich_Williams.player_G = 7
Kenrich_Williams.player_MP = 120
Kenrich_Williams.player_MP = 120
Kenrich_Williams.player_FG = 18
Kenrich_Williams.player_FGA = 29
Kenrich_Williams.player_FT = 2
Kenrich_Williams.player_FTA = 6
Kenrich_Williams.player_TRB = 19
Kenrich_Williams.player_AST = 13
Kenrich_Williams.player_STL = 2
Kenrich_Williams.player_BLK = 0
Kenrich_Williams.player_TOV = 1
Kenrich_Williams.player_PF = 16
Kenrich_Williams.player_PTS = 45

Mark_Williams = Player('Mark_Williams')
Mark_Williams.hasClubTeam.append(Charlotte_Hornets)
Mark_Williams.hasPosition.append(CE)
Mark_Williams.player_Age = 22
Mark_Williams.player_G = 16
Mark_Williams.player_MP = 427
Mark_Williams.player_MP = 427
Mark_Williams.player_FG = 87
Mark_Williams.player_FGA = 129
Mark_Williams.player_FT = 41
Mark_Williams.player_FTA = 58
Mark_Williams.player_TRB = 163
Mark_Williams.player_AST = 20
Mark_Williams.player_STL = 14
Mark_Williams.player_BLK = 15
Mark_Williams.player_TOV = 15
Mark_Williams.player_PF = 40
Mark_Williams.player_PTS = 215

Patrick_Williams = Player('Patrick_Williams')
Patrick_Williams.hasClubTeam.append(Chicago_Bulls)
Patrick_Williams.hasPosition.append(PF)
Patrick_Williams.player_Age = 22
Patrick_Williams.player_G = 19
Patrick_Williams.player_MP = 452
Patrick_Williams.player_MP = 452
Patrick_Williams.player_FG = 50
Patrick_Williams.player_FGA = 127
Patrick_Williams.player_FT = 23
Patrick_Williams.player_FTA = 28
Patrick_Williams.player_TRB = 75
Patrick_Williams.player_AST = 23
Patrick_Williams.player_STL = 17
Patrick_Williams.player_BLK = 16
Patrick_Williams.player_TOV = 22
Patrick_Williams.player_PF = 28
Patrick_Williams.player_PTS = 143

Robert_Williams = Player('Robert_Williams')
Robert_Williams.hasClubTeam.append(Portland_Trail_Blazers)
Robert_Williams.hasPosition.append(CE)
Robert_Williams.player_Age = 26
Robert_Williams.player_G = 6
Robert_Williams.player_MP = 119
Robert_Williams.player_MP = 119
Robert_Williams.player_FG = 17
Robert_Williams.player_FGA = 26
Robert_Williams.player_FT = 7
Robert_Williams.player_FTA = 9
Robert_Williams.player_TRB = 38
Robert_Williams.player_AST = 5
Robert_Williams.player_STL = 7
Robert_Williams.player_BLK = 7
Robert_Williams.player_TOV = 7
Robert_Williams.player_PF = 17
Robert_Williams.player_PTS = 41

Vince_Williams_Jr = Player('Vince_Williams_Jr.')
Vince_Williams_Jr.hasClubTeam.append(Memphis_Grizzlies)
Vince_Williams_Jr.hasPosition.append(SG)
Vince_Williams_Jr.player_Age = 23
Vince_Williams_Jr.player_G = 8
Vince_Williams_Jr.player_MP = 76
Vince_Williams_Jr.player_MP = 76
Vince_Williams_Jr.player_FG = 5
Vince_Williams_Jr.player_FGA = 17
Vince_Williams_Jr.player_FT = 7
Vince_Williams_Jr.player_FTA = 8
Vince_Williams_Jr.player_TRB = 14
Vince_Williams_Jr.player_AST = 6
Vince_Williams_Jr.player_STL = 2
Vince_Williams_Jr.player_BLK = 5
Vince_Williams_Jr.player_TOV = 2
Vince_Williams_Jr.player_PF = 11
Vince_Williams_Jr.player_PTS = 21

Ziaire_Williams = Player('Ziaire_Williams')
Ziaire_Williams.hasClubTeam.append(Memphis_Grizzlies)
Ziaire_Williams.hasPosition.append(SF)
Ziaire_Williams.player_Age = 22
Ziaire_Williams.player_G = 15
Ziaire_Williams.player_MP = 345
Ziaire_Williams.player_MP = 345
Ziaire_Williams.player_FG = 45
Ziaire_Williams.player_FGA = 123
Ziaire_Williams.player_FT = 21
Ziaire_Williams.player_FTA = 24
Ziaire_Williams.player_TRB = 69
Ziaire_Williams.player_AST = 22
Ziaire_Williams.player_STL = 6
Ziaire_Williams.player_BLK = 5
Ziaire_Williams.player_TOV = 19
Ziaire_Williams.player_PF = 33
Ziaire_Williams.player_PTS = 130

Zion_Williamson = Player('Zion_Williamson')
Zion_Williamson.hasClubTeam.append(New_Orleans_Pelicans)
Zion_Williamson.hasPosition.append(PF)
Zion_Williamson.player_Age = 23
Zion_Williamson.player_G = 14
Zion_Williamson.player_MP = 445
Zion_Williamson.player_MP = 445
Zion_Williamson.player_FG = 131
Zion_Williamson.player_FGA = 239
Zion_Williamson.player_FT = 63
Zion_Williamson.player_FTA = 102
Zion_Williamson.player_TRB = 81
Zion_Williamson.player_AST = 67
Zion_Williamson.player_STL = 14
Zion_Williamson.player_BLK = 4
Zion_Williamson.player_TOV = 37
Zion_Williamson.player_PF = 37
Zion_Williamson.player_PTS = 327

Jalen_Wilson = Player('Jalen_Wilson')
Jalen_Wilson.hasClubTeam.append(Brooklyn_Nets)
Jalen_Wilson.hasPosition.append(PF)
Jalen_Wilson.player_Age = 23
Jalen_Wilson.player_G = 2
Jalen_Wilson.player_MP = 7
Jalen_Wilson.player_MP = 7
Jalen_Wilson.player_FG = 0
Jalen_Wilson.player_FGA = 1
Jalen_Wilson.player_FT = 0
Jalen_Wilson.player_FTA = 0
Jalen_Wilson.player_TRB = 1
Jalen_Wilson.player_AST = 0
Jalen_Wilson.player_STL = 0
Jalen_Wilson.player_BLK = 1
Jalen_Wilson.player_TOV = 0
Jalen_Wilson.player_PF = 0
Jalen_Wilson.player_PTS = 0

Dylan_Windler = Player('Dylan_Windler')
Dylan_Windler.hasClubTeam.append(New_York_Knicks)
Dylan_Windler.hasPosition.append(SF)
Dylan_Windler.player_Age = 27
Dylan_Windler.player_G = 3
Dylan_Windler.player_MP = 7
Dylan_Windler.player_MP = 7
Dylan_Windler.player_FG = 1
Dylan_Windler.player_FGA = 2
Dylan_Windler.player_FT = 0
Dylan_Windler.player_FTA = 0
Dylan_Windler.player_TRB = 1
Dylan_Windler.player_AST = 1
Dylan_Windler.player_STL = 0
Dylan_Windler.player_BLK = 0
Dylan_Windler.player_TOV = 0
Dylan_Windler.player_PF = 1
Dylan_Windler.player_PTS = 3

James_Wiseman = Player('James_Wiseman')
James_Wiseman.hasClubTeam.append(Detroit_Pistons)
James_Wiseman.hasPosition.append(CE)
James_Wiseman.player_Age = 22
James_Wiseman.player_G = 9
James_Wiseman.player_MP = 99
James_Wiseman.player_MP = 99
James_Wiseman.player_FG = 22
James_Wiseman.player_FGA = 35
James_Wiseman.player_FT = 6
James_Wiseman.player_FTA = 11
James_Wiseman.player_TRB = 27
James_Wiseman.player_AST = 3
James_Wiseman.player_STL = 1
James_Wiseman.player_BLK = 3
James_Wiseman.player_TOV = 7
James_Wiseman.player_PF = 16
James_Wiseman.player_PTS = 50

Christian_Wood = Player('Christian_Wood')
Christian_Wood.hasClubTeam.append(Los_Angeles_Lakers)
Christian_Wood.hasPosition.append(PF)
Christian_Wood.player_Age = 28
Christian_Wood.player_G = 18
Christian_Wood.player_MP = 368
Christian_Wood.player_MP = 368
Christian_Wood.player_FG = 46
Christian_Wood.player_FGA = 99
Christian_Wood.player_FT = 21
Christian_Wood.player_FTA = 32
Christian_Wood.player_TRB = 108
Christian_Wood.player_AST = 15
Christian_Wood.player_STL = 3
Christian_Wood.player_BLK = 10
Christian_Wood.player_TOV = 24
Christian_Wood.player_PF = 35
Christian_Wood.player_PTS = 127

Delon_Wright = Player('Delon_Wright')
Delon_Wright.hasClubTeam.append(Washington_Wizards)
Delon_Wright.hasPosition.append(PG)
Delon_Wright.player_Age = 31
Delon_Wright.player_G = 8
Delon_Wright.player_MP = 141
Delon_Wright.player_MP = 141
Delon_Wright.player_FG = 11
Delon_Wright.player_FGA = 30
Delon_Wright.player_FT = 14
Delon_Wright.player_FTA = 16
Delon_Wright.player_TRB = 20
Delon_Wright.player_AST = 35
Delon_Wright.player_STL = 13
Delon_Wright.player_BLK = 1
Delon_Wright.player_TOV = 4
Delon_Wright.player_PF = 6
Delon_Wright.player_PTS = 40

Thaddeus_Young = Player('Thaddeus_Young')
Thaddeus_Young.hasClubTeam.append(Toronto_Raptors)
Thaddeus_Young.hasPosition.append(PF)
Thaddeus_Young.player_Age = 35
Thaddeus_Young.player_G = 3
Thaddeus_Young.player_MP = 10
Thaddeus_Young.player_MP = 10
Thaddeus_Young.player_FG = 2
Thaddeus_Young.player_FGA = 4
Thaddeus_Young.player_FT = 0
Thaddeus_Young.player_FTA = 2
Thaddeus_Young.player_TRB = 3
Thaddeus_Young.player_AST = 3
Thaddeus_Young.player_STL = 0
Thaddeus_Young.player_BLK = 0
Thaddeus_Young.player_TOV = 1
Thaddeus_Young.player_PF = 0
Thaddeus_Young.player_PTS = 4

Trae_Young = Player('Trae_Young')
Trae_Young.hasClubTeam.append(Atlanta_Hawks)
Trae_Young.hasPosition.append(PG)
Trae_Young.player_Age = 25
Trae_Young.player_G = 16
Trae_Young.player_MP = 572
Trae_Young.player_MP = 572
Trae_Young.player_FG = 118
Trae_Young.player_FGA = 300
Trae_Young.player_FT = 126
Trae_Young.player_FTA = 144
Trae_Young.player_TRB = 46
Trae_Young.player_AST = 166
Trae_Young.player_STL = 25
Trae_Young.player_BLK = 0
Trae_Young.player_TOV = 62
Trae_Young.player_PF = 26
Trae_Young.player_PTS = 410

Omer_Yurtseven = Player('Omer_Yurtseven')
Omer_Yurtseven.hasClubTeam.append(Utah_Jazz)
Omer_Yurtseven.hasPosition.append(CE)
Omer_Yurtseven.player_Age = 25
Omer_Yurtseven.player_G = 11
Omer_Yurtseven.player_MP = 113
Omer_Yurtseven.player_MP = 113
Omer_Yurtseven.player_FG = 21
Omer_Yurtseven.player_FGA = 34
Omer_Yurtseven.player_FT = 5
Omer_Yurtseven.player_FTA = 7
Omer_Yurtseven.player_TRB = 40
Omer_Yurtseven.player_AST = 7
Omer_Yurtseven.player_STL = 1
Omer_Yurtseven.player_BLK = 5
Omer_Yurtseven.player_TOV = 5
Omer_Yurtseven.player_PF = 12
Omer_Yurtseven.player_PTS = 50

Cody_Zeller = Player('Cody_Zeller')
Cody_Zeller.hasClubTeam.append(New_Orleans_Pelicans)
Cody_Zeller.hasPosition.append(CE)
Cody_Zeller.player_Age = 31
Cody_Zeller.player_G = 14
Cody_Zeller.player_MP = 129
Cody_Zeller.player_MP = 129
Cody_Zeller.player_FG = 9
Cody_Zeller.player_FGA = 25
Cody_Zeller.player_FT = 6
Cody_Zeller.player_FTA = 16
Cody_Zeller.player_TRB = 47
Cody_Zeller.player_AST = 17
Cody_Zeller.player_STL = 2
Cody_Zeller.player_BLK = 2
Cody_Zeller.player_TOV = 4
Cody_Zeller.player_PF = 14
Cody_Zeller.player_PTS = 24

Ivica_Zubac = Player('Ivica_Zubac')
Ivica_Zubac.hasClubTeam.append(Los_Angeles_Clippers)
Ivica_Zubac.hasPosition.append(CE)
Ivica_Zubac.player_Age = 26
Ivica_Zubac.player_G = 16
Ivica_Zubac.player_MP = 410
Ivica_Zubac.player_MP = 410
Ivica_Zubac.player_FG = 74
Ivica_Zubac.player_FGA = 121
Ivica_Zubac.player_FT = 32
Ivica_Zubac.player_FTA = 53
Ivica_Zubac.player_TRB = 143
Ivica_Zubac.player_AST = 12
Ivica_Zubac.player_STL = 2
Ivica_Zubac.player_BLK = 21
Ivica_Zubac.player_TOV = 22
Ivica_Zubac.player_PF = 44
Ivica_Zubac.player_PTS = 180

# %% [markdown]
# # test

# %%
print(Toronto_Raptors)
print(Toronto_Raptors.hasCoach)
print(Toronto_Raptors.hasGeneral_manager)
print(Toronto_Raptors.hasManager)
print(Toronto_Raptors.hasYears)
print(Toronto_Raptors.hasGame_num)
print(Toronto_Raptors.hasWin_num)
print(Toronto_Raptors.hasLose_num)
# Out:
# onto.Toronto Raptors
# [onto.Rayhan_Malik, onto.Mike_Batiste, onto.Ivo_Simovic, onto.Drew_Jones, onto.Vin_Bhavnani, onto.ma_Mahlalela, onto.Jim_Sann, onto.Pat_Delany]
# [onto.Bobby_Webster]
# [onto.Darko_Rajakovic]
# 29
# 2246
# 1079
# 1167

# %%
print(Achiuwa.hasClubTeam)
print(Achiuwa.hasPosition)
print(Achiuwa.player_Age)
print(Achiuwa.player_G)
print(Achiuwa.player_MP)
print(Achiuwa.player_FG)
print(Achiuwa.player_FGA)
print(Achiuwa.player_FT)
print(Achiuwa.player_FTA)
print(Achiuwa.player_TRB)
print(Achiuwa.player_AST)
print(Achiuwa.player_STL)
print(Achiuwa.player_TOV)
print(Achiuwa.player_BLK)
print(Achiuwa.player_PF)
print(Achiuwa.player_PTS)
print(Toronto_Raptors.hasPlayer)
# Out:
# [onto.Toronto Raptors]
# [onto.CE]
# 24
# 12
# 218
# 32
# 74
# 11
# 21
# 70
# 26
# 6
# 16
# 6
# 21
# 80
# [onto.Achiuwa, onto.OG_Anunoby, onto.Scottie_Barnes, onto.Nicolas_Batum, onto.Chris_Boucher, onto.Robert_Covington, onto.Gradey_Dick, onto.Malachi_Flynn, onto.Ron_Harper_Jr., onto.KJ_Martin, onto.Jalen_McDaniels, onto.Markquis_Nowell, onto.Filip_Petrusev, onto.Jakob_Poeltl, onto.Otto_Porter_Jr., onto.Dennis_Schroder, onto.Pascal_Siakam, onto.Garrett_Temple, onto.Daniel_Theis, onto.Gary_Trent_Jr., onto.P.J._Tucker, onto.Thaddeus_Young]

# %% [markdown]
# # 파일 저장

# %%
onto.save(file='./nba.owl', format='rdfxml')

# %% [markdown]
# # sparql

# %%
from flask import Flask, render_template
from rdflib import Graph, Namespace, RDF
from tqdm import tqdm
from urllib.parse import quote
import pandas as pd

# %%
# Load the RDF/XML file into an RDFLib graph
g = Graph()
g.parse("./nba.owl", format="xml")
# Out:
# http://NBA_ontology/onto.owl#Atlanta Hawks does not look like a valid URI, trying to serialize this will break.
# http://NBA_ontology/onto.owl#Boston Celtics does not look like a valid URI, trying to serialize this will break.
# http://NBA_ontology/onto.owl#Brooklyn Nets does not look like a valid URI, trying to serialize this will break.
# http://NBA_ontology/onto.owl#Charlotte Hornets does not look like a valid URI, trying to serialize this will break.
# http://NBA_ontology/onto.owl#Chicago Bulls does not look like a valid URI, trying to serialize this will break.
# http://NBA_ontology/onto.owl#Cleveland Cavaliers does not look like a valid URI, trying to serialize this will break.
# http://NBA_ontology/onto.owl#Dallas Mavericks does not look like a valid URI, trying to serialize this will break.
# http://NBA_ontology/onto.owl#Denver Nuggets does not look like a valid URI, trying to serialize this will break.
# ...

# %%
# Define the 'nba' prefix
nba = Namespace("http://NBA_ontology/onto.owl#")

# %% [markdown]
# ## query example

# %% [markdown]
# - 선수 정보 출력(선수 이름, 팀명, 포지션, 나이, 출전 경기 수, points)

# %%
query = """
    SELECT ?player ?team ?position ?age ?gamesPlayed ?points
    WHERE {
        # ?player rdf:type nba:Player ;
                nba:hasClubTeam ?team ;
                nba:hasPosition ?position ;
                nba:player_Age ?age ;
                nba:player_G ?gamesPlayed ;
                nba:player_PTS ?points .
    }
"""

# %% [markdown]
# - class 개수

# %%
query = """
           SELECT (COUNT(?x) AS ?nb)
           { ?x a owl:Class . FILTER(ISIRI(?x)) }
    """

# %% [markdown]
# - MVP 수상 확률이 높은 선수 상위 5명 출력
#     - PTS+TRB+AST+STL+BLK-TOV-FGA+FG-FTA+FT
#     - 득점+리바운드+어시스트+스틸+블록-실책-야투시도+야투성공-자유투시도+자유투성공
#     - 이 점수가 높을수록 시즌 MVP 수상 확률이 높아짐

# %%
query = '''
    SELECT ?player ?team ?position ?age ?gamesPlayed ?points
    WHERE {
      # ?player rdf:type nba:Player ;
              nba:hasClubTeam ?team ;
              nba:hasPosition ?position ;
              nba:player_Age ?age ;
              nba:player_G ?gamesPlayed ;
              nba:player_PTS ?points ;
              nba:player_TRB ?rebounds ;
              nba:player_AST ?assists ;
              nba:player_STL ?steals ;
              nba:player_BLK ?blocks ;
              nba:player_TOV ?turnovers ;
              nba:player_FGA ?fieldGoalAttempts ;
              nba:player_FG ?fieldGoals ;
              nba:player_FTA ?freeThrowAttempts ;
              nba:player_FT ?freeThrows .

      BIND(?points + ?rebounds + ?assists + ?steals + ?blocks - ?turnovers - ?fieldGoalAttempts + ?fieldGoals - ?freeThrowAttempts + ?freeThrows AS ?mvpProbability)

      FILTER(?mvpProbability > 0) 
    }
    ORDER BY DESC(?mvpProbability)
    LIMIT 5
'''

# %% [markdown]
# - 유망주
#     - 24세 이하
#     - PTS + FT + FG 높은 상위 10명
#     - 동부인지 서부인지까지 출력

# %%
query = '''
    SELECT ?player ?team ?age ?conference ?totalScore
    WHERE {
      # ?player rdf:type nba:Player ;
              nba:hasClubTeam ?team ;
              nba:player_Age ?age ;
              nba:player_PTS ?points ;
              nba:player_FT ?freeThrows ;
              nba:player_FG ?fieldGoals .

      OPTIONAL {
      # ?team rdf:type nba:Eastern_Conference .
      BIND("East" AS ?conference)
      }

      OPTIONAL {
        # ?team rdf:type nba:Western_Conference .
        BIND("West" AS ?conference)
      }
      
      BIND(?points + ?freeThrows + ?fieldGoals AS ?totalScore)

      FILTER(?age <= 24)
    }
    ORDER BY DESC(?totalScore)
    LIMIT 10
'''

# %% [markdown]
# - 전체 팀 수

# %%
query = '''
    SELECT (COUNT(?team) AS ?totalTeam)
    WHERE {
      {
        # ?team rdf:type nba:Western_Conference .
      } UNION {
        # ?team rdf:type nba:Eastern_Conference .
      }
    }
'''

# %% [markdown]
# - 승률 높은 팀 보기
#     - hasWin_num/hasGame_num 상위 3개

# %% [markdown]
# - 서부

# %%
query = '''
    SELECT ?team ?winNum ?gameNum ?roundedWinPercentage
    WHERE {
      # ?team rdf:type nba:Western_Conference ;
            nba:hasWin_num ?winNum ;
            nba:hasGame_num ?gameNum .

      BIND(?winNum / ?gameNum AS ?winPercentage)
      BIND(FLOOR(?winPercentage * 100) / 100 AS ?roundedWinPercentage)
    }
    ORDER BY DESC(?winPercentage)
    LIMIT 3
'''

# %% [markdown]
# - 동부

# %%
query = '''
    SELECT ?team ?winNum ?gameNum ?roundedWinPercentage
    WHERE {
      # ?team rdf:type nba:Eastern_Conference ;
            nba:hasWin_num ?winNum ;
            nba:hasGame_num ?gameNum .

      BIND(?winNum / ?gameNum AS ?winPercentage)
      BIND(FLOOR(?winPercentage * 100) / 100 AS ?roundedWinPercentage)
    }
    ORDER BY DESC(?winPercentage)
    LIMIT 3
'''

# %% [markdown]
# - 포지션이 Center면서 BLK는 7이상 TRB는 46이상인 선수

# %%
query = '''
SELECT ?player ?team ?position ?blk ?trb
WHERE {
  # ?player rdf:type nba:Player ;
          nba:hasClubTeam ?team ;
          nba:hasPosition ?position ;
          nba:player_BLK ?blk ;
          nba:player_TRB ?trb .

  FILTER (?position = nba:CE && ?blk >= 7 && ?trb >= 46)
}
'''

# %% [markdown]
# - G+MP 의 값은 작은데 EFF 값이 높은 선수 상위 10명

# %%
query = '''
SELECT ?player ?team ?position ?age ?gamesPlayed ?points ?efficiency
WHERE {
    # ?player rdf:type nba:Player ;
            nba:hasClubTeam ?team ;
            nba:hasPosition ?position ;
            nba:player_Age ?age ;
            nba:player_G ?gamesPlayed ;
            nba:player_PTS ?points ;
            nba:player_TRB ?rebounds ;
            nba:player_AST ?assists ;
            nba:player_STL ?steals ;
            nba:player_BLK ?blocks ;
            nba:player_TOV ?turnovers ;
            nba:player_FGA ?fieldGoalsAttempted ;
            nba:player_FG ?fieldGoalsMade ;
            nba:player_FTA ?freeThrowsAttempted ;
            nba:player_FT ?freeThrowsMade .
            
    BIND(?points + ?rebounds + ?assists + ?steals + ?blocks - ?turnovers - ?fieldGoalsAttempted + ?fieldGoalsMade - ?freeThrowsAttempted + ?freeThrowsMade AS ?efficiency)
    FILTER(?gamesPlayed > 0)  # Exclude players with zero games played
}
ORDER BY DESC(?efficiency)  # Sorting by efficiency in descending order
LIMIT 10
'''

# %% [markdown]
# - 속한 팀이 65년 이상되었고 포지션이 SG인 선수
#     - nba_team으로 보면 아무것도 안나오고, 동부, 서부로 들어가서 파악해야함

# %%
query = '''
SELECT ?player ?team ?position ?conference ?teamYears
WHERE {
  # ?player rdf:type nba:Player ;
          nba:hasClubTeam ?team ;
          nba:hasPosition ?position .
          
  OPTIONAL {
      # ?team rdf:type nba:Eastern_Conference ;
              nba:hasYears ?teamYears .
      BIND("East" AS ?conference)
      }

  OPTIONAL {
    # ?team rdf:type nba:Western_Conference ;
            nba:hasYears ?teamYears .
    BIND("West" AS ?conference)
  }

  FILTER (?position = nba:SG && ?teamYears >= 65)
}
'''

# %%
# Execute SPARQL query for players
results = g.query(query, initNs={"rdf": RDF, "nba": nba})

# %%
 # Convert SPARQL query results to a pandas DataFrame
columns = [str(var) for var in results.vars]
data = [[str(result[var].toPython()).split('#')[-1] for var in results.vars] for result in results]
df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#                  player                   team position conference teamYears
# 0            RJ_Barrett        New York Knicks       SG       East        78
# 1     Bogdan_Bogdanović          Atlanta Hawks       SG       East        75
# 2           Kobe_Bufkin          Atlanta Hawks       SG       East        75
# 3            Alec_Burks        Detroit Pistons       SG       East        76
# 4       Malcolm_Cazalon        Detroit Pistons       SG       East        76
# 5          Max_Christie     Los Angeles Lakers       SG       West        76
# 6      Donte_DiVincenzo        New York Knicks       SG       East        78
# 7            Keon_Ellis       Sacramento Kings       SG       West        76
# 8         Trent_Forrest          Atlanta Hawks       SG       East        75
# 9         Evan_Fournier        New York Knicks       SG       East        78
# 10       Quentin_Grimes        New York Knicks       SG       East        78
# ...
